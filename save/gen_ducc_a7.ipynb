# %%
import wicked as w
from IPython.display import display, Math, Latex
from numpy import einsum

def latex(expr):
    """Function to render any object that has a member latex() function"""
    display(Math(expr.latex()))

# orbital spaces occ, virt
w.reset_space()
w.add_space("o", "fermion", "occupied", ['i','j','k','l','m'])
w.add_space("v", "fermion", "unoccupied", ['a','b','c','d','e','f'])
w.add_space("V", "fermion", "unoccupied", ['A','B','C','D','E','G'])

wt = w.WickTheorem()

# %%
# external amplitudes
s1_ext = w.op('t1',['V+ o']) - w.op('t1',['o+ V'])
# print("s1_ext")
# print(s1_ext)

s2_ext =  w.op('t2',['v+ V+ o o']) - w.op('t2',['o+ o+ V v'])
s2_ext += w.op('t2',['V+ V+ o o']) - w.op('t2',['o+ o+ V V'])
# print("s2_ext")
# print(s2_ext)

# %%
# Fock operator
F = w.utils.gen_op('f',1,'ovV','ovV')
# print("Fock")
# print(F)

# Interaction operator
W = w.utils.gen_op('v',2,'ovV','ovV')
# print("Interaction")
# print(V)

# %%
# [F,s1_ext]
print("[F,s1_ext]")
Fs1 = w.commutator(F,s1_ext)
expr = wt.contract(Fs1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
        
print("break")
expr = wt.contract(Fs1,minrank=0,maxrank=0)
mbeq = expr.to_manybody_equations('fs1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
        
print("break")
expr = wt.contract(Fs1,minrank=2,maxrank=2)
mbeq = expr.to_manybody_equations('fs1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [F,s1_ext]
# fs1VV += -1.000000000 * np.einsum("Ai,iB->AB",f["Vo"],t1["oV"],optimize="optimal")
# fs1VV += -1.000000000 * np.einsum("iA,Bi->BA",f["oV"],t1["Vo"],optimize="optimal")
# fs1Vo += -1.000000000 * np.einsum("ji,Aj->Ai",f["oo"],t1["Vo"],optimize="optimal")
# fs1Vo += 1.000000000 * np.einsum("AB,Bi->Ai",f["VV"],t1["Vo"],optimize="optimal")
# fs1Vv += -1.000000000 * np.einsum("ia,Ai->Aa",f["ov"],t1["Vo"],optimize="optimal")
# fs1oV += -1.000000000 * np.einsum("ij,jA->iA",f["oo"],t1["oV"],optimize="optimal")
# fs1oV += 1.000000000 * np.einsum("BA,iB->iA",f["VV"],t1["oV"],optimize="optimal")
# fs1oo += 1.000000000 * np.einsum("Ai,jA->ji",f["Vo"],t1["oV"],optimize="optimal")
# fs1oo += 1.000000000 * np.einsum("iA,Aj->ij",f["oV"],t1["Vo"],optimize="optimal")
# fs1ov += 1.000000000 * np.einsum("Aa,iA->ia",f["Vv"],t1["oV"],optimize="optimal")
# fs1vV += -1.000000000 * np.einsum("ai,iA->aA",f["vo"],t1["oV"],optimize="optimal")
# fs1vo += 1.000000000 * np.einsum("aA,Ai->ai",f["vV"],t1["Vo"],optimize="optimal")
# fs1 += 1.000000000 * np.einsum("Ai,iA->",f["Vo"],t1["oV"],optimize="optimal")
# fs1 += 1.000000000 * np.einsum("iA,Ai->",f["oV"],t1["Vo"],optimize="optimal")
# break
# fs1 += 1.000000000 * np.einsum("Ai,iA->",f["Vo"],t1["oV"],optimize="optimal")
# fs1 += 1.000000000 * np.einsum("iA,Ai->",f["oV"],t1["Vo"],optimize="optimal")
# break
# fs1VV += -1.000000000 * np.einsum("Ai,iB->AB",f["Vo"],t1["oV"],optimize="optimal")
# fs1VV += -1.000000000 * np.einsum("iA,Bi->BA",f["oV"],t1["Vo"],optimize="optimal")
# fs1Vo += -1.000000000 * np.einsum("ji,Aj->Ai",f["oo"],t1["Vo"],optimize="optimal")
# fs1Vo += 1.000000000 * np.einsum("AB,Bi->Ai",f["VV"],t1["Vo"],optimize="optimal")
# fs1Vv += -1.000000000 * np.einsum("ia,Ai->Aa",f["ov"],t1["Vo"],optimize="optimal")
# fs1oV += -1.000000000 * np.einsum("ij,jA->iA",f["oo"],t1["oV"],optimize="optimal")
# fs1oV += 1.000000000 * np.einsum("BA,iB->iA",f["VV"],t1["oV"],optimize="optimal")
# fs1oo += 1.000000000 * np.einsum("Ai,jA->ji",f["Vo"],t1["oV"],optimize="optimal")
# fs1oo += 1.000000000 * np.einsum("iA,Aj->ij",f["oV"],t1["Vo"],optimize="optimal")
# fs1ov += 1.000000000 * np.einsum("Aa,iA->ia",f["Vv"],t1["oV"],optimize="optimal")
# fs1vV += -1.000000000 * np.einsum("ai,iA->aA",f["vo"],t1["oV"],optimize="optimal")
# fs1vo += 1.000000000 * np.einsum("aA,Ai->ai",f["vV"],t1["Vo"],optimize="optimal")

# %%
# [F,s2_ext]
print("[F,s2_ext]")
Fs2 = w.commutator(F,s2_ext)
expr = wt.contract(Fs2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))

print("Break")
expr = wt.contract(Fs2,minrank=0,maxrank=0)
mbeq = expr.to_manybody_equations('fs2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [F,s2_ext]
# fs2VVoV += -0.500000000 * np.einsum("jA,BCij->BCiA",f["oV"],t2["VVoo"],optimize="optimal")
# fs2VVoo += 0.500000000 * np.einsum("ki,ABjk->ABij",f["oo"],t2["VVoo"],optimize="optimal")
# fs2VVoo += 0.500000000 * np.einsum("Aa,aBij->ABij",f["Vv"],t2["vVoo"],optimize="optimal")
# fs2VVoo += -0.500000000 * np.einsum("AC,BCij->ABij",f["VV"],t2["VVoo"],optimize="optimal")
# fs2VVov += -0.500000000 * np.einsum("ja,ABij->ABia",f["ov"],t2["VVoo"],optimize="optimal")
# fs2Vo += -1.000000000 * np.einsum("ja,aAij->Ai",f["ov"],t2["vVoo"],optimize="optimal")
# fs2Vo += 1.000000000 * np.einsum("jB,ABij->Ai",f["oV"],t2["VVoo"],optimize="optimal")
# fs2oVVV += -0.500000000 * np.einsum("Aj,ijBC->iABC",f["Vo"],t2["ooVV"],optimize="optimal")
# fs2oVvV += -1.000000000 * np.einsum("Aj,ijaB->iAaB",f["Vo"],t2["oovV"],optimize="optimal")
# fs2oVoo += 0.500000000 * np.einsum("ia,aAjk->iAjk",f["ov"],t2["vVoo"],optimize="optimal")
# fs2oVoo += -0.500000000 * np.einsum("iB,ABjk->iAjk",f["oV"],t2["VVoo"],optimize="optimal")
# fs2ooVV += 0.500000000 * np.einsum("ik,jkAB->ijAB",f["oo"],t2["ooVV"],optimize="optimal")
# fs2ooVV += 0.500000000 * np.einsum("aA,ijaB->ijAB",f["vV"],t2["oovV"],optimize="optimal")
# fs2ooVV += -0.500000000 * np.einsum("CA,ijBC->ijAB",f["VV"],t2["ooVV"],optimize="optimal")
# fs2oooV += 0.500000000 * np.einsum("ai,jkaA->jkiA",f["vo"],t2["oovV"],optimize="optimal")
# fs2oooV += -0.500000000 * np.einsum("Bi,jkAB->jkiA",f["Vo"],t2["ooVV"],optimize="optimal")
# fs2oovV += 1.000000000 * np.einsum("ik,jkaA->ijaA",f["oo"],t2["oovV"],optimize="optimal")
# fs2oovV += 0.500000000 * np.einsum("ba,ijbA->ijaA",f["vv"],t2["oovV"],optimize="optimal")
# fs2oovV += -0.500000000 * np.einsum("Ba,ijAB->ijaA",f["Vv"],t2["ooVV"],optimize="optimal")
# fs2oovV += 0.500000000 * np.einsum("BA,ijaB->ijaA",f["VV"],t2["oovV"],optimize="optimal")
# fs2ooov += -0.500000000 * np.einsum("Ai,jkaA->jkia",f["Vo"],t2["oovV"],optimize="optimal")
# fs2oovv += -0.500000000 * np.einsum("Aa,ijbA->ijab",f["Vv"],t2["oovV"],optimize="optimal")
# fs2ovVV += -0.500000000 * np.einsum("aj,ijAB->iaAB",f["vo"],t2["ooVV"],optimize="optimal")
# fs2ovvV += -1.000000000 * np.einsum("aj,ijbA->iabA",f["vo"],t2["oovV"],optimize="optimal")
# fs2ovoo += -0.500000000 * np.einsum("iA,aAjk->iajk",f["oV"],t2["vVoo"],optimize="optimal")
# fs2oV += -1.000000000 * np.einsum("aj,ijaA->iA",f["vo"],t2["oovV"],optimize="optimal")
# fs2oV += 1.000000000 * np.einsum("Bj,ijAB->iA",f["Vo"],t2["ooVV"],optimize="optimal")
# fs2ov += 1.000000000 * np.einsum("Aj,ijaA->ia",f["Vo"],t2["oovV"],optimize="optimal")
# fs2vVoV += -1.000000000 * np.einsum("jA,aBij->aBiA",f["oV"],t2["vVoo"],optimize="optimal")
# fs2vVoo += 1.000000000 * np.einsum("ki,aAjk->aAij",f["oo"],t2["vVoo"],optimize="optimal")
# fs2vVoo += 0.500000000 * np.einsum("ab,bAij->aAij",f["vv"],t2["vVoo"],optimize="optimal")
# fs2vVoo += -0.500000000 * np.einsum("aB,ABij->aAij",f["vV"],t2["VVoo"],optimize="optimal")
# fs2vVoo += 0.500000000 * np.einsum("AB,aBij->aAij",f["VV"],t2["vVoo"],optimize="optimal")
# fs2vVov += -1.000000000 * np.einsum("ja,bAij->bAia",f["ov"],t2["vVoo"],optimize="optimal")
# fs2vvoo += -0.500000000 * np.einsum("aA,bAij->abij",f["vV"],t2["vVoo"],optimize="optimal")
# fs2vo += 1.000000000 * np.einsum("jA,aAij->ai",f["oV"],t2["vVoo"],optimize="optimal")
# Break

# %%
# [W,s1_ext]
print("[W,s1_ext]")
Ws1 = w.commutator(W,s1_ext)
expr = wt.contract(Ws1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [W,s1_ext]
# ws1VVVV += -0.500000000 * np.einsum("Ai,iDBC->ADBC",t1["Vo"],v["oVVV"],optimize="optimal")
# ws1VVVV += -0.500000000 * np.einsum("iA,CDiB->CDAB",t1["oV"],v["VVoV"],optimize="optimal")
# ws1VVoV += -0.500000000 * np.einsum("Di,BCAD->BCiA",t1["Vo"],v["VVVV"],optimize="optimal")
# ws1VVoV += -1.000000000 * np.einsum("Aj,jCiB->ACiB",t1["Vo"],v["oVoV"],optimize="optimal")
# ws1VVoV += -0.500000000 * np.einsum("jA,BCij->BCiA",t1["oV"],v["VVoo"],optimize="optimal")
# ws1VVvV += -1.000000000 * np.einsum("Ai,iCaB->ACaB",t1["Vo"],v["oVvV"],optimize="optimal")
# ws1VVvV += 0.500000000 * np.einsum("iA,BCia->BCaA",t1["oV"],v["VVov"],optimize="optimal")
# ws1VVoo += -0.500000000 * np.einsum("Ci,ABjC->ABij",t1["Vo"],v["VVoV"],optimize="optimal")
# ws1VVoo += -0.500000000 * np.einsum("Ak,kBij->ABij",t1["Vo"],v["oVoo"],optimize="optimal")
# ws1VVov += -0.500000000 * np.einsum("Ci,ABaC->ABia",t1["Vo"],v["VVvV"],optimize="optimal")
# ws1VVov += -1.000000000 * np.einsum("Aj,jBia->ABia",t1["Vo"],v["oVov"],optimize="optimal")
# ws1VVvv += -0.500000000 * np.einsum("Ai,iBab->ABab",t1["Vo"],v["oVvv"],optimize="optimal")
# ws1VV += -1.000000000 * np.einsum("Ci,iBAC->BA",t1["Vo"],v["oVVV"],optimize="optimal")
# ws1VV += -1.000000000 * np.einsum("iC,BCiA->BA",t1["oV"],v["VVoV"],optimize="optimal")
# ws1Vo += -1.000000000 * np.einsum("Bj,jAiB->Ai",t1["Vo"],v["oVoV"],optimize="optimal")
# ws1Vo += 1.000000000 * np.einsum("jB,ABij->Ai",t1["oV"],v["VVoo"],optimize="optimal")
# ws1Vv += -1.000000000 * np.einsum("Bi,iAaB->Aa",t1["Vo"],v["oVvV"],optimize="optimal")
# ws1Vv += -1.000000000 * np.einsum("iB,ABia->Aa",t1["oV"],v["VVov"],optimize="optimal")
# ws1oVVV += -0.500000000 * np.einsum("Aj,ijBC->iABC",t1["Vo"],v["ooVV"],optimize="optimal")
# ws1oVVV += -1.000000000 * np.einsum("jA,iCjB->iCAB",t1["oV"],v["oVoV"],optimize="optimal")
# ws1oVVV += -0.500000000 * np.einsum("iD,CDAB->iCAB",t1["oV"],v["VVVV"],optimize="optimal")
# ws1oVoV += -1.000000000 * np.einsum("Ci,jBAC->jBiA",t1["Vo"],v["oVVV"],optimize="optimal")
# ws1oVoV += -1.000000000 * np.einsum("Ak,jkiB->jAiB",t1["Vo"],v["oooV"],optimize="optimal")
# ws1oVoV += -1.000000000 * np.einsum("kA,jBik->jBiA",t1["oV"],v["oVoo"],optimize="optimal")
# ws1oVoV += -1.000000000 * np.einsum("iC,BCjA->iBjA",t1["oV"],v["VVoV"],optimize="optimal")
# ws1oVvV += -1.000000000 * np.einsum("Aj,ijaB->iAaB",t1["Vo"],v["oovV"],optimize="optimal")
# ws1oVvV += 1.000000000 * np.einsum("jA,iBja->iBaA",t1["oV"],v["oVov"],optimize="optimal")
# ws1oVvV += -1.000000000 * np.einsum("iC,BCaA->iBaA",t1["oV"],v["VVvV"],optimize="optimal")
# ws1oVoo += -1.000000000 * np.einsum("Bi,kAjB->kAij",t1["Vo"],v["oVoV"],optimize="optimal")
# ws1oVoo += -0.500000000 * np.einsum("Al,klij->kAij",t1["Vo"],v["oooo"],optimize="optimal")
# ws1oVoo += -0.500000000 * np.einsum("iB,ABjk->iAjk",t1["oV"],v["VVoo"],optimize="optimal")
# ws1oVov += -1.000000000 * np.einsum("Bi,jAaB->jAia",t1["Vo"],v["oVvV"],optimize="optimal")
# ws1oVov += -1.000000000 * np.einsum("Ak,jkia->jAia",t1["Vo"],v["ooov"],optimize="optimal")
# ws1oVov += -1.000000000 * np.einsum("iB,ABja->iAja",t1["oV"],v["VVov"],optimize="optimal")
# ws1oVvv += -0.500000000 * np.einsum("Aj,ijab->iAab",t1["Vo"],v["oovv"],optimize="optimal")
# ws1oVvv += -0.500000000 * np.einsum("iB,ABab->iAab",t1["oV"],v["VVvv"],optimize="optimal")
# ws1ooVV += -0.500000000 * np.einsum("kA,ijkB->ijAB",t1["oV"],v["oooV"],optimize="optimal")
# ws1ooVV += -0.500000000 * np.einsum("iC,jCAB->ijAB",t1["oV"],v["oVVV"],optimize="optimal")
# ws1oooV += -0.500000000 * np.einsum("Bi,jkAB->jkiA",t1["Vo"],v["ooVV"],optimize="optimal")
# ws1oooV += -0.500000000 * np.einsum("lA,jkil->jkiA",t1["oV"],v["oooo"],optimize="optimal")
# ws1oooV += -1.000000000 * np.einsum("iB,kBjA->ikjA",t1["oV"],v["oVoV"],optimize="optimal")
# ws1oovV += 0.500000000 * np.einsum("kA,ijka->ijaA",t1["oV"],v["ooov"],optimize="optimal")
# ws1oovV += -1.000000000 * np.einsum("iB,jBaA->ijaA",t1["oV"],v["oVvV"],optimize="optimal")
# ws1oooo += -0.500000000 * np.einsum("Ai,kljA->klij",t1["Vo"],v["oooV"],optimize="optimal")
# ws1oooo += -0.500000000 * np.einsum("iA,lAjk->iljk",t1["oV"],v["oVoo"],optimize="optimal")
# ws1ooov += -0.500000000 * np.einsum("Ai,jkaA->jkia",t1["Vo"],v["oovV"],optimize="optimal")
# ws1ooov += -1.000000000 * np.einsum("iA,kAja->ikja",t1["oV"],v["oVov"],optimize="optimal")
# ws1oovv += -0.500000000 * np.einsum("iA,jAab->ijab",t1["oV"],v["oVvv"],optimize="optimal")
# ws1ovVV += -1.000000000 * np.einsum("jA,iajB->iaAB",t1["oV"],v["ovoV"],optimize="optimal")
# ws1ovVV += -0.500000000 * np.einsum("iC,aCAB->iaAB",t1["oV"],v["vVVV"],optimize="optimal")
# ws1ovoV += -1.000000000 * np.einsum("Bi,jaAB->jaiA",t1["Vo"],v["ovVV"],optimize="optimal")
# ws1ovoV += -1.000000000 * np.einsum("kA,jaik->jaiA",t1["oV"],v["ovoo"],optimize="optimal")
# ws1ovoV += -1.000000000 * np.einsum("iB,aBjA->iajA",t1["oV"],v["vVoV"],optimize="optimal")
# ws1ovvV += 1.000000000 * np.einsum("jA,ibja->ibaA",t1["oV"],v["ovov"],optimize="optimal")
# ws1ovvV += -1.000000000 * np.einsum("iB,bBaA->ibaA",t1["oV"],v["vVvV"],optimize="optimal")
# ws1ovoo += -1.000000000 * np.einsum("Ai,kajA->kaij",t1["Vo"],v["ovoV"],optimize="optimal")
# ws1ovoo += -0.500000000 * np.einsum("iA,aAjk->iajk",t1["oV"],v["vVoo"],optimize="optimal")
# ws1ovov += -1.000000000 * np.einsum("Ai,jbaA->jbia",t1["Vo"],v["ovvV"],optimize="optimal")
# ws1ovov += -1.000000000 * np.einsum("iA,bAja->ibja",t1["oV"],v["vVov"],optimize="optimal")
# ws1ovvv += -0.500000000 * np.einsum("iA,cAab->icab",t1["oV"],v["vVvv"],optimize="optimal")
# ws1oV += 1.000000000 * np.einsum("Bj,ijAB->iA",t1["Vo"],v["ooVV"],optimize="optimal")
# ws1oV += -1.000000000 * np.einsum("jB,iBjA->iA",t1["oV"],v["oVoV"],optimize="optimal")
# ws1oo += 1.000000000 * np.einsum("Ak,jkiA->ji",t1["Vo"],v["oooV"],optimize="optimal")
# ws1oo += 1.000000000 * np.einsum("kA,jAik->ji",t1["oV"],v["oVoo"],optimize="optimal")
# ws1ov += 1.000000000 * np.einsum("Aj,ijaA->ia",t1["Vo"],v["oovV"],optimize="optimal")
# ws1ov += -1.000000000 * np.einsum("jA,iAja->ia",t1["oV"],v["oVov"],optimize="optimal")
# ws1vVVV += 0.500000000 * np.einsum("Ai,iaBC->aABC",t1["Vo"],v["ovVV"],optimize="optimal")
# ws1vVVV += -1.000000000 * np.einsum("iA,aCiB->aCAB",t1["oV"],v["vVoV"],optimize="optimal")
# ws1vVoV += -1.000000000 * np.einsum("Ci,aBAC->aBiA",t1["Vo"],v["vVVV"],optimize="optimal")
# ws1vVoV += 1.000000000 * np.einsum("Aj,jaiB->aAiB",t1["Vo"],v["ovoV"],optimize="optimal")
# ws1vVoV += -1.000000000 * np.einsum("jA,aBij->aBiA",t1["oV"],v["vVoo"],optimize="optimal")
# ws1vVvV += 1.000000000 * np.einsum("Ai,ibaB->bAaB",t1["Vo"],v["ovvV"],optimize="optimal")
# ws1vVvV += 1.000000000 * np.einsum("iA,bBia->bBaA",t1["oV"],v["vVov"],optimize="optimal")
# ws1vVoo += -1.000000000 * np.einsum("Bi,aAjB->aAij",t1["Vo"],v["vVoV"],optimize="optimal")
# ws1vVoo += 0.500000000 * np.einsum("Ak,kaij->aAij",t1["Vo"],v["ovoo"],optimize="optimal")
# ws1vVov += -1.000000000 * np.einsum("Bi,bAaB->bAia",t1["Vo"],v["vVvV"],optimize="optimal")
# ws1vVov += 1.000000000 * np.einsum("Aj,jbia->bAia",t1["Vo"],v["ovov"],optimize="optimal")
# ws1vVvv += 0.500000000 * np.einsum("Ai,icab->cAab",t1["Vo"],v["ovvv"],optimize="optimal")
# ws1vvVV += -0.500000000 * np.einsum("iA,abiB->abAB",t1["oV"],v["vvoV"],optimize="optimal")
# ws1vvoV += -0.500000000 * np.einsum("Bi,abAB->abiA",t1["Vo"],v["vvVV"],optimize="optimal")
# ws1vvoV += -0.500000000 * np.einsum("jA,abij->abiA",t1["oV"],v["vvoo"],optimize="optimal")
# ws1vvvV += 0.500000000 * np.einsum("iA,bcia->bcaA",t1["oV"],v["vvov"],optimize="optimal")
# ws1vvoo += -0.500000000 * np.einsum("Ai,abjA->abij",t1["Vo"],v["vvoV"],optimize="optimal")
# ws1vvov += -0.500000000 * np.einsum("Ai,bcaA->bcia",t1["Vo"],v["vvvV"],optimize="optimal")
# ws1vV += -1.000000000 * np.einsum("Bi,iaAB->aA",t1["Vo"],v["ovVV"],optimize="optimal")
# ws1vV += -1.000000000 * np.einsum("iB,aBiA->aA",t1["oV"],v["vVoV"],optimize="optimal")
# ws1vo += -1.000000000 * np.einsum("Aj,jaiA->ai",t1["Vo"],v["ovoV"],optimize="optimal")
# ws1vo += 1.000000000 * np.einsum("jA,aAij->ai",t1["oV"],v["vVoo"],optimize="optimal")
# ws1vv += -1.000000000 * np.einsum("Ai,ibaA->ba",t1["Vo"],v["ovvV"],optimize="optimal")
# ws1vv += -1.000000000 * np.einsum("iA,bAia->ba",t1["oV"],v["vVov"],optimize="optimal")

# %%
# [W,s2_ext]
print("[W,s2_ext]")
Ws2 = w.commutator(W,s2_ext)
expr = wt.contract(Ws2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [W,s2_ext]
# ws2VVVoVV += -0.250000000 * np.einsum("ABij,jECD->ABEiCD",t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2VVVooV += -0.250000000 * np.einsum("aAij,CDaB->ACDijB",t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2VVVooV += -0.250000000 * np.einsum("AEij,CDBE->ACDijB",t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2VVVooV += -0.500000000 * np.einsum("ABik,kDjC->ABDijC",t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2VVVovV += -0.500000000 * np.einsum("ABij,jDaC->ABDiaC",t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2VVVooo += 0.250000000 * np.einsum("aAij,BCka->ABCijk",t2["vVoo"],v["VVov"],optimize="optimal")
# ws2VVVooo += -0.250000000 * np.einsum("ADij,BCkD->ABCijk",t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2VVVooo += -0.250000000 * np.einsum("ABil,lCjk->ABCijk",t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2VVVoov += 0.250000000 * np.einsum("bAij,BCab->ABCija",t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2VVVoov += -0.250000000 * np.einsum("ADij,BCaD->ABCija",t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2VVVoov += -0.500000000 * np.einsum("ABik,kCja->ABCija",t2["VVoo"],v["oVov"],optimize="optimal")
# ws2VVVovv += -0.250000000 * np.einsum("ABij,jCab->ABCiab",t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2VVVV += 0.125000000 * np.einsum("ABij,ijCD->ABCD",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2VVVV += 0.125000000 * np.einsum("ijAB,CDij->CDAB",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2VVoV += -1.000000000 * np.einsum("aAij,jCaB->ACiB",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2VVoV += -1.000000000 * np.einsum("ADij,jCBD->ACiB",t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2VVoV += 0.250000000 * np.einsum("ABjk,jkiC->ABiC",t2["VVoo"],v["oooV"],optimize="optimal")
# ws2VVvV += 0.250000000 * np.einsum("ABij,ijaC->ABaC",t2["VVoo"],v["oovV"],optimize="optimal")
# ws2VVvV += 0.250000000 * np.einsum("ijaA,BCij->BCaA",t2["oovV"],v["VVoo"],optimize="optimal")
# ws2VVoo += 0.250000000 * np.einsum("aCij,ABaC->ABij",t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2VVoo += 0.125000000 * np.einsum("CDij,ABCD->ABij",t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2VVoo += 1.000000000 * np.einsum("aAik,kBja->ABij",t2["vVoo"],v["oVov"],optimize="optimal")
# ws2VVoo += -1.000000000 * np.einsum("ACik,kBjC->ABij",t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2VVoo += 0.125000000 * np.einsum("ABkl,klij->ABij",t2["VVoo"],v["oooo"],optimize="optimal")
# ws2VVov += 1.000000000 * np.einsum("bAij,jBab->ABia",t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2VVov += -1.000000000 * np.einsum("ACij,jBaC->ABia",t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2VVov += 0.250000000 * np.einsum("ABjk,jkia->ABia",t2["VVoo"],v["ooov"],optimize="optimal")
# ws2VVvv += 0.125000000 * np.einsum("ABij,ijab->ABab",t2["VVoo"],v["oovv"],optimize="optimal")
# ws2VV += -0.500000000 * np.einsum("aAij,ijaB->AB",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2VV += -0.500000000 * np.einsum("ACij,ijBC->AB",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2VV += -0.500000000 * np.einsum("ijaA,aBij->BA",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2VV += -0.500000000 * np.einsum("ijAC,BCij->BA",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2Vo += -1.000000000 * np.einsum("aBij,jAaB->Ai",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2Vo += -0.500000000 * np.einsum("BCij,jABC->Ai",t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2Vo += 0.500000000 * np.einsum("aAjk,jkia->Ai",t2["vVoo"],v["ooov"],optimize="optimal")
# ws2Vo += -0.500000000 * np.einsum("ABjk,jkiB->Ai",t2["VVoo"],v["oooV"],optimize="optimal")
# ws2Vv += 0.500000000 * np.einsum("bAij,ijab->Aa",t2["vVoo"],v["oovv"],optimize="optimal")
# ws2Vv += -0.500000000 * np.einsum("ABij,ijaB->Aa",t2["VVoo"],v["oovV"],optimize="optimal")
# ws2Vv += -0.500000000 * np.einsum("ijaB,ABij->Aa",t2["oovV"],v["VVoo"],optimize="optimal")
# ws2oVVVVV += -0.250000000 * np.einsum("ijAB,DEjC->iDEABC",t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2oVVoVV += 0.250000000 * np.einsum("ABik,jkCD->jABiCD",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2oVVoVV += 0.250000000 * np.einsum("ikAB,CDjk->iCDjAB",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2oVVvVV += -0.500000000 * np.einsum("ijaA,CDjB->iCDaAB",t2["oovV"],v["VVoV"],optimize="optimal")
# ws2oVVvVV += -0.250000000 * np.einsum("ijAB,CDja->iCDaAB",t2["ooVV"],v["VVov"],optimize="optimal")
# ws2oVVooV += 0.500000000 * np.einsum("aAij,kCaB->kACijB",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2oVVooV += 0.500000000 * np.einsum("ADij,kCBD->kACijB",t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2oVVooV += 0.500000000 * np.einsum("ABil,kljC->kABijC",t2["VVoo"],v["oooV"],optimize="optimal")
# ws2oVVovV += 0.500000000 * np.einsum("ABik,jkaC->jABiaC",t2["VVoo"],v["oovV"],optimize="optimal")
# ws2oVVovV += 0.500000000 * np.einsum("ikaA,BCjk->iBCjaA",t2["oovV"],v["VVoo"],optimize="optimal")
# ws2oVVvvV += 0.500000000 * np.einsum("ijaA,BCjb->iBCabA",t2["oovV"],v["VVov"],optimize="optimal")
# ws2oVVooo += -0.500000000 * np.einsum("aAij,lBka->lABijk",t2["vVoo"],v["oVov"],optimize="optimal")
# ws2oVVooo += 0.500000000 * np.einsum("ACij,lBkC->lABijk",t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2oVVooo += 0.250000000 * np.einsum("ABim,lmjk->lABijk",t2["VVoo"],v["oooo"],optimize="optimal")
# ws2oVVoov += -0.500000000 * np.einsum("bAij,kBab->kABija",t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2oVVoov += 0.500000000 * np.einsum("ACij,kBaC->kABija",t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2oVVoov += 0.500000000 * np.einsum("ABil,klja->kABija",t2["VVoo"],v["ooov"],optimize="optimal")
# ws2oVVovv += 0.250000000 * np.einsum("ABik,jkab->jABiab",t2["VVoo"],v["oovv"],optimize="optimal")
# ws2oVVV += -1.000000000 * np.einsum("ijaA,aCjB->iCAB",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2oVVV += 0.250000000 * np.einsum("jkAB,iCjk->iCAB",t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2oVVV += -1.000000000 * np.einsum("ijAD,CDjB->iCAB",t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2oVoV += -1.000000000 * np.einsum("aAik,jkaB->jAiB",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2oVoV += -1.000000000 * np.einsum("ACik,jkBC->jAiB",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2oVoV += -1.000000000 * np.einsum("ikaA,aBjk->iBjA",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2oVoV += -1.000000000 * np.einsum("ikAC,BCjk->iBjA",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2oVvV += 0.500000000 * np.einsum("jkaA,iBjk->iBaA",t2["oovV"],v["oVoo"],optimize="optimal")
# ws2oVvV += -1.000000000 * np.einsum("ijaC,BCjA->iBaA",t2["oovV"],v["VVoV"],optimize="optimal")
# ws2oVvV += 1.000000000 * np.einsum("ijbA,bBja->iBaA",t2["oovV"],v["vVov"],optimize="optimal")
# ws2oVvV += 1.000000000 * np.einsum("ijAC,BCja->iBaA",t2["ooVV"],v["VVov"],optimize="optimal")
# ws2oVoo += 0.500000000 * np.einsum("aBij,kAaB->kAij",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2oVoo += 0.250000000 * np.einsum("BCij,kABC->kAij",t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2oVoo += 1.000000000 * np.einsum("aAil,klja->kAij",t2["vVoo"],v["ooov"],optimize="optimal")
# ws2oVoo += -1.000000000 * np.einsum("ABil,kljB->kAij",t2["VVoo"],v["oooV"],optimize="optimal")
# ws2oVov += 1.000000000 * np.einsum("bAik,jkab->jAia",t2["vVoo"],v["oovv"],optimize="optimal")
# ws2oVov += -1.000000000 * np.einsum("ABik,jkaB->jAia",t2["VVoo"],v["oovV"],optimize="optimal")
# ws2oVov += -1.000000000 * np.einsum("ikaB,ABjk->iAja",t2["oovV"],v["VVoo"],optimize="optimal")
# ws2oVvv += -1.000000000 * np.einsum("ijaB,ABjb->iAab",t2["oovV"],v["VVov"],optimize="optimal")
# ws2ooVVVV += -0.250000000 * np.einsum("ijaA,aDBC->ijDABC",t2["oovV"],v["vVVV"],optimize="optimal")
# ws2ooVVVV += -0.500000000 * np.einsum("ikAB,jDkC->ijDABC",t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2ooVVVV += -0.250000000 * np.einsum("ijAE,DEBC->ijDABC",t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2ooVoVV += 0.500000000 * np.einsum("ijaA,aCkB->ijCkAB",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2ooVoVV += 0.500000000 * np.einsum("ilAB,kCjl->ikCjAB",t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2ooVoVV += 0.500000000 * np.einsum("ijAD,CDkB->ijCkAB",t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2ooVvVV += -1.000000000 * np.einsum("ikaA,jCkB->ijCaAB",t2["oovV"],v["oVoV"],optimize="optimal")
# ws2ooVvVV += -0.250000000 * np.einsum("ijaD,CDAB->ijCaAB",t2["oovV"],v["VVVV"],optimize="optimal")
# ws2ooVvVV += 0.500000000 * np.einsum("ijbA,bCaB->ijCaAB",t2["oovV"],v["vVvV"],optimize="optimal")
# ws2ooVvVV += -0.500000000 * np.einsum("ikAB,jCka->ijCaAB",t2["ooVV"],v["oVov"],optimize="optimal")
# ws2ooVvVV += 0.500000000 * np.einsum("ijAD,CDaB->ijCaAB",t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2ooVooV += -0.250000000 * np.einsum("aAij,klaB->klAijB",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2ooVooV += -0.250000000 * np.einsum("ACij,klBC->klAijB",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2ooVooV += -0.250000000 * np.einsum("ijaA,aBkl->ijBklA",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2ooVooV += -0.250000000 * np.einsum("ijAC,BCkl->ijBklA",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2ooVovV += 1.000000000 * np.einsum("ilaA,kBjl->ikBjaA",t2["oovV"],v["oVoo"],optimize="optimal")
# ws2ooVovV += 0.500000000 * np.einsum("ijaC,BCkA->ijBkaA",t2["oovV"],v["VVoV"],optimize="optimal")
# ws2ooVovV += -0.500000000 * np.einsum("ijbA,bBka->ijBkaA",t2["oovV"],v["vVov"],optimize="optimal")
# ws2ooVovV += -0.500000000 * np.einsum("ijAC,BCka->ijBkaA",t2["ooVV"],v["VVov"],optimize="optimal")
# ws2ooVvvV += 1.000000000 * np.einsum("ikaA,jBkb->ijBabA",t2["oovV"],v["oVov"],optimize="optimal")
# ws2ooVvvV += -0.500000000 * np.einsum("ijaC,BCbA->ijBabA",t2["oovV"],v["VVvV"],optimize="optimal")
# ws2ooVvvV += -0.250000000 * np.einsum("ijcA,cBab->ijBabA",t2["oovV"],v["vVvv"],optimize="optimal")
# ws2ooVvvV += -0.250000000 * np.einsum("ijAC,BCab->ijBabA",t2["ooVV"],v["VVvv"],optimize="optimal")
# ws2ooVooo += 0.250000000 * np.einsum("aAij,lmka->lmAijk",t2["vVoo"],v["ooov"],optimize="optimal")
# ws2ooVooo += -0.250000000 * np.einsum("ABij,lmkB->lmAijk",t2["VVoo"],v["oooV"],optimize="optimal")
# ws2ooVoov += 0.250000000 * np.einsum("bAij,klab->klAija",t2["vVoo"],v["oovv"],optimize="optimal")
# ws2ooVoov += -0.250000000 * np.einsum("ABij,klaB->klAija",t2["VVoo"],v["oovV"],optimize="optimal")
# ws2ooVoov += -0.250000000 * np.einsum("ijaB,ABkl->ijAkla",t2["oovV"],v["VVoo"],optimize="optimal")
# ws2ooVovv += 0.500000000 * np.einsum("ijaB,ABkb->ijAkab",t2["oovV"],v["VVov"],optimize="optimal")
# ws2ooVvvv += -0.250000000 * np.einsum("ijaB,ABbc->ijAabc",t2["oovV"],v["VVvv"],optimize="optimal")
# ws2oooVVV += 0.250000000 * np.einsum("ijaA,kaBC->ijkABC",t2["oovV"],v["ovVV"],optimize="optimal")
# ws2oooVVV += -0.250000000 * np.einsum("ilAB,jklC->ijkABC",t2["ooVV"],v["oooV"],optimize="optimal")
# ws2oooVVV += -0.250000000 * np.einsum("ijAD,kDBC->ijkABC",t2["ooVV"],v["oVVV"],optimize="optimal")
# ws2ooooVV += -0.500000000 * np.einsum("ijaA,lakB->ijlkAB",t2["oovV"],v["ovoV"],optimize="optimal")
# ws2ooooVV += 0.250000000 * np.einsum("imAB,kljm->ikljAB",t2["ooVV"],v["oooo"],optimize="optimal")
# ws2ooooVV += 0.500000000 * np.einsum("ijAC,lCkB->ijlkAB",t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2ooovVV += -0.500000000 * np.einsum("ilaA,jklB->ijkaAB",t2["oovV"],v["oooV"],optimize="optimal")
# ws2ooovVV += -0.250000000 * np.einsum("ijaC,kCAB->ijkaAB",t2["oovV"],v["oVVV"],optimize="optimal")
# ws2ooovVV += -0.500000000 * np.einsum("ijbA,kbaB->ijkaAB",t2["oovV"],v["ovvV"],optimize="optimal")
# ws2ooovVV += -0.250000000 * np.einsum("ilAB,jkla->ijkaAB",t2["ooVV"],v["ooov"],optimize="optimal")
# ws2ooovVV += 0.500000000 * np.einsum("ijAC,kCaB->ijkaAB",t2["ooVV"],v["oVvV"],optimize="optimal")
# ws2oooooV += 0.250000000 * np.einsum("ijaA,makl->ijmklA",t2["oovV"],v["ovoo"],optimize="optimal")
# ws2oooooV += -0.250000000 * np.einsum("ijAB,mBkl->ijmklA",t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2oooovV += 0.500000000 * np.einsum("imaA,kljm->ikljaA",t2["oovV"],v["oooo"],optimize="optimal")
# ws2oooovV += 0.500000000 * np.einsum("ijaB,lBkA->ijlkaA",t2["oovV"],v["oVoV"],optimize="optimal")
# ws2oooovV += 0.500000000 * np.einsum("ijbA,lbka->ijlkaA",t2["oovV"],v["ovov"],optimize="optimal")
# ws2oooovV += -0.500000000 * np.einsum("ijAB,lBka->ijlkaA",t2["ooVV"],v["oVov"],optimize="optimal")
# ws2ooovvV += 0.500000000 * np.einsum("ilaA,jklb->ijkabA",t2["oovV"],v["ooov"],optimize="optimal")
# ws2ooovvV += -0.500000000 * np.einsum("ijaB,kBbA->ijkabA",t2["oovV"],v["oVvV"],optimize="optimal")
# ws2ooovvV += 0.250000000 * np.einsum("ijcA,kcab->ijkabA",t2["oovV"],v["ovvv"],optimize="optimal")
# ws2ooovvV += -0.250000000 * np.einsum("ijAB,kBab->ijkabA",t2["ooVV"],v["oVvv"],optimize="optimal")
# ws2ooooov += -0.250000000 * np.einsum("ijaA,mAkl->ijmkla",t2["oovV"],v["oVoo"],optimize="optimal")
# ws2oooovv += 0.500000000 * np.einsum("ijaA,lAkb->ijlkab",t2["oovV"],v["oVov"],optimize="optimal")
# ws2ooovvv += -0.250000000 * np.einsum("ijaA,kAbc->ijkabc",t2["oovV"],v["oVvv"],optimize="optimal")
# ws2oovVVV += 0.250000000 * np.einsum("ijbA,abBC->ijaABC",t2["oovV"],v["vvVV"],optimize="optimal")
# ws2oovVVV += -0.500000000 * np.einsum("ikAB,jakC->ijaABC",t2["ooVV"],v["ovoV"],optimize="optimal")
# ws2oovVVV += -0.250000000 * np.einsum("ijAD,aDBC->ijaABC",t2["ooVV"],v["vVVV"],optimize="optimal")
# ws2oovoVV += -0.500000000 * np.einsum("ijbA,abkB->ijakAB",t2["oovV"],v["vvoV"],optimize="optimal")
# ws2oovoVV += 0.500000000 * np.einsum("ilAB,kajl->ikajAB",t2["ooVV"],v["ovoo"],optimize="optimal")
# ws2oovoVV += 0.500000000 * np.einsum("ijAC,aCkB->ijakAB",t2["ooVV"],v["vVoV"],optimize="optimal")
# ws2oovvVV += -1.000000000 * np.einsum("ikaA,jbkB->ijbaAB",t2["oovV"],v["ovoV"],optimize="optimal")
# ws2oovvVV += -0.250000000 * np.einsum("ijaC,bCAB->ijbaAB",t2["oovV"],v["vVVV"],optimize="optimal")
# ws2oovvVV += -0.500000000 * np.einsum("ijcA,bcaB->ijbaAB",t2["oovV"],v["vvvV"],optimize="optimal")
# ws2oovvVV += -0.500000000 * np.einsum("ikAB,jbka->ijbaAB",t2["ooVV"],v["ovov"],optimize="optimal")
# ws2oovvVV += 0.500000000 * np.einsum("ijAC,bCaB->ijbaAB",t2["ooVV"],v["vVvV"],optimize="optimal")
# ws2oovooV += -0.250000000 * np.einsum("aBij,klAB->klaijA",t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2oovooV += 0.250000000 * np.einsum("ijbA,abkl->ijaklA",t2["oovV"],v["vvoo"],optimize="optimal")
# ws2oovooV += -0.250000000 * np.einsum("ijAB,aBkl->ijaklA",t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2oovovV += 1.000000000 * np.einsum("ilaA,kbjl->ikbjaA",t2["oovV"],v["ovoo"],optimize="optimal")
# ws2oovovV += 0.500000000 * np.einsum("ijaB,bBkA->ijbkaA",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2oovovV += 0.500000000 * np.einsum("ijcA,bcka->ijbkaA",t2["oovV"],v["vvov"],optimize="optimal")
# ws2oovovV += -0.500000000 * np.einsum("ijAB,bBka->ijbkaA",t2["ooVV"],v["vVov"],optimize="optimal")
# ws2oovvvV += 1.000000000 * np.einsum("ikaA,jckb->ijcabA",t2["oovV"],v["ovov"],optimize="optimal")
# ws2oovvvV += -0.500000000 * np.einsum("ijaB,cBbA->ijcabA",t2["oovV"],v["vVvV"],optimize="optimal")
# ws2oovvvV += 0.250000000 * np.einsum("ijdA,cdab->ijcabA",t2["oovV"],v["vvvv"],optimize="optimal")
# ws2oovvvV += -0.250000000 * np.einsum("ijAB,cBab->ijcabA",t2["ooVV"],v["vVvv"],optimize="optimal")
# ws2oovooo += -0.250000000 * np.einsum("aAij,lmkA->lmaijk",t2["vVoo"],v["oooV"],optimize="optimal")
# ws2oovoov += -0.250000000 * np.einsum("aAij,klbA->klaijb",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2oovoov += -0.250000000 * np.einsum("ijaA,bAkl->ijbkla",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2oovovv += 0.500000000 * np.einsum("ijaA,cAkb->ijckab",t2["oovV"],v["vVov"],optimize="optimal")
# ws2oovvvv += -0.250000000 * np.einsum("ijaA,dAbc->ijdabc",t2["oovV"],v["vVvv"],optimize="optimal")
# ws2ooVV += 1.000000000 * np.einsum("ikaA,jakB->ijAB",t2["oovV"],v["ovoV"],optimize="optimal")
# ws2ooVV += 0.250000000 * np.einsum("ijaC,aCAB->ijAB",t2["oovV"],v["vVVV"],optimize="optimal")
# ws2ooVV += 0.125000000 * np.einsum("klAB,ijkl->ijAB",t2["ooVV"],v["oooo"],optimize="optimal")
# ws2ooVV += -1.000000000 * np.einsum("ikAC,jCkB->ijAB",t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2ooVV += 0.125000000 * np.einsum("ijCD,CDAB->ijAB",t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2oooV += 1.000000000 * np.einsum("ilaA,kajl->ikjA",t2["oovV"],v["ovoo"],optimize="optimal")
# ws2oooV += 0.500000000 * np.einsum("ijaB,aBkA->ijkA",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2oooV += -1.000000000 * np.einsum("ilAB,kBjl->ikjA",t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2oooV += 0.250000000 * np.einsum("ijBC,BCkA->ijkA",t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2oovV += 0.250000000 * np.einsum("klaA,ijkl->ijaA",t2["oovV"],v["oooo"],optimize="optimal")
# ws2oovV += -1.000000000 * np.einsum("ikaB,jBkA->ijaA",t2["oovV"],v["oVoV"],optimize="optimal")
# ws2oovV += -1.000000000 * np.einsum("ikbA,jbka->ijaA",t2["oovV"],v["ovov"],optimize="optimal")
# ws2oovV += 0.500000000 * np.einsum("ijbB,bBaA->ijaA",t2["oovV"],v["vVvV"],optimize="optimal")
# ws2oovV += 1.000000000 * np.einsum("ikAB,jBka->ijaA",t2["ooVV"],v["oVov"],optimize="optimal")
# ws2oovV += 0.250000000 * np.einsum("ijBC,BCaA->ijaA",t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2oooo += 0.250000000 * np.einsum("aAij,klaA->klij",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2oooo += 0.125000000 * np.einsum("ABij,klAB->klij",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2oooo += 0.250000000 * np.einsum("ijaA,aAkl->ijkl",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2oooo += 0.125000000 * np.einsum("ijAB,ABkl->ijkl",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2ooov += -1.000000000 * np.einsum("ilaA,kAjl->ikja",t2["oovV"],v["oVoo"],optimize="optimal")
# ws2ooov += 0.500000000 * np.einsum("ijbA,bAka->ijka",t2["oovV"],v["vVov"],optimize="optimal")
# ws2ooov += 0.250000000 * np.einsum("ijAB,ABka->ijka",t2["ooVV"],v["VVov"],optimize="optimal")
# ws2oovv += -1.000000000 * np.einsum("ikaA,jAkb->ijab",t2["oovV"],v["oVov"],optimize="optimal")
# ws2oovv += 0.250000000 * np.einsum("ijcA,cAab->ijab",t2["oovV"],v["vVvv"],optimize="optimal")
# ws2oovv += 0.125000000 * np.einsum("ijAB,ABab->ijab",t2["ooVV"],v["VVvv"],optimize="optimal")
# ws2ovVVVV += -0.500000000 * np.einsum("ijAB,aDjC->iaDABC",t2["ooVV"],v["vVoV"],optimize="optimal")
# ws2ovVoVV += 0.500000000 * np.einsum("aAik,jkBC->jaAiBC",t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2ovVoVV += 0.500000000 * np.einsum("ikAB,aCjk->iaCjAB",t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2ovVvVV += -1.000000000 * np.einsum("ijaA,bCjB->ibCaAB",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2ovVvVV += -0.500000000 * np.einsum("ijAB,bCja->ibCaAB",t2["ooVV"],v["vVov"],optimize="optimal")
# ws2ovVooV += 0.500000000 * np.einsum("aCij,kBAC->kaBijA",t2["vVoo"],v["oVVV"],optimize="optimal")
# ws2ovVooV += -0.500000000 * np.einsum("bAij,kabB->kaAijB",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2ovVooV += -0.500000000 * np.einsum("ACij,kaBC->kaAijB",t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2ovVooV += 1.000000000 * np.einsum("aAil,kljB->kaAijB",t2["vVoo"],v["oooV"],optimize="optimal")
# ws2ovVovV += 1.000000000 * np.einsum("aAik,jkbB->jaAibB",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2ovVovV += 1.000000000 * np.einsum("ikaA,bBjk->ibBjaA",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2ovVvvV += 1.000000000 * np.einsum("ijaA,cBjb->icBabA",t2["oovV"],v["vVov"],optimize="optimal")
# ws2ovVooo += 0.500000000 * np.einsum("aBij,lAkB->laAijk",t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2ovVooo += 0.500000000 * np.einsum("bAij,lakb->laAijk",t2["vVoo"],v["ovov"],optimize="optimal")
# ws2ovVooo += -0.500000000 * np.einsum("ABij,lakB->laAijk",t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2ovVooo += 0.500000000 * np.einsum("aAim,lmjk->laAijk",t2["vVoo"],v["oooo"],optimize="optimal")
# ws2ovVoov += 0.500000000 * np.einsum("aBij,kAbB->kaAijb",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2ovVoov += 0.500000000 * np.einsum("cAij,kbac->kbAija",t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2ovVoov += -0.500000000 * np.einsum("ABij,kbaB->kbAija",t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2ovVoov += 1.000000000 * np.einsum("aAil,kljb->kaAijb",t2["vVoo"],v["ooov"],optimize="optimal")
# ws2ovVovv += 0.500000000 * np.einsum("aAik,jkbc->jaAibc",t2["vVoo"],v["oovv"],optimize="optimal")
# ws2ovvVVV += -0.250000000 * np.einsum("ijAB,abjC->iabABC",t2["ooVV"],v["vvoV"],optimize="optimal")
# ws2ovvoVV += 0.250000000 * np.einsum("ikAB,abjk->iabjAB",t2["ooVV"],v["vvoo"],optimize="optimal")
# ws2ovvvVV += -0.500000000 * np.einsum("ijaA,bcjB->ibcaAB",t2["oovV"],v["vvoV"],optimize="optimal")
# ws2ovvvVV += -0.250000000 * np.einsum("ijAB,bcja->ibcaAB",t2["ooVV"],v["vvov"],optimize="optimal")
# ws2ovvooV += 0.500000000 * np.einsum("aBij,kbAB->kabijA",t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2ovvovV += 0.500000000 * np.einsum("ikaA,bcjk->ibcjaA",t2["oovV"],v["vvoo"],optimize="optimal")
# ws2ovvvvV += 0.500000000 * np.einsum("ijaA,cdjb->icdabA",t2["oovV"],v["vvov"],optimize="optimal")
# ws2ovvooo += 0.500000000 * np.einsum("aAij,lbkA->labijk",t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2ovvoov += 0.500000000 * np.einsum("aAij,kcbA->kacijb",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2ovVV += 1.000000000 * np.einsum("ijbA,abjB->iaAB",t2["oovV"],v["vvoV"],optimize="optimal")
# ws2ovVV += 0.250000000 * np.einsum("jkAB,iajk->iaAB",t2["ooVV"],v["ovoo"],optimize="optimal")
# ws2ovVV += -1.000000000 * np.einsum("ijAC,aCjB->iaAB",t2["ooVV"],v["vVoV"],optimize="optimal")
# ws2ovoV += -1.000000000 * np.einsum("aBik,jkAB->jaiA",t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2ovoV += 1.000000000 * np.einsum("ikbA,abjk->iajA",t2["oovV"],v["vvoo"],optimize="optimal")
# ws2ovoV += -1.000000000 * np.einsum("ikAB,aBjk->iajA",t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2ovvV += 0.500000000 * np.einsum("jkaA,ibjk->ibaA",t2["oovV"],v["ovoo"],optimize="optimal")
# ws2ovvV += -1.000000000 * np.einsum("ijaB,bBjA->ibaA",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2ovvV += -1.000000000 * np.einsum("ijcA,bcja->ibaA",t2["oovV"],v["vvov"],optimize="optimal")
# ws2ovvV += 1.000000000 * np.einsum("ijAB,bBja->ibaA",t2["ooVV"],v["vVov"],optimize="optimal")
# ws2ovoo += 0.500000000 * np.einsum("bAij,kabA->kaij",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2ovoo += 0.250000000 * np.einsum("ABij,kaAB->kaij",t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2ovoo += -1.000000000 * np.einsum("aAil,kljA->kaij",t2["vVoo"],v["oooV"],optimize="optimal")
# ws2ovov += -1.000000000 * np.einsum("aAik,jkbA->jaib",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2ovov += -1.000000000 * np.einsum("ikaA,bAjk->ibja",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2ovvv += -1.000000000 * np.einsum("ijaA,cAjb->icab",t2["oovV"],v["vVov"],optimize="optimal")
# ws2oV += 0.500000000 * np.einsum("jkaA,iajk->iA",t2["oovV"],v["ovoo"],optimize="optimal")
# ws2oV += -1.000000000 * np.einsum("ijaB,aBjA->iA",t2["oovV"],v["vVoV"],optimize="optimal")
# ws2oV += -0.500000000 * np.einsum("jkAB,iBjk->iA",t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2oV += -0.500000000 * np.einsum("ijBC,BCjA->iA",t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2oo += 1.000000000 * np.einsum("aAik,jkaA->ji",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2oo += 0.500000000 * np.einsum("ABik,jkAB->ji",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2oo += 1.000000000 * np.einsum("ikaA,aAjk->ij",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2oo += 0.500000000 * np.einsum("ikAB,ABjk->ij",t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2ov += -0.500000000 * np.einsum("jkaA,iAjk->ia",t2["oovV"],v["oVoo"],optimize="optimal")
# ws2ov += -1.000000000 * np.einsum("ijbA,bAja->ia",t2["oovV"],v["vVov"],optimize="optimal")
# ws2ov += -0.500000000 * np.einsum("ijAB,ABja->ia",t2["ooVV"],v["VVov"],optimize="optimal")
# ws2vVVoVV += -0.500000000 * np.einsum("aAij,jDBC->aADiBC",t2["vVoo"],v["oVVV"],optimize="optimal")
# ws2vVVoVV += -0.250000000 * np.einsum("ABij,jaCD->aABiCD",t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2vVVooV += -0.250000000 * np.einsum("aDij,BCAD->aBCijA",t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2vVVooV += 0.500000000 * np.einsum("bAij,aCbB->aACijB",t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2vVVooV += 0.500000000 * np.einsum("ADij,aCBD->aACijB",t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2vVVooV += -1.000000000 * np.einsum("aAik,kCjB->aACijB",t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2vVVooV += -0.500000000 * np.einsum("ABik,kajC->aABijC",t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2vVVovV += -1.000000000 * np.einsum("aAij,jCbB->aACibB",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2vVVovV += -0.500000000 * np.einsum("ABij,jbaC->bABiaC",t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2vVVooo += -0.250000000 * np.einsum("aCij,ABkC->aABijk",t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2vVVooo += -0.500000000 * np.einsum("bAij,aBkb->aABijk",t2["vVoo"],v["vVov"],optimize="optimal")
# ws2vVVooo += 0.500000000 * np.einsum("ACij,aBkC->aABijk",t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2vVVooo += -0.500000000 * np.einsum("aAil,lBjk->aABijk",t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2vVVooo += -0.250000000 * np.einsum("ABil,lajk->aABijk",t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2vVVoov += -0.250000000 * np.einsum("aCij,ABbC->aABijb",t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2vVVoov += -0.500000000 * np.einsum("cAij,bBac->bABija",t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2vVVoov += 0.500000000 * np.einsum("ACij,bBaC->bABija",t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2vVVoov += -1.000000000 * np.einsum("aAik,kBjb->aABijb",t2["vVoo"],v["oVov"],optimize="optimal")
# ws2vVVoov += -0.500000000 * np.einsum("ABik,kbja->bABija",t2["VVoo"],v["ovov"],optimize="optimal")
# ws2vVVovv += -0.500000000 * np.einsum("aAij,jBbc->aABibc",t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2vVVovv += -0.250000000 * np.einsum("ABij,jcab->cABiab",t2["VVoo"],v["ovvv"],optimize="optimal")
# ws2vVVV += 0.250000000 * np.einsum("aAij,ijBC->aABC",t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2vVVV += 0.250000000 * np.einsum("ijAB,aCij->aCAB",t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2vVoV += -1.000000000 * np.einsum("aCij,jBAC->aBiA",t2["vVoo"],v["oVVV"],optimize="optimal")
# ws2vVoV += 1.000000000 * np.einsum("bAij,jabB->aAiB",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2vVoV += 1.000000000 * np.einsum("ACij,jaBC->aAiB",t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2vVoV += 0.500000000 * np.einsum("aAjk,jkiB->aAiB",t2["vVoo"],v["oooV"],optimize="optimal")
# ws2vVvV += 0.500000000 * np.einsum("aAij,ijbB->aAbB",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2vVvV += 0.500000000 * np.einsum("ijaA,bBij->bBaA",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2vVoo += 0.500000000 * np.einsum("bBij,aAbB->aAij",t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2vVoo += 0.250000000 * np.einsum("BCij,aABC->aAij",t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2vVoo += -1.000000000 * np.einsum("aBik,kAjB->aAij",t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2vVoo += -1.000000000 * np.einsum("bAik,kajb->aAij",t2["vVoo"],v["ovov"],optimize="optimal")
# ws2vVoo += 1.000000000 * np.einsum("ABik,kajB->aAij",t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2vVoo += 0.250000000 * np.einsum("aAkl,klij->aAij",t2["vVoo"],v["oooo"],optimize="optimal")
# ws2vVov += -1.000000000 * np.einsum("aBij,jAbB->aAib",t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2vVov += -1.000000000 * np.einsum("cAij,jbac->bAia",t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2vVov += 1.000000000 * np.einsum("ABij,jbaB->bAia",t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2vVov += 0.500000000 * np.einsum("aAjk,jkib->aAib",t2["vVoo"],v["ooov"],optimize="optimal")
# ws2vVvv += 0.250000000 * np.einsum("aAij,ijbc->aAbc",t2["vVoo"],v["oovv"],optimize="optimal")
# ws2vvVoVV += 0.500000000 * np.einsum("aAij,jbBC->abAiBC",t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2vvVooV += -0.500000000 * np.einsum("aCij,bBAC->abBijA",t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2vvVooV += -0.250000000 * np.einsum("cAij,abcB->abAijB",t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2vvVooV += -0.250000000 * np.einsum("ACij,abBC->abAijB",t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2vvVooV += 1.000000000 * np.einsum("aAik,kbjB->abAijB",t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2vvVovV += 1.000000000 * np.einsum("aAij,jcbB->acAibB",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2vvVooo += -0.500000000 * np.einsum("aBij,bAkB->abAijk",t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2vvVooo += 0.250000000 * np.einsum("cAij,abkc->abAijk",t2["vVoo"],v["vvov"],optimize="optimal")
# ws2vvVooo += -0.250000000 * np.einsum("ABij,abkB->abAijk",t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2vvVooo += 0.500000000 * np.einsum("aAil,lbjk->abAijk",t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2vvVoov += -0.500000000 * np.einsum("aBij,cAbB->acAijb",t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2vvVoov += 0.250000000 * np.einsum("dAij,bcad->bcAija",t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2vvVoov += -0.250000000 * np.einsum("ABij,bcaB->bcAija",t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2vvVoov += 1.000000000 * np.einsum("aAik,kcjb->acAijb",t2["vVoo"],v["ovov"],optimize="optimal")
# ws2vvVovv += 0.500000000 * np.einsum("aAij,jdbc->adAibc",t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2vvvooV += -0.250000000 * np.einsum("aBij,bcAB->abcijA",t2["vVoo"],v["vvVV"],optimize="optimal")
# ws2vvvooo += -0.250000000 * np.einsum("aAij,bckA->abcijk",t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2vvvoov += -0.250000000 * np.einsum("aAij,cdbA->acdijb",t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2vvVV += 0.125000000 * np.einsum("ijAB,abij->abAB",t2["ooVV"],v["vvoo"],optimize="optimal")
# ws2vvoV += -1.000000000 * np.einsum("aBij,jbAB->abiA",t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2vvvV += 0.250000000 * np.einsum("ijaA,bcij->bcaA",t2["oovV"],v["vvoo"],optimize="optimal")
# ws2vvoo += 0.250000000 * np.einsum("cAij,abcA->abij",t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2vvoo += 0.125000000 * np.einsum("ABij,abAB->abij",t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2vvoo += -1.000000000 * np.einsum("aAik,kbjA->abij",t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2vvov += -1.000000000 * np.einsum("aAij,jcbA->acib",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2vV += -0.500000000 * np.einsum("aBij,ijAB->aA",t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2vV += 0.500000000 * np.einsum("ijbA,abij->aA",t2["oovV"],v["vvoo"],optimize="optimal")
# ws2vV += -0.500000000 * np.einsum("ijAB,aBij->aA",t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2vo += -1.000000000 * np.einsum("bAij,jabA->ai",t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2vo += -0.500000000 * np.einsum("ABij,jaAB->ai",t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2vo += -0.500000000 * np.einsum("aAjk,jkiA->ai",t2["vVoo"],v["oooV"],optimize="optimal")
# ws2vv += -0.500000000 * np.einsum("aAij,ijbA->ab",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2vv += -0.500000000 * np.einsum("ijaA,bAij->ba",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2 += 0.500000000 * np.einsum("aAij,ijaA->",t2["vVoo"],v["oovV"],optimize="optimal")
# ws2 += 0.250000000 * np.einsum("ABij,ijAB->",t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2 += 0.500000000 * np.einsum("ijaA,aAij->",t2["oovV"],v["vVoo"],optimize="optimal")
# ws2 += 0.250000000 * np.einsum("ijAB,ABij->",t2["ooVV"],v["VVoo"],optimize="optimal")

# %%
# [[F,s1_ext],s1_ext]
print("[[F,s1_ext],s1_ext]")
Fs1s1 = w.commutator(F,s1_ext,s1_ext)
expr = wt.contract(Fs1s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[F,s1_ext],s1_ext]
# fs1s1VV += 2.000000000 * np.einsum("ji,iA,Bj->BA",f["oo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1VV += -1.000000000 * np.einsum("CA,iC,Bi->BA",f["VV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1VV += -1.000000000 * np.einsum("AC,iB,Ci->AB",f["VV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1Vo += -1.000000000 * np.einsum("Bi,jB,Aj->Ai",f["Vo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1Vo += -1.000000000 * np.einsum("Aj,jB,Bi->Ai",f["Vo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1Vo += -2.000000000 * np.einsum("jB,Bi,Aj->Ai",f["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1Vv += -1.000000000 * np.einsum("Ba,iB,Ai->Aa",f["Vv"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1oV += -2.000000000 * np.einsum("Bj,jA,iB->iA",f["Vo"],t1["oV"],t1["oV"],optimize="optimal")
# fs1s1oV += -1.000000000 * np.einsum("jA,iB,Bj->iA",f["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1oV += -1.000000000 * np.einsum("iB,jA,Bj->iA",f["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1oo += -1.000000000 * np.einsum("ki,jA,Ak->ji",f["oo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1oo += -1.000000000 * np.einsum("ik,kA,Aj->ij",f["oo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1oo += 2.000000000 * np.einsum("BA,iB,Aj->ij",f["VV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1ov += -1.000000000 * np.einsum("ja,iA,Aj->ia",f["ov"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1vV += -1.000000000 * np.einsum("aB,iA,Bi->aA",f["vV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1vo += -1.000000000 * np.einsum("aj,jA,Ai->ai",f["vo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1 += -2.000000000 * np.einsum("ji,iA,Aj->",f["oo"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1 += 2.000000000 * np.einsum("BA,iB,Ai->",f["VV"],t1["oV"],t1["Vo"],optimize="optimal")

# %%
# [[F,s1_ext],s2_ext]
print("[[F,s1_ext],s2_ext]")
Fs1s2 = w.commutator(F,s1_ext,s2_ext)
expr = wt.contract(Fs1s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[F,s1_ext],s2_ext]
# fs1s2VVoV += 0.500000000 * np.einsum("kj,jA,BCik->BCiA",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2VVoV += -0.500000000 * np.einsum("DA,jD,BCij->BCiA",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2VVoo += 0.500000000 * np.einsum("Ci,kC,ABjk->ABij",f["Vo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2VVoo += 0.500000000 * np.einsum("Ak,kC,BCij->ABij",f["Vo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2VVoo += -0.500000000 * np.einsum("ka,Ak,aBij->ABij",f["ov"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2VVoo += 0.500000000 * np.einsum("kC,Ci,ABjk->ABij",f["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2VVoo += 0.500000000 * np.einsum("kC,Ak,BCij->ABij",f["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2VVov += -0.500000000 * np.einsum("Ca,jC,ABij->ABia",f["Vv"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2Vo += -1.000000000 * np.einsum("kj,jB,ABik->Ai",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2Vo += -1.000000000 * np.einsum("Ba,jB,aAij->Ai",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2Vo += 1.000000000 * np.einsum("CB,jC,ABij->Ai",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2oVVV += 0.500000000 * np.einsum("kj,Ak,ijBC->iABC",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oVVV += -0.500000000 * np.einsum("AD,Dj,ijBC->iABC",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oVvV += 1.000000000 * np.einsum("kj,Ak,ijaB->iAaB",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oVvV += -1.000000000 * np.einsum("AC,Cj,ijaB->iAaB",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oVoo += 0.500000000 * np.einsum("il,lB,ABjk->iAjk",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2oVoo += 0.500000000 * np.einsum("Ba,iB,aAjk->iAjk",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2oVoo += -0.500000000 * np.einsum("CB,iC,ABjk->iAjk",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2ooVV += -0.500000000 * np.einsum("ak,kA,ijaB->ijAB",f["vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs1s2ooVV += 0.500000000 * np.einsum("Ck,kA,ijBC->ijAB",f["Vo"],t1["oV"],t2["ooVV"],optimize="optimal")
# fs1s2ooVV += 0.500000000 * np.einsum("Ck,iC,jkAB->ijAB",f["Vo"],t1["oV"],t2["ooVV"],optimize="optimal")
# fs1s2ooVV += 0.500000000 * np.einsum("kA,Ck,ijBC->ijAB",f["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2ooVV += 0.500000000 * np.einsum("iC,Ck,jkAB->ijAB",f["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oooV += 0.500000000 * np.einsum("li,Bl,jkAB->jkiA",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oooV += 0.500000000 * np.einsum("aB,Bi,jkaA->jkiA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oooV += -0.500000000 * np.einsum("CB,Bi,jkAC->jkiA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oovV += -0.500000000 * np.einsum("Bk,kA,ijaB->ijaA",f["Vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs1s2oovV += 1.000000000 * np.einsum("Bk,iB,jkaA->ijaA",f["Vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs1s2oovV += 0.500000000 * np.einsum("ka,Bk,ijAB->ijaA",f["ov"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oovV += -0.500000000 * np.einsum("kA,Bk,ijaB->ijaA",f["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oovV += 1.000000000 * np.einsum("iB,Bk,jkaA->ijaA",f["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2ooov += 0.500000000 * np.einsum("li,Al,jkaA->jkia",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2ooov += -0.500000000 * np.einsum("BA,Ai,jkaB->jkia",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oovv += 0.500000000 * np.einsum("ka,Ak,ijbA->ijab",f["ov"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2ovVV += -0.500000000 * np.einsum("aC,Cj,ijAB->iaAB",f["vV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2ovvV += -1.000000000 * np.einsum("aB,Bj,ijbA->iabA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2ovoo += 0.500000000 * np.einsum("il,lA,aAjk->iajk",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2ovoo += -0.500000000 * np.einsum("BA,iB,aAjk->iajk",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2oV += -1.000000000 * np.einsum("kj,Bk,ijAB->iA",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2oV += -1.000000000 * np.einsum("aB,Bj,ijaA->iA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2oV += 1.000000000 * np.einsum("CB,Bj,ijAC->iA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2ov += -1.000000000 * np.einsum("kj,Ak,ijaA->ia",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2ov += 1.000000000 * np.einsum("BA,Aj,ijaB->ia",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2vVoV += 1.000000000 * np.einsum("kj,jA,aBik->aBiA",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vVoV += -1.000000000 * np.einsum("CA,jC,aBij->aBiA",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vVoo += 1.000000000 * np.einsum("Bi,kB,aAjk->aAij",f["Vo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vVoo += 0.500000000 * np.einsum("ak,kB,ABij->aAij",f["vo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2vVoo += -0.500000000 * np.einsum("Ak,kB,aBij->aAij",f["Vo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vVoo += 1.000000000 * np.einsum("kB,Bi,aAjk->aAij",f["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2vVoo += -0.500000000 * np.einsum("kB,Ak,aBij->aAij",f["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2vVov += -1.000000000 * np.einsum("Ba,jB,bAij->bAia",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vvoo += 0.500000000 * np.einsum("ak,kA,bAij->abij",f["vo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vo += -1.000000000 * np.einsum("kj,jA,aAik->ai",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2vo += 1.000000000 * np.einsum("BA,jB,aAij->ai",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")

# %%
# [[F,s2_ext],s1_ext]
print("[[F,s2_ext],s1_ext]")
Fs2s1 = w.commutator(F,s2_ext,s1_ext)
expr = wt.contract(Fs2s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[F,s2_ext],s1_ext]
# fs2s1VVVV += 0.500000000 * np.einsum("Ai,Bj,ijCD->ABCD",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1VVVV += 0.500000000 * np.einsum("iA,jB,CDij->CDAB",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VVoV += 0.500000000 * np.einsum("ji,kA,BCjk->BCiA",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VVoV += 0.500000000 * np.einsum("kj,jA,BCik->BCiA",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VVoV += -1.000000000 * np.einsum("Aa,jB,aCij->ACiB",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1VVoV += 1.000000000 * np.einsum("AD,jB,CDij->ACiB",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VVvV += 1.000000000 * np.einsum("Ai,Bj,ijaC->ABaC",f["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1VVvV += 0.500000000 * np.einsum("ia,jA,BCij->BCaA",f["ov"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VVoo += -0.500000000 * np.einsum("ka,Ak,aBij->ABij",f["ov"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1VVoo += 0.500000000 * np.einsum("kC,Ci,ABjk->ABij",f["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1VVoo += 0.500000000 * np.einsum("kC,Ak,BCij->ABij",f["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1VV += -1.000000000 * np.einsum("ai,Aj,ijaB->AB",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1VV += -1.000000000 * np.einsum("Ai,Cj,ijBC->AB",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1VV += 1.000000000 * np.einsum("Ci,Aj,ijBC->AB",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1VV += -1.000000000 * np.einsum("ia,jA,aBij->BA",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1VV += -1.000000000 * np.einsum("iA,jC,BCij->BA",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1VV += 1.000000000 * np.einsum("iC,jA,BCij->BA",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1Vo += -1.000000000 * np.einsum("ji,kB,ABjk->Ai",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1Vo += -1.000000000 * np.einsum("kj,jB,ABik->Ai",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1Vo += 1.000000000 * np.einsum("Aa,jB,aBij->Ai",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1Vo += -1.000000000 * np.einsum("Ba,jB,aAij->Ai",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1Vo += 1.000000000 * np.einsum("AB,jC,BCij->Ai",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1Vo += 1.000000000 * np.einsum("CB,jC,ABij->Ai",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1Vv += -1.000000000 * np.einsum("Ai,Bj,ijaB->Aa",f["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1Vv += 1.000000000 * np.einsum("Bi,Aj,ijaB->Aa",f["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1Vv += -1.000000000 * np.einsum("ia,jB,ABij->Aa",f["ov"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVVV += 0.500000000 * np.einsum("ij,Ak,jkBC->iABC",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVVV += 0.500000000 * np.einsum("kj,Ak,ijBC->iABC",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVVV += -1.000000000 * np.einsum("aA,Bj,ijaC->iBAC",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVVV += 1.000000000 * np.einsum("DA,Bj,ijCD->iBAC",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVoV += -1.000000000 * np.einsum("ai,Ak,jkaB->jAiB",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVoV += 1.000000000 * np.einsum("Ci,Ak,jkBC->jAiB",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVoV += 1.000000000 * np.einsum("Ak,Ci,jkBC->jAiB",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVoV += -1.000000000 * np.einsum("ia,kA,aBjk->iBjA",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oVoV += 1.000000000 * np.einsum("kA,iC,BCjk->iBjA",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVoV += 1.000000000 * np.einsum("iC,kA,BCjk->iBjA",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVvV += 1.000000000 * np.einsum("ij,Ak,jkaB->iAaB",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVvV += 1.000000000 * np.einsum("kj,Ak,ijaB->iAaB",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVvV += -1.000000000 * np.einsum("ba,Aj,ijbB->iAaB",f["vv"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVvV += 1.000000000 * np.einsum("Ca,Aj,ijBC->iAaB",f["Vv"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oVvV += -1.000000000 * np.einsum("CA,Bj,ijaC->iBaA",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVoo += -1.000000000 * np.einsum("li,jB,ABkl->jAik",f["oo"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVoo += -0.500000000 * np.einsum("Aa,iB,aBjk->iAjk",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oVoo += 0.500000000 * np.einsum("Ba,iB,aAjk->iAjk",f["Vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oVoo += -0.500000000 * np.einsum("AB,iC,BCjk->iAjk",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVoo += -0.500000000 * np.einsum("CB,iC,ABjk->iAjk",f["VV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVov += 1.000000000 * np.einsum("Bi,Ak,jkaB->jAia",f["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVov += 1.000000000 * np.einsum("Ak,Bi,jkaB->jAia",f["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oVov += 1.000000000 * np.einsum("ka,iB,ABjk->iAja",f["ov"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oVvv += 1.000000000 * np.einsum("Ba,Aj,ijbB->iAab",f["Vv"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ooVV += -0.500000000 * np.einsum("ak,kA,ijaB->ijAB",f["vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs2s1ooVV += 0.500000000 * np.einsum("Ck,kA,ijBC->ijAB",f["Vo"],t1["oV"],t2["ooVV"],optimize="optimal")
# fs2s1ooVV += 0.500000000 * np.einsum("Ck,iC,jkAB->ijAB",f["Vo"],t1["oV"],t2["ooVV"],optimize="optimal")
# fs2s1oooV += -1.000000000 * np.einsum("il,Bj,klAB->ikjA",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oooV += -0.500000000 * np.einsum("aA,Bi,jkaB->jkiA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oooV += -0.500000000 * np.einsum("BA,Ci,jkBC->jkiA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oooV += 0.500000000 * np.einsum("aB,Bi,jkaA->jkiA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oooV += -0.500000000 * np.einsum("CB,Bi,jkAC->jkiA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oovV += -0.500000000 * np.einsum("Bk,kA,ijaB->ijaA",f["Vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs2s1oovV += 1.000000000 * np.einsum("Bk,iB,jkaA->ijaA",f["Vo"],t1["oV"],t2["oovV"],optimize="optimal")
# fs2s1oooo += 0.500000000 * np.einsum("ai,Aj,klaA->klij",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oooo += 0.500000000 * np.einsum("Ai,Bj,klAB->klij",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oooo += 0.500000000 * np.einsum("ia,jA,aAkl->ijkl",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oooo += 0.500000000 * np.einsum("iA,jB,ABkl->ijkl",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1ooov += -1.000000000 * np.einsum("il,Aj,klaA->ikja",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ooov += -0.500000000 * np.einsum("ba,Ai,jkbA->jkia",f["vv"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ooov += -0.500000000 * np.einsum("Aa,Bi,jkAB->jkia",f["Vv"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1ooov += -0.500000000 * np.einsum("BA,Ai,jkaB->jkia",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ovoV += 1.000000000 * np.einsum("ak,Bi,jkAB->jaiA",f["vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1ovoV += 1.000000000 * np.einsum("kA,iB,aBjk->iajA",f["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1ovoV += 1.000000000 * np.einsum("iB,kA,aBjk->iajA",f["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1ovoo += -1.000000000 * np.einsum("li,jA,aAkl->jaik",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1ovoo += -0.500000000 * np.einsum("ab,iA,bAjk->iajk",f["vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1ovoo += -0.500000000 * np.einsum("aA,iB,ABjk->iajk",f["vV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1ovoo += -0.500000000 * np.einsum("BA,iB,aAjk->iajk",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1ovov += 1.000000000 * np.einsum("ak,Ai,jkbA->jaib",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ovov += 1.000000000 * np.einsum("ka,iA,bAjk->ibja",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oV += -1.000000000 * np.einsum("ij,Bk,jkAB->iA",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oV += -1.000000000 * np.einsum("kj,Bk,ijAB->iA",f["oo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oV += 1.000000000 * np.einsum("aA,Bj,ijaB->iA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oV += 1.000000000 * np.einsum("BA,Cj,ijBC->iA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oV += -1.000000000 * np.einsum("aB,Bj,ijaA->iA",f["vV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oV += 1.000000000 * np.einsum("CB,Bj,ijAC->iA",f["VV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oo += 1.000000000 * np.einsum("ai,Ak,jkaA->ji",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oo += 1.000000000 * np.einsum("Ai,Bk,jkAB->ji",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oo += -1.000000000 * np.einsum("ak,Ai,jkaA->ji",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1oo += -1.000000000 * np.einsum("Ak,Bi,jkAB->ji",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1oo += 1.000000000 * np.einsum("ia,kA,aAjk->ij",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oo += -1.000000000 * np.einsum("ka,iA,aAjk->ij",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1oo += 1.000000000 * np.einsum("iA,kB,ABjk->ij",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1oo += -1.000000000 * np.einsum("kA,iB,ABjk->ij",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1ov += -1.000000000 * np.einsum("ij,Ak,jkaA->ia",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ov += -1.000000000 * np.einsum("kj,Ak,ijaA->ia",f["oo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ov += 1.000000000 * np.einsum("ba,Aj,ijbA->ia",f["vv"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1ov += 1.000000000 * np.einsum("Aa,Bj,ijAB->ia",f["Vv"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1ov += 1.000000000 * np.einsum("BA,Aj,ijaB->ia",f["VV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1vVVV += 0.500000000 * np.einsum("ai,Aj,ijBC->aABC",f["vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1vVVV += 1.000000000 * np.einsum("iA,jB,aCij->aCAB",f["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVoV += 1.000000000 * np.einsum("ji,kA,aBjk->aBiA",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVoV += 1.000000000 * np.einsum("kj,jA,aBik->aBiA",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVoV += -1.000000000 * np.einsum("ab,jA,bBij->aBiA",f["vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVoV += 1.000000000 * np.einsum("aC,jA,BCij->aBiA",f["vV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1vVoV += -1.000000000 * np.einsum("AC,jB,aCij->aAiB",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVvV += 1.000000000 * np.einsum("ai,Aj,ijbB->aAbB",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1vVvV += 1.000000000 * np.einsum("ia,jA,bBij->bBaA",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vVoo += 1.000000000 * np.einsum("kB,Bi,aAjk->aAij",f["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1vVoo += -0.500000000 * np.einsum("kB,Ak,aBij->aAij",f["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1vvoV += 1.000000000 * np.einsum("aB,jA,bBij->abiA",f["vV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vV += -1.000000000 * np.einsum("ai,Bj,ijAB->aA",f["vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1vV += -1.000000000 * np.einsum("iA,jB,aBij->aA",f["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vV += 1.000000000 * np.einsum("iB,jA,aBij->aA",f["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vo += -1.000000000 * np.einsum("ji,kA,aAjk->ai",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vo += -1.000000000 * np.einsum("kj,jA,aAik->ai",f["oo"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vo += 1.000000000 * np.einsum("ab,jA,bAij->ai",f["vv"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vo += 1.000000000 * np.einsum("aA,jB,ABij->ai",f["vV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1vo += 1.000000000 * np.einsum("BA,jB,aAij->ai",f["VV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1vv += -1.000000000 * np.einsum("ai,Aj,ijbA->ab",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1vv += -1.000000000 * np.einsum("ia,jA,bAij->ba",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1 += 1.000000000 * np.einsum("ai,Aj,ijaA->",f["vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1 += 1.000000000 * np.einsum("Ai,Bj,ijAB->",f["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1 += 1.000000000 * np.einsum("ia,jA,aAij->",f["ov"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1 += 1.000000000 * np.einsum("iA,jB,ABij->",f["oV"],t1["oV"],t2["VVoo"],optimize="optimal")

# %%
# [[F,s2_ext],s2_ext]
print("[[F,s2_ext],s2_ext]")
Fs2s2 = w.commutator(F,s2_ext,s2_ext)
expr = wt.contract(Fs2s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[F,s2_ext],s2_ext]
# fs2s2VVVoVV += -0.250000000 * np.einsum("Aj,jkBC,DEik->ADEiBC",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVVovV += -0.500000000 * np.einsum("Aj,jkaB,CDik->ACDiaB",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVVooo += -0.500000000 * np.einsum("la,ABil,aCjk->ABCijk",f["ov"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2VVVooo += 0.500000000 * np.einsum("lD,ADij,BCkl->ABCijk",f["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2VVVV += -0.500000000 * np.einsum("ji,ikAB,CDjk->CDAB",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVVV += 0.250000000 * np.einsum("Aa,ijBC,aDij->ADBC",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2VVVV += 0.250000000 * np.einsum("aA,ijaB,CDij->CDAB",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVVV += -0.250000000 * np.einsum("EA,ijBE,CDij->CDAB",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVVV += -0.250000000 * np.einsum("AE,ijBC,DEij->ADBC",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVoV += 0.250000000 * np.einsum("ai,jkaA,BCjk->BCiA",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVoV += -0.250000000 * np.einsum("Di,jkAD,BCjk->BCiA",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVoV += -0.500000000 * np.einsum("aj,jkaA,BCik->BCiA",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVoV += 1.000000000 * np.einsum("Aj,jkaB,aCik->ACiB",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VVoV += 1.000000000 * np.einsum("Aj,jkBD,CDik->ACiB",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVoV += 0.500000000 * np.einsum("Dj,jkAD,BCik->BCiA",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvV += -1.000000000 * np.einsum("ji,ikaA,BCjk->BCaA",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvV += 0.250000000 * np.einsum("ba,ijbA,BCij->BCaA",f["vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvV += -0.250000000 * np.einsum("Da,ijAD,BCij->BCaA",f["Vv"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvV += 0.500000000 * np.einsum("Ab,ijaB,bCij->ACaB",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VVvV += 0.250000000 * np.einsum("DA,ijaD,BCij->BCaA",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvV += -0.500000000 * np.einsum("AD,ijaB,CDij->ACaB",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVov += -0.250000000 * np.einsum("Ci,jkaC,ABjk->ABia",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVov += 1.000000000 * np.einsum("Aj,jkaC,BCik->ABia",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVov += 0.500000000 * np.einsum("Cj,jkaC,ABik->ABia",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VVvv += -0.250000000 * np.einsum("Ca,ijbC,ABij->ABab",f["Vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += 2.000000000 * np.einsum("ji,ikaA,aBjk->BA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += 2.000000000 * np.einsum("ji,ikAC,BCjk->BA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += -1.000000000 * np.einsum("ba,ijbA,aBij->BA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("Aa,ijBC,aCij->AB",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += 1.000000000 * np.einsum("Ca,ijAC,aBij->BA",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("aA,ijaC,BCij->BA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("CA,ijaC,aBij->BA",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("CA,ijCD,BDij->BA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += 1.000000000 * np.einsum("aC,ijaA,BCij->BA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("AC,ijaB,aCij->AB",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2VV += -0.500000000 * np.einsum("AC,ijBD,CDij->AB",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2VV += -1.000000000 * np.einsum("DC,ijAD,BCij->BA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2Vo += -0.500000000 * np.einsum("ai,jkaB,ABjk->Ai",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2Vo += -0.500000000 * np.einsum("Bi,jkaB,aAjk->Ai",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vo += -0.500000000 * np.einsum("Bi,jkBC,ACjk->Ai",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2Vo += 1.000000000 * np.einsum("aj,jkaB,ABik->Ai",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2Vo += -1.000000000 * np.einsum("Aj,jkaB,aBik->Ai",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vo += -0.500000000 * np.einsum("Aj,jkBC,BCik->Ai",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2Vo += 1.000000000 * np.einsum("Bj,jkaB,aAik->Ai",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vo += 1.000000000 * np.einsum("Bj,jkBC,ACik->Ai",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2Vv += 2.000000000 * np.einsum("ji,ikaB,ABjk->Aa",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2Vv += -0.500000000 * np.einsum("ba,ijbB,ABij->Aa",f["vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2Vv += -0.500000000 * np.einsum("Ba,ijbB,bAij->Aa",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vv += -0.500000000 * np.einsum("Ba,ijBC,ACij->Aa",f["Vv"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2Vv += -0.500000000 * np.einsum("Ab,ijaB,bBij->Aa",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vv += 1.000000000 * np.einsum("Bb,ijaB,bAij->Aa",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2Vv += -0.500000000 * np.einsum("AB,ijaC,BCij->Aa",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2Vv += -1.000000000 * np.einsum("CB,ijaC,ABij->Aa",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVVVV += -0.250000000 * np.einsum("jA,ikBC,DEjk->iDEABC",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += -0.250000000 * np.einsum("ki,jlAB,CDkl->jCDiAB",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += -0.250000000 * np.einsum("ik,klAB,CDjl->iCDjAB",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += -0.500000000 * np.einsum("lk,ikAB,CDjl->iCDjAB",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += 0.500000000 * np.einsum("Aa,ikBC,aDjk->iADjBC",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVoVV += 0.500000000 * np.einsum("aA,ikaB,CDjk->iCDjAB",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += -0.500000000 * np.einsum("EA,ikBE,CDjk->iCDjAB",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoVV += -0.500000000 * np.einsum("AE,ikBC,DEjk->iADjBC",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVvVV += -0.250000000 * np.einsum("ja,ikAB,CDjk->iCDaAB",f["ov"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVvVV += 0.500000000 * np.einsum("jA,ikaB,CDjk->iCDaAB",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVooV += -0.500000000 * np.einsum("ai,jlaA,BCkl->jBCikA",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVooV += 0.500000000 * np.einsum("Di,jlAD,BCkl->jBCikA",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVooV += 0.500000000 * np.einsum("Al,ilaB,aCjk->iACjkB",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVooV += 0.500000000 * np.einsum("Al,ilBD,CDjk->iACjkB",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += -0.500000000 * np.einsum("ki,jlaA,BCkl->jBCiaA",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += -0.500000000 * np.einsum("ik,klaA,BCjl->iBCjaA",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += -1.000000000 * np.einsum("lk,ikaA,BCjl->iBCjaA",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += 0.500000000 * np.einsum("ba,ikbA,BCjk->iBCjaA",f["vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += -0.500000000 * np.einsum("Da,ikAD,BCjk->iBCjaA",f["Vv"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += 1.000000000 * np.einsum("Ab,ikaB,bCjk->iACjaB",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVovV += 0.500000000 * np.einsum("DA,ikaD,BCjk->iBCjaA",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovV += -1.000000000 * np.einsum("AD,ikaB,CDjk->iACjaB",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVvvV += -0.500000000 * np.einsum("ja,ikbA,BCjk->iBCabA",f["ov"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoov += 0.500000000 * np.einsum("Ci,jlaC,ABkl->jABika",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVoov += 0.500000000 * np.einsum("Al,ilaC,BCjk->iABjka",f["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVovv += -0.500000000 * np.einsum("Ca,ikbC,ABjk->iABjab",f["Vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVV += 0.250000000 * np.einsum("ia,jkAB,aCjk->iCAB",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVV += -0.500000000 * np.einsum("ja,ikAB,aCjk->iCAB",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVV += 1.000000000 * np.einsum("jA,ikaB,aCjk->iCAB",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVVV += 1.000000000 * np.einsum("jA,ikBD,CDjk->iCAB",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVV += -0.250000000 * np.einsum("iD,jkAB,CDjk->iCAB",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVVV += 0.500000000 * np.einsum("jD,ikAB,CDjk->iCAB",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += 1.000000000 * np.einsum("ki,jlaA,aBkl->jBiA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += 1.000000000 * np.einsum("ki,jlAC,BCkl->jBiA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += 1.000000000 * np.einsum("ik,klaA,aBjl->iBjA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += 1.000000000 * np.einsum("ik,klAC,BCjl->iBjA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += 2.000000000 * np.einsum("lk,ikaA,aBjl->iBjA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += 2.000000000 * np.einsum("lk,ikAC,BCjl->iBjA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += -2.000000000 * np.einsum("ba,ikbA,aBjk->iBjA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("Aa,ikBC,aCjk->iAjB",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += 2.000000000 * np.einsum("Ca,ikAC,aBjk->iBjA",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("aA,ikaC,BCjk->iBjA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("CA,ikaC,aBjk->iBjA",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("CA,ikCD,BDjk->iBjA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += 2.000000000 * np.einsum("aC,ikaA,BCjk->iBjA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("AC,ikaB,aCjk->iAjB",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoV += -1.000000000 * np.einsum("AC,ikBD,CDjk->iAjB",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoV += -2.000000000 * np.einsum("DC,ikAD,BCjk->iBjA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVvV += 1.000000000 * np.einsum("ja,ikbA,bBjk->iBaA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVvV += 1.000000000 * np.einsum("ja,ikAC,BCjk->iBaA",f["ov"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVvV += 0.500000000 * np.einsum("ib,jkaA,bBjk->iBaA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVvV += -1.000000000 * np.einsum("jb,ikaA,bBjk->iBaA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVvV += -1.000000000 * np.einsum("jA,ikaC,BCjk->iBaA",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVvV += -0.500000000 * np.einsum("iC,jkaA,BCjk->iBaA",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVvV += 1.000000000 * np.einsum("jC,ikaA,BCjk->iBaA",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoo += 1.000000000 * np.einsum("ai,jlaB,ABkl->jAik",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoo += 1.000000000 * np.einsum("Bi,jlaB,aAkl->jAik",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoo += 1.000000000 * np.einsum("Bi,jlBC,ACkl->jAik",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoo += 0.500000000 * np.einsum("al,ilaB,ABjk->iAjk",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoo += -0.500000000 * np.einsum("Al,ilaB,aBjk->iAjk",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoo += -0.250000000 * np.einsum("Al,ilBC,BCjk->iAjk",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVoo += 0.500000000 * np.einsum("Bl,ilaB,aAjk->iAjk",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVoo += 0.500000000 * np.einsum("Bl,ilBC,ACjk->iAjk",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += 1.000000000 * np.einsum("ki,jlaB,ABkl->jAia",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += 1.000000000 * np.einsum("ik,klaB,ABjl->iAja",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += 2.000000000 * np.einsum("lk,ikaB,ABjl->iAja",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += -1.000000000 * np.einsum("ba,ikbB,ABjk->iAja",f["vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += -1.000000000 * np.einsum("Ba,ikbB,bAjk->iAja",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVov += -1.000000000 * np.einsum("Ba,ikBC,ACjk->iAja",f["Vv"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += -1.000000000 * np.einsum("Ab,ikaB,bBjk->iAja",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVov += 2.000000000 * np.einsum("Bb,ikaB,bAjk->iAja",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oVov += -1.000000000 * np.einsum("AB,ikaC,BCjk->iAja",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVov += -2.000000000 * np.einsum("CB,ikaC,ABjk->iAja",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oVvv += 1.000000000 * np.einsum("ja,ikbB,ABjk->iAab",f["ov"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoVV += -0.500000000 * np.einsum("ia,jlAB,aCkl->ijCkAB",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVoVV += 0.500000000 * np.einsum("lA,ijaB,aCkl->ijCkAB",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVoVV += 0.500000000 * np.einsum("lA,ijBD,CDkl->ijCkAB",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoVV += 0.500000000 * np.einsum("iD,jlAB,CDkl->ijCkAB",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("mi,jkaA,aBlm->jkBilA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("mi,jkAC,BClm->jkBilA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("im,jmaA,aBkl->ijBklA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("im,jmAC,BCkl->ijBklA",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("ba,ijbA,aBkl->ijBklA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("Aa,ijBC,aCkl->ijAklB",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += 0.500000000 * np.einsum("Ca,ijAC,aBkl->ijBklA",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("aA,ijaC,BCkl->ijBklA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("CA,ijaC,aBkl->ijBklA",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("CA,ijCD,BDkl->ijBklA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += 0.500000000 * np.einsum("aC,ijaA,BCkl->ijBklA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("AC,ijaB,aCkl->ijAklB",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooV += -0.250000000 * np.einsum("AC,ijBD,CDkl->ijAklB",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooV += -0.500000000 * np.einsum("DC,ijAD,BCkl->ijBklA",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVovV += 0.500000000 * np.einsum("la,ijbA,bBkl->ijBkaA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVovV += 0.500000000 * np.einsum("la,ijAC,BCkl->ijBkaA",f["ov"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVovV += -1.000000000 * np.einsum("ib,jlaA,bBkl->ijBkaA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVovV += -0.500000000 * np.einsum("lA,ijaC,BCkl->ijBkaA",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVovV += 1.000000000 * np.einsum("iC,jlaA,BCkl->ijBkaA",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooo += -0.250000000 * np.einsum("ai,jkaB,ABlm->jkAilm",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVooo += -0.250000000 * np.einsum("Bi,jkaB,aAlm->jkAilm",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVooo += -0.250000000 * np.einsum("Bi,jkBC,AClm->jkAilm",f["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.500000000 * np.einsum("mi,jkaB,ABlm->jkAila",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.500000000 * np.einsum("im,jmaB,ABkl->ijAkla",f["oo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.250000000 * np.einsum("ba,ijbB,ABkl->ijAkla",f["vv"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.250000000 * np.einsum("Ba,ijbB,bAkl->ijAkla",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVoov += -0.250000000 * np.einsum("Ba,ijBC,ACkl->ijAkla",f["Vv"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.250000000 * np.einsum("Ab,ijaB,bBkl->ijAkla",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVoov += 0.500000000 * np.einsum("Bb,ijaB,bAkl->ijAkla",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooVoov += -0.250000000 * np.einsum("AB,ijaC,BCkl->ijAkla",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVoov += -0.500000000 * np.einsum("CB,ijaC,ABkl->ijAkla",f["VV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooVovv += 0.500000000 * np.einsum("la,ijbB,ABkl->ijAkab",f["ov"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oooVVV += -0.500000000 * np.einsum("al,ilAB,jkaC->ijkABC",f["vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s2oooVVV += 0.500000000 * np.einsum("Dl,ilAB,jkCD->ijkABC",f["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs2s2ooovVV += -1.000000000 * np.einsum("bl,ilaA,jkbB->ijkaAB",f["vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs2s2ooovVV += 0.500000000 * np.einsum("Cl,ilAB,jkaC->ijkaAB",f["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s2ooovVV += -1.000000000 * np.einsum("Cl,ijAC,klaB->ijkaAB",f["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s2oooooV += -0.250000000 * np.einsum("ia,jkAB,aBlm->ijklmA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oooooV += -0.250000000 * np.einsum("iB,jkaA,aBlm->ijklmA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooooV += -0.250000000 * np.einsum("iB,jkAC,BClm->ijklmA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooovvV += -1.000000000 * np.einsum("Bl,ilaA,jkbB->ijkabA",f["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs2s2ooooov += -0.250000000 * np.einsum("ib,jkaA,bAlm->ijklma",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooooov += -0.250000000 * np.einsum("iA,jkaB,ABlm->ijklma",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oovoVV += 0.500000000 * np.einsum("lA,ijBC,aCkl->ijakAB",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoVV += 0.500000000 * np.einsum("iC,jlAB,aCkl->ijakAB",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.500000000 * np.einsum("mi,jkAB,aBlm->jkailA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.500000000 * np.einsum("im,jmAB,aBkl->ijaklA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.250000000 * np.einsum("ab,ijAB,bBkl->ijaklA",f["vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.250000000 * np.einsum("bA,ijbB,aBkl->ijaklA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.250000000 * np.einsum("BA,ijBC,aCkl->ijaklA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.250000000 * np.einsum("aB,ijbA,bBkl->ijaklA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.250000000 * np.einsum("aB,ijAC,BCkl->ijaklA",f["vV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oovooV += 0.500000000 * np.einsum("bB,ijbA,aBkl->ijaklA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooV += -0.500000000 * np.einsum("CB,ijAC,aBkl->ijaklA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovovV += 0.500000000 * np.einsum("la,ijAB,bBkl->ijbkaA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovovV += -0.500000000 * np.einsum("lA,ijaB,bBkl->ijbkaA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovovV += 1.000000000 * np.einsum("iB,jlaA,bBkl->ijbkaA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooo += -0.250000000 * np.einsum("bi,jkbA,aAlm->jkailm",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovooo += -0.250000000 * np.einsum("Ai,jkAB,aBlm->jkailm",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.500000000 * np.einsum("mi,jkaA,bAlm->jkbila",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.500000000 * np.einsum("im,jmaA,bAkl->ijbkla",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.250000000 * np.einsum("ca,ijcA,bAkl->ijbkla",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.250000000 * np.einsum("Aa,ijAB,bBkl->ijbkla",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.250000000 * np.einsum("ac,ijbA,cAkl->ijaklb",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovoov += -0.250000000 * np.einsum("aA,ijbB,ABkl->ijaklb",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oovoov += -0.500000000 * np.einsum("BA,ijaB,bAkl->ijbkla",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oovovv += 0.500000000 * np.einsum("la,ijbA,cAkl->ijckab",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += 1.000000000 * np.einsum("ia,jlAB,aBkl->ijkA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += 0.500000000 * np.einsum("la,ijAB,aBkl->ijkA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += -0.500000000 * np.einsum("lA,ijaB,aBkl->ijkA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += -0.250000000 * np.einsum("lA,ijBC,BCkl->ijkA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oooV += 1.000000000 * np.einsum("iB,jlaA,aBkl->ijkA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += 1.000000000 * np.einsum("iB,jlAC,BCkl->ijkA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oooV += 0.500000000 * np.einsum("lB,ijaA,aBkl->ijkA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooV += 0.500000000 * np.einsum("lB,ijAC,BCkl->ijkA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("mi,jkaA,aAlm->jkil",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooo += 0.250000000 * np.einsum("mi,jkAB,ABlm->jkil",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("im,jmaA,aAkl->ijkl",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooo += 0.250000000 * np.einsum("im,jmAB,ABkl->ijkl",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("ba,ijbA,aAkl->ijkl",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("Aa,ijAB,aBkl->ijkl",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("aA,ijaB,ABkl->ijkl",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("BA,ijaB,aAkl->ijkl",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oooo += 0.500000000 * np.einsum("BA,ijBC,ACkl->ijkl",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooov += -0.500000000 * np.einsum("la,ijbA,bAkl->ijka",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooov += -0.250000000 * np.einsum("la,ijAB,ABkl->ijka",f["ov"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ooov += 1.000000000 * np.einsum("ib,jlaA,bAkl->ijka",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooov += 0.500000000 * np.einsum("lb,ijaA,bAkl->ijka",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ooov += 1.000000000 * np.einsum("iA,jlaB,ABkl->ijka",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ooov += 0.500000000 * np.einsum("lA,ijaB,ABkl->ijka",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ovVVVV += -0.500000000 * np.einsum("jA,ikBC,aDjk->iaDABC",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += -0.500000000 * np.einsum("ki,jlAB,aCkl->jaCiAB",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += -0.500000000 * np.einsum("ik,klAB,aCjl->iaCjAB",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += -1.000000000 * np.einsum("lk,ikAB,aCjl->iaCjAB",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += 0.500000000 * np.einsum("ab,ikAB,bCjk->iaCjAB",f["vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += 1.000000000 * np.einsum("bA,ikbB,aCjk->iaCjAB",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += -1.000000000 * np.einsum("DA,ikBD,aCjk->iaCjAB",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoVV += -0.500000000 * np.einsum("aD,ikAB,CDjk->iaCjAB",f["vV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ovVoVV += 0.500000000 * np.einsum("AD,ikBC,aDjk->iaAjBC",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVvVV += -0.500000000 * np.einsum("ja,ikAB,bCjk->ibCaAB",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVvVV += 1.000000000 * np.einsum("jA,ikaB,bCjk->ibCaAB",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVooV += -1.000000000 * np.einsum("bi,jlbA,aBkl->jaBikA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVooV += 1.000000000 * np.einsum("Ci,jlAC,aBkl->jaBikA",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVooV += 0.500000000 * np.einsum("al,ilbA,bBjk->iaBjkA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVooV += 0.500000000 * np.einsum("al,ilAC,BCjk->iaBjkA",f["vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ovVooV += -0.500000000 * np.einsum("Al,ilBC,aCjk->iaAjkB",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += -1.000000000 * np.einsum("ki,jlaA,bBkl->jbBiaA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += -1.000000000 * np.einsum("ik,klaA,bBjl->ibBjaA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += -2.000000000 * np.einsum("lk,ikaA,bBjl->ibBjaA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += 1.000000000 * np.einsum("ca,ikcA,bBjk->ibBjaA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += -1.000000000 * np.einsum("Ca,ikAC,bBjk->ibBjaA",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += 1.000000000 * np.einsum("ac,ikbA,cBjk->iaBjbA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += 1.000000000 * np.einsum("CA,ikaC,bBjk->ibBjaA",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovV += -1.000000000 * np.einsum("aC,ikbA,BCjk->iaBjbA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ovVovV += 1.000000000 * np.einsum("AC,ikaB,bCjk->ibAjaB",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVvvV += -1.000000000 * np.einsum("ja,ikbA,cBjk->icBabA",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoov += 1.000000000 * np.einsum("Bi,jlaB,bAkl->jbAika",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVoov += 0.500000000 * np.einsum("al,ilbB,ABjk->iaAjkb",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ovVoov += -0.500000000 * np.einsum("Al,ilaB,bBjk->ibAjka",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVovv += -1.000000000 * np.einsum("Ba,ikbB,cAjk->icAjab",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvoVV += -0.500000000 * np.einsum("aC,ikAB,bCjk->iabjAB",f["vV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvooV += 0.500000000 * np.einsum("al,ilAB,bBjk->iabjkA",f["vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvovV += -1.000000000 * np.einsum("aB,ikbA,cBjk->iacjbA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvoov += 0.500000000 * np.einsum("al,ilbA,cAjk->iacjkb",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVV += 1.000000000 * np.einsum("jA,ikBC,aCjk->iaAB",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVV += -0.250000000 * np.einsum("iC,jkAB,aCjk->iaAB",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovVV += 0.500000000 * np.einsum("jC,ikAB,aCjk->iaAB",f["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += 1.000000000 * np.einsum("ki,jlAB,aBkl->jaiA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += 1.000000000 * np.einsum("ik,klAB,aBjl->iajA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += 2.000000000 * np.einsum("lk,ikAB,aBjl->iajA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -1.000000000 * np.einsum("ab,ikAB,bBjk->iajA",f["vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -1.000000000 * np.einsum("bA,ikbB,aBjk->iajA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -1.000000000 * np.einsum("BA,ikBC,aCjk->iajA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -1.000000000 * np.einsum("aB,ikbA,bBjk->iajA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -1.000000000 * np.einsum("aB,ikAC,BCjk->iajA",f["vV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ovoV += 2.000000000 * np.einsum("bB,ikbA,aBjk->iajA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoV += -2.000000000 * np.einsum("CB,ikAC,aBjk->iajA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvV += 1.000000000 * np.einsum("ja,ikAB,bBjk->ibaA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvV += -1.000000000 * np.einsum("jA,ikaB,bBjk->ibaA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvV += -0.500000000 * np.einsum("iB,jkaA,bBjk->ibaA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvV += 1.000000000 * np.einsum("jB,ikaA,bBjk->ibaA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoo += 1.000000000 * np.einsum("bi,jlbA,aAkl->jaik",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoo += 1.000000000 * np.einsum("Ai,jlAB,aBkl->jaik",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoo += -0.500000000 * np.einsum("al,ilbA,bAjk->iajk",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoo += -0.250000000 * np.einsum("al,ilAB,ABjk->iajk",f["vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ovoo += 0.500000000 * np.einsum("bl,ilbA,aAjk->iajk",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovoo += 0.500000000 * np.einsum("Al,ilAB,aBjk->iajk",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += 1.000000000 * np.einsum("ki,jlaA,bAkl->jbia",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += 1.000000000 * np.einsum("ik,klaA,bAjl->ibja",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += 2.000000000 * np.einsum("lk,ikaA,bAjl->ibja",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += -1.000000000 * np.einsum("ca,ikcA,bAjk->ibja",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += -1.000000000 * np.einsum("Aa,ikAB,bBjk->ibja",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += -1.000000000 * np.einsum("ac,ikbA,cAjk->iajb",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovov += -1.000000000 * np.einsum("aA,ikbB,ABjk->iajb",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ovov += -2.000000000 * np.einsum("BA,ikaB,bAjk->ibja",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ovvv += 1.000000000 * np.einsum("ja,ikbA,cAjk->icab",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += -0.500000000 * np.einsum("ia,jkAB,aBjk->iA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += 1.000000000 * np.einsum("ja,ikAB,aBjk->iA",f["ov"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += -1.000000000 * np.einsum("jA,ikaB,aBjk->iA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += -0.500000000 * np.einsum("jA,ikBC,BCjk->iA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oV += -0.500000000 * np.einsum("iB,jkaA,aBjk->iA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += -0.500000000 * np.einsum("iB,jkAC,BCjk->iA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oV += 1.000000000 * np.einsum("jB,ikaA,aBjk->iA",f["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oV += 1.000000000 * np.einsum("jB,ikAC,BCjk->iA",f["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oo += -1.000000000 * np.einsum("ki,jlaA,aAkl->ji",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += -0.500000000 * np.einsum("ki,jlAB,ABkl->ji",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oo += -1.000000000 * np.einsum("ik,klaA,aAjl->ij",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += -0.500000000 * np.einsum("ik,klAB,ABjl->ij",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oo += -2.000000000 * np.einsum("lk,ikaA,aAjl->ij",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += -1.000000000 * np.einsum("lk,ikAB,ABjl->ij",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2oo += 2.000000000 * np.einsum("ba,ikbA,aAjk->ij",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += 2.000000000 * np.einsum("Aa,ikAB,aBjk->ij",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += 2.000000000 * np.einsum("aA,ikaB,ABjk->ij",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2oo += 2.000000000 * np.einsum("BA,ikaB,aAjk->ij",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2oo += 2.000000000 * np.einsum("BA,ikBC,ACjk->ij",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ov += -1.000000000 * np.einsum("ja,ikbA,bAjk->ia",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ov += -0.500000000 * np.einsum("ja,ikAB,ABjk->ia",f["ov"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2ov += -0.500000000 * np.einsum("ib,jkaA,bAjk->ia",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ov += 1.000000000 * np.einsum("jb,ikaA,bAjk->ia",f["ov"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2ov += -0.500000000 * np.einsum("iA,jkaB,ABjk->ia",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2ov += 1.000000000 * np.einsum("jA,ikaB,ABjk->ia",f["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2vVVoVV += -0.250000000 * np.einsum("aj,jkAB,CDik->aCDiAB",f["vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2vVVoVV += 0.500000000 * np.einsum("Aj,jkBC,aDik->aADiBC",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVovV += -0.500000000 * np.einsum("aj,jkbA,BCik->aBCibA",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2vVVovV += 1.000000000 * np.einsum("Aj,jkaB,bCik->bACiaB",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVooo += 1.000000000 * np.einsum("lb,bAij,aBkl->aABijk",f["ov"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2vVVooo += -1.000000000 * np.einsum("lC,ACij,aBkl->aABijk",f["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2vVVooo += 0.500000000 * np.einsum("lC,ABil,aCjk->aABijk",f["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2vVVV += -1.000000000 * np.einsum("ji,ikAB,aCjk->aCAB",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVV += 0.250000000 * np.einsum("ab,ijAB,bCij->aCAB",f["vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVV += 0.500000000 * np.einsum("bA,ijbB,aCij->aCAB",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVV += -0.500000000 * np.einsum("DA,ijBD,aCij->aCAB",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVVV += -0.250000000 * np.einsum("aD,ijAB,CDij->aCAB",f["vV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2vVVV += 0.250000000 * np.einsum("AD,ijBC,aDij->aABC",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += 0.500000000 * np.einsum("bi,jkbA,aBjk->aBiA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += -0.500000000 * np.einsum("Ci,jkAC,aBjk->aBiA",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += 1.000000000 * np.einsum("aj,jkbA,bBik->aBiA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += 1.000000000 * np.einsum("aj,jkAC,BCik->aBiA",f["vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2vVoV += -1.000000000 * np.einsum("bj,jkbA,aBik->aBiA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += -1.000000000 * np.einsum("Aj,jkBC,aCik->aAiB",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVoV += 1.000000000 * np.einsum("Cj,jkAC,aBik->aBiA",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += -2.000000000 * np.einsum("ji,ikaA,bBjk->bBaA",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += 0.500000000 * np.einsum("ca,ijcA,bBij->bBaA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += -0.500000000 * np.einsum("Ca,ijAC,bBij->bBaA",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += 0.500000000 * np.einsum("ac,ijbA,cBij->aBbA",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += 0.500000000 * np.einsum("CA,ijaC,bBij->bBaA",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvV += -0.500000000 * np.einsum("aC,ijbA,BCij->aBbA",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2vVvV += 0.500000000 * np.einsum("AC,ijaB,bCij->bAaB",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVov += -0.500000000 * np.einsum("Bi,jkaB,bAjk->bAia",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVov += 1.000000000 * np.einsum("aj,jkbB,ABik->aAib",f["vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2vVov += -1.000000000 * np.einsum("Aj,jkaB,bBik->bAia",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVov += 1.000000000 * np.einsum("Bj,jkaB,bAik->bAia",f["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vVvv += -0.500000000 * np.einsum("Ba,ijbB,cAij->cAab",f["Vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vvVoVV += -0.500000000 * np.einsum("aj,jkAB,bCik->abCiAB",f["vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vvVovV += -1.000000000 * np.einsum("aj,jkbA,cBik->acBibA",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vvVooo += 1.000000000 * np.einsum("lB,aBij,bAkl->abAijk",f["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2vvVV += -0.250000000 * np.einsum("aC,ijAB,bCij->abAB",f["vV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vvoV += 1.000000000 * np.einsum("aj,jkAB,bBik->abiA",f["vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vvvV += -0.500000000 * np.einsum("aB,ijbA,cBij->acbA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vvov += 1.000000000 * np.einsum("aj,jkbA,cAik->acib",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += 2.000000000 * np.einsum("ji,ikAB,aBjk->aA",f["oo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -0.500000000 * np.einsum("ab,ijAB,bBij->aA",f["vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -0.500000000 * np.einsum("bA,ijbB,aBij->aA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -0.500000000 * np.einsum("BA,ijBC,aCij->aA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -0.500000000 * np.einsum("aB,ijbA,bBij->aA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -0.500000000 * np.einsum("aB,ijAC,BCij->aA",f["vV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2vV += 1.000000000 * np.einsum("bB,ijbA,aBij->aA",f["vV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vV += -1.000000000 * np.einsum("CB,ijAC,aBij->aA",f["VV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vo += -0.500000000 * np.einsum("bi,jkbA,aAjk->ai",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vo += -0.500000000 * np.einsum("Ai,jkAB,aBjk->ai",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vo += -1.000000000 * np.einsum("aj,jkbA,bAik->ai",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vo += -0.500000000 * np.einsum("aj,jkAB,ABik->ai",f["vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2vo += 1.000000000 * np.einsum("bj,jkbA,aAik->ai",f["vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vo += 1.000000000 * np.einsum("Aj,jkAB,aBik->ai",f["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vv += 2.000000000 * np.einsum("ji,ikaA,bAjk->ba",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vv += -0.500000000 * np.einsum("ca,ijcA,bAij->ba",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vv += -0.500000000 * np.einsum("Aa,ijAB,bBij->ba",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2vv += -0.500000000 * np.einsum("ac,ijbA,cAij->ab",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2vv += -0.500000000 * np.einsum("aA,ijbB,ABij->ab",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2vv += -1.000000000 * np.einsum("BA,ijaB,bAij->ba",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2 += -2.000000000 * np.einsum("ji,ikaA,aAjk->",f["oo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2 += -1.000000000 * np.einsum("ji,ikAB,ABjk->",f["oo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2 += 1.000000000 * np.einsum("ba,ijbA,aAij->",f["vv"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2 += 1.000000000 * np.einsum("Aa,ijAB,aBij->",f["Vv"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2 += 1.000000000 * np.einsum("aA,ijaB,ABij->",f["vV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2 += 1.000000000 * np.einsum("BA,ijaB,aAij->",f["VV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2 += 1.000000000 * np.einsum("BA,ijBC,ACij->",f["VV"],t2["ooVV"],t2["VVoo"],optimize="optimal")

# %%
# [[W,s1_ext],s1_ext]
print("[[W,s1_ext],s1_ext]")
Ws1s1 = w.commutator(W,s1_ext,s1_ext)
expr = wt.contract(Ws1s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws1s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[W,s1_ext],s1_ext]
# ws1s1VVVV += 0.500000000 * np.einsum("Ai,Bj,ijCD->ABCD",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1VVVV += 0.500000000 * np.einsum("iA,Ei,CDBE->CDAB",t1["oV"],t1["Vo"],v["VVVV"],optimize="optimal")
# ws1s1VVVV += 2.000000000 * np.einsum("iA,Bj,jDiC->BDAC",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1VVVV += 0.500000000 * np.einsum("iA,jB,CDij->CDAB",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")
# ws1s1VVVV += 0.500000000 * np.einsum("iE,Ai,DEBC->ADBC",t1["oV"],t1["Vo"],v["VVVV"],optimize="optimal")
# ws1s1VVoV += 2.000000000 * np.einsum("Di,Aj,jCBD->ACiB",t1["Vo"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1VVoV += 1.000000000 * np.einsum("Aj,Bk,jkiC->ABiC",t1["Vo"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1VVoV += 1.000000000 * np.einsum("jA,Di,BCjD->BCiA",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1VVoV += -0.500000000 * np.einsum("jA,Dj,BCiD->BCiA",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1VVoV += 2.000000000 * np.einsum("jA,Bk,kCij->BCiA",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1VVoV += -0.500000000 * np.einsum("jD,Di,BCjA->BCiA",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1VVoV += 1.000000000 * np.einsum("jD,Aj,CDiB->ACiB",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1VVvV += 1.000000000 * np.einsum("Ai,Bj,ijaC->ABaC",t1["Vo"],t1["Vo"],v["oovV"],optimize="optimal")
# ws1s1VVvV += -0.500000000 * np.einsum("iA,Di,BCaD->BCaA",t1["oV"],t1["Vo"],v["VVvV"],optimize="optimal")
# ws1s1VVvV += -2.000000000 * np.einsum("iA,Bj,jCia->BCaA",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1VVvV += 1.000000000 * np.einsum("iD,Ai,CDaB->ACaB",t1["oV"],t1["Vo"],v["VVvV"],optimize="optimal")
# ws1s1VVoo += 0.500000000 * np.einsum("Ci,Dj,ABCD->ABij",t1["Vo"],t1["Vo"],v["VVVV"],optimize="optimal")
# ws1s1VVoo += 2.000000000 * np.einsum("Ci,Ak,kBjC->ABij",t1["Vo"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1VVoo += 0.500000000 * np.einsum("Ak,Bl,klij->ABij",t1["Vo"],t1["Vo"],v["oooo"],optimize="optimal")
# ws1s1VVoo += 0.500000000 * np.einsum("kC,Ci,ABjk->ABij",t1["oV"],t1["Vo"],v["VVoo"],optimize="optimal")
# ws1s1VVoo += 0.500000000 * np.einsum("kC,Ak,BCij->ABij",t1["oV"],t1["Vo"],v["VVoo"],optimize="optimal")
# ws1s1VVov += 2.000000000 * np.einsum("Ci,Aj,jBaC->ABia",t1["Vo"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1VVov += 1.000000000 * np.einsum("Aj,Bk,jkia->ABia",t1["Vo"],t1["Vo"],v["ooov"],optimize="optimal")
# ws1s1VVov += -0.500000000 * np.einsum("jC,Ci,ABja->ABia",t1["oV"],t1["Vo"],v["VVov"],optimize="optimal")
# ws1s1VVov += 1.000000000 * np.einsum("jC,Aj,BCia->ABia",t1["oV"],t1["Vo"],v["VVov"],optimize="optimal")
# ws1s1VVvv += 0.500000000 * np.einsum("Ai,Bj,ijab->ABab",t1["Vo"],t1["Vo"],v["oovv"],optimize="optimal")
# ws1s1VVvv += 0.500000000 * np.einsum("iC,Ai,BCab->ABab",t1["oV"],t1["Vo"],v["VVvv"],optimize="optimal")
# ws1s1VV += -2.000000000 * np.einsum("Ai,Cj,ijBC->AB",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1VV += 2.000000000 * np.einsum("iA,Cj,jBiC->BA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1VV += -2.000000000 * np.einsum("iA,jC,BCij->BA",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")
# ws1s1VV += 2.000000000 * np.einsum("iC,Di,BCAD->BA",t1["oV"],t1["Vo"],v["VVVV"],optimize="optimal")
# ws1s1VV += 2.000000000 * np.einsum("iC,Aj,jCiB->AB",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1VV += -2.000000000 * np.einsum("iC,Cj,jBiA->BA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1Vo += -2.000000000 * np.einsum("Bi,Cj,jABC->Ai",t1["Vo"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1Vo += -2.000000000 * np.einsum("Aj,Bk,jkiB->Ai",t1["Vo"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1Vo += -2.000000000 * np.einsum("jB,Ci,ABjC->Ai",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1Vo += 2.000000000 * np.einsum("jB,Cj,ABiC->Ai",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1Vo += -2.000000000 * np.einsum("jB,Ak,kBij->Ai",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1Vo += 2.000000000 * np.einsum("jB,Bk,kAij->Ai",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1Vv += -2.000000000 * np.einsum("Ai,Bj,ijaB->Aa",t1["Vo"],t1["Vo"],v["oovV"],optimize="optimal")
# ws1s1Vv += 2.000000000 * np.einsum("iB,Ci,ABaC->Aa",t1["oV"],t1["Vo"],v["VVvV"],optimize="optimal")
# ws1s1Vv += 2.000000000 * np.einsum("iB,Aj,jBia->Aa",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1Vv += -2.000000000 * np.einsum("iB,Bj,jAia->Aa",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1oVVV += 1.000000000 * np.einsum("jA,Dj,iCBD->iCAB",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oVVV += 2.000000000 * np.einsum("jA,Bk,ikjC->iBAC",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oVVV += 1.000000000 * np.einsum("jA,kB,iCjk->iCAB",t1["oV"],t1["oV"],v["oVoo"],optimize="optimal")
# ws1s1oVVV += 2.000000000 * np.einsum("jA,iD,CDjB->iCAB",t1["oV"],t1["oV"],v["VVoV"],optimize="optimal")
# ws1s1oVVV += 1.000000000 * np.einsum("iD,Aj,jDBC->iABC",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oVVV += -0.500000000 * np.einsum("iD,Dj,jCAB->iCAB",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oVVV += -0.500000000 * np.einsum("jD,Aj,iDBC->iABC",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("Ci,Ak,jkBC->jAiB",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("kA,Ci,jBkC->jBiA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVoV += -1.000000000 * np.einsum("kA,Ck,jBiC->jBiA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("kA,Bl,jlik->jBiA",t1["oV"],t1["Vo"],v["oooo"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("kA,iC,BCjk->iBjA",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("iC,Dj,BCAD->iBjA",t1["oV"],t1["Vo"],v["VVVV"],optimize="optimal")
# ws1s1oVoV += 2.000000000 * np.einsum("iC,Ak,kCjB->iAjB",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVoV += -1.000000000 * np.einsum("iC,Ck,kBjA->iBjA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVoV += -1.000000000 * np.einsum("kC,Ci,jBkA->jBiA",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVoV += -1.000000000 * np.einsum("kC,Ak,jCiB->jAiB",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oVvV += -1.000000000 * np.einsum("jA,Cj,iBaC->iBaA",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1oVvV += -2.000000000 * np.einsum("jA,Bk,ikja->iBaA",t1["oV"],t1["Vo"],v["ooov"],optimize="optimal")
# ws1s1oVvV += -2.000000000 * np.einsum("jA,iC,BCja->iBaA",t1["oV"],t1["oV"],v["VVov"],optimize="optimal")
# ws1s1oVvV += 2.000000000 * np.einsum("iC,Aj,jCaB->iAaB",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1oVvV += -1.000000000 * np.einsum("iC,Cj,jBaA->iBaA",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1oVvV += -1.000000000 * np.einsum("jC,Aj,iCaB->iAaB",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1oVoo += 1.000000000 * np.einsum("Bi,Cj,kABC->kAij",t1["Vo"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oVoo += 2.000000000 * np.einsum("Bi,Al,kljB->kAij",t1["Vo"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oVoo += 2.000000000 * np.einsum("iB,Cj,ABkC->iAjk",t1["oV"],t1["Vo"],v["VVoV"],optimize="optimal")
# ws1s1oVoo += 1.000000000 * np.einsum("iB,Al,lBjk->iAjk",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1oVoo += -0.500000000 * np.einsum("iB,Bl,lAjk->iAjk",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1oVoo += 1.000000000 * np.einsum("lB,Bi,kAjl->kAij",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1oVoo += -0.500000000 * np.einsum("lB,Al,kBij->kAij",t1["oV"],t1["Vo"],v["oVoo"],optimize="optimal")
# ws1s1oVov += 2.000000000 * np.einsum("Bi,Ak,jkaB->jAia",t1["Vo"],t1["Vo"],v["oovV"],optimize="optimal")
# ws1s1oVov += 2.000000000 * np.einsum("iB,Cj,ABaC->iAja",t1["oV"],t1["Vo"],v["VVvV"],optimize="optimal")
# ws1s1oVov += 2.000000000 * np.einsum("iB,Ak,kBja->iAja",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1oVov += -1.000000000 * np.einsum("iB,Bk,kAja->iAja",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1oVov += -1.000000000 * np.einsum("kB,Bi,jAka->jAia",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1oVov += -1.000000000 * np.einsum("kB,Ak,jBia->jAia",t1["oV"],t1["Vo"],v["oVov"],optimize="optimal")
# ws1s1oVvv += 1.000000000 * np.einsum("iB,Aj,jBab->iAab",t1["oV"],t1["Vo"],v["oVvv"],optimize="optimal")
# ws1s1oVvv += -0.500000000 * np.einsum("iB,Bj,jAab->iAab",t1["oV"],t1["Vo"],v["oVvv"],optimize="optimal")
# ws1s1oVvv += -0.500000000 * np.einsum("jB,Aj,iBab->iAab",t1["oV"],t1["Vo"],v["oVvv"],optimize="optimal")
# ws1s1ooVV += 0.500000000 * np.einsum("kA,Ck,ijBC->ijAB",t1["oV"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1ooVV += 0.500000000 * np.einsum("kA,lB,ijkl->ijAB",t1["oV"],t1["oV"],v["oooo"],optimize="optimal")
# ws1s1ooVV += 2.000000000 * np.einsum("kA,iC,jCkB->ijAB",t1["oV"],t1["oV"],v["oVoV"],optimize="optimal")
# ws1s1ooVV += 0.500000000 * np.einsum("iC,Ck,jkAB->ijAB",t1["oV"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1ooVV += 0.500000000 * np.einsum("iC,jD,CDAB->ijAB",t1["oV"],t1["oV"],v["VVVV"],optimize="optimal")
# ws1s1oooV += 1.000000000 * np.einsum("lA,Bi,jklB->jkiA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oooV += -0.500000000 * np.einsum("lA,Bl,jkiB->jkiA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oooV += 2.000000000 * np.einsum("lA,iB,kBjl->ikjA",t1["oV"],t1["oV"],v["oVoo"],optimize="optimal")
# ws1s1oooV += 2.000000000 * np.einsum("iB,Cj,kBAC->ikjA",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oooV += 1.000000000 * np.einsum("iB,Bl,kljA->ikjA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oooV += 1.000000000 * np.einsum("iB,jC,BCkA->ijkA",t1["oV"],t1["oV"],v["VVoV"],optimize="optimal")
# ws1s1oooV += -0.500000000 * np.einsum("lB,Bi,jklA->jkiA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oovV += -0.500000000 * np.einsum("kA,Bk,ijaB->ijaA",t1["oV"],t1["Vo"],v["oovV"],optimize="optimal")
# ws1s1oovV += -2.000000000 * np.einsum("kA,iB,jBka->ijaA",t1["oV"],t1["oV"],v["oVov"],optimize="optimal")
# ws1s1oovV += 1.000000000 * np.einsum("iB,Bk,jkaA->ijaA",t1["oV"],t1["Vo"],v["oovV"],optimize="optimal")
# ws1s1oovV += 1.000000000 * np.einsum("iB,jC,BCaA->ijaA",t1["oV"],t1["oV"],v["VVvV"],optimize="optimal")
# ws1s1oooo += 0.500000000 * np.einsum("Ai,Bj,klAB->klij",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1oooo += 2.000000000 * np.einsum("iA,Bj,lAkB->iljk",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oooo += 0.500000000 * np.einsum("iA,Am,lmjk->iljk",t1["oV"],t1["Vo"],v["oooo"],optimize="optimal")
# ws1s1oooo += 0.500000000 * np.einsum("iA,jB,ABkl->ijkl",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")
# ws1s1oooo += 0.500000000 * np.einsum("mA,Ai,kljm->klij",t1["oV"],t1["Vo"],v["oooo"],optimize="optimal")
# ws1s1ooov += 2.000000000 * np.einsum("iA,Bj,kAaB->ikja",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1ooov += 1.000000000 * np.einsum("iA,Al,klja->ikja",t1["oV"],t1["Vo"],v["ooov"],optimize="optimal")
# ws1s1ooov += 1.000000000 * np.einsum("iA,jB,ABka->ijka",t1["oV"],t1["oV"],v["VVov"],optimize="optimal")
# ws1s1ooov += -0.500000000 * np.einsum("lA,Ai,jkla->jkia",t1["oV"],t1["Vo"],v["ooov"],optimize="optimal")
# ws1s1oovv += 0.500000000 * np.einsum("iA,Ak,jkab->ijab",t1["oV"],t1["Vo"],v["oovv"],optimize="optimal")
# ws1s1oovv += 0.500000000 * np.einsum("iA,jB,ABab->ijab",t1["oV"],t1["oV"],v["VVvv"],optimize="optimal")
# ws1s1ovVV += 1.000000000 * np.einsum("jA,Cj,iaBC->iaAB",t1["oV"],t1["Vo"],v["ovVV"],optimize="optimal")
# ws1s1ovVV += 1.000000000 * np.einsum("jA,kB,iajk->iaAB",t1["oV"],t1["oV"],v["ovoo"],optimize="optimal")
# ws1s1ovVV += 2.000000000 * np.einsum("jA,iC,aCjB->iaAB",t1["oV"],t1["oV"],v["vVoV"],optimize="optimal")
# ws1s1ovVV += -0.500000000 * np.einsum("iC,Cj,jaAB->iaAB",t1["oV"],t1["Vo"],v["ovVV"],optimize="optimal")
# ws1s1ovoV += 2.000000000 * np.einsum("kA,Bi,jakB->jaiA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1ovoV += -1.000000000 * np.einsum("kA,Bk,jaiB->jaiA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1ovoV += 2.000000000 * np.einsum("kA,iB,aBjk->iajA",t1["oV"],t1["oV"],v["vVoo"],optimize="optimal")
# ws1s1ovoV += 2.000000000 * np.einsum("iB,Cj,aBAC->iajA",t1["oV"],t1["Vo"],v["vVVV"],optimize="optimal")
# ws1s1ovoV += -1.000000000 * np.einsum("iB,Bk,kajA->iajA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1ovoV += -1.000000000 * np.einsum("kB,Bi,jakA->jaiA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1ovvV += -1.000000000 * np.einsum("jA,Bj,ibaB->ibaA",t1["oV"],t1["Vo"],v["ovvV"],optimize="optimal")
# ws1s1ovvV += -2.000000000 * np.einsum("jA,iB,bBja->ibaA",t1["oV"],t1["oV"],v["vVov"],optimize="optimal")
# ws1s1ovvV += -1.000000000 * np.einsum("iB,Bj,jbaA->ibaA",t1["oV"],t1["Vo"],v["ovvV"],optimize="optimal")
# ws1s1ovoo += 1.000000000 * np.einsum("Ai,Bj,kaAB->kaij",t1["Vo"],t1["Vo"],v["ovVV"],optimize="optimal")
# ws1s1ovoo += 2.000000000 * np.einsum("iA,Bj,aAkB->iajk",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1ovoo += -0.500000000 * np.einsum("iA,Al,lajk->iajk",t1["oV"],t1["Vo"],v["ovoo"],optimize="optimal")
# ws1s1ovoo += 1.000000000 * np.einsum("lA,Ai,kajl->kaij",t1["oV"],t1["Vo"],v["ovoo"],optimize="optimal")
# ws1s1ovov += 2.000000000 * np.einsum("iA,Bj,bAaB->ibja",t1["oV"],t1["Vo"],v["vVvV"],optimize="optimal")
# ws1s1ovov += -1.000000000 * np.einsum("iA,Ak,kbja->ibja",t1["oV"],t1["Vo"],v["ovov"],optimize="optimal")
# ws1s1ovov += -1.000000000 * np.einsum("kA,Ai,jbka->jbia",t1["oV"],t1["Vo"],v["ovov"],optimize="optimal")
# ws1s1ovvv += -0.500000000 * np.einsum("iA,Aj,jcab->icab",t1["oV"],t1["Vo"],v["ovvv"],optimize="optimal")
# ws1s1oV += -2.000000000 * np.einsum("jA,Bk,ikjB->iA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oV += -2.000000000 * np.einsum("jA,kB,iBjk->iA",t1["oV"],t1["oV"],v["oVoo"],optimize="optimal")
# ws1s1oV += -2.000000000 * np.einsum("iB,Cj,jBAC->iA",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oV += -2.000000000 * np.einsum("iB,jC,BCjA->iA",t1["oV"],t1["oV"],v["VVoV"],optimize="optimal")
# ws1s1oV += 2.000000000 * np.einsum("jB,Cj,iBAC->iA",t1["oV"],t1["Vo"],v["oVVV"],optimize="optimal")
# ws1s1oV += 2.000000000 * np.einsum("jB,Bk,ikjA->iA",t1["oV"],t1["Vo"],v["oooV"],optimize="optimal")
# ws1s1oo += 2.000000000 * np.einsum("Ai,Bk,jkAB->ji",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1oo += -2.000000000 * np.einsum("iA,Bk,kAjB->ij",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oo += 2.000000000 * np.einsum("iA,kB,ABjk->ij",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")
# ws1s1oo += -2.000000000 * np.einsum("kA,Bi,jAkB->ji",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oo += 2.000000000 * np.einsum("kA,Bk,jAiB->ji",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1oo += -2.000000000 * np.einsum("kA,Al,jlik->ji",t1["oV"],t1["Vo"],v["oooo"],optimize="optimal")
# ws1s1ov += -2.000000000 * np.einsum("iA,Bj,jAaB->ia",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1ov += -2.000000000 * np.einsum("iA,jB,ABja->ia",t1["oV"],t1["oV"],v["VVov"],optimize="optimal")
# ws1s1ov += 2.000000000 * np.einsum("jA,Bj,iAaB->ia",t1["oV"],t1["Vo"],v["oVvV"],optimize="optimal")
# ws1s1ov += 2.000000000 * np.einsum("jA,Ak,ikja->ia",t1["oV"],t1["Vo"],v["ooov"],optimize="optimal")
# ws1s1vVVV += 1.000000000 * np.einsum("iA,Di,aCBD->aCAB",t1["oV"],t1["Vo"],v["vVVV"],optimize="optimal")
# ws1s1vVVV += -2.000000000 * np.einsum("iA,Bj,jaiC->aBAC",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1vVVV += 1.000000000 * np.einsum("iA,jB,aCij->aCAB",t1["oV"],t1["oV"],v["vVoo"],optimize="optimal")
# ws1s1vVVV += -0.500000000 * np.einsum("iD,Ai,aDBC->aABC",t1["oV"],t1["Vo"],v["vVVV"],optimize="optimal")
# ws1s1vVoV += -2.000000000 * np.einsum("Ci,Aj,jaBC->aAiB",t1["Vo"],t1["Vo"],v["ovVV"],optimize="optimal")
# ws1s1vVoV += 2.000000000 * np.einsum("jA,Ci,aBjC->aBiA",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vVoV += -1.000000000 * np.einsum("jA,Cj,aBiC->aBiA",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vVoV += -2.000000000 * np.einsum("jA,Bk,kaij->aBiA",t1["oV"],t1["Vo"],v["ovoo"],optimize="optimal")
# ws1s1vVoV += -1.000000000 * np.einsum("jC,Ci,aBjA->aBiA",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vVoV += -1.000000000 * np.einsum("jC,Aj,aCiB->aAiB",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vVvV += -1.000000000 * np.einsum("iA,Ci,bBaC->bBaA",t1["oV"],t1["Vo"],v["vVvV"],optimize="optimal")
# ws1s1vVvV += 2.000000000 * np.einsum("iA,Bj,jbia->bBaA",t1["oV"],t1["Vo"],v["ovov"],optimize="optimal")
# ws1s1vVvV += -1.000000000 * np.einsum("iC,Ai,bCaB->bAaB",t1["oV"],t1["Vo"],v["vVvV"],optimize="optimal")
# ws1s1vVoo += 1.000000000 * np.einsum("Bi,Cj,aABC->aAij",t1["Vo"],t1["Vo"],v["vVVV"],optimize="optimal")
# ws1s1vVoo += -2.000000000 * np.einsum("Bi,Ak,kajB->aAij",t1["Vo"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1vVoo += 1.000000000 * np.einsum("kB,Bi,aAjk->aAij",t1["oV"],t1["Vo"],v["vVoo"],optimize="optimal")
# ws1s1vVoo += -0.500000000 * np.einsum("kB,Ak,aBij->aAij",t1["oV"],t1["Vo"],v["vVoo"],optimize="optimal")
# ws1s1vVov += -2.000000000 * np.einsum("Bi,Aj,jbaB->bAia",t1["Vo"],t1["Vo"],v["ovvV"],optimize="optimal")
# ws1s1vVov += -1.000000000 * np.einsum("jB,Bi,bAja->bAia",t1["oV"],t1["Vo"],v["vVov"],optimize="optimal")
# ws1s1vVov += -1.000000000 * np.einsum("jB,Aj,bBia->bAia",t1["oV"],t1["Vo"],v["vVov"],optimize="optimal")
# ws1s1vVvv += -0.500000000 * np.einsum("iB,Ai,cBab->cAab",t1["oV"],t1["Vo"],v["vVvv"],optimize="optimal")
# ws1s1vvVV += 0.500000000 * np.einsum("iA,Ci,abBC->abAB",t1["oV"],t1["Vo"],v["vvVV"],optimize="optimal")
# ws1s1vvVV += 0.500000000 * np.einsum("iA,jB,abij->abAB",t1["oV"],t1["oV"],v["vvoo"],optimize="optimal")
# ws1s1vvoV += 1.000000000 * np.einsum("jA,Bi,abjB->abiA",t1["oV"],t1["Vo"],v["vvoV"],optimize="optimal")
# ws1s1vvoV += -0.500000000 * np.einsum("jA,Bj,abiB->abiA",t1["oV"],t1["Vo"],v["vvoV"],optimize="optimal")
# ws1s1vvoV += -0.500000000 * np.einsum("jB,Bi,abjA->abiA",t1["oV"],t1["Vo"],v["vvoV"],optimize="optimal")
# ws1s1vvvV += -0.500000000 * np.einsum("iA,Bi,bcaB->bcaA",t1["oV"],t1["Vo"],v["vvvV"],optimize="optimal")
# ws1s1vvoo += 0.500000000 * np.einsum("Ai,Bj,abAB->abij",t1["Vo"],t1["Vo"],v["vvVV"],optimize="optimal")
# ws1s1vvoo += 0.500000000 * np.einsum("kA,Ai,abjk->abij",t1["oV"],t1["Vo"],v["vvoo"],optimize="optimal")
# ws1s1vvov += -0.500000000 * np.einsum("jA,Ai,bcja->bcia",t1["oV"],t1["Vo"],v["vvov"],optimize="optimal")
# ws1s1vV += 2.000000000 * np.einsum("iA,Bj,jaiB->aA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1vV += -2.000000000 * np.einsum("iA,jB,aBij->aA",t1["oV"],t1["oV"],v["vVoo"],optimize="optimal")
# ws1s1vV += 2.000000000 * np.einsum("iB,Ci,aBAC->aA",t1["oV"],t1["Vo"],v["vVVV"],optimize="optimal")
# ws1s1vV += -2.000000000 * np.einsum("iB,Bj,jaiA->aA",t1["oV"],t1["Vo"],v["ovoV"],optimize="optimal")
# ws1s1vo += -2.000000000 * np.einsum("Ai,Bj,jaAB->ai",t1["Vo"],t1["Vo"],v["ovVV"],optimize="optimal")
# ws1s1vo += -2.000000000 * np.einsum("jA,Bi,aAjB->ai",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vo += 2.000000000 * np.einsum("jA,Bj,aAiB->ai",t1["oV"],t1["Vo"],v["vVoV"],optimize="optimal")
# ws1s1vo += 2.000000000 * np.einsum("jA,Ak,kaij->ai",t1["oV"],t1["Vo"],v["ovoo"],optimize="optimal")
# ws1s1vv += 2.000000000 * np.einsum("iA,Bi,bAaB->ba",t1["oV"],t1["Vo"],v["vVvV"],optimize="optimal")
# ws1s1vv += -2.000000000 * np.einsum("iA,Aj,jbia->ba",t1["oV"],t1["Vo"],v["ovov"],optimize="optimal")
# ws1s1 += 1.000000000 * np.einsum("Ai,Bj,ijAB->",t1["Vo"],t1["Vo"],v["ooVV"],optimize="optimal")
# ws1s1 += -2.000000000 * np.einsum("iA,Bj,jAiB->",t1["oV"],t1["Vo"],v["oVoV"],optimize="optimal")
# ws1s1 += 1.000000000 * np.einsum("iA,jB,ABij->",t1["oV"],t1["oV"],v["VVoo"],optimize="optimal")

# %%
# [[W,s1_ext],s2_ext]
print("[[W,s1_ext],s2_ext]")
Ws1s2 = w.commutator(W,s1_ext,s2_ext)
expr = wt.contract(Ws1s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws1s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[W,s1_ext],s2_ext]
# ws1s2VVVoVV += -0.250000000 * np.einsum("Aj,BCik,jkDE->ABCiDE",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2VVVoVV += 0.500000000 * np.einsum("jA,BCik,kEjD->BCEiAD",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVVoVV += 0.250000000 * np.einsum("jG,ABij,EGCD->ABEiCD",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2VVVooV += -0.500000000 * np.einsum("Ei,ABjk,kDCE->ABDijC",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVVooV += -0.500000000 * np.einsum("Ak,aBij,kDaC->ABDijC",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVVooV += -0.500000000 * np.einsum("Ak,BEij,kDCE->ABDijC",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVVooV += -0.500000000 * np.einsum("Ak,BCil,kljD->ABCijD",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VVVooV += -0.250000000 * np.einsum("kA,aBij,CDka->BCDijA",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2VVVooV += 0.250000000 * np.einsum("kA,BEij,CDkE->BCDijA",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVVooV += 0.500000000 * np.einsum("kA,BCil,lDjk->BCDijA",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2VVVooV += -0.250000000 * np.einsum("kE,AEij,CDkB->ACDijB",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVVooV += 0.500000000 * np.einsum("kE,ABik,DEjC->ABDijC",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVVovV += -0.500000000 * np.einsum("Aj,BCik,jkaD->ABCiaD",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2VVVovV += -0.500000000 * np.einsum("jA,BCik,kDja->BCDiaA",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2VVVovV += 0.500000000 * np.einsum("jE,ABij,DEaC->ABDiaC",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws1s2VVVooo += -0.250000000 * np.einsum("Di,aAjk,BCaD->ABCijk",t1["Vo"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2VVVooo += -0.250000000 * np.einsum("Di,AEjk,BCDE->ABCijk",t1["Vo"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2VVVooo += -0.500000000 * np.einsum("Di,ABjl,lCkD->ABCijk",t1["Vo"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVVooo += 0.500000000 * np.einsum("Al,aBij,lCka->ABCijk",t1["Vo"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2VVVooo += -0.500000000 * np.einsum("Al,BDij,lCkD->ABCijk",t1["Vo"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVVooo += -0.250000000 * np.einsum("Al,BCim,lmjk->ABCijk",t1["Vo"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2VVVooo += 0.250000000 * np.einsum("lD,ADij,BCkl->ABCijk",t1["oV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws1s2VVVooo += 0.250000000 * np.einsum("lD,ABil,CDjk->ABCijk",t1["oV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws1s2VVVoov += -0.500000000 * np.einsum("Di,ABjk,kCaD->ABCija",t1["Vo"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVVoov += 0.500000000 * np.einsum("Ak,bBij,kCab->ABCija",t1["Vo"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2VVVoov += -0.500000000 * np.einsum("Ak,BDij,kCaD->ABCija",t1["Vo"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVVoov += -0.500000000 * np.einsum("Ak,BCil,klja->ABCija",t1["Vo"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2VVVoov += -0.250000000 * np.einsum("kD,ADij,BCka->ABCija",t1["oV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws1s2VVVoov += 0.500000000 * np.einsum("kD,ABik,CDja->ABCija",t1["oV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws1s2VVVovv += -0.250000000 * np.einsum("Aj,BCik,jkab->ABCiab",t1["Vo"],t2["VVoo"],v["oovv"],optimize="optimal")
# ws1s2VVVovv += 0.250000000 * np.einsum("jD,ABij,CDab->ABCiab",t1["oV"],t2["VVoo"],v["VVvv"],optimize="optimal")
# ws1s2VVVV += -0.250000000 * np.einsum("Ai,jkBC,iDjk->ADBC",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2VVVV += -0.250000000 * np.einsum("Ei,ijAB,CDjE->CDAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2VVVV += -0.250000000 * np.einsum("iA,BCjk,jkiD->BCAD",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VVVV += -0.250000000 * np.einsum("iE,ABij,jECD->ABCD",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVoV += -0.250000000 * np.einsum("Di,ABjk,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2VVoV += 1.000000000 * np.einsum("Aj,aBik,jkaC->ABiC",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2VVoV += 1.000000000 * np.einsum("Aj,BDik,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2VVoV += 0.500000000 * np.einsum("Dj,ABik,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2VVoV += -1.000000000 * np.einsum("jA,aBik,kCja->BCiA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2VVoV += 1.000000000 * np.einsum("jA,BDik,kCjD->BCiA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVoV += -0.250000000 * np.einsum("jA,BCkl,klij->BCiA",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2VVoV += 1.000000000 * np.einsum("jD,aAij,CDaB->ACiB",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2VVoV += 1.000000000 * np.einsum("jD,AEij,CDBE->ACiB",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2VVoV += 0.500000000 * np.einsum("jD,ABik,kDjC->ABiC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVoV += -1.000000000 * np.einsum("jD,ADik,kCjB->ACiB",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVoV += -0.500000000 * np.einsum("jD,ABjk,kDiC->ABiC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2VVvV += -0.500000000 * np.einsum("Ai,jkaB,iCjk->ACaB",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2VVvV += -0.500000000 * np.einsum("Di,ijaA,BCjD->BCaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2VVvV += 0.250000000 * np.einsum("iA,BCjk,jkia->BCaA",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2VVvV += -0.500000000 * np.einsum("iD,ABij,jDaC->ABaC",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVoo += 1.000000000 * np.einsum("Ci,aAjk,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVoo += 1.000000000 * np.einsum("Ci,ADjk,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVoo += -0.250000000 * np.einsum("Ci,ABkl,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VVoo += -0.500000000 * np.einsum("Ak,aCij,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVoo += -0.250000000 * np.einsum("Ak,CDij,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVoo += -1.000000000 * np.einsum("Ak,aBil,klja->ABij",t1["Vo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2VVoo += 1.000000000 * np.einsum("Ak,BCil,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VVoo += 0.500000000 * np.einsum("Ck,aAij,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2VVoo += 0.500000000 * np.einsum("Ck,ADij,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VVoo += 0.500000000 * np.einsum("Ck,ABil,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VVoo += 0.500000000 * np.einsum("kC,aAij,BCka->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2VVoo += 0.250000000 * np.einsum("kC,aCij,ABka->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2VVoo += -0.500000000 * np.einsum("kC,ADij,BCkD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVoo += -0.250000000 * np.einsum("kC,CDij,ABkD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVoo += -1.000000000 * np.einsum("kC,aAik,BCja->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2VVoo += 1.000000000 * np.einsum("kC,ADik,BCjD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2VVoo += -0.500000000 * np.einsum("kC,ABil,lCjk->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2VVoo += 1.000000000 * np.einsum("kC,ACil,lBjk->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2VVoo += -0.250000000 * np.einsum("kC,ABkl,lCij->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2VVov += -0.250000000 * np.einsum("Ci,ABjk,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2VVov += -1.000000000 * np.einsum("Aj,bBik,jkab->ABia",t1["Vo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws1s2VVov += 1.000000000 * np.einsum("Aj,BCik,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2VVov += 0.500000000 * np.einsum("Cj,ABik,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2VVov += -1.000000000 * np.einsum("jC,bAij,BCab->ABia",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws1s2VVov += 1.000000000 * np.einsum("jC,ADij,BCaD->ABia",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws1s2VVov += 0.500000000 * np.einsum("jC,ABik,kCja->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2VVov += -1.000000000 * np.einsum("jC,ACik,kBja->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2VVov += -0.500000000 * np.einsum("jC,ABjk,kCia->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2VVvv += -0.250000000 * np.einsum("iC,ABij,jCab->ABab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws1s2VV += -0.500000000 * np.einsum("Ai,jkaB,iajk->AB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2VV += 0.500000000 * np.einsum("Ai,jkBC,iCjk->AB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2VV += 1.000000000 * np.einsum("Ci,ijaA,aBjC->BA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2VV += -0.500000000 * np.einsum("Ci,jkAC,iBjk->BA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2VV += 1.000000000 * np.einsum("Ci,ijAD,BDjC->BA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2VV += -0.500000000 * np.einsum("iA,aBjk,jkia->BA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2VV += 0.500000000 * np.einsum("iA,BCjk,jkiC->BA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2VV += 1.000000000 * np.einsum("iC,aAij,jCaB->AB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2VV += 1.000000000 * np.einsum("iC,ADij,jCBD->AB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2VV += -0.500000000 * np.einsum("iC,ACjk,jkiB->AB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2Vo += -0.500000000 * np.einsum("Bi,aAjk,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2Vo += -0.500000000 * np.einsum("Bi,ACjk,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2Vo += -1.000000000 * np.einsum("Aj,aBik,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2Vo += -0.500000000 * np.einsum("Aj,BCik,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("Bj,aAik,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("Bj,ACik,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("jB,aCij,ABaC->Ai",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2Vo += 0.500000000 * np.einsum("jB,CDij,ABCD->Ai",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("jB,aAik,kBja->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2Vo += -1.000000000 * np.einsum("jB,aBik,kAja->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2Vo += -1.000000000 * np.einsum("jB,ACik,kBjC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("jB,BCik,kAjC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2Vo += -1.000000000 * np.einsum("jB,aAjk,kBia->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2Vo += 1.000000000 * np.einsum("jB,ACjk,kBiC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2Vo += 0.500000000 * np.einsum("jB,ABkl,klij->Ai",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2Vv += 0.500000000 * np.einsum("Ai,jkaB,iBjk->Aa",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2Vv += -0.500000000 * np.einsum("Bi,jkaB,iAjk->Aa",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2Vv += 1.000000000 * np.einsum("Bi,ijaC,ACjB->Aa",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2Vv += -1.000000000 * np.einsum("iB,bAij,jBab->Aa",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2Vv += 1.000000000 * np.einsum("iB,ACij,jBaC->Aa",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2Vv += -0.500000000 * np.einsum("iB,ABjk,jkia->Aa",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2oVVVVV += 0.500000000 * np.einsum("Aj,ikBC,jEkD->iAEBCD",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oVVVVV += 0.250000000 * np.einsum("Gj,ijAB,DECG->iDEABC",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws1s2oVVVVV += -0.250000000 * np.einsum("jA,ikBC,DEjk->iDEABC",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2oVVoVV += -0.250000000 * np.einsum("Ei,jkAB,CDkE->jCDiAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2oVVoVV += -0.500000000 * np.einsum("Ak,ilBC,kDjl->iADjBC",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2oVVoVV += 0.250000000 * np.einsum("Ek,ikAB,CDjE->iCDjAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2oVVoVV += -0.500000000 * np.einsum("kA,BCil,jlkD->jBCiAD",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2oVVoVV += -0.250000000 * np.einsum("iE,ABjk,kECD->iABjCD",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2oVVoVV += 0.250000000 * np.einsum("kE,ABik,jECD->jABiCD",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2oVVvVV += 1.000000000 * np.einsum("Aj,ikaB,jDkC->iADaBC",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2oVVvVV += 0.500000000 * np.einsum("Aj,ikBC,jDka->iADaBC",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2oVVvVV += 0.500000000 * np.einsum("Ej,ijaA,CDBE->iCDaAB",t1["Vo"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws1s2oVVvVV += 0.250000000 * np.einsum("Ej,ijAB,CDaE->iCDaAB",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws1s2oVVvVV += 0.500000000 * np.einsum("jA,ikaB,CDjk->iCDaAB",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("Di,ABjl,klCD->kABijC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("Al,aBij,klaC->kABijC",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("Al,BDij,klCD->kABijC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("lA,aBij,kCla->kBCijA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2oVVooV += -0.500000000 * np.einsum("lA,BDij,kClD->kBCijA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVVooV += -0.500000000 * np.einsum("lA,BCim,kmjl->kBCijA",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2oVVooV += -0.500000000 * np.einsum("iD,aAjk,CDaB->iACjkB",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2oVVooV += -0.500000000 * np.einsum("iD,AEjk,CDBE->iACjkB",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2oVVooV += -0.500000000 * np.einsum("iD,ABjl,lDkC->iABjkC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("lD,ADij,kClB->kACijB",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVVooV += 0.500000000 * np.einsum("lD,ABil,kDjC->kABijC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVVovV += -0.500000000 * np.einsum("Di,jkaA,BCkD->jBCiaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2oVVovV += -1.000000000 * np.einsum("Ak,ilaB,kCjl->iACjaB",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2oVVovV += 0.500000000 * np.einsum("Dk,ikaA,BCjD->iBCjaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2oVVovV += 0.500000000 * np.einsum("kA,BCil,jlka->jBCiaA",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2oVVovV += -0.500000000 * np.einsum("iD,ABjk,kDaC->iABjaC",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVVovV += 0.500000000 * np.einsum("kD,ABik,jDaC->jABiaC",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVVvvV += -1.000000000 * np.einsum("Aj,ikaB,jCkb->iACabB",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2oVVvvV += -0.500000000 * np.einsum("Dj,ijaA,BCbD->iBCabA",t1["Vo"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws1s2oVVooo += 0.500000000 * np.einsum("Ci,aAjk,lBaC->lABijk",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVVooo += 0.500000000 * np.einsum("Ci,ADjk,lBCD->lABijk",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2oVVooo += 0.500000000 * np.einsum("Ci,ABjm,lmkC->lABijk",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2oVVooo += -0.500000000 * np.einsum("Am,aBij,lmka->lABijk",t1["Vo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2oVVooo += 0.500000000 * np.einsum("Am,BCij,lmkC->lABijk",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2oVVooo += 0.500000000 * np.einsum("iC,aAjk,BCla->iABjkl",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2oVVooo += -0.500000000 * np.einsum("iC,ADjk,BClD->iABjkl",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws1s2oVVooo += -0.250000000 * np.einsum("iC,ABjm,mCkl->iABjkl",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2oVVooo += -0.500000000 * np.einsum("mC,ACij,lBkm->lABijk",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2oVVooo += 0.250000000 * np.einsum("mC,ABim,lCjk->lABijk",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws1s2oVVoov += 0.500000000 * np.einsum("Ci,ABjl,klaC->kABija",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2oVVoov += -0.500000000 * np.einsum("Al,bBij,klab->kABija",t1["Vo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws1s2oVVoov += 0.500000000 * np.einsum("Al,BCij,klaC->kABija",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws1s2oVVoov += 0.500000000 * np.einsum("iC,bAjk,BCab->iABjka",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws1s2oVVoov += -0.500000000 * np.einsum("iC,ADjk,BCaD->iABjka",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws1s2oVVoov += -0.500000000 * np.einsum("iC,ABjl,lCka->iABjka",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2oVVoov += 0.500000000 * np.einsum("lC,ACij,kBla->kABija",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2oVVoov += 0.500000000 * np.einsum("lC,ABil,kCja->kABija",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws1s2oVVovv += -0.250000000 * np.einsum("iC,ABjk,kCab->iABjab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws1s2oVVovv += 0.250000000 * np.einsum("kC,ABik,jCab->jABiab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws1s2oVVV += -1.000000000 * np.einsum("Aj,ikaB,jakC->iABC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oVVV += -0.250000000 * np.einsum("Aj,klBC,ijkl->iABC",t1["Vo"],t2["ooVV"],v["oooo"],optimize="optimal")
# ws1s2oVVV += 1.000000000 * np.einsum("Aj,ikBD,jDkC->iABC",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oVVV += 1.000000000 * np.einsum("Dj,ijaA,aCBD->iCAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws1s2oVVV += 0.500000000 * np.einsum("Dj,ikAB,jCkD->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oVVV += -0.500000000 * np.einsum("Dj,jkAB,iCkD->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oVVV += -1.000000000 * np.einsum("Dj,ikAD,jCkB->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oVVV += 1.000000000 * np.einsum("Dj,ijAE,CEBD->iCAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws1s2oVVV += 1.000000000 * np.einsum("jA,ikaB,aCjk->iCAB",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws1s2oVVV += 1.000000000 * np.einsum("jA,ikBD,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2oVVV += -0.250000000 * np.einsum("iD,jkAB,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2oVVV += 0.500000000 * np.einsum("jD,ikAB,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("Ci,jkaA,aBkC->jBiA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("Ci,jkAD,BDkC->jBiA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("Ak,ilaB,kajl->iAjB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("Ak,ilBC,kCjl->iAjB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("Ck,ikaA,aBjC->iBjA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("Ck,ilAC,kBjl->iBjA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("Ck,ikAD,BDjC->iBjA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("kA,aBil,jlka->jBiA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("kA,BCil,jlkC->jBiA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("iC,aAjk,kCaB->iAjB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVoV += 1.000000000 * np.einsum("iC,ADjk,kCBD->iAjB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("kC,aAik,jCaB->jAiB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("kC,ADik,jCBD->jAiB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2oVoV += -1.000000000 * np.einsum("kC,ACil,jlkB->jAiB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2oVvV += -0.500000000 * np.einsum("Aj,klaB,ijkl->iAaB",t1["Vo"],t2["oovV"],v["oooo"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("Aj,ikaC,jCkB->iAaB",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("Aj,ikbB,jbka->iAaB",t1["Vo"],t2["oovV"],v["ovov"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("Aj,ikBC,jCka->iAaB",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("Cj,ikaA,jBkC->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("Cj,jkaA,iBkC->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("Cj,ikaC,jBkA->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("Cj,ijaD,BDAC->iBaA",t1["Vo"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("Cj,ijbA,bBaC->iBaA",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("Cj,ikAC,jBka->iBaA",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("Cj,ijAD,BDaC->iBaA",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws1s2oVvV += -1.000000000 * np.einsum("jA,ikaC,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2oVvV += -0.500000000 * np.einsum("iC,jkaA,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2oVvV += 1.000000000 * np.einsum("jC,ikaA,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2oVoo += 1.000000000 * np.einsum("Bi,aAjl,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2oVoo += 1.000000000 * np.einsum("Bi,ACjl,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2oVoo += -0.500000000 * np.einsum("Al,aBij,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2oVoo += -0.250000000 * np.einsum("Al,BCij,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2oVoo += 0.500000000 * np.einsum("Bl,aAij,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2oVoo += 0.500000000 * np.einsum("Bl,ACij,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2oVoo += -0.500000000 * np.einsum("iB,aCjk,ABaC->iAjk",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2oVoo += -0.250000000 * np.einsum("iB,CDjk,ABCD->iAjk",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws1s2oVoo += -1.000000000 * np.einsum("iB,aAjl,lBka->iAjk",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2oVoo += 1.000000000 * np.einsum("iB,ACjl,lBkC->iAjk",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVoo += -0.500000000 * np.einsum("lB,aAij,kBla->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2oVoo += 0.500000000 * np.einsum("lB,aBij,kAla->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2oVoo += 0.500000000 * np.einsum("lB,ACij,kBlC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVoo += -0.500000000 * np.einsum("lB,BCij,kAlC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVoo += 1.000000000 * np.einsum("lB,aAil,kBja->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2oVoo += -1.000000000 * np.einsum("lB,ACil,kBjC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2oVoo += 1.000000000 * np.einsum("lB,ABim,kmjl->kAij",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2oVov += 1.000000000 * np.einsum("Bi,jkaC,ACkB->jAia",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2oVov += 1.000000000 * np.einsum("Ak,ilaB,kBjl->iAja",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2oVov += -1.000000000 * np.einsum("Bk,ilaB,kAjl->iAja",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2oVov += -1.000000000 * np.einsum("Bk,ikaC,ACjB->iAja",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2oVov += -1.000000000 * np.einsum("iB,bAjk,kBab->iAja",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2oVov += 1.000000000 * np.einsum("iB,ACjk,kBaC->iAja",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVov += 1.000000000 * np.einsum("kB,bAik,jBab->jAia",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2oVov += -1.000000000 * np.einsum("kB,ACik,jBaC->jAia",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2oVov += -1.000000000 * np.einsum("kB,ABil,jlka->jAia",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2oVvv += 1.000000000 * np.einsum("Aj,ikaB,jBkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2oVvv += -1.000000000 * np.einsum("Bj,ikaB,jAkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2oVvv += 1.000000000 * np.einsum("Bj,ijaC,ACbB->iAab",t1["Vo"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws1s2ooVVVV += -0.250000000 * np.einsum("Ak,ijaB,kaCD->ijABCD",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws1s2ooVVVV += 0.500000000 * np.einsum("Ak,ilBC,jklD->ijABCD",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws1s2ooVVVV += 0.250000000 * np.einsum("Ak,ijBE,kECD->ijABCD",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws1s2ooVVVV += 0.500000000 * np.einsum("Ek,ikAB,jDCE->ijDABC",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws1s2ooVVVV += -0.250000000 * np.einsum("Ek,ijAE,kDBC->ijDABC",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws1s2ooVVVV += -0.500000000 * np.einsum("kA,ijaB,aDkC->ijDABC",t1["oV"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2ooVVVV += -0.500000000 * np.einsum("kA,ilBC,jDkl->ijDABC",t1["oV"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2ooVVVV += -0.500000000 * np.einsum("kA,ijBE,DEkC->ijDABC",t1["oV"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2ooVVVV += -0.500000000 * np.einsum("iE,jkAB,DEkC->ijDABC",t1["oV"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2ooVoVV += -0.500000000 * np.einsum("Di,jkaA,aCBD->jkCiAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws1s2ooVoVV += -0.500000000 * np.einsum("Di,jlAB,kClD->jkCiAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2ooVoVV += -0.500000000 * np.einsum("Di,jkAE,CEBD->jkCiAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("Al,ijaB,lakC->ijAkBC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2ooVoVV += -0.500000000 * np.einsum("Al,imBC,kljm->ikAjBC",t1["Vo"],t2["ooVV"],v["oooo"],optimize="optimal")
# ws1s2ooVoVV += -0.500000000 * np.einsum("Al,ijBD,lDkC->ijAkBC",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("Dl,ilAB,kCjD->ikCjAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("Dl,ijAD,lCkB->ijCkAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("lA,ijaB,aCkl->ijCkAB",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("lA,ijBD,CDkl->ijCkAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2ooVoVV += 0.500000000 * np.einsum("iD,jlAB,CDkl->ijCkAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2ooVvVV += 1.000000000 * np.einsum("Ak,ilaB,jklC->ijAaBC",t1["Vo"],t2["oovV"],v["oooV"],optimize="optimal")
# ws1s2ooVvVV += 0.250000000 * np.einsum("Ak,ijaD,kDBC->ijAaBC",t1["Vo"],t2["oovV"],v["oVVV"],optimize="optimal")
# ws1s2ooVvVV += 0.500000000 * np.einsum("Ak,ijbB,kbaC->ijAaBC",t1["Vo"],t2["oovV"],v["ovvV"],optimize="optimal")
# ws1s2ooVvVV += 0.500000000 * np.einsum("Ak,ilBC,jkla->ijAaBC",t1["Vo"],t2["ooVV"],v["ooov"],optimize="optimal")
# ws1s2ooVvVV += -0.500000000 * np.einsum("Ak,ijBD,kDaC->ijAaBC",t1["Vo"],t2["ooVV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvVV += 1.000000000 * np.einsum("Dk,ikaA,jCBD->ijCaAB",t1["Vo"],t2["oovV"],v["oVVV"],optimize="optimal")
# ws1s2ooVvVV += -0.250000000 * np.einsum("Dk,ijaD,kCAB->ijCaAB",t1["Vo"],t2["oovV"],v["oVVV"],optimize="optimal")
# ws1s2ooVvVV += 0.500000000 * np.einsum("Dk,ikAB,jCaD->ijCaAB",t1["Vo"],t2["ooVV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvVV += 0.500000000 * np.einsum("Dk,ijAD,kCaB->ijCaAB",t1["Vo"],t2["ooVV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvVV += 1.000000000 * np.einsum("kA,ilaB,jCkl->ijCaAB",t1["oV"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2ooVvVV += 0.500000000 * np.einsum("kA,ijaD,CDkB->ijCaAB",t1["oV"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2ooVvVV += -0.500000000 * np.einsum("kA,ijbB,bCka->ijCaAB",t1["oV"],t2["oovV"],v["vVov"],optimize="optimal")
# ws1s2ooVvVV += -0.500000000 * np.einsum("kA,ijBD,CDka->ijCaAB",t1["oV"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws1s2ooVvVV += -1.000000000 * np.einsum("iD,jkaA,CDkB->ijCaAB",t1["oV"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2ooVvVV += -0.500000000 * np.einsum("iD,jkAB,CDka->ijCaAB",t1["oV"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws1s2ooVooV += 0.500000000 * np.einsum("Ci,jkaA,aBlC->jkBilA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2ooVooV += 0.500000000 * np.einsum("Ci,jkAD,BDlC->jkBilA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2ooVooV += -0.250000000 * np.einsum("Am,ijaB,makl->ijAklB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2ooVooV += 0.250000000 * np.einsum("Am,ijBC,mCkl->ijAklB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2ooVooV += -0.250000000 * np.einsum("Cm,ijAC,mBkl->ijBklA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2ooVooV += -0.250000000 * np.einsum("mA,aBij,klma->klBijA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2ooVooV += 0.250000000 * np.einsum("mA,BCij,klmC->klBijA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2ooVooV += 0.500000000 * np.einsum("iC,aAjk,lCaB->ilAjkB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2ooVooV += 0.500000000 * np.einsum("iC,ADjk,lCBD->ilAjkB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2ooVooV += -0.250000000 * np.einsum("mC,ACij,klmB->klAijB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws1s2ooVovV += -1.000000000 * np.einsum("Ci,jlaA,kBlC->jkBiaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooVovV += -0.500000000 * np.einsum("Ci,jkaD,BDAC->jkBiaA",t1["Vo"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws1s2ooVovV += 0.500000000 * np.einsum("Ci,jkbA,bBaC->jkBiaA",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws1s2ooVovV += 0.500000000 * np.einsum("Ci,jkAD,BDaC->jkBiaA",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws1s2ooVovV += -1.000000000 * np.einsum("Al,imaB,kljm->ikAjaB",t1["Vo"],t2["oovV"],v["oooo"],optimize="optimal")
# ws1s2ooVovV += -0.500000000 * np.einsum("Al,ijaC,lCkB->ijAkaB",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooVovV += -0.500000000 * np.einsum("Al,ijbB,lbka->ijAkaB",t1["Vo"],t2["oovV"],v["ovov"],optimize="optimal")
# ws1s2ooVovV += 0.500000000 * np.einsum("Al,ijBC,lCka->ijAkaB",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2ooVovV += 1.000000000 * np.einsum("Cl,ilaA,kBjC->ikBjaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooVovV += 0.500000000 * np.einsum("Cl,ijaC,lBkA->ijBkaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooVovV += -0.500000000 * np.einsum("Cl,ijAC,lBka->ijBkaA",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2ooVovV += -0.500000000 * np.einsum("lA,ijaC,BCkl->ijBkaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2ooVovV += 1.000000000 * np.einsum("iC,jlaA,BCkl->ijBkaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2ooVvvV += -1.000000000 * np.einsum("Ak,ilaB,jklb->ijAabB",t1["Vo"],t2["oovV"],v["ooov"],optimize="optimal")
# ws1s2ooVvvV += 0.500000000 * np.einsum("Ak,ijaC,kCbB->ijAabB",t1["Vo"],t2["oovV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvvV += -0.250000000 * np.einsum("Ak,ijcB,kcab->ijAabB",t1["Vo"],t2["oovV"],v["ovvv"],optimize="optimal")
# ws1s2ooVvvV += 0.250000000 * np.einsum("Ak,ijBC,kCab->ijAabB",t1["Vo"],t2["ooVV"],v["oVvv"],optimize="optimal")
# ws1s2ooVvvV += -1.000000000 * np.einsum("Ck,ikaA,jBbC->ijBabA",t1["Vo"],t2["oovV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvvV += -0.500000000 * np.einsum("Ck,ijaC,kBbA->ijBabA",t1["Vo"],t2["oovV"],v["oVvV"],optimize="optimal")
# ws1s2ooVvvV += -0.250000000 * np.einsum("Ck,ijAC,kBab->ijBabA",t1["Vo"],t2["ooVV"],v["oVvv"],optimize="optimal")
# ws1s2ooVvvV += -0.500000000 * np.einsum("kA,ijaC,BCkb->ijBabA",t1["oV"],t2["oovV"],v["VVov"],optimize="optimal")
# ws1s2ooVvvV += 1.000000000 * np.einsum("iC,jkaA,BCkb->ijBabA",t1["oV"],t2["oovV"],v["VVov"],optimize="optimal")
# ws1s2ooVooo += -0.250000000 * np.einsum("Bi,aAjk,lmaB->lmAijk",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2ooVooo += -0.250000000 * np.einsum("Bi,ACjk,lmBC->lmAijk",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws1s2ooVooo += -0.500000000 * np.einsum("iB,aAjk,mBla->imAjkl",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2ooVooo += 0.500000000 * np.einsum("iB,ACjk,mBlC->imAjkl",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws1s2ooVooo += 0.250000000 * np.einsum("aB,ABij,lmka->lmAijk",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws1s2ooVoov += 0.500000000 * np.einsum("Bi,jkaC,AClB->jkAila",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2ooVoov += 0.250000000 * np.einsum("Am,ijaB,mBkl->ijAkla",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2ooVoov += -0.250000000 * np.einsum("Bm,ijaB,mAkl->ijAkla",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2ooVoov += -0.500000000 * np.einsum("iB,bAjk,lBab->ilAjka",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2ooVoov += 0.500000000 * np.einsum("iB,ACjk,lBaC->ilAjka",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws1s2ooVoov += -0.250000000 * np.einsum("mB,ABij,klma->klAija",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws1s2ooVovv += -0.500000000 * np.einsum("Bi,jkaC,ACbB->jkAiab",t1["Vo"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws1s2ooVovv += -0.500000000 * np.einsum("Al,ijaB,lBkb->ijAkab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2ooVovv += 0.500000000 * np.einsum("Bl,ijaB,lAkb->ijAkab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2ooVvvv += 0.250000000 * np.einsum("Ak,ijaB,kBbc->ijAabc",t1["Vo"],t2["oovV"],v["oVvv"],optimize="optimal")
# ws1s2ooVvvv += -0.250000000 * np.einsum("Bk,ijaB,kAbc->ijAabc",t1["Vo"],t2["oovV"],v["oVvv"],optimize="optimal")
# ws1s2oooVVV += 0.250000000 * np.einsum("Dl,ilAB,jkCD->ijkABC",t1["Vo"],t2["ooVV"],v["ooVV"],optimize="optimal")
# ws1s2oooVVV += 0.250000000 * np.einsum("Dl,ijAD,klBC->ijkABC",t1["Vo"],t2["ooVV"],v["ooVV"],optimize="optimal")
# ws1s2oooVVV += 0.500000000 * np.einsum("lA,ijaB,kalC->ijkABC",t1["oV"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oooVVV += -0.250000000 * np.einsum("lA,imBC,jklm->ijkABC",t1["oV"],t2["ooVV"],v["oooo"],optimize="optimal")
# ws1s2oooVVV += -0.500000000 * np.einsum("lA,ijBD,kDlC->ijkABC",t1["oV"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oooVVV += -0.250000000 * np.einsum("iD,jkaA,aDBC->ijkABC",t1["oV"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws1s2oooVVV += -0.500000000 * np.einsum("iD,jlAB,kDlC->ijkABC",t1["oV"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oooVVV += -0.250000000 * np.einsum("iD,jkAE,DEBC->ijkABC",t1["oV"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws1s2ooooVV += 0.500000000 * np.einsum("Ci,jkaA,laBC->jkliAB",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws1s2ooooVV += -0.250000000 * np.einsum("Ci,jmAB,klmC->jkliAB",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws1s2ooooVV += -0.500000000 * np.einsum("Ci,jkAD,lDBC->jkliAB",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws1s2ooooVV += 0.250000000 * np.einsum("Cm,imAB,kljC->ikljAB",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws1s2ooooVV += -0.500000000 * np.einsum("Cm,ijAC,lmkB->ijlkAB",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws1s2ooooVV += -0.500000000 * np.einsum("mA,ijaB,lakm->ijlkAB",t1["oV"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2ooooVV += 0.500000000 * np.einsum("mA,ijBC,lCkm->ijlkAB",t1["oV"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2ooooVV += 0.500000000 * np.einsum("iC,jkaA,aClB->ijklAB",t1["oV"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2ooooVV += 0.500000000 * np.einsum("iC,jmAB,lCkm->ijlkAB",t1["oV"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2ooooVV += 0.500000000 * np.einsum("iC,jkAD,CDlB->ijklAB",t1["oV"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("Cl,ilaA,jkBC->ijkaAB",t1["Vo"],t2["oovV"],v["ooVV"],optimize="optimal")
# ws1s2ooovVV += 0.250000000 * np.einsum("Cl,ijaC,klAB->ijkaAB",t1["Vo"],t2["oovV"],v["ooVV"],optimize="optimal")
# ws1s2ooovVV += 0.250000000 * np.einsum("Cl,ilAB,jkaC->ijkaAB",t1["Vo"],t2["ooVV"],v["oovV"],optimize="optimal")
# ws1s2ooovVV += -0.500000000 * np.einsum("Cl,ijAC,klaB->ijkaAB",t1["Vo"],t2["ooVV"],v["oovV"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("lA,imaB,jklm->ijkaAB",t1["oV"],t2["oovV"],v["oooo"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("lA,ijaC,kClB->ijkaAB",t1["oV"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("lA,ijbB,kbla->ijkaAB",t1["oV"],t2["oovV"],v["ovov"],optimize="optimal")
# ws1s2ooovVV += -0.500000000 * np.einsum("lA,ijBC,kCla->ijkaAB",t1["oV"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2ooovVV += -1.000000000 * np.einsum("iC,jlaA,kClB->ijkaAB",t1["oV"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooovVV += -0.250000000 * np.einsum("iC,jkaD,CDAB->ijkaAB",t1["oV"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("iC,jkbA,bCaB->ijkaAB",t1["oV"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws1s2ooovVV += -0.500000000 * np.einsum("iC,jlAB,kCla->ijkaAB",t1["oV"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws1s2ooovVV += 0.500000000 * np.einsum("iC,jkAD,CDaB->ijkaAB",t1["oV"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws1s2oooooV += -0.500000000 * np.einsum("Bi,jkaA,malB->jkmilA",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oooooV += 0.500000000 * np.einsum("Bi,jkAC,mClB->jkmilA",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws1s2oooooV += 0.250000000 * np.einsum("Ba,ijAB,makl->ijmklA",t1["Vo"],t2["ooVV"],v["oooo"],optimize="optimal")
# ws1s2oooooV += -0.250000000 * np.einsum("iB,jkaA,aBlm->ijklmA",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws1s2oooooV += -0.250000000 * np.einsum("iB,jkAC,BClm->ijklmA",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("Bi,jmaA,klmB->jkliaA",t1["Vo"],t2["oovV"],v["oooV"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("Bi,jkaC,lCAB->jkliaA",t1["Vo"],t2["oovV"],v["oVVV"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("Bi,jkbA,lbaB->jkliaA",t1["Vo"],t2["oovV"],v["ovvV"],optimize="optimal")
# ws1s2oooovV += 0.500000000 * np.einsum("Bi,jkAC,lCaB->jkliaA",t1["Vo"],t2["ooVV"],v["oVvV"],optimize="optimal")
# ws1s2oooovV += 0.500000000 * np.einsum("Bm,imaA,kljB->ikljaA",t1["Vo"],t2["oovV"],v["oooV"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("Bm,ijaB,lmkA->ijlkaA",t1["Vo"],t2["oovV"],v["oooV"],optimize="optimal")
# ws1s2oooovV += 0.500000000 * np.einsum("Bm,ijAB,lmka->ijlkaA",t1["Vo"],t2["ooVV"],v["ooov"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("mA,ijaB,lBkm->ijlkaA",t1["oV"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2oooovV += 1.000000000 * np.einsum("iB,jmaA,lBkm->ijlkaA",t1["oV"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws1s2oooovV += 0.500000000 * np.einsum("iB,jkaC,BClA->ijklaA",t1["oV"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("iB,jkbA,bBla->ijklaA",t1["oV"],t2["oovV"],v["vVov"],optimize="optimal")
# ws1s2oooovV += -0.500000000 * np.einsum("iB,jkAC,BCla->ijklaA",t1["oV"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws1s2ooovvV += -0.500000000 * np.einsum("Bl,ilaA,jkbB->ijkabA",t1["Vo"],t2["oovV"],v["oovV"],optimize="optimal")
# ws1s2ooovvV += 0.500000000 * np.einsum("Bl,ijaB,klbA->ijkabA",t1["Vo"],t2["oovV"],v["oovV"],optimize="optimal")
# ws1s2ooovvV += 0.250000000 * np.einsum("Bl,ijAB,klab->ijkabA",t1["Vo"],t2["ooVV"],v["oovv"],optimize="optimal")
# ws1s2ooovvV += -0.500000000 * np.einsum("lA,ijaB,kBlb->ijkabA",t1["oV"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2ooovvV += 1.000000000 * np.einsum("iB,jlaA,kBlb->ijkabA",t1["oV"],t2["oovV"],v["oVov"],optimize="optimal")
# ws1s2ooovvV += -0.500000000 * np.einsum("iB,jkaC,BCbA->ijkabA",t1["oV"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws1s2ooovvV += -0.250000000 * np.einsum("iB,jkcA,cBab->ijkabA",t1["oV"],t2["oovV"],v["vVvv"],optimize="optimal")
# ws1s2ooovvV += -0.250000000 * np.einsum("iB,jkAC,BCab->ijkabA",t1["oV"],t2["ooVV"],v["VVvv"],optimize="optimal")
# ws1s2ooooov += 0.500000000 * np.einsum("Ai,jkaB,mBlA->jkmila",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws1s2ooooov += 0.250000000 * np.einsum("Aa,ijbA,makl->ijmklb",t1["Vo"],t2["oovV"],v["oooo"],optimize="optimal")
# ws1s2ooooov += -0.250000000 * np.einsum("iA,jkaB,ABlm->ijklma",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws1s2oooovv += -0.500000000 * np.einsum("Ai,jkaB,lBbA->jkliab",t1["Vo"],t2["oovV"],v["oVvV"],optimize="optimal")
# ws1s2oooovv += -0.500000000 * np.einsum("Am,ijaA,lmkb->ijlkab",t1["Vo"],t2["oovV"],v["ooov"],optimize="optimal")
# ws1s2oooovv += 0.500000000 * np.einsum("iA,jkaB,ABlb->ijklab",t1["oV"],t2["oovV"],v["VVov"],optimize="optimal")
# ws1s2ooovvv += 0.250000000 * np.einsum("Al,ijaA,klbc->ijkabc",t1["Vo"],t2["oovV"],v["oovv"],optimize="optimal")
# ws1s2ooovvv += -0.250000000 * np.einsum("iA,jkaB,ABbc->ijkabc",t1["oV"],t2["oovV"],v["VVvv"],optimize="optimal")
# ws1s2oovVVV += 0.500000000 * np.einsum("Dk,ikAB,jaCD->ijaABC",t1["Vo"],t2["ooVV"],v["ovVV"],optimize="optimal")
# ws1s2oovVVV += -0.250000000 * np.einsum("Dk,ijAD,kaBC->ijaABC",t1["Vo"],t2["ooVV"],v["ovVV"],optimize="optimal")
# ws1s2oovVVV += 0.500000000 * np.einsum("kA,ijbB,abkC->ijaABC",t1["oV"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws1s2oovVVV += -0.500000000 * np.einsum("kA,ilBC,jakl->ijaABC",t1["oV"],t2["ooVV"],v["ovoo"],optimize="optimal")
# ws1s2oovVVV += -0.500000000 * np.einsum("kA,ijBD,aDkC->ijaABC",t1["oV"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws1s2oovVVV += -0.500000000 * np.einsum("iD,jkAB,aDkC->ijaABC",t1["oV"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws1s2oovoVV += 0.500000000 * np.einsum("Ci,jkbA,abBC->jkaiAB",t1["Vo"],t2["oovV"],v["vvVV"],optimize="optimal")
# ws1s2oovoVV += -0.500000000 * np.einsum("Ci,jlAB,kalC->jkaiAB",t1["Vo"],t2["ooVV"],v["ovoV"],optimize="optimal")
# ws1s2oovoVV += -0.500000000 * np.einsum("Ci,jkAD,aDBC->jkaiAB",t1["Vo"],t2["ooVV"],v["vVVV"],optimize="optimal")
# ws1s2oovoVV += 0.500000000 * np.einsum("Cl,ilAB,kajC->ikajAB",t1["Vo"],t2["ooVV"],v["ovoV"],optimize="optimal")
# ws1s2oovoVV += 0.500000000 * np.einsum("Cl,ijAC,lakB->ijakAB",t1["Vo"],t2["ooVV"],v["ovoV"],optimize="optimal")
# ws1s2oovoVV += -0.500000000 * np.einsum("lA,ijbB,abkl->ijakAB",t1["oV"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws1s2oovoVV += 0.500000000 * np.einsum("lA,ijBC,aCkl->ijakAB",t1["oV"],t2["ooVV"],v["vVoo"],optimize="optimal")
# ws1s2oovoVV += 0.500000000 * np.einsum("iC,jlAB,aCkl->ijakAB",t1["oV"],t2["ooVV"],v["vVoo"],optimize="optimal")
# ws1s2oovvVV += 1.000000000 * np.einsum("Ck,ikaA,jbBC->ijbaAB",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws1s2oovvVV += -0.250000000 * np.einsum("Ck,ijaC,kbAB->ijbaAB",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws1s2oovvVV += 0.500000000 * np.einsum("Ck,ikAB,jbaC->ijbaAB",t1["Vo"],t2["ooVV"],v["ovvV"],optimize="optimal")
# ws1s2oovvVV += 0.500000000 * np.einsum("Ck,ijAC,kbaB->ijbaAB",t1["Vo"],t2["ooVV"],v["ovvV"],optimize="optimal")
# ws1s2oovvVV += 1.000000000 * np.einsum("kA,ilaB,jbkl->ijbaAB",t1["oV"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2oovvVV += 0.500000000 * np.einsum("kA,ijaC,bCkB->ijbaAB",t1["oV"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2oovvVV += 0.500000000 * np.einsum("kA,ijcB,bcka->ijbaAB",t1["oV"],t2["oovV"],v["vvov"],optimize="optimal")
# ws1s2oovvVV += -0.500000000 * np.einsum("kA,ijBC,bCka->ijbaAB",t1["oV"],t2["ooVV"],v["vVov"],optimize="optimal")
# ws1s2oovvVV += -1.000000000 * np.einsum("iC,jkaA,bCkB->ijbaAB",t1["oV"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2oovvVV += -0.500000000 * np.einsum("iC,jkAB,bCka->ijbaAB",t1["oV"],t2["ooVV"],v["vVov"],optimize="optimal")
# ws1s2oovooV += -0.500000000 * np.einsum("Bi,jkbA,ablB->jkailA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws1s2oovooV += 0.500000000 * np.einsum("Bi,jkAC,aClB->jkailA",t1["Vo"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws1s2oovooV += -0.250000000 * np.einsum("Bm,ijAB,makl->ijaklA",t1["Vo"],t2["ooVV"],v["ovoo"],optimize="optimal")
# ws1s2oovooV += 0.250000000 * np.einsum("mA,aBij,klmB->klaijA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2oovooV += 0.500000000 * np.einsum("iB,aCjk,lBAC->ilajkA",t1["oV"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws1s2oovooV += -0.250000000 * np.einsum("mB,aBij,klmA->klaijA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2oovovV += -1.000000000 * np.einsum("Bi,jlaA,kblB->jkbiaA",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oovovV += -0.500000000 * np.einsum("Bi,jkaC,bCAB->jkbiaA",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws1s2oovovV += -0.500000000 * np.einsum("Bi,jkcA,bcaB->jkbiaA",t1["Vo"],t2["oovV"],v["vvvV"],optimize="optimal")
# ws1s2oovovV += 0.500000000 * np.einsum("Bi,jkAC,bCaB->jkbiaA",t1["Vo"],t2["ooVV"],v["vVvV"],optimize="optimal")
# ws1s2oovovV += 1.000000000 * np.einsum("Bl,ilaA,kbjB->ikbjaA",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oovovV += 0.500000000 * np.einsum("Bl,ijaB,lbkA->ijbkaA",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws1s2oovovV += -0.500000000 * np.einsum("Bl,ijAB,lbka->ijbkaA",t1["Vo"],t2["ooVV"],v["ovov"],optimize="optimal")
# ws1s2oovovV += -0.500000000 * np.einsum("lA,ijaB,bBkl->ijbkaA",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws1s2oovovV += 1.000000000 * np.einsum("iB,jlaA,bBkl->ijbkaA",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws1s2oovvvV += -1.000000000 * np.einsum("Bk,ikaA,jcbB->ijcabA",t1["Vo"],t2["oovV"],v["ovvV"],optimize="optimal")
# ws1s2oovvvV += -0.500000000 * np.einsum("Bk,ijaB,kcbA->ijcabA",t1["Vo"],t2["oovV"],v["ovvV"],optimize="optimal")
# ws1s2oovvvV += -0.250000000 * np.einsum("Bk,ijAB,kcab->ijcabA",t1["Vo"],t2["ooVV"],v["ovvv"],optimize="optimal")
# ws1s2oovvvV += -0.500000000 * np.einsum("kA,ijaB,cBkb->ijcabA",t1["oV"],t2["oovV"],v["vVov"],optimize="optimal")
# ws1s2oovvvV += 1.000000000 * np.einsum("iB,jkaA,cBkb->ijcabA",t1["oV"],t2["oovV"],v["vVov"],optimize="optimal")
# ws1s2oovooo += -0.250000000 * np.einsum("Ai,aBjk,lmAB->lmaijk",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2oovooo += 0.500000000 * np.einsum("iA,aBjk,mAlB->imajkl",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2oovooo += 0.250000000 * np.einsum("aA,bAij,lmka->lmbijk",t1["oV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws1s2oovoov += 0.500000000 * np.einsum("Ai,jkaB,bBlA->jkbila",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2oovoov += -0.250000000 * np.einsum("Am,ijaA,mbkl->ijbkla",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2oovoov += 0.500000000 * np.einsum("iA,aBjk,lAbB->ilajkb",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2oovoov += -0.250000000 * np.einsum("mA,aAij,klmb->klaijb",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2oovovv += -0.500000000 * np.einsum("Ai,jkaB,cBbA->jkciab",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ...
# ws1s2vVVooo += 0.250000000 * np.einsum("lC,aCij,ABkl->aABijk",t1["oV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws1s2vVVooo += -0.500000000 * np.einsum("lC,ACij,aBkl->aABijk",t1["oV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws1s2vVVooo += 0.500000000 * np.einsum("lC,aAil,BCjk->aABijk",t1["oV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws1s2vVVooo += 0.250000000 * np.einsum("lC,ABil,aCjk->aABijk",t1["oV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws1s2vVVoov += -1.000000000 * np.einsum("Ci,aAjk,kBbC->aABijb",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2vVVoov += -0.500000000 * np.einsum("Ci,ABjk,kbaC->bABija",t1["Vo"],t2["VVoo"],v["ovvV"],optimize="optimal")
# ws1s2vVVoov += 0.500000000 * np.einsum("Ak,aCij,kBbC->aABijb",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2vVVoov += 0.500000000 * np.einsum("Ak,cBij,kbac->bABija",t1["Vo"],t2["vVoo"],v["ovvv"],optimize="optimal")
# ws1s2vVVoov += -0.500000000 * np.einsum("Ak,BCij,kbaC->bABija",t1["Vo"],t2["VVoo"],v["ovvV"],optimize="optimal")
# ws1s2vVVoov += 1.000000000 * np.einsum("Ak,aBil,kljb->aABijb",t1["Vo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2vVVoov += -0.250000000 * np.einsum("kC,aCij,ABkb->aABijb",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2vVVoov += 0.500000000 * np.einsum("kC,ACij,bBka->bABija",t1["oV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws1s2vVVoov += 1.000000000 * np.einsum("kC,aAik,BCjb->aABijb",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws1s2vVVoov += 0.500000000 * np.einsum("kC,ABik,bCja->bABija",t1["oV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws1s2vVVovv += 0.500000000 * np.einsum("Aj,aBik,jkbc->aABibc",t1["Vo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws1s2vVVovv += 0.500000000 * np.einsum("jC,aAij,BCbc->aABibc",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws1s2vVVovv += 0.250000000 * np.einsum("jC,ABij,cCab->cABiab",t1["oV"],t2["VVoo"],v["vVvv"],optimize="optimal")
# ws1s2vVVV += 0.250000000 * np.einsum("Ai,jkBC,iajk->aABC",t1["Vo"],t2["ooVV"],v["ovoo"],optimize="optimal")
# ws1s2vVVV += -0.500000000 * np.einsum("Di,ijAB,aCjD->aCAB",t1["Vo"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws1s2vVVV += -0.500000000 * np.einsum("iA,aBjk,jkiC->aBAC",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vVVV += -0.500000000 * np.einsum("iD,aAij,jDBC->aABC",t1["oV"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws1s2vVoV += -0.500000000 * np.einsum("Ci,aAjk,jkBC->aAiB",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("Aj,aCik,jkBC->aAiB",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("Cj,aAik,jkBC->aAiB",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("jA,aCik,kBjC->aBiA",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("jA,bBik,kajb->aBiA",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("jA,BCik,kajC->aBiA",t1["oV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws1s2vVoV += -0.500000000 * np.einsum("jA,aBkl,klij->aBiA",t1["oV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("jC,aDij,BCAD->aBiA",t1["oV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("jC,bAij,aCbB->aAiB",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("jC,ADij,aCBD->aAiB",t1["oV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("jC,aAik,kCjB->aAiB",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("jC,aCik,kBjA->aBiA",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vVoV += 1.000000000 * np.einsum("jC,ACik,kajB->aAiB",t1["oV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws1s2vVoV += -1.000000000 * np.einsum("jC,aAjk,kCiB->aAiB",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vVvV += 0.500000000 * np.einsum("Ai,jkaB,ibjk->bAaB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2vVvV += -1.000000000 * np.einsum("Ci,ijaA,bBjC->bBaA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2vVvV += 0.500000000 * np.einsum("iA,aBjk,jkib->aBbA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2vVvV += -1.000000000 * np.einsum("iC,aAij,jCbB->aAbB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2vVoo += 1.000000000 * np.einsum("Bi,aCjk,kABC->aAij",t1["Vo"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("Bi,bAjk,kabB->aAij",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("Bi,ACjk,kaBC->aAij",t1["Vo"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("Bi,aAkl,kljB->aAij",t1["Vo"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vVoo += 0.500000000 * np.einsum("Ak,bBij,kabB->aAij",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws1s2vVoo += 0.250000000 * np.einsum("Ak,BCij,kaBC->aAij",t1["Vo"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("Ak,aBil,kljB->aAij",t1["Vo"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vVoo += 0.500000000 * np.einsum("Bk,aCij,kABC->aAij",t1["Vo"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("Bk,bAij,kabB->aAij",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("Bk,ACij,kaBC->aAij",t1["Vo"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws1s2vVoo += 1.000000000 * np.einsum("Bk,aAil,kljB->aAij",t1["Vo"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("kB,aCij,ABkC->aAij",t1["oV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("kB,bAij,aBkb->aAij",t1["oV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws1s2vVoo += 0.500000000 * np.einsum("kB,bBij,aAkb->aAij",t1["oV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws1s2vVoo += 0.500000000 * np.einsum("kB,ACij,aBkC->aAij",t1["oV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("kB,BCij,aAkC->aAij",t1["oV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws1s2vVoo += 1.000000000 * np.einsum("kB,aCik,ABjC->aAij",t1["oV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws1s2vVoo += 1.000000000 * np.einsum("kB,bAik,aBjb->aAij",t1["oV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("kB,ACik,aBjC->aAij",t1["oV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("kB,aAil,lBjk->aAij",t1["oV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws1s2vVoo += 1.000000000 * np.einsum("kB,aBil,lAjk->aAij",t1["oV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws1s2vVoo += -1.000000000 * np.einsum("kB,ABil,lajk->aAij",t1["oV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws1s2vVoo += -0.500000000 * np.einsum("kB,aAkl,lBij->aAij",t1["oV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws1s2vVov += -0.500000000 * np.einsum("Bi,aAjk,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2vVov += -1.000000000 * np.einsum("Aj,aBik,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2vVov += 1.000000000 * np.einsum("Bj,aAik,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws1s2vVov += 1.000000000 * np.einsum("jB,aCij,ABbC->aAib",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws1s2vVov += 1.000000000 * np.einsum("jB,cAij,bBac->bAia",t1["oV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws1s2vVov += -1.000000000 * np.einsum("jB,ACij,bBaC->bAia",t1["oV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws1s2vVov += 1.000000000 * np.einsum("jB,aAik,kBjb->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2vVov += -1.000000000 * np.einsum("jB,aBik,kAjb->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2vVov += 1.000000000 * np.einsum("jB,ABik,kbja->bAia",t1["oV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws1s2vVov += -1.000000000 * np.einsum("jB,aAjk,kBib->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws1s2vVvv += -0.500000000 * np.einsum("iB,aAij,jBbc->aAbc",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws1s2vvVoVV += -1.000000000 * np.einsum("jA,aBik,kbjC->abBiAC",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws1s2vvVoVV += -0.500000000 * np.einsum("jD,aAij,bDBC->abAiBC",t1["oV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws1s2vvVooV += 1.000000000 * np.einsum("Ci,aAjk,kbBC->abAijB",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws1s2vvVooV += -0.500000000 * np.einsum("Ak,aCij,kbBC->abAijB",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws1s2vvVooV += 0.500000000 * np.einsum("kA,aCij,bBkC->abBijA",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws1s2vvVooV += -0.250000000 * np.einsum("kA,cBij,abkc->abBijA",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws1s2vvVooV += 0.250000000 * np.einsum("kA,BCij,abkC->abBijA",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws1s2vvVooV += -1.000000000 * np.einsum("kA,aBil,lbjk->abBijA",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws1s2vvVooV += -0.500000000 * np.einsum("kC,aCij,bBkA->abBijA",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws1s2vvVooV += -0.250000000 * np.einsum("kC,ACij,abkB->abAijB",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws1s2vvVooV += -1.000000000 * np.einsum("kC,aAik,bCjB->abAijB",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws1s2vvVovV += 1.000000000 * np.einsum("jA,aBik,kcjb->acBibA",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws1s2vvVovV += -1.000000000 * np.einsum("jC,aAij,cCbB->acAibB",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws1s2vvVooo += -0.500000000 * np.einsum("Bi,aCjk,bABC->abAijk",t1["Vo"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws1s2vvVooo += -0.250000000 * np.einsum("Bi,cAjk,abcB->abAijk",t1["Vo"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws1s2vvVooo += -0.250000000 * np.einsum("Bi,ACjk,abBC->abAijk",t1["Vo"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws1s2vvVooo += 1.000000000 * np.einsum("Bi,aAjl,lbkB->abAijk",t1["Vo"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws1s2vvVooo += -0.500000000 * np.einsum("Al,aBij,lbkB->abAijk",t1["Vo"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws1s2vvVooo += 0.500000000 * np.einsum("lB,aBij,bAkl->abAijk",t1["oV"],t2["vVoo"],v["vVoo"],optimize="optimal")
# ws1s2vvVooo += 0.250000000 * np.einsum("lB,ABij,abkl->abAijk",t1["oV"],t2["VVoo"],v["vvoo"],optimize="optimal")
# ws1s2vvVooo += -0.500000000 * np.einsum("lB,aAil,bBjk->abAijk",t1["oV"],t2["vVoo"],v["vVoo"],optimize="optimal")
# ws1s2vvVoov += 1.000000000 * np.einsum("Bi,aAjk,kcbB->acAijb",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws1s2vvVoov += -0.500000000 * np.einsum("Ak,aBij,kcbB->acAijb",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws1s2vvVoov += -0.500000000 * np.einsum("kB,aBij,cAkb->acAijb",t1["oV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws1s2vvVoov += -0.250000000 * np.einsum("kB,ABij,bcka->bcAija",t1["oV"],t2["VVoo"],v["vvov"],optimize="optimal")
# ws1s2vvVoov += -1.000000000 * np.einsum("kB,aAik,cBjb->acAijb",t1["oV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws1s2vvVovv += -0.500000000 * np.einsum("jB,aAij,dBbc->adAibc",t1["oV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws1s2vvvooV += 0.250000000 * np.einsum("kA,aBij,bckB->abcijA",t1["oV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws1s2vvvooV += -0.250000000 * np.einsum("kB,aBij,bckA->abcijA",t1["oV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws1s2vvvooo += -0.250000000 * np.einsum("Ai,aBjk,bcAB->abcijk",t1["Vo"],t2["vVoo"],v["vvVV"],optimize="optimal")
# ws1s2vvvooo += 0.250000000 * np.einsum("lA,aAij,bckl->abcijk",t1["oV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws1s2vvvoov += -0.250000000 * np.einsum("kA,aAij,cdkb->acdijb",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws1s2vvVV += -0.250000000 * np.einsum("Ci,ijAB,abjC->abAB",t1["Vo"],t2["ooVV"],v["vvoV"],optimize="optimal")
# ws1s2vvoV += 1.000000000 * np.einsum("jA,aBik,kbjB->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws1s2vvoV += 1.000000000 * np.einsum("jB,aCij,bBAC->abiA",t1["oV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws1s2vvoV += -1.000000000 * np.einsum("jB,aBik,kbjA->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws1s2vvvV += -0.500000000 * np.einsum("Bi,ijaA,bcjB->bcaA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws1s2vvoo += 1.000000000 * np.einsum("Ai,aBjk,kbAB->abij",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws1s2vvoo += 0.500000000 * np.einsum("Ak,aBij,kbAB->abij",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws1s2vvoo += -0.500000000 * np.einsum("kA,aBij,bAkB->abij",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws1s2vvoo += 0.250000000 * np.einsum("kA,cAij,abkc->abij",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws1s2vvoo += -0.250000000 * np.einsum("kA,ABij,abkB->abij",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws1s2vvoo += 1.000000000 * np.einsum("kA,aBik,bAjB->abij",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws1s2vvoo += 1.000000000 * np.einsum("kA,aAil,lbjk->abij",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws1s2vvov += 1.000000000 * np.einsum("jA,aBij,cAbB->acib",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws1s2vvov += -1.000000000 * np.einsum("jA,aAik,kcjb->acib",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws1s2vV += -1.000000000 * np.einsum("Bi,ijbA,abjB->aA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws1s2vV += -0.500000000 * np.einsum("Bi,jkAB,iajk->aA",t1["Vo"],t2["ooVV"],v["ovoo"],optimize="optimal")
# ws1s2vV += 1.000000000 * np.einsum("Bi,ijAC,aCjB->aA",t1["Vo"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws1s2vV += 0.500000000 * np.einsum("iA,aBjk,jkiB->aA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vV += 1.000000000 * np.einsum("iB,aCij,jBAC->aA",t1["oV"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws1s2vV += -0.500000000 * np.einsum("iB,aBjk,jkiA->aA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws1s2vo += -0.500000000 * np.einsum("Ai,aBjk,jkAB->ai",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2vo += 1.000000000 * np.einsum("Aj,aBik,jkAB->ai",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws1s2vo += 1.000000000 * np.einsum("jA,bBij,aAbB->ai",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws1s2vo += 0.500000000 * np.einsum("jA,BCij,aABC->ai",t1["oV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws1s2vo += -1.000000000 * np.einsum("jA,aBik,kAjB->ai",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vo += -1.000000000 * np.einsum("jA,bAik,kajb->ai",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws1s2vo += 1.000000000 * np.einsum("jA,ABik,kajB->ai",t1["oV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws1s2vo += 1.000000000 * np.einsum("jA,aBjk,kAiB->ai",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws1s2vo += 0.500000000 * np.einsum("jA,aAkl,klij->ai",t1["oV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws1s2vv += -0.500000000 * np.einsum("Ai,jkaA,ibjk->ba",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2vv += 1.000000000 * np.einsum("Ai,ijaB,bBjA->ba",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2vv += 1.000000000 * np.einsum("iA,aBij,jAbB->ab",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2vv += -0.500000000 * np.einsum("iA,aAjk,jkib->ab",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2 += 0.500000000 * np.einsum("Ai,jkaA,iajk->",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws1s2 += -1.000000000 * np.einsum("Ai,ijaB,aBjA->",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws1s2 += -0.500000000 * np.einsum("Ai,jkAB,iBjk->",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws1s2 += -0.500000000 * np.einsum("Ai,ijBC,BCjA->",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws1s2 += -1.000000000 * np.einsum("iA,aBij,jAaB->",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws1s2 += -0.500000000 * np.einsum("iA,BCij,jABC->",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws1s2 += 0.500000000 * np.einsum("iA,aAjk,jkia->",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws1s2 += -0.500000000 * np.einsum("iA,ABjk,jkiB->",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")

# %%
# [[W,s2_ext],s1_ext]
print("[[W,s2_ext],s1_ext]")
Ws2s1 = w.commutator(W,s2_ext,s1_ext)
expr = wt.contract(Ws2s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws2s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[W,s2_ext],s1_ext]
# ws2s1VVVVVV += 0.250000000 * np.einsum("Ai,ijBC,EGjD->AEGBCD",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VVVVVV += 0.250000000 * np.einsum("iA,BCij,jGDE->BCGADE",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVVoVV += -0.250000000 * np.einsum("Aj,BCik,jkDE->ABCiDE",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1VVVoVV += -0.250000000 * np.einsum("Aj,jkBC,DEik->ADEiBC",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1VVVoVV += 0.500000000 * np.einsum("jA,aBij,DEaC->BDEiAC",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVVoVV += 0.500000000 * np.einsum("jA,BGij,DECG->BDEiAC",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1VVVoVV += 0.500000000 * np.einsum("jA,BCik,kEjD->BCEiAD",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVVoVV += -0.500000000 * np.einsum("jA,BCjk,kEiD->BCEiAD",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVVvVV += 0.500000000 * np.einsum("Ai,ijaB,DEjC->ADEaBC",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1VVVvVV += 0.250000000 * np.einsum("Ai,ijBC,DEja->ADEaBC",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1VVVvVV += -0.500000000 * np.einsum("iA,BCij,jEaD->BCEaAD",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVVooV += -0.500000000 * np.einsum("Ei,ABjk,kDCE->ABDijC",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVVooV += -0.500000000 * np.einsum("Ak,aBij,kDaC->ABDijC",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVVooV += -0.500000000 * np.einsum("Ak,BEij,kDCE->ABDijC",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVVooV += -0.500000000 * np.einsum("Ak,BCil,kljD->ABCijD",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VVVooV += -0.250000000 * np.einsum("kA,aBij,CDka->BCDijA",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVVooV += 0.250000000 * np.einsum("kA,BEij,CDkE->BCDijA",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVVooV += 0.500000000 * np.einsum("kA,aBik,CDja->BCDijA",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVVooV += -0.500000000 * np.einsum("kA,BEik,CDjE->BCDijA",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVVooV += 0.500000000 * np.einsum("kA,BCil,lDjk->BCDijA",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVVooV += 0.250000000 * np.einsum("kA,BCkl,lDij->BCDijA",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVVovV += -0.500000000 * np.einsum("Aj,BCik,jkaD->ABCiaD",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1VVVovV += -0.500000000 * np.einsum("Aj,jkaB,CDik->ACDiaB",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1VVVovV += 0.500000000 * np.einsum("jA,bBij,CDab->BCDiaA",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s1VVVovV += -0.500000000 * np.einsum("jA,BEij,CDaE->BCDiaA",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVVovV += -0.500000000 * np.einsum("jA,BCik,kDja->BCDiaA",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVVovV += 0.500000000 * np.einsum("jA,BCjk,kDia->BCDiaA",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVVvvV += -0.500000000 * np.einsum("Ai,ijaB,CDjb->ACDabB",t1["Vo"],t2["oovV"],v["VVov"],optimize="optimal")
# ws2s1VVVvvV += 0.250000000 * np.einsum("iA,BCij,jDab->BCDabA",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2s1VVVooo += -0.250000000 * np.einsum("Di,aAjk,BCaD->ABCijk",t1["Vo"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVVooo += -0.250000000 * np.einsum("Di,AEjk,BCDE->ABCijk",t1["Vo"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1VVVooo += -0.500000000 * np.einsum("Di,ABjl,lCkD->ABCijk",t1["Vo"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVVooo += 0.500000000 * np.einsum("Al,aBij,lCka->ABCijk",t1["Vo"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1VVVooo += -0.500000000 * np.einsum("Al,BDij,lCkD->ABCijk",t1["Vo"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVVooo += -0.250000000 * np.einsum("Al,BCim,lmjk->ABCijk",t1["Vo"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1VVVoov += -0.500000000 * np.einsum("Di,ABjk,kCaD->ABCija",t1["Vo"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVVoov += 0.500000000 * np.einsum("Ak,bBij,kCab->ABCija",t1["Vo"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1VVVoov += -0.500000000 * np.einsum("Ak,BDij,kCaD->ABCija",t1["Vo"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVVoov += -0.500000000 * np.einsum("Ak,BCil,klja->ABCija",t1["Vo"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1VVVovv += -0.250000000 * np.einsum("Aj,BCik,jkab->ABCiab",t1["Vo"],t2["VVoo"],v["oovv"],optimize="optimal")
# ws2s1VVVV += 1.000000000 * np.einsum("Ai,ijaB,aDjC->ADBC",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1VVVV += -0.250000000 * np.einsum("Ai,jkBC,iDjk->ADBC",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1VVVV += 1.000000000 * np.einsum("Ai,ijBE,DEjC->ADBC",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VVVV += -0.250000000 * np.einsum("Ei,ijAB,CDjE->CDAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VVVV += 0.500000000 * np.einsum("Ei,ijAE,CDjB->CDAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VVVV += 1.000000000 * np.einsum("iA,aBij,jDaC->BDAC",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVVV += 1.000000000 * np.einsum("iA,BEij,jDCE->BDAC",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVVV += -0.250000000 * np.einsum("iA,BCjk,jkiD->BCAD",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VVVV += -0.250000000 * np.einsum("iE,ABij,jECD->ABCD",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVVV += 0.500000000 * np.einsum("iE,AEij,jDBC->ADBC",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVoV += -0.250000000 * np.einsum("Di,ABjk,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1VVoV += -0.250000000 * np.einsum("Di,jkAD,BCjk->BCiA",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("Aj,aBik,jkaC->ABiC",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("Aj,BDik,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("Aj,jkaB,aCik->ACiB",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("Aj,jkBD,CDik->ACiB",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1VVoV += 0.500000000 * np.einsum("Dj,ABik,jkCD->ABiC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1VVoV += 0.500000000 * np.einsum("Dj,jkAD,BCik->BCiA",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1VVoV += -0.500000000 * np.einsum("jA,aDij,BCaD->BCiA",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVoV += -0.250000000 * np.einsum("jA,DEij,BCDE->BCiA",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1VVoV += -1.000000000 * np.einsum("jA,aBik,kCja->BCiA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("jA,BDik,kCjD->BCiA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("jA,aBjk,kCia->BCiA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1VVoV += -1.000000000 * np.einsum("jA,BDjk,kCiD->BCiA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVoV += -0.250000000 * np.einsum("jA,BCkl,klij->BCiA",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("jD,aAij,CDaB->ACiB",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVoV += 0.500000000 * np.einsum("jD,aDij,BCaA->BCiA",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("jD,AEij,CDBE->ACiB",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1VVoV += 0.500000000 * np.einsum("jD,DEij,BCAE->BCiA",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1VVoV += 0.500000000 * np.einsum("jD,ABik,kDjC->ABiC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVoV += -1.000000000 * np.einsum("jD,ADik,kCjB->ACiB",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVoV += -0.500000000 * np.einsum("jD,ABjk,kDiC->ABiC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVoV += 1.000000000 * np.einsum("jD,ADjk,kCiB->ACiB",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1VVvV += -0.500000000 * np.einsum("Ai,jkaB,iCjk->ACaB",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1VVvV += 1.000000000 * np.einsum("Ai,ijaD,CDjB->ACaB",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1VVvV += -1.000000000 * np.einsum("Ai,ijbB,bCja->ACaB",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1VVvV += -1.000000000 * np.einsum("Ai,ijBD,CDja->ACaB",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1VVvV += -0.500000000 * np.einsum("Di,ijaA,BCjD->BCaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1VVvV += 0.500000000 * np.einsum("Di,ijaD,BCjA->BCaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1VVvV += -0.500000000 * np.einsum("Di,ijAD,BCja->BCaA",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1VVvV += 1.000000000 * np.einsum("iA,bBij,jCab->BCaA",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1VVvV += -1.000000000 * np.einsum("iA,BDij,jCaD->BCaA",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVvV += 0.250000000 * np.einsum("iA,BCjk,jkia->BCaA",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1VVvV += -0.500000000 * np.einsum("iD,ABij,jDaC->ABaC",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVvV += 1.000000000 * np.einsum("iD,ADij,jCaB->ACaB",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVoo += 1.000000000 * np.einsum("Ci,aAjk,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVoo += 1.000000000 * np.einsum("Ci,ADjk,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVoo += -0.250000000 * np.einsum("Ci,ABkl,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VVoo += -0.500000000 * np.einsum("Ak,aCij,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVoo += -0.250000000 * np.einsum("Ak,CDij,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVoo += -1.000000000 * np.einsum("Ak,aBil,klja->ABij",t1["Vo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1VVoo += 1.000000000 * np.einsum("Ak,BCil,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("Ck,aAij,kBaC->ABij",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("Ck,ADij,kBCD->ABij",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("Ck,ABil,kljC->ABij",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("kC,aAij,BCka->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVoo += 0.250000000 * np.einsum("kC,aCij,ABka->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVoo += -0.500000000 * np.einsum("kC,ADij,BCkD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVoo += -0.250000000 * np.einsum("kC,CDij,ABkD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVoo += -1.000000000 * np.einsum("kC,aAik,BCja->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVoo += -0.500000000 * np.einsum("kC,aCik,ABja->ABij",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1VVoo += 1.000000000 * np.einsum("kC,ADik,BCjD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("kC,CDik,ABjD->ABij",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1VVoo += -0.500000000 * np.einsum("kC,ABil,lCjk->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVoo += 1.000000000 * np.einsum("kC,ACil,lBjk->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVoo += -0.250000000 * np.einsum("kC,ABkl,lCij->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVoo += 0.500000000 * np.einsum("kC,ACkl,lBij->ABij",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1VVov += -0.250000000 * np.einsum("Ci,ABjk,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1VVov += -0.250000000 * np.einsum("Ci,jkaC,ABjk->ABia",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1VVov += -1.000000000 * np.einsum("Aj,bBik,jkab->ABia",t1["Vo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s1VVov += 1.000000000 * np.einsum("Aj,BCik,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1VVov += 1.000000000 * np.einsum("Aj,jkaC,BCik->ABia",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1VVov += 0.500000000 * np.einsum("Cj,ABik,jkaC->ABia",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1VVov += 0.500000000 * np.einsum("Cj,jkaC,ABik->ABia",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1VVov += -1.000000000 * np.einsum("jC,bAij,BCab->ABia",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s1VVov += -0.500000000 * np.einsum("jC,bCij,ABab->ABia",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s1VVov += 1.000000000 * np.einsum("jC,ADij,BCaD->ABia",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVov += 0.500000000 * np.einsum("jC,CDij,ABaD->ABia",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s1VVov += 0.500000000 * np.einsum("jC,ABik,kCja->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVov += -1.000000000 * np.einsum("jC,ACik,kBja->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVov += -0.500000000 * np.einsum("jC,ABjk,kCia->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVov += 1.000000000 * np.einsum("jC,ACjk,kBia->ABia",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1VVvv += 1.000000000 * np.einsum("Ai,ijaC,BCjb->ABab",t1["Vo"],t2["oovV"],v["VVov"],optimize="optimal")
# ws2s1VVvv += 0.500000000 * np.einsum("Ci,ijaC,ABjb->ABab",t1["Vo"],t2["oovV"],v["VVov"],optimize="optimal")
# ws2s1VVvv += -0.250000000 * np.einsum("iC,ABij,jCab->ABab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2s1VVvv += 0.500000000 * np.einsum("iC,ACij,jBab->ABab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2s1VV += -0.500000000 * np.einsum("Ai,jkaB,iajk->AB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("Ai,ijaC,aCjB->AB",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1VV += 0.500000000 * np.einsum("Ai,jkBC,iCjk->AB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1VV += 0.500000000 * np.einsum("Ai,ijCD,CDjB->AB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("Ci,ijaA,aBjC->BA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1VV += -1.000000000 * np.einsum("Ci,ijaC,aBjA->BA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1VV += -0.500000000 * np.einsum("Ci,jkAC,iBjk->BA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("Ci,ijAD,BDjC->BA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VV += -1.000000000 * np.einsum("Ci,ijCD,BDjA->BA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("iA,aCij,jBaC->BA",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VV += 0.500000000 * np.einsum("iA,CDij,jBCD->BA",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VV += -0.500000000 * np.einsum("iA,aBjk,jkia->BA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1VV += 0.500000000 * np.einsum("iA,BCjk,jkiC->BA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("iC,aAij,jCaB->AB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VV += -1.000000000 * np.einsum("iC,aCij,jBaA->BA",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1VV += 1.000000000 * np.einsum("iC,ADij,jCBD->AB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VV += -1.000000000 * np.einsum("iC,CDij,jBAD->BA",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1VV += -0.500000000 * np.einsum("iC,ACjk,jkiB->AB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Bi,aAjk,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Bi,ACjk,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Bi,jkaB,aAjk->Ai",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Bi,jkBC,ACjk->Ai",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("Aj,aBik,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Aj,BCik,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("Aj,jkaB,aBik->Ai",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1Vo += -0.500000000 * np.einsum("Aj,jkBC,BCik->Ai",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("Bj,aAik,jkaB->Ai",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("Bj,ACik,jkBC->Ai",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("Bj,jkaB,aAik->Ai",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("Bj,jkBC,ACik->Ai",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("jB,aCij,ABaC->Ai",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1Vo += 0.500000000 * np.einsum("jB,CDij,ABCD->Ai",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("jB,aAik,kBja->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("jB,aBik,kAja->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("jB,ACik,kBjC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("jB,BCik,kAjC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("jB,aAjk,kBia->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("jB,aBjk,kAia->Ai",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1Vo += 1.000000000 * np.einsum("jB,ACjk,kBiC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1Vo += -1.000000000 * np.einsum("jB,BCjk,kAiC->Ai",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1Vo += 0.500000000 * np.einsum("jB,ABkl,klij->Ai",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1Vv += 0.500000000 * np.einsum("Ai,jkaB,iBjk->Aa",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1Vv += 1.000000000 * np.einsum("Ai,ijbB,bBja->Aa",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1Vv += 0.500000000 * np.einsum("Ai,ijBC,BCja->Aa",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1Vv += -0.500000000 * np.einsum("Bi,jkaB,iAjk->Aa",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1Vv += 1.000000000 * np.einsum("Bi,ijaC,ACjB->Aa",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1Vv += -1.000000000 * np.einsum("Bi,ijbB,bAja->Aa",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1Vv += -1.000000000 * np.einsum("Bi,ijBC,ACja->Aa",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1Vv += -1.000000000 * np.einsum("iB,bAij,jBab->Aa",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1Vv += 1.000000000 * np.einsum("iB,bBij,jAab->Aa",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1Vv += 1.000000000 * np.einsum("iB,ACij,jBaC->Aa",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1Vv += -1.000000000 * np.einsum("iB,BCij,jAaC->Aa",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1Vv += -0.500000000 * np.einsum("iB,ABjk,jkia->Aa",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVVVVV += 0.500000000 * np.einsum("Aj,ijaB,aECD->iAEBCD",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1oVVVVV += 0.500000000 * np.einsum("Aj,ikBC,jEkD->iAEBCD",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVVVV += -0.500000000 * np.einsum("Aj,jkBC,iEkD->iAEBCD",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVVVV += 0.500000000 * np.einsum("Aj,ijBG,EGCD->iAEBCD",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1oVVVVV += -0.250000000 * np.einsum("jA,BCjk,ikDE->iBCADE",t1["oV"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVVVV += -0.250000000 * np.einsum("jA,ikBC,DEjk->iDEABC",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVVoVV += -0.250000000 * np.einsum("Ei,jkAB,CDkE->jCDiAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVVoVV += 0.500000000 * np.einsum("Ei,jkAE,CDkB->jCDiAB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVVoVV += -1.000000000 * np.einsum("Ak,ikaB,aDjC->iADjBC",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVVoVV += -0.500000000 * np.einsum("Ak,ilBC,kDjl->iADjBC",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVVoVV += 0.500000000 * np.einsum("Ak,klBC,jDil->jADiBC",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVVoVV += -1.000000000 * np.einsum("Ak,ikBE,DEjC->iADjBC",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVVoVV += -1.000000000 * np.einsum("kA,aBik,jDaC->jBDiAC",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVVoVV += -1.000000000 * np.einsum("kA,BEik,jDCE->jBDiAC",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVVoVV += -0.500000000 * np.einsum("kA,BCil,jlkD->jBCiAD",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVVoVV += 0.500000000 * np.einsum("kA,BCkl,jliD->jBCiAD",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVVoVV += -0.250000000 * np.einsum("iE,ABjk,kECD->iABjCD",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVVoVV += 0.500000000 * np.einsum("iE,AEjk,kDBC->iADjBC",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVVvVV += 1.000000000 * np.einsum("Aj,ikaB,jDkC->iADaBC",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVVvVV += -1.000000000 * np.einsum("Aj,jkaB,iDkC->iADaBC",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVVvVV += 0.500000000 * np.einsum("Aj,ijaE,DEBC->iADaBC",t1["Vo"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws2s1oVVvVV += -1.000000000 * np.einsum("Aj,ijbB,bDaC->iADaBC",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws2s1oVVvVV += 0.500000000 * np.einsum("Aj,ikBC,jDka->iADaBC",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVVvVV += -0.500000000 * np.einsum("Aj,jkBC,iDka->iADaBC",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVVvVV += -1.000000000 * np.einsum("Aj,ijBE,DEaC->iADaBC",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2s1oVVvVV += 0.500000000 * np.einsum("jA,BCjk,ikaD->iBCaAD",t1["oV"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVVvVV += 0.500000000 * np.einsum("jA,ikaB,CDjk->iCDaAB",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Di,ABjl,klCD->kABijC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Di,jlAD,BCkl->jBCikA",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Al,aBij,klaC->kABijC",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Al,BDij,klCD->kABijC",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Al,ilaB,aCjk->iACjkB",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("Al,ilBD,CDjk->iACjkB",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVVooV += 0.500000000 * np.einsum("lA,aBij,kCla->kBCijA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVVooV += -0.500000000 * np.einsum("lA,BDij,kClD->kBCijA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVVooV += -1.000000000 * np.einsum("lA,aBil,kCja->kBCijA",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVVooV += 1.000000000 * np.einsum("lA,BDil,kCjD->kBCijA",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVVooV += -0.500000000 * np.einsum("lA,BCim,kmjl->kBCijA",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1oVVooV += -0.250000000 * np.einsum("lA,BClm,kmij->kBCijA",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1oVVooV += -0.500000000 * np.einsum("iD,aAjk,CDaB->iACjkB",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1oVVooV += -0.250000000 * np.einsum("iD,aDjk,BCaA->iBCjkA",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1oVVooV += -0.500000000 * np.einsum("iD,AEjk,CDBE->iACjkB",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1oVVooV += -0.250000000 * np.einsum("iD,DEjk,BCAE->iBCjkA",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1oVVooV += -0.500000000 * np.einsum("iD,ABjl,lDkC->iABjkC",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVVooV += 1.000000000 * np.einsum("iD,ADjl,lCkB->iACjkB",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVVovV += -0.500000000 * np.einsum("Di,jkaA,BCkD->jBCiaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1oVVovV += 0.500000000 * np.einsum("Di,jkaD,BCkA->jBCiaA",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1oVVovV += -0.500000000 * np.einsum("Di,jkAD,BCka->jBCiaA",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1oVVovV += -1.000000000 * np.einsum("Ak,ilaB,kCjl->iACjaB",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVVovV += 1.000000000 * np.einsum("Ak,klaB,jCil->jACiaB",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVVovV += -1.000000000 * np.einsum("Ak,ikaD,CDjB->iACjaB",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1oVVovV += 1.000000000 * np.einsum("Ak,ikbB,bCja->iACjaB",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1oVVovV += 1.000000000 * np.einsum("Ak,ikBD,CDja->iACjaB",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1oVVovV += -1.000000000 * np.einsum("kA,bBik,jCab->jBCiaA",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVVovV += 1.000000000 * np.einsum("kA,BDik,jCaD->jBCiaA",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVVovV += 0.500000000 * np.einsum("kA,BCil,jlka->jBCiaA",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVVovV += -0.500000000 * np.einsum("kA,BCkl,jlia->jBCiaA",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVVovV += -0.500000000 * np.einsum("iD,ABjk,kDaC->iABjaC",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVVovV += 1.000000000 * np.einsum("iD,ADjk,kCaB->iACjaB",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVVvvV += -1.000000000 * np.einsum("Aj,ikaB,jCkb->iACabB",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVVvvV += 1.000000000 * np.einsum("Aj,jkaB,iCkb->iACabB",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVVvvV += 1.000000000 * np.einsum("Aj,ijaD,CDbB->iACabB",t1["Vo"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws2s1oVVvvV += 0.500000000 * np.einsum("Aj,ijcB,cCab->iACabB",t1["Vo"],t2["oovV"],v["vVvv"],optimize="optimal")
# ws2s1oVVvvV += 0.500000000 * np.einsum("Aj,ijBD,CDab->iACabB",t1["Vo"],t2["ooVV"],v["VVvv"],optimize="optimal")
# ws2s1oVVvvV += -0.250000000 * np.einsum("jA,BCjk,ikab->iBCabA",t1["oV"],t2["VVoo"],v["oovv"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("Ci,aAjk,lBaC->lABijk",t1["Vo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("Ci,ADjk,lBCD->lABijk",t1["Vo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("Ci,ABjm,lmkC->lABijk",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVVooo += -0.500000000 * np.einsum("Am,aBij,lmka->lABijk",t1["Vo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("Am,BCij,lmkC->lABijk",t1["Vo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("iC,aAjk,BCla->iABjkl",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1oVVooo += 0.250000000 * np.einsum("iC,aCjk,ABla->iABjkl",t1["oV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s1oVVooo += -0.500000000 * np.einsum("iC,ADjk,BClD->iABjkl",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1oVVooo += -0.250000000 * np.einsum("iC,CDjk,ABlD->iABjkl",t1["oV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s1oVVooo += -0.250000000 * np.einsum("iC,ABjm,mCkl->iABjkl",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1oVVooo += 0.500000000 * np.einsum("iC,ACjm,mBkl->iABjkl",t1["oV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s1oVVoov += 0.500000000 * np.einsum("Ci,ABjl,klaC->kABija",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVVoov += 0.500000000 * np.einsum("Ci,jlaC,ABkl->jABika",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVVoov += -0.500000000 * np.einsum("Al,bBij,klab->kABija",t1["Vo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s1oVVoov += 0.500000000 * np.einsum("Al,BCij,klaC->kABija",t1["Vo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVVoov += 0.500000000 * np.einsum("Al,ilaC,BCjk->iABjka",t1["Vo"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVVoov += 0.500000000 * np.einsum("iC,bAjk,BCab->iABjka",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s1oVVoov += 0.250000000 * np.einsum("iC,bCjk,ABab->iABjka",t1["oV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s1oVVoov += -0.500000000 * np.einsum("iC,ADjk,BCaD->iABjka",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s1oVVoov += -0.250000000 * np.einsum("iC,CDjk,ABaD->iABjka",t1["oV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s1oVVoov += -0.500000000 * np.einsum("iC,ABjl,lCka->iABjka",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1oVVoov += 1.000000000 * np.einsum("iC,ACjl,lBka->iABjka",t1["oV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s1oVVovv += 0.500000000 * np.einsum("Ci,jkaC,ABkb->jABiab",t1["Vo"],t2["oovV"],v["VVov"],optimize="optimal")
# ws2s1oVVovv += -1.000000000 * np.einsum("Ak,ikaC,BCjb->iABjab",t1["Vo"],t2["oovV"],v["VVov"],optimize="optimal")
# ws2s1oVVovv += -0.250000000 * np.einsum("iC,ABjk,kCab->iABjab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVVovv += 0.500000000 * np.einsum("iC,ACjk,kBab->iABjab",t1["oV"],t2["VVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVVvvv += 0.500000000 * np.einsum("Aj,ijaC,BCbc->iABabc",t1["Vo"],t2["oovV"],v["VVvv"],optimize="optimal")
# ws2s1oVVV += -1.000000000 * np.einsum("Aj,ikaB,jakC->iABC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("Aj,jkaB,iakC->iABC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws2s1oVVV += -0.500000000 * np.einsum("Aj,ijaD,aDBC->iABC",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1oVVV += -0.250000000 * np.einsum("Aj,klBC,ijkl->iABC",t1["Vo"],t2["ooVV"],v["oooo"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("Aj,ikBD,jDkC->iABC",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += -1.000000000 * np.einsum("Aj,jkBD,iDkC->iABC",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += -0.250000000 * np.einsum("Aj,ijDE,DEBC->iABC",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("Dj,ijaA,aCBD->iCAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1oVVV += 0.500000000 * np.einsum("Dj,ijaD,aCAB->iCAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1oVVV += 0.500000000 * np.einsum("Dj,ikAB,jCkD->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += -0.500000000 * np.einsum("Dj,jkAB,iCkD->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += -1.000000000 * np.einsum("Dj,ikAD,jCkB->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("Dj,jkAD,iCkB->iCAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("Dj,ijAE,CEBD->iCAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1oVVV += 0.500000000 * np.einsum("Dj,ijDE,CEAB->iCAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("jA,aBjk,ikaC->iBAC",t1["oV"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("jA,BDjk,ikCD->iBAC",t1["oV"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("jA,ikaB,aCjk->iCAB",t1["oV"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1oVVV += 1.000000000 * np.einsum("jA,ikBD,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVVV += -0.250000000 * np.einsum("iD,ADjk,jkBC->iABC",t1["oV"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVV += -0.250000000 * np.einsum("iD,jkAB,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVVV += 0.500000000 * np.einsum("jD,ADjk,ikBC->iABC",t1["oV"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVVV += 0.500000000 * np.einsum("jD,ikAB,CDjk->iCAB",t1["oV"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ci,jkaA,aBkC->jBiA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ci,jkaC,aBkA->jBiA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVoV += -0.500000000 * np.einsum("Ci,klAC,jBkl->jBiA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ci,jkAD,BDkC->jBiA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ci,jkCD,BDkA->jBiA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ak,ilaB,kajl->iAjB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ak,klaB,jail->jAiB",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ak,ikaC,aCjB->iAjB",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ak,ilBC,kCjl->iAjB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ak,klBC,jCil->jAiB",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVoV += -0.500000000 * np.einsum("Ak,ikCD,CDjB->iAjB",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ck,ikaA,aBjC->iBjA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ck,ikaC,aBjA->iBjA",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ck,ilAC,kBjl->iBjA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ck,klAC,jBil->jBiA",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("Ck,ikAD,BDjC->iBjA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("Ck,ikCD,BDjA->iBjA",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kA,aCik,jBaC->jBiA",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVoV += -0.500000000 * np.einsum("kA,CDik,jBCD->jBiA",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kA,aBil,jlka->jBiA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("kA,BCil,jlkC->jBiA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("kA,aBkl,jlia->jBiA",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kA,BCkl,jliC->jBiA",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("iC,aAjk,kCaB->iAjB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("iC,aCjk,kBaA->iBjA",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("iC,ADjk,kCBD->iAjB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("iC,CDjk,kBAD->iBjA",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVoV += -0.500000000 * np.einsum("iC,ACkl,kljB->iAjB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kC,aAik,jCaB->jAiB",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("kC,aCik,jBaA->jBiA",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kC,ADik,jCBD->jAiB",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("kC,CDik,jBAD->jBiA",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1oVoV += -1.000000000 * np.einsum("kC,ACil,jlkB->jAiB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVoV += 1.000000000 * np.einsum("kC,ACkl,jliB->jAiB",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s1oVvV += -0.500000000 * np.einsum("Aj,klaB,ijkl->iAaB",t1["Vo"],t2["oovV"],v["oooo"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Aj,ikaC,jCkB->iAaB",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Aj,jkaC,iCkB->iAaB",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Aj,ikbB,jbka->iAaB",t1["Vo"],t2["oovV"],v["ovov"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Aj,jkbB,ibka->iAaB",t1["Vo"],t2["oovV"],v["ovov"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Aj,ijbC,bCaB->iAaB",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Aj,ikBC,jCka->iAaB",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Aj,jkBC,iCka->iAaB",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVvV += -0.500000000 * np.einsum("Aj,ijCD,CDaB->iAaB",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,ikaA,jBkC->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Cj,jkaA,iBkC->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Cj,ikaC,jBkA->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,jkaC,iBkA->iBaA",t1["Vo"],t2["oovV"],v["oVoV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,ijaD,BDAC->iBaA",t1["Vo"],t2["oovV"],v["VVVV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Cj,ijbA,bBaC->iBaA",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,ijbC,bBaA->iBaA",t1["Vo"],t2["oovV"],v["vVvV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,ikAC,jBka->iBaA",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Cj,jkAC,iBka->iBaA",t1["Vo"],t2["ooVV"],v["oVov"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("Cj,ijAD,BDaC->iBaA",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("Cj,ijCD,BDaA->iBaA",t1["Vo"],t2["ooVV"],v["VVvV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("jA,bBjk,ikab->iBaA",t1["oV"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("jA,BCjk,ikaC->iBaA",t1["oV"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVvV += -1.000000000 * np.einsum("jA,ikaC,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVvV += -0.500000000 * np.einsum("iC,ACjk,jkaB->iAaB",t1["oV"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVvV += -0.500000000 * np.einsum("iC,jkaA,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("jC,ACjk,ikaB->iAaB",t1["oV"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s1oVvV += 1.000000000 * np.einsum("jC,ikaA,BCjk->iBaA",t1["oV"],t2["oovV"],v["VVoo"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("Bi,aAjl,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("Bi,ACjl,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("Bi,jlaB,aAkl->jAik",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("Bi,jlBC,ACkl->jAik",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVoo += -0.500000000 * np.einsum("Al,aBij,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1oVoo += -0.250000000 * np.einsum("Al,BCij,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVoo += -0.500000000 * np.einsum("Al,ilaB,aBjk->iAjk",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1oVoo += -0.250000000 * np.einsum("Al,ilBC,BCjk->iAjk",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("Bl,aAij,klaB->kAij",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("Bl,ACij,klBC->kAij",t1["Vo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("Bl,ilaB,aAjk->iAjk",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("Bl,ilBC,ACjk->iAjk",t1["Vo"],t2["ooVV"],v["VVoo"],optimize="optimal")
# ws2s1oVoo += -0.500000000 * np.einsum("iB,aCjk,ABaC->iAjk",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1oVoo += -0.250000000 * np.einsum("iB,CDjk,ABCD->iAjk",t1["oV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s1oVoo += -1.000000000 * np.einsum("iB,aAjl,lBka->iAjk",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("iB,aBjl,lAka->iAjk",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("iB,ACjl,lBkC->iAjk",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += -1.000000000 * np.einsum("iB,BCjl,lAkC->iAjk",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += -0.250000000 * np.einsum("iB,ABlm,lmjk->iAjk",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1oVoo += -0.500000000 * np.einsum("lB,aAij,kBla->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("lB,aBij,kAla->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("lB,ACij,kBlC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += -0.500000000 * np.einsum("lB,BCij,kAlC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("lB,aAil,kBja->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += -1.000000000 * np.einsum("lB,aBil,kAja->kAij",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1oVoo += -1.000000000 * np.einsum("lB,ACil,kBjC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("lB,BCil,kAjC->kAij",t1["oV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s1oVoo += 1.000000000 * np.einsum("lB,ABim,kmjl->kAij",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1oVoo += 0.500000000 * np.einsum("lB,ABlm,kmij->kAij",t1["oV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s1oVov += -0.500000000 * np.einsum("Bi,klaB,jAkl->jAia",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("Bi,jkaC,ACkB->jAia",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Bi,jkbB,bAka->jAia",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Bi,jkBC,ACka->jAia",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("Ak,ilaB,kBjl->iAja",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Ak,klaB,jBil->jAia",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Ak,ikbB,bBja->iAja",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1oVov += -0.500000000 * np.einsum("Ak,ikBC,BCja->iAja",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Bk,ilaB,kAjl->iAja",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("Bk,klaB,jAil->jAia",t1["Vo"],t2["oovV"],v["oVoo"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("Bk,ikaC,ACjB->iAja",t1["Vo"],t2["oovV"],v["VVoV"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("Bk,ikbB,bAja->iAja",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("Bk,ikBC,ACja->iAja",t1["Vo"],t2["ooVV"],v["VVov"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("iB,bAjk,kBab->iAja",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("iB,bBjk,kAab->iAja",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("iB,ACjk,kBaC->iAja",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("iB,BCjk,kAaC->iAja",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVov += -0.500000000 * np.einsum("iB,ABkl,klja->iAja",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("kB,bAik,jBab->jAia",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("kB,bBik,jAab->jAia",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("kB,ACik,jBaC->jAia",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("kB,BCik,jAaC->jAia",t1["oV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s1oVov += -1.000000000 * np.einsum("kB,ABil,jlka->jAia",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVov += 1.000000000 * np.einsum("kB,ABkl,jlia->jAia",t1["oV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s1oVvv += 1.000000000 * np.einsum("Aj,ikaB,jBkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVvv += -1.000000000 * np.einsum("Aj,jkaB,iBkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVvv += -0.500000000 * np.einsum("Aj,ijcB,cBab->iAab",t1["Vo"],t2["oovV"],v["vVvv"],optimize="optimal")
# ws2s1oVvv += -0.250000000 * np.einsum("Aj,ijBC,BCab->iAab",t1["Vo"],t2["ooVV"],v["VVvv"],optimize="optimal")
# ws2s1oVvv += -1.000000000 * np.einsum("Bj,ikaB,jAkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVvv += 1.000000000 * np.einsum("Bj,jkaB,iAkb->iAab",t1["Vo"],t2["oovV"],v["oVov"],optimize="optimal")
# ws2s1oVvv += 1.000000000 * np.einsum("Bj,ijaC,ACbB->iAab",t1["Vo"],t2["oovV"],v["VVvV"],optimize="optimal")
# ws2s1oVvv += 0.500000000 * np.einsum("Bj,ijcB,cAab->iAab",t1["Vo"],t2["oovV"],v["vVvv"],optimize="optimal")
# ws2s1oVvv += 0.500000000 * np.einsum("Bj,ijBC,ACab->iAab",t1["Vo"],t2["ooVV"],v["VVvv"],optimize="optimal")
# ws2s1oVvv += -0.250000000 * np.einsum("iB,ABjk,jkab->iAab",t1["oV"],t2["VVoo"],v["oovv"],optimize="optimal")
# ws2s1oVvv += 0.500000000 * np.einsum("jB,ABjk,ikab->iAab",t1["oV"],t2["VVoo"],v["oovv"],optimize="optimal")
# ws2s1ooVVVV += -0.250000000 * np.einsum("Ak,ijaB,kaCD->ijABCD",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws2s1ooVVVV += 0.500000000 * np.einsum("Ak,ikaB,jaCD->ijABCD",t1["Vo"],t2["oovV"],v["ovVV"],optimize="optimal")
# ws2s1ooVVVV += 0.500000000 * np.einsum("Ak,ilBC,jklD->ijABCD",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws2s1ooVVVV += 0.250000000 * np.einsum("Ak,klBC,ijlD->ijABCD",t1["Vo"],t2["ooVV"],v["oooV"],optimize="optimal")
# ws2s1ooVVVV += 0.250000000 * np.einsum("Ak,ijBE,kECD->ijABCD",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws2s1ooVVVV += -0.500000000 * np.einsum("Ak,ikBE,jECD->ijABCD",t1["Vo"],t2["ooVV"],v["oVVV"],optimize="optimal")
# ws2s1ooVVVV += -0.500000000 * np.einsum("kA,ijaB,aDkC->ijDABC",t1["oV"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1ooVVVV += -0.500000000 * np.einsum("kA,ilBC,jDkl->ijDABC",t1["oV"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1ooVVVV += -0.500000000 * np.einsum("kA,ijBE,DEkC->ijDABC",t1["oV"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1ooVVVV += -0.500000000 * np.einsum("iE,jkAB,DEkC->ijDABC",t1["oV"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1ooVoVV += -0.500000000 * np.einsum("Di,jkaA,aCBD->jkCiAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1ooVoVV += -0.250000000 * np.einsum("Di,jkaD,aCAB->jkCiAB",t1["Vo"],t2["oovV"],v["vVVV"],optimize="optimal")
# ws2s1ooVoVV += -0.500000000 * np.einsum("Di,jlAB,kClD->jkCiAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1ooVoVV += 1.000000000 * np.einsum("Di,jlAD,kClB->jkCiAB",t1["Vo"],t2["ooVV"],v["oVoV"],optimize="optimal")
# ws2s1ooVoVV += -0.500000000 * np.einsum("Di,jkAE,CEBD->jkCiAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1ooVoVV += -0.250000000 * np.einsum("Di,jkDE,CEAB->jkCiAB",t1["Vo"],t2["ooVV"],v["VVVV"],optimize="optimal")
# ws2s1ooVoVV += 0.500000000 * np.einsum("Al,ijaB,lakC->ijAkBC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws2s1ooVoVV += -1.000000000 * np.einsum("Al,ilaB,kajC->ikAjBC",t1["Vo"],t2["oovV"],v["ovoV"],optimize="optimal")
# ws2s1ooVoVV += -0.500000000 * np.einsum("Al,imBC,kljm->ikAjBC",t1["Vo"],t2["ooVV"],v["oooo"],optimize="optimal")
# ...
# ws2s1vVoo += 0.500000000 * np.einsum("kB,aBkl,lAij->aAij",t1["oV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s1vVoo += -0.500000000 * np.einsum("kB,ABkl,laij->aAij",t1["oV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s1vVov += -0.500000000 * np.einsum("Bi,aAjk,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1vVov += -0.500000000 * np.einsum("Bi,jkaB,bAjk->bAia",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("Aj,aBik,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("Aj,jkaB,bBik->bAia",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("Bj,aAik,jkbB->aAib",t1["Vo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("Bj,jkaB,bAik->bAia",t1["Vo"],t2["oovV"],v["vVoo"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,aCij,ABbC->aAib",t1["oV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,cAij,bBac->bAia",t1["oV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("jB,cBij,bAac->bAia",t1["oV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("jB,ACij,bBaC->bAia",t1["oV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,BCij,bAaC->bAia",t1["oV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,aAik,kBjb->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("jB,aBik,kAjb->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,ABik,kbja->bAia",t1["oV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("jB,aAjk,kBib->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1vVov += 1.000000000 * np.einsum("jB,aBjk,kAib->aAib",t1["oV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s1vVov += -1.000000000 * np.einsum("jB,ABjk,kbia->bAia",t1["oV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws2s1vVvv += -1.000000000 * np.einsum("Ai,ijaB,cBjb->cAab",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1vVvv += 1.000000000 * np.einsum("Bi,ijaB,cAjb->cAab",t1["Vo"],t2["oovV"],v["vVov"],optimize="optimal")
# ws2s1vVvv += -0.500000000 * np.einsum("iB,aAij,jBbc->aAbc",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1vVvv += 0.500000000 * np.einsum("iB,aBij,jAbc->aAbc",t1["oV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s1vVvv += -0.500000000 * np.einsum("iB,ABij,jcab->cAab",t1["oV"],t2["VVoo"],v["ovvv"],optimize="optimal")
# ws2s1vvVVVV += 0.250000000 * np.einsum("Ai,ijBC,abjD->abABCD",t1["Vo"],t2["ooVV"],v["vvoV"],optimize="optimal")
# ws2s1vvVVVV += -0.500000000 * np.einsum("iA,aBij,jbCD->abBACD",t1["oV"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvVoVV += -0.250000000 * np.einsum("Aj,jkBC,abik->abAiBC",t1["Vo"],t2["ooVV"],v["vvoo"],optimize="optimal")
# ws2s1vvVoVV += 1.000000000 * np.einsum("jA,aDij,bCBD->abCiAB",t1["oV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s1vvVoVV += 0.500000000 * np.einsum("jA,cBij,abcC->abBiAC",t1["oV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvVoVV += 0.500000000 * np.einsum("jA,BDij,abCD->abBiAC",t1["oV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvVoVV += -1.000000000 * np.einsum("jA,aBik,kbjC->abBiAC",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvVoVV += 1.000000000 * np.einsum("jA,aBjk,kbiC->abBiAC",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvVvVV += 0.500000000 * np.einsum("Ai,ijaB,bcjC->bcAaBC",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws2s1vvVvVV += 0.250000000 * np.einsum("Ai,ijBC,bcja->bcAaBC",t1["Vo"],t2["ooVV"],v["vvov"],optimize="optimal")
# ws2s1vvVvVV += 1.000000000 * np.einsum("iA,aBij,jcbC->acBbAC",t1["oV"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vvVooV += 1.000000000 * np.einsum("Ci,aAjk,kbBC->abAijB",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvVooV += -0.500000000 * np.einsum("Ak,aCij,kbBC->abAijB",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvVooV += 0.500000000 * np.einsum("kA,aCij,bBkC->abBijA",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s1vvVooV += -0.250000000 * np.einsum("kA,cBij,abkc->abBijA",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s1vvVooV += 0.250000000 * np.einsum("kA,BCij,abkC->abBijA",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvVooV += -1.000000000 * np.einsum("kA,aCik,bBjC->abBijA",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s1vvVooV += 0.500000000 * np.einsum("kA,cBik,abjc->abBijA",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s1vvVooV += -0.500000000 * np.einsum("kA,BCik,abjC->abBijA",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvVooV += -1.000000000 * np.einsum("kA,aBil,lbjk->abBijA",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s1vvVooV += -0.500000000 * np.einsum("kA,aBkl,lbij->abBijA",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s1vvVovV += -0.500000000 * np.einsum("Aj,jkaB,bcik->bcAiaB",t1["Vo"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws2s1vvVovV += -1.000000000 * np.einsum("jA,aCij,cBbC->acBibA",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s1vvVovV += 0.500000000 * np.einsum("jA,dBij,bcad->bcBiaA",t1["oV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s1vvVovV += -0.500000000 * np.einsum("jA,BCij,bcaC->bcBiaA",t1["oV"],t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvVovV += 1.000000000 * np.einsum("jA,aBik,kcjb->acBibA",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vvVovV += -1.000000000 * np.einsum("jA,aBjk,kcib->acBibA",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vvVvvV += -0.500000000 * np.einsum("Ai,ijaB,cdjb->cdAabB",t1["Vo"],t2["oovV"],v["vvov"],optimize="optimal")
# ws2s1vvVvvV += -0.500000000 * np.einsum("iA,aBij,jdbc->adBbcA",t1["oV"],t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2s1vvVooo += -0.500000000 * np.einsum("Bi,aCjk,bABC->abAijk",t1["Vo"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s1vvVooo += -0.250000000 * np.einsum("Bi,cAjk,abcB->abAijk",t1["Vo"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvVooo += -0.250000000 * np.einsum("Bi,ACjk,abBC->abAijk",t1["Vo"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvVooo += 1.000000000 * np.einsum("Bi,aAjl,lbkB->abAijk",t1["Vo"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvVooo += -0.500000000 * np.einsum("Al,aBij,lbkB->abAijk",t1["Vo"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvVoov += 1.000000000 * np.einsum("Bi,aAjk,kcbB->acAijb",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vvVoov += -0.500000000 * np.einsum("Ak,aBij,kcbB->acAijb",t1["Vo"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vvvoVV += 0.500000000 * np.einsum("jA,aCij,bcBC->abciAB",t1["oV"],t2["vVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvvooV += 0.250000000 * np.einsum("kA,aBij,bckB->abcijA",t1["oV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvvooV += -0.500000000 * np.einsum("kA,aBik,bcjB->abcijA",t1["oV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvvovV += -0.500000000 * np.einsum("jA,aBij,cdbB->acdibA",t1["oV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvvooo += -0.250000000 * np.einsum("Ai,aBjk,bcAB->abcijk",t1["Vo"],t2["vVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvVV += -0.250000000 * np.einsum("Ci,ijAB,abjC->abAB",t1["Vo"],t2["ooVV"],v["vvoV"],optimize="optimal")
# ws2s1vvVV += 0.500000000 * np.einsum("Ci,ijAC,abjB->abAB",t1["Vo"],t2["ooVV"],v["vvoV"],optimize="optimal")
# ws2s1vvVV += 1.000000000 * np.einsum("iA,aCij,jbBC->abAB",t1["oV"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvVV += 0.500000000 * np.einsum("iC,aCij,jbAB->abAB",t1["oV"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvoV += -0.250000000 * np.einsum("Bi,jkAB,abjk->abiA",t1["Vo"],t2["ooVV"],v["vvoo"],optimize="optimal")
# ws2s1vvoV += 0.500000000 * np.einsum("Bj,jkAB,abik->abiA",t1["Vo"],t2["ooVV"],v["vvoo"],optimize="optimal")
# ws2s1vvoV += -0.500000000 * np.einsum("jA,cBij,abcB->abiA",t1["oV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvoV += -0.250000000 * np.einsum("jA,BCij,abBC->abiA",t1["oV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvoV += 1.000000000 * np.einsum("jA,aBik,kbjB->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvoV += -1.000000000 * np.einsum("jA,aBjk,kbiB->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvoV += 1.000000000 * np.einsum("jB,aCij,bBAC->abiA",t1["oV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s1vvoV += 0.500000000 * np.einsum("jB,cBij,abcA->abiA",t1["oV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvoV += 0.500000000 * np.einsum("jB,BCij,abAC->abiA",t1["oV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s1vvoV += -1.000000000 * np.einsum("jB,aBik,kbjA->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvoV += 1.000000000 * np.einsum("jB,aBjk,kbiA->abiA",t1["oV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s1vvvV += -0.500000000 * np.einsum("Bi,ijaA,bcjB->bcaA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws2s1vvvV += 0.500000000 * np.einsum("Bi,ijaB,bcjA->bcaA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws2s1vvvV += -0.500000000 * np.einsum("Bi,ijAB,bcja->bcaA",t1["Vo"],t2["ooVV"],v["vvov"],optimize="optimal")
# ws2s1vvvV += -1.000000000 * np.einsum("iA,aBij,jcbB->acbA",t1["oV"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vvvV += 1.000000000 * np.einsum("iB,aBij,jcbA->acbA",t1["oV"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vvoo += 1.000000000 * np.einsum("Ai,aBjk,kbAB->abij",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvoo += 0.500000000 * np.einsum("Ak,aBij,kbAB->abij",t1["Vo"],t2["vVoo"],v["ovVV"],optimize="optimal")
# ws2s1vvoo += -0.500000000 * np.einsum("kA,aBij,bAkB->abij",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s1vvoo += 0.250000000 * np.einsum("kA,cAij,abkc->abij",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s1vvoo += -0.250000000 * np.einsum("kA,ABij,abkB->abij",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvoo += 1.000000000 * np.einsum("kA,aBik,bAjB->abij",t1["oV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s1vvoo += -0.500000000 * np.einsum("kA,cAik,abjc->abij",t1["oV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s1vvoo += 0.500000000 * np.einsum("kA,ABik,abjB->abij",t1["oV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s1vvoo += 1.000000000 * np.einsum("kA,aAil,lbjk->abij",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s1vvoo += 0.500000000 * np.einsum("kA,aAkl,lbij->abij",t1["oV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s1vvov += -0.250000000 * np.einsum("Ai,jkaA,bcjk->bcia",t1["Vo"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws2s1vvov += 0.500000000 * np.einsum("Aj,jkaA,bcik->bcia",t1["Vo"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws2s1vvov += 1.000000000 * np.einsum("jA,aBij,cAbB->acib",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s1vvov += -0.500000000 * np.einsum("jA,dAij,bcad->bcia",t1["oV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s1vvov += 0.500000000 * np.einsum("jA,ABij,bcaB->bcia",t1["oV"],t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2s1vvov += -1.000000000 * np.einsum("jA,aAik,kcjb->acib",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vvov += 1.000000000 * np.einsum("jA,aAjk,kcib->acib",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vvvv += 0.500000000 * np.einsum("Ai,ijaA,cdjb->cdab",t1["Vo"],t2["oovV"],v["vvov"],optimize="optimal")
# ws2s1vvvv += 0.500000000 * np.einsum("iA,aAij,jdbc->adbc",t1["oV"],t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2s1vV += -1.000000000 * np.einsum("Bi,ijbA,abjB->aA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws2s1vV += 1.000000000 * np.einsum("Bi,ijbB,abjA->aA",t1["Vo"],t2["oovV"],v["vvoV"],optimize="optimal")
# ws2s1vV += -0.500000000 * np.einsum("Bi,jkAB,iajk->aA",t1["Vo"],t2["ooVV"],v["ovoo"],optimize="optimal")
# ws2s1vV += 1.000000000 * np.einsum("Bi,ijAC,aCjB->aA",t1["Vo"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws2s1vV += -1.000000000 * np.einsum("Bi,ijBC,aCjA->aA",t1["Vo"],t2["ooVV"],v["vVoV"],optimize="optimal")
# ws2s1vV += 1.000000000 * np.einsum("iA,bBij,jabB->aA",t1["oV"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vV += 0.500000000 * np.einsum("iA,BCij,jaBC->aA",t1["oV"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2s1vV += 0.500000000 * np.einsum("iA,aBjk,jkiB->aA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws2s1vV += 1.000000000 * np.einsum("iB,aCij,jBAC->aA",t1["oV"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws2s1vV += -1.000000000 * np.einsum("iB,bBij,jabA->aA",t1["oV"],t2["vVoo"],v["ovvV"],optimize="optimal")
# ws2s1vV += -1.000000000 * np.einsum("iB,BCij,jaAC->aA",t1["oV"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2s1vV += -0.500000000 * np.einsum("iB,aBjk,jkiA->aA",t1["oV"],t2["vVoo"],v["oooV"],optimize="optimal")
# ws2s1vo += -0.500000000 * np.einsum("Ai,aBjk,jkAB->ai",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2s1vo += 0.500000000 * np.einsum("Ai,jkbA,abjk->ai",t1["Vo"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws2s1vo += -0.500000000 * np.einsum("Ai,jkAB,aBjk->ai",t1["Vo"],t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("Aj,aBik,jkAB->ai",t1["Vo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2s1vo += -1.000000000 * np.einsum("Aj,jkbA,abik->ai",t1["Vo"],t2["oovV"],v["vvoo"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("Aj,jkAB,aBik->ai",t1["Vo"],t2["ooVV"],v["vVoo"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("jA,bBij,aAbB->ai",t1["oV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s1vo += 0.500000000 * np.einsum("jA,BCij,aABC->ai",t1["oV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s1vo += -1.000000000 * np.einsum("jA,aBik,kAjB->ai",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s1vo += -1.000000000 * np.einsum("jA,bAik,kajb->ai",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("jA,ABik,kajB->ai",t1["oV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("jA,aBjk,kAiB->ai",t1["oV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s1vo += 1.000000000 * np.einsum("jA,bAjk,kaib->ai",t1["oV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s1vo += -1.000000000 * np.einsum("jA,ABjk,kaiB->ai",t1["oV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s1vo += 0.500000000 * np.einsum("jA,aAkl,klij->ai",t1["oV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws2s1vv += -0.500000000 * np.einsum("Ai,jkaA,ibjk->ba",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws2s1vv += 1.000000000 * np.einsum("Ai,ijaB,bBjA->ba",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1vv += 1.000000000 * np.einsum("Ai,ijcA,bcja->ba",t1["Vo"],t2["oovV"],v["vvov"],optimize="optimal")
# ws2s1vv += -1.000000000 * np.einsum("Ai,ijAB,bBja->ba",t1["Vo"],t2["ooVV"],v["vVov"],optimize="optimal")
# ws2s1vv += 1.000000000 * np.einsum("iA,aBij,jAbB->ab",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1vv += 1.000000000 * np.einsum("iA,cAij,jbac->ba",t1["oV"],t2["vVoo"],v["ovvv"],optimize="optimal")
# ws2s1vv += -1.000000000 * np.einsum("iA,ABij,jbaB->ba",t1["oV"],t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2s1vv += -0.500000000 * np.einsum("iA,aAjk,jkib->ab",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1 += 0.500000000 * np.einsum("Ai,jkaA,iajk->",t1["Vo"],t2["oovV"],v["ovoo"],optimize="optimal")
# ws2s1 += -1.000000000 * np.einsum("Ai,ijaB,aBjA->",t1["Vo"],t2["oovV"],v["vVoV"],optimize="optimal")
# ws2s1 += -0.500000000 * np.einsum("Ai,jkAB,iBjk->",t1["Vo"],t2["ooVV"],v["oVoo"],optimize="optimal")
# ws2s1 += -0.500000000 * np.einsum("Ai,ijBC,BCjA->",t1["Vo"],t2["ooVV"],v["VVoV"],optimize="optimal")
# ws2s1 += -1.000000000 * np.einsum("iA,aBij,jAaB->",t1["oV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s1 += -0.500000000 * np.einsum("iA,BCij,jABC->",t1["oV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s1 += 0.500000000 * np.einsum("iA,aAjk,jkia->",t1["oV"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s1 += -0.500000000 * np.einsum("iA,ABjk,jkiB->",t1["oV"],t2["VVoo"],v["oooV"],optimize="optimal")

# %%
# [[W,s2_ext],s2_ext]
print("[[W,s2_ext],s2_ext]")
Ws2s2 = w.commutator(W,s2_ext,s2_ext)
expr = wt.contract(Ws2s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('ws2s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[W,s2_ext],s2_ext]
# ws2s2VVVVVV += -0.125000000 * np.einsum("ijaA,BCij,aGDE->BCGADE",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VVVVVV += -0.125000000 * np.einsum("ijAB,aCij,EGaD->CEGABD",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVVVV += -0.125000000 * np.einsum("ijAB,Caij,EGDa->CEGABD",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVVVV += -0.500000000 * np.einsum("ijAB,CDik,kGjE->CDGABE",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVVVV += -0.125000000 * np.einsum("ijAa,BCij,GaDE->BCGADE",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkaA,aBij,DEkC->BDEiAC",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkaA,BCij,aEkD->BCEiAD",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.250000000 * np.einsum("jkaA,BCjk,aEiD->BCEiAD",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkAB,aCij,DEka->CDEiAB",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVoVV += -0.500000000 * np.einsum("jkAB,CGij,DEkG->CDEiAB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVoVV += -0.250000000 * np.einsum("jkAB,CDil,lEjk->CDEiAB",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVVoVV += 0.125000000 * np.einsum("jkAB,aCjk,DEia->CDEiAB",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVoVV += -0.125000000 * np.einsum("jkAB,CGjk,DEiG->CDEiAB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkAB,CDjl,lEik->CDEiAB",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkAG,BCij,EGkD->BCEiAD",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.500000000 * np.einsum("jkAG,BGij,DEkC->BDEiAC",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVoVV += 0.250000000 * np.einsum("jkAG,BCjk,EGiD->BCEiAD",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVvVV += -0.250000000 * np.einsum("ijaA,bBij,DEbC->BDEaAC",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVvVV += -0.250000000 * np.einsum("ijaA,BGij,DECG->BDEaAC",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVvVV += -1.000000000 * np.einsum("ijaA,BCik,kEjD->BCEaAD",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVvVV += -0.125000000 * np.einsum("ijaG,ABij,EGCD->ABEaCD",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVvVV += 0.250000000 * np.einsum("ijbA,BCij,bEaD->BCEaAD",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2VVVvVV += 0.125000000 * np.einsum("ijAB,bCij,DEab->CDEaAB",t2["ooVV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVVvVV += -0.125000000 * np.einsum("ijAB,CGij,DEaG->CDEaAB",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVvVV += -0.500000000 * np.einsum("ijAB,CDik,kEja->CDEaAB",t2["ooVV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVVvVV += 0.250000000 * np.einsum("ijAG,BCij,EGaD->BCEaAD",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVooV += -0.250000000 * np.einsum("AEij,BCkl,klDE->ABCijD",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVVooV += 1.000000000 * np.einsum("ABik,aCjl,klaD->ABCijD",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVVooV += 1.000000000 * np.einsum("ABik,CEjl,klDE->ABCijD",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVVooV += -0.250000000 * np.einsum("ABkl,aCij,klaD->ABCijD",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVVooV += -0.125000000 * np.einsum("klaA,aBij,CDkl->BCDijA",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVooV += 0.500000000 * np.einsum("klaA,aBik,CDjl->BCDijA",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVooV += 0.500000000 * np.einsum("klaA,BCik,aDjl->BCDijA",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVVooV += -0.125000000 * np.einsum("klaA,BCkl,aDij->BCDijA",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVVooV += -0.125000000 * np.einsum("klAE,BEij,CDkl->BCDijA",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVooV += 0.500000000 * np.einsum("klAE,BCik,DEjl->BCDijA",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVooV += 0.500000000 * np.einsum("klAE,BEik,CDjl->BCDijA",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVooV += -0.125000000 * np.einsum("klAE,BCkl,DEij->BCDijA",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVovV += 1.000000000 * np.einsum("jkaA,bBij,CDkb->BCDiaA",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovV += -1.000000000 * np.einsum("jkaA,BEij,CDkE->BCDiaA",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVovV += -0.500000000 * np.einsum("jkaA,BCil,lDjk->BCDiaA",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVVovV += 0.250000000 * np.einsum("jkaA,bBjk,CDib->BCDiaA",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovV += -0.250000000 * np.einsum("jkaA,BEjk,CDiE->BCDiaA",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVovV += 1.000000000 * np.einsum("jkaA,BCjl,lDik->BCDiaA",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVVovV += 0.500000000 * np.einsum("jkaE,ABij,DEkC->ABDiaC",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVovV += 0.500000000 * np.einsum("jkaE,AEij,CDkB->ACDiaB",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVovV += 0.250000000 * np.einsum("jkaE,ABjk,DEiC->ABDiaC",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVVovV += -0.500000000 * np.einsum("jkbA,bBij,CDka->BCDiaA",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovV += -0.500000000 * np.einsum("jkbA,BCij,bDka->BCDiaA",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVVovV += -0.250000000 * np.einsum("jkbA,BCjk,bDia->BCDiaA",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVVovV += -0.500000000 * np.einsum("jkAE,BCij,DEka->BCDiaA",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovV += -0.500000000 * np.einsum("jkAE,BEij,CDka->BCDiaA",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovV += -0.250000000 * np.einsum("jkAE,BCjk,DEia->BCDiaA",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVvvV += -0.250000000 * np.einsum("ijaA,cBij,CDbc->BCDabA",t2["oovV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVVvvV += 0.250000000 * np.einsum("ijaA,BEij,CDbE->BCDabA",t2["oovV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVvvV += 1.000000000 * np.einsum("ijaA,BCik,kDjb->BCDabA",t2["oovV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVVvvV += -0.250000000 * np.einsum("ijaE,ABij,DEbC->ABDabC",t2["oovV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVvvV += -0.125000000 * np.einsum("ijcA,BCij,cDab->BCDabA",t2["oovV"],t2["VVoo"],v["vVvv"],optimize="optimal")
# ws2s2VVVvvV += -0.125000000 * np.einsum("ijAE,BCij,DEab->BCDabA",t2["ooVV"],t2["VVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVVooo += 1.000000000 * np.einsum("aAij,bBkl,lCab->ABCijk",t2["vVoo"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s2VVVooo += 1.000000000 * np.einsum("ADij,aBkl,lCaD->ABCijk",t2["VVoo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2VVVooo += 1.000000000 * np.einsum("ADij,BEkl,lCDE->ABCijk",t2["VVoo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2VVVooo += -0.250000000 * np.einsum("ADij,BClm,lmkD->ABCijk",t2["VVoo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2VVVooo += -0.250000000 * np.einsum("DEij,ABkl,lCDE->ABCijk",t2["VVoo"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2VVVooo += -0.500000000 * np.einsum("ABil,aDjk,lCaD->ABCijk",t2["VVoo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2VVVooo += -1.000000000 * np.einsum("ABil,aCjm,lmka->ABCijk",t2["VVoo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s2VVVooo += 1.000000000 * np.einsum("ABil,CDjm,lmkD->ABCijk",t2["VVoo"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2VVVooo += 1.000000000 * np.einsum("ADil,aBjk,lCaD->ABCijk",t2["VVoo"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2VVVooo += 0.250000000 * np.einsum("ABlm,aCij,lmka->ABCijk",t2["VVoo"],t2["vVoo"],v["ooov"],optimize="optimal")
# ws2s2VVVoov += -0.250000000 * np.einsum("ADij,BCkl,klaD->ABCija",t2["VVoo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s2VVVoov += -1.000000000 * np.einsum("ABik,bCjl,klab->ABCija",t2["VVoo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s2VVVoov += 1.000000000 * np.einsum("ABik,CDjl,klaD->ABCija",t2["VVoo"],t2["VVoo"],v["oovV"],optimize="optimal")
# ws2s2VVVoov += 0.250000000 * np.einsum("ABkl,bCij,klab->ABCija",t2["VVoo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s2VVVoov += -0.125000000 * np.einsum("klaD,ADij,BCkl->ABCija",t2["oovV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVoov += 0.500000000 * np.einsum("klaD,ABik,CDjl->ABCija",t2["oovV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVoov += 0.500000000 * np.einsum("klaD,ADik,BCjl->ABCija",t2["oovV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVoov += -0.125000000 * np.einsum("klaD,ABkl,CDij->ABCija",t2["oovV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVVovv += 0.500000000 * np.einsum("jkaD,ABij,CDkb->ABCiab",t2["oovV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovv += 0.500000000 * np.einsum("jkaD,ADij,BCkb->ABCiab",t2["oovV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVovv += 0.250000000 * np.einsum("jkaD,ABjk,CDib->ABCiab",t2["oovV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVVvvv += -0.125000000 * np.einsum("ijaD,ABij,CDbc->ABCabc",t2["oovV"],t2["VVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVVV += 0.250000000 * np.einsum("ijaA,aEij,CDBE->CDAB",t2["oovV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijaA,bBij,aDbC->BDAC",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijaA,BEij,aDCE->BDAC",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VVVV += 2.000000000 * np.einsum("ijaA,aBik,kDjC->BDAC",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVV += 1.000000000 * np.einsum("ijaA,BCik,kajD->BCAD",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2VVVV += 0.250000000 * np.einsum("ijaE,aAij,DEBC->ADBC",t2["oovV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += 0.125000000 * np.einsum("ijaE,ABij,aECD->ABCD",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VVVV += -0.250000000 * np.einsum("ijaE,AEij,aDBC->ADBC",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VVVV += 0.125000000 * np.einsum("ijAB,aEij,CDaE->CDAB",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVV += 0.062500000 * np.einsum("ijAB,EGij,CDEG->CDAB",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += 1.000000000 * np.einsum("ijAB,aCik,kDja->CDAB",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijAB,CEik,kDjE->CDAB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVV += 0.125000000 * np.einsum("ijAB,CDkl,klij->CDAB",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijAE,aBij,DEaC->BDAC",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVV += -0.250000000 * np.einsum("ijAE,aEij,CDaB->CDAB",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijAE,BGij,DECG->BDAC",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += -0.250000000 * np.einsum("ijAE,EGij,CDBG->CDAB",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += -1.000000000 * np.einsum("ijAE,BCik,kEjD->BCAD",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVV += 2.000000000 * np.einsum("ijAE,BEik,kDjC->BDAC",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVVV += 0.062500000 * np.einsum("ijEG,ABij,EGCD->ABCD",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVVV += -0.250000000 * np.einsum("ijEG,AEij,DGBC->ADBC",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkaA,aDij,BCkD->BCiA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += -2.000000000 * np.einsum("jkaA,bBij,aCkb->BCiA",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2VVoV += 2.000000000 * np.einsum("jkaA,BDij,aCkD->BCiA",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkaA,aBil,lCjk->BCiA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += -0.500000000 * np.einsum("jkaA,BCil,lajk->BCiA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2VVoV += -0.250000000 * np.einsum("jkaA,aDjk,BCiD->BCiA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkaA,bBjk,aCib->BCiA",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2VVoV += 1.000000000 * np.einsum("jkaA,BDjk,aCiD->BCiA",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += 2.000000000 * np.einsum("jkaA,aBjl,lCik->BCiA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += 1.000000000 * np.einsum("jkaA,BCjl,laik->BCiA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2VVoV += 1.000000000 * np.einsum("jkaD,aAij,CDkB->ACiB",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.500000000 * np.einsum("jkaD,aDij,BCkA->BCiA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.500000000 * np.einsum("jkaD,ABij,aDkC->ABiC",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkaD,ADij,aCkB->ACiB",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += 0.500000000 * np.einsum("jkaD,aAjk,CDiB->ACiB",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.250000000 * np.einsum("jkaD,ABjk,aDiC->ABiC",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += -0.500000000 * np.einsum("jkaD,ADjk,aCiB->ACiB",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2VVoV += -2.000000000 * np.einsum("jkAD,aBij,CDka->BCiA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkAD,aDij,BCka->BCiA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVoV += 2.000000000 * np.einsum("jkAD,BEij,CDkE->BCiA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 1.000000000 * np.einsum("jkAD,DEij,BCkE->BCiA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.500000000 * np.einsum("jkAD,BCil,lDjk->BCiA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkAD,BDil,lCjk->BCiA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkAD,aBjk,CDia->BCiA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVoV += -0.250000000 * np.einsum("jkAD,aDjk,BCia->BCiA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVoV += 1.000000000 * np.einsum("jkAD,BEjk,CDiE->BCiA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.250000000 * np.einsum("jkAD,DEjk,BCiE->BCiA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkAD,BCjl,lDik->BCiA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += 2.000000000 * np.einsum("jkAD,BDjl,lCik->BCiA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVoV += 0.250000000 * np.einsum("jkDE,ABij,DEkC->ABiC",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += -1.000000000 * np.einsum("jkDE,ADij,CEkB->ACiB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.250000000 * np.einsum("jkDE,DEij,BCkA->BCiA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += 0.125000000 * np.einsum("jkDE,ABjk,DEiC->ABiC",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVoV += -0.500000000 * np.einsum("jkDE,ADjk,CEiB->ACiB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVvV += 0.250000000 * np.einsum("ijaA,bDij,BCbD->BCaA",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += 0.125000000 * np.einsum("ijaA,DEij,BCDE->BCaA",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVvV += 2.000000000 * np.einsum("ijaA,bBik,kCjb->BCaA",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvV += -2.000000000 * np.einsum("ijaA,BDik,kCjD->BCaA",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVvV += 0.250000000 * np.einsum("ijaA,BCkl,klij->BCaA",t2["oovV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijaD,bAij,CDbB->ACaB",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += -0.250000000 * np.einsum("ijaD,bDij,BCbA->BCaA",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijaD,AEij,CDBE->ACaB",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVvV += -0.250000000 * np.einsum("ijaD,DEij,BCAE->BCaA",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijaD,ABik,kDjC->ABaC",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVvV += 2.000000000 * np.einsum("ijaD,ADik,kCjB->ACaB",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VVvV += -0.250000000 * np.einsum("ijbA,bDij,BCaD->BCaA",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijbA,cBij,bCac->BCaA",t2["oovV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s2VVvV += 1.000000000 * np.einsum("ijbA,BDij,bCaD->BCaA",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2VVvV += -2.000000000 * np.einsum("ijbA,bBik,kCja->BCaA",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijbA,BCik,kbja->BCaA",t2["oovV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws2s2VVvV += 0.500000000 * np.einsum("ijbD,bAij,CDaB->ACaB",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += 0.250000000 * np.einsum("ijbD,ABij,bDaC->ABaC",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2VVvV += -0.500000000 * np.einsum("ijbD,ADij,bCaB->ACaB",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2VVvV += -1.000000000 * np.einsum("ijAD,bBij,CDab->BCaA",t2["ooVV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvV += -0.250000000 * np.einsum("ijAD,bDij,BCab->BCaA",t2["ooVV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvV += 1.000000000 * np.einsum("ijAD,BEij,CDaE->BCaA",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += 0.250000000 * np.einsum("ijAD,DEij,BCaE->BCaA",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += 1.000000000 * np.einsum("ijAD,BCik,kDja->BCaA",t2["ooVV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvV += -2.000000000 * np.einsum("ijAD,BDik,kCja->BCaA",t2["ooVV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvV += 0.125000000 * np.einsum("ijDE,ABij,DEaC->ABaC",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvV += -0.500000000 * np.einsum("ijDE,ADij,CEaB->ACaB",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("aAij,bBkl,klab->ABij",t2["vVoo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("ACij,aBkl,klaC->ABij",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("ACij,BDkl,klCD->ABij",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVoo += 0.125000000 * np.einsum("CDij,ABkl,klCD->ABij",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVoo += 1.000000000 * np.einsum("aAik,bBjl,klab->ABij",t2["vVoo"],t2["vVoo"],v["oovv"],optimize="optimal")
# ws2s2VVoo += -1.000000000 * np.einsum("ABik,aCjl,klaC->ABij",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("ABik,CDjl,klCD->ABij",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVoo += 2.000000000 * np.einsum("ACik,aBjl,klaC->ABij",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVoo += 1.000000000 * np.einsum("ACik,BDjl,klCD->ABij",t2["VVoo"],t2["VVoo"],v["ooVV"],optimize="optimal")
# ws2s2VVoo += 0.250000000 * np.einsum("ABkl,aCij,klaC->ABij",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("ACkl,aBij,klaC->ABij",t2["VVoo"],t2["vVoo"],v["oovV"],optimize="optimal")
# ws2s2VVoo += 0.250000000 * np.einsum("klaC,aAij,BCkl->ABij",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += 0.125000000 * np.einsum("klaC,aCij,ABkl->ABij",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klaC,ACij,aBkl->ABij",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVoo += -1.000000000 * np.einsum("klaC,aAik,BCjl->ABij",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("klaC,aCik,ABjl->ABij",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.500000000 * np.einsum("klaC,ABik,aCjl->ABij",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVoo += 1.000000000 * np.einsum("klaC,ACik,aBjl->ABij",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVoo += 0.250000000 * np.einsum("klaC,aAkl,BCij->ABij",t2["oovV"],t2["vVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += 0.125000000 * np.einsum("klaC,ABkl,aCij->ABij",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klaC,ACkl,aBij->ABij",t2["oovV"],t2["VVoo"],v["vVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klCD,ACij,BDkl->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += 0.062500000 * np.einsum("klCD,CDij,ABkl->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klCD,ABik,CDjl->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += 1.000000000 * np.einsum("klCD,ACik,BDjl->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klCD,CDik,ABjl->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += 0.062500000 * np.einsum("klCD,ABkl,CDij->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVoo += -0.250000000 * np.einsum("klCD,ACkl,BDij->ABij",t2["ooVV"],t2["VVoo"],v["VVoo"],optimize="optimal")
# ws2s2VVov += -2.000000000 * np.einsum("jkaC,bAij,BCkb->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkaC,bCij,ABkb->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 2.000000000 * np.einsum("jkaC,ADij,BCkD->ABia",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVov += 1.000000000 * np.einsum("jkaC,CDij,ABkD->ABia",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVov += 0.500000000 * np.einsum("jkaC,ABil,lCjk->ABia",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkaC,ACil,lBjk->ABia",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkaC,bAjk,BCib->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += -0.250000000 * np.einsum("jkaC,bCjk,ABib->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 1.000000000 * np.einsum("jkaC,ADjk,BCiD->ABia",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVov += 0.250000000 * np.einsum("jkaC,CDjk,ABiD->ABia",t2["oovV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkaC,ABjl,lCik->ABia",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVov += 2.000000000 * np.einsum("jkaC,ACjl,lBik->ABia",t2["oovV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2VVov += 1.000000000 * np.einsum("jkbC,bAij,BCka->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 0.500000000 * np.einsum("jkbC,bCij,ABka->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 0.500000000 * np.einsum("jkbC,ABij,bCka->ABia",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkbC,ACij,bBka->ABia",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVov += 0.500000000 * np.einsum("jkbC,bAjk,BCia->ABia",t2["oovV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 0.250000000 * np.einsum("jkbC,ABjk,bCia->ABia",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVov += -0.500000000 * np.einsum("jkbC,ACjk,bBia->ABia",t2["oovV"],t2["VVoo"],v["vVov"],optimize="optimal")
# ws2s2VVov += 0.250000000 * np.einsum("jkCD,ABij,CDka->ABia",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += -1.000000000 * np.einsum("jkCD,ACij,BDka->ABia",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 0.250000000 * np.einsum("jkCD,CDij,ABka->ABia",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += 0.125000000 * np.einsum("jkCD,ABjk,CDia->ABia",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVov += -0.500000000 * np.einsum("jkCD,ACjk,BDia->ABia",t2["ooVV"],t2["VVoo"],v["VVov"],optimize="optimal")
# ws2s2VVvv += 1.000000000 * np.einsum("ijaC,cAij,BCbc->ABab",t2["oovV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvv += 0.250000000 * np.einsum("ijaC,cCij,ABbc->ABab",t2["oovV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvv += -1.000000000 * np.einsum("ijaC,ADij,BCbD->ABab",t2["oovV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvv += -0.250000000 * np.einsum("ijaC,CDij,ABbD->ABab",t2["oovV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2VVvv += -1.000000000 * np.einsum("ijaC,ABik,kCjb->ABab",t2["oovV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvv += 2.000000000 * np.einsum("ijaC,ACik,kBjb->ABab",t2["oovV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2VVvv += 0.250000000 * np.einsum("ijcC,cAij,BCab->ABab",t2["oovV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvv += 0.125000000 * np.einsum("ijcC,ABij,cCab->ABab",t2["oovV"],t2["VVoo"],v["vVvv"],optimize="optimal")
# ws2s2VVvv += -0.250000000 * np.einsum("ijcC,ACij,cBab->ABab",t2["oovV"],t2["VVoo"],v["vVvv"],optimize="optimal")
# ws2s2VVvv += 0.062500000 * np.einsum("ijCD,ABij,CDab->ABab",t2["ooVV"],t2["VVoo"],v["VVvv"],optimize="optimal")
# ws2s2VVvv += -0.250000000 * np.einsum("ijCD,ACij,BDab->ABab",t2["ooVV"],t2["VVoo"],v["VVvv"],optimize="optimal")
# ws2s2VV += -1.000000000 * np.einsum("ijaA,bCij,aBbC->BA",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijaA,CDij,aBCD->BA",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijaA,aCik,kBjC->BA",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijaA,bBik,kajb->BA",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2VV += -2.000000000 * np.einsum("ijaA,BCik,kajC->BA",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijaA,aBkl,klij->BA",t2["oovV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws2s2VV += 1.000000000 * np.einsum("ijaC,aDij,BCAD->BA",t2["oovV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2VV += -1.000000000 * np.einsum("ijaC,bAij,aCbB->AB",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2VV += 1.000000000 * np.einsum("ijaC,bCij,aBbA->BA",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2VV += -1.000000000 * np.einsum("ijaC,ADij,aCBD->AB",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VV += 1.000000000 * np.einsum("ijaC,CDij,aBAD->BA",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijaC,aAik,kCjB->AB",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += -2.000000000 * np.einsum("ijaC,aCik,kBjA->BA",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijaC,ACik,kajB->AB",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2VV += -1.000000000 * np.einsum("ijAC,aDij,BCaD->BA",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijAC,DEij,BCDE->BA",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VV += -2.000000000 * np.einsum("ijAC,aBik,kCja->BA",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijAC,aCik,kBja->BA",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2VV += 2.000000000 * np.einsum("ijAC,BDik,kCjD->BA",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += -2.000000000 * np.einsum("ijAC,CDik,kBjD->BA",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijAC,BCkl,klij->BA",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijCD,aAij,CDaB->AB",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VV += 1.000000000 * np.einsum("ijCD,aCij,BDaA->BA",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2VV += -0.500000000 * np.einsum("ijCD,AEij,CDBE->AB",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VV += 1.000000000 * np.einsum("ijCD,CEij,BDAE->BA",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2VV += -2.000000000 * np.einsum("ijCD,ACik,kDjB->AB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2VV += -1.000000000 * np.einsum("ijCD,CDik,kBjA->BA",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkaB,aCij,ABkC->Ai",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkaB,bAij,aBkb->Ai",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2Vo += -2.000000000 * np.einsum("jkaB,bBij,aAkb->Ai",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2Vo += -2.000000000 * np.einsum("jkaB,ACij,aBkC->Ai",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkaB,BCij,aAkC->Ai",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkaB,aAil,lBjk->Ai",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkaB,aBil,lAjk->Ai",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkaB,ABil,lajk->Ai",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkaB,aCjk,ABiC->Ai",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkaB,bAjk,aBib->Ai",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkaB,bBjk,aAib->Ai",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkaB,ACjk,aBiC->Ai",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkaB,BCjk,aAiC->Ai",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2Vo += -2.000000000 * np.einsum("jkaB,aAjl,lBik->Ai",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkaB,aBjl,lAik->Ai",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += -2.000000000 * np.einsum("jkaB,ABjl,laik->Ai",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkBC,aAij,BCka->Ai",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2Vo += -2.000000000 * np.einsum("jkBC,aBij,ACka->Ai",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkBC,ADij,BCkD->Ai",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkBC,BDij,ACkD->Ai",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkBC,ABil,lCjk->Ai",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += -0.500000000 * np.einsum("jkBC,BCil,lAjk->Ai",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += 0.500000000 * np.einsum("jkBC,aAjk,BCia->Ai",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2Vo += -1.000000000 * np.einsum("jkBC,aBjk,ACia->Ai",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2Vo += -0.500000000 * np.einsum("jkBC,ADjk,BCiD->Ai",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkBC,BDjk,ACiD->Ai",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2Vo += 2.000000000 * np.einsum("jkBC,ABjl,lCik->Ai",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vo += 1.000000000 * np.einsum("jkBC,BCjl,lAik->Ai",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2Vv += -1.000000000 * np.einsum("ijaB,bCij,ABbC->Aa",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2Vv += -0.500000000 * np.einsum("ijaB,CDij,ABCD->Aa",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2Vv += -2.000000000 * np.einsum("ijaB,bAik,kBjb->Aa",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2Vv += 2.000000000 * np.einsum("ijaB,bBik,kAjb->Aa",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2Vv += 2.000000000 * np.einsum("ijaB,ACik,kBjC->Aa",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2Vv += -2.000000000 * np.einsum("ijaB,BCik,kAjC->Aa",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2Vv += -0.500000000 * np.einsum("ijaB,ABkl,klij->Aa",t2["oovV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2Vv += 1.000000000 * np.einsum("ijbB,bCij,ABaC->Aa",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2Vv += 1.000000000 * np.einsum("ijbB,cAij,bBac->Aa",t2["oovV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s2Vv += -1.000000000 * np.einsum("ijbB,cBij,bAac->Aa",t2["oovV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s2Vv += -1.000000000 * np.einsum("ijbB,ACij,bBaC->Aa",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2Vv += 1.000000000 * np.einsum("ijbB,BCij,bAaC->Aa",t2["oovV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2Vv += 2.000000000 * np.einsum("ijbB,bAik,kBja->Aa",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2Vv += -2.000000000 * np.einsum("ijbB,bBik,kAja->Aa",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2Vv += 2.000000000 * np.einsum("ijbB,ABik,kbja->Aa",t2["oovV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws2s2Vv += 0.500000000 * np.einsum("ijBC,bAij,BCab->Aa",t2["ooVV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2Vv += -1.000000000 * np.einsum("ijBC,bBij,ACab->Aa",t2["ooVV"],t2["vVoo"],v["VVvv"],optimize="optimal")
# ws2s2Vv += -0.500000000 * np.einsum("ijBC,ADij,BCaD->Aa",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2Vv += 1.000000000 * np.einsum("ijBC,BDij,ACaD->Aa",t2["ooVV"],t2["VVoo"],v["VVvV"],optimize="optimal")
# ws2s2Vv += -2.000000000 * np.einsum("ijBC,ABik,kCja->Aa",t2["ooVV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2Vv += -1.000000000 * np.einsum("ijBC,BCik,kAja->Aa",t2["ooVV"],t2["VVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("ijaA,aBjk,kECD->iBEACD",t2["oovV"],t2["vVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("ijaA,BCjk,kaDE->iBCADE",t2["oovV"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2s2oVVVVV += 0.125000000 * np.einsum("jkaA,BCjk,iaDE->iBCADE",t2["oovV"],t2["VVoo"],v["ovVV"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("ijAB,aCjk,kEaD->iCEABD",t2["ooVV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("ijAB,CGjk,kEDG->iCEABD",t2["ooVV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVVVV += -0.250000000 * np.einsum("ijAB,CDkl,kljE->iCDABE",t2["ooVV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2oVVVVV += 0.250000000 * np.einsum("jkAB,aCjk,iEaD->iCEABD",t2["ooVV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVVVV += 0.250000000 * np.einsum("jkAB,CGjk,iEDG->iCEABD",t2["ooVV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("jkAB,CDjl,ilkE->iCDABE",t2["ooVV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2oVVVVV += -0.500000000 * np.einsum("ijAG,BCjk,kGDE->iBCADE",t2["ooVV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVVVV += 0.500000000 * np.einsum("ijAG,BGjk,kECD->iBEACD",t2["ooVV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVVVV += -0.125000000 * np.einsum("jkAG,BCjk,iGDE->iBCADE",t2["ooVV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVoVV += 0.500000000 * np.einsum("ikaA,aEjk,CDBE->iCDjAB",t2["oovV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += -2.000000000 * np.einsum("ikaA,bBjk,aDbC->iBDjAC",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2oVVoVV += -2.000000000 * np.einsum("ikaA,BEjk,aDCE->iBDjAC",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2oVVoVV += 2.000000000 * np.einsum("ikaA,aBjl,lDkC->iBDjAC",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 1.000000000 * np.einsum("ikaA,BCjl,lakD->iBCjAD",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("ikaA,aBkl,lDjC->iBDjAC",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("ikaA,BCkl,lajD->iBCjAD",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("klaA,aBik,jDlC->jBDiAC",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("klaA,BCik,jalD->jBCiAD",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2oVVoVV += -0.250000000 * np.einsum("klaA,BCkl,jaiD->jBCiAD",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2oVVoVV += 0.500000000 * np.einsum("ikaE,aAjk,DEBC->iADjBC",t2["oovV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("ikaE,ABjk,aECD->iABjCD",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("ikaE,AEjk,aDBC->iADjBC",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("ikAB,aEjk,CDaE->iCDjAB",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2oVVoVV += 0.125000000 * np.einsum("ikAB,EGjk,CDEG->iCDjAB",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += 1.000000000 * np.einsum("ikAB,aCjl,lDka->iCDjAB",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("ikAB,CEjl,lDkE->iCDjAB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("ikAB,aCkl,lDja->iCDjAB",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVoVV += 0.500000000 * np.einsum("ikAB,CEkl,lDjE->iCDjAB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("ikAB,CDlm,lmjk->iCDjAB",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("klAB,aCik,jDla->jCDiAB",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVoVV += 1.000000000 * np.einsum("klAB,CEik,jDlE->jCDiAB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("klAB,CDim,jmkl->jCDiAB",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2oVVoVV += -0.250000000 * np.einsum("klAB,aCkl,jDia->jCDiAB",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("klAB,CEkl,jDiE->jCDiAB",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("klAB,CDkm,jmil->jCDiAB",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2oVVoVV += -2.000000000 * np.einsum("ikAE,aBjk,DEaC->iBDjAC",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("ikAE,aEjk,CDaB->iCDjAB",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2oVVoVV += -2.000000000 * np.einsum("ikAE,BGjk,DECG->iBDjAC",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("ikAE,EGjk,CDBG->iCDjAB",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("ikAE,BCjl,lEkD->iBCjAD",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 2.000000000 * np.einsum("ikAE,BEjl,lDkC->iBDjAC",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 1.000000000 * np.einsum("ikAE,BCkl,lEjD->iBCjAD",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("ikAE,BEkl,lDjC->iBDjAC",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 0.500000000 * np.einsum("klAE,BCik,jElD->jBCiAD",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += -1.000000000 * np.einsum("klAE,BEik,jDlC->jBDiAC",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 0.250000000 * np.einsum("klAE,BCkl,jEiD->jBCiAD",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVoVV += 0.125000000 * np.einsum("ikEG,ABjk,EGCD->iABjCD",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVoVV += -0.500000000 * np.einsum("ikEG,AEjk,DGBC->iADjBC",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVvVV += 1.000000000 * np.einsum("ijaA,bBjk,kDbC->iBDaAC",t2["oovV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += 1.000000000 * np.einsum("ijaA,BEjk,kDCE->iBDaAC",t2["oovV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVvVV += -0.500000000 * np.einsum("ijaA,BCkl,kljD->iBCaAD",t2["oovV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2oVVvVV += 0.500000000 * np.einsum("jkaA,bBjk,iDbC->iBDaAC",t2["oovV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += 0.500000000 * np.einsum("jkaA,BEjk,iDCE->iBDaAC",t2["oovV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVvVV += 1.000000000 * np.einsum("jkaA,BCjl,ilkD->iBCaAD",t2["oovV"],t2["VVoo"],v["oooV"],optimize="optimal")
# ws2s2oVVvVV += -0.500000000 * np.einsum("ijaE,ABjk,kECD->iABaCD",t2["oovV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVvVV += 0.500000000 * np.einsum("ijaE,AEjk,kDBC->iADaBC",t2["oovV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVvVV += -0.125000000 * np.einsum("jkaE,ABjk,iECD->iABaCD",t2["oovV"],t2["VVoo"],v["oVVV"],optimize="optimal")
# ws2s2oVVvVV += -1.000000000 * np.einsum("ijbA,bBjk,kDaC->iBDaAC",t2["oovV"],t2["vVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += -1.000000000 * np.einsum("ijbA,BCjk,kbaD->iBCaAD",t2["oovV"],t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2s2oVVvVV += -0.250000000 * np.einsum("jkbA,BCjk,ibaD->iBCaAD",t2["oovV"],t2["VVoo"],v["ovvV"],optimize="optimal")
# ws2s2oVVvVV += -0.500000000 * np.einsum("ijAB,bCjk,kDab->iCDaAB",t2["ooVV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s2oVVvVV += 0.500000000 * np.einsum("ijAB,CEjk,kDaE->iCDaAB",t2["ooVV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += -0.250000000 * np.einsum("ijAB,CDkl,klja->iCDaAB",t2["ooVV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s2oVVvVV += -0.250000000 * np.einsum("jkAB,bCjk,iDab->iCDaAB",t2["ooVV"],t2["vVoo"],v["oVvv"],optimize="optimal")
# ws2s2oVVvVV += 0.250000000 * np.einsum("jkAB,CEjk,iDaE->iCDaAB",t2["ooVV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += 0.500000000 * np.einsum("jkAB,CDjl,ilka->iCDaAB",t2["ooVV"],t2["VVoo"],v["ooov"],optimize="optimal")
# ws2s2oVVvVV += 1.000000000 * np.einsum("ijAE,BCjk,kEaD->iBCaAD",t2["ooVV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += -1.000000000 * np.einsum("ijAE,BEjk,kDaC->iBDaAC",t2["ooVV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVvVV += 0.250000000 * np.einsum("jkAE,BCjk,iEaD->iBCaAD",t2["ooVV"],t2["VVoo"],v["oVvV"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilaA,aDjk,BClD->iBCjkA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += 1.000000000 * np.einsum("ilaA,bBjk,aClb->iBCjkA",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("ilaA,BDjk,aClD->iBCjkA",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("ilaA,aDjl,BCkD->iBCjkA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -2.000000000 * np.einsum("ilaA,bBjl,aCkb->iBCjkA",t2["oovV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2oVVooV += 2.000000000 * np.einsum("ilaA,BDjl,aCkD->iBCjkA",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2oVVooV += 2.000000000 * np.einsum("ilaA,aBjm,mCkl->iBCjkA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 1.000000000 * np.einsum("ilaA,BCjm,makl->iBCjkA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilaA,aBlm,mCjk->iBCjkA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilaA,BClm,majk->iBCjkA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2oVVooV += 0.250000000 * np.einsum("lmaA,aBij,kClm->kBCijA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("lmaA,aBil,kCjm->kBCijA",t2["oovV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("lmaA,BCil,kajm->kBCijA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2oVVooV += 0.125000000 * np.einsum("lmaA,BClm,kaij->kBCijA",t2["oovV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("ilaD,aAjk,CDlB->iACjkB",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -0.250000000 * np.einsum("ilaD,aDjk,BClA->iBCjkA",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilaD,ADjk,aClB->iACjkB",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2oVVooV += 1.000000000 * np.einsum("ilaD,aAjl,CDkB->iACjkB",t2["oovV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilaD,ABjl,aDkC->iABjkC",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("ilaD,ADjl,aCkB->iACjkB",t2["oovV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2oVVooV += 1.000000000 * np.einsum("ilAD,aBjk,CDla->iBCjkA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilAD,aDjk,BCla->iBCjkA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("ilAD,BEjk,CDlE->iBCjkA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("ilAD,DEjk,BClE->iBCjkA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -2.000000000 * np.einsum("ilAD,aBjl,CDka->iBCjkA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("ilAD,aDjl,BCka->iBCjkA",t2["ooVV"],t2["vVoo"],v["VVov"],optimize="optimal")
# ws2s2oVVooV += 2.000000000 * np.einsum("ilAD,BEjl,CDkE->iBCjkA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilAD,DEjl,BCkE->iBCjkA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("ilAD,BCjm,mDkl->iBCjkA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 2.000000000 * np.einsum("ilAD,BDjm,mCkl->iBCjkA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += -0.500000000 * np.einsum("ilAD,BClm,mDjk->iBCjkA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilAD,BDlm,mCjk->iBCjkA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 0.250000000 * np.einsum("lmAD,BDij,kClm->kBCijA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("lmAD,BCil,kDjm->kBCijA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("lmAD,BDil,kCjm->kBCijA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += -0.125000000 * np.einsum("lmAD,BClm,kDij->kBCijA",t2["ooVV"],t2["VVoo"],v["oVoo"],optimize="optimal")
# ws2s2oVVooV += 0.500000000 * np.einsum("ilDE,ADjk,CElB->iACjkB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -0.125000000 * np.einsum("ilDE,DEjk,BClA->iBCjkA",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += 0.250000000 * np.einsum("ilDE,ABjl,DEkC->iABjkC",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVooV += -1.000000000 * np.einsum("ilDE,ADjl,CEkB->iACjkB",t2["ooVV"],t2["VVoo"],v["VVoV"],optimize="optimal")
# ws2s2oVVovV += 0.500000000 * np.einsum("ikaA,bDjk,BCbD->iBCjaA",t2["oovV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2oVVovV += 0.250000000 * np.einsum("ikaA,DEjk,BCDE->iBCjaA",t2["oovV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2oVVovV += 2.000000000 * np.einsum("ikaA,bBjl,lCkb->iBCjaA",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVovV += -2.000000000 * np.einsum("ikaA,BDjl,lCkD->iBCjaA",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVovV += -1.000000000 * np.einsum("ikaA,bBkl,lCjb->iBCjaA",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2oVVovV += 1.000000000 * np.einsum("ikaA,BDkl,lCjD->iBCjaA",t2["oovV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2oVVovV += 0.500000000 * np.einsum("ikaA,BClm,lmjk->iBCjaA",t2["oovV"],t2["VVoo"],v["oooo"],optimize="optimal")
# ws2s2oVVovV += -2.000000000 * np.einsum("klaA,bBik,jClb->jBCiaA",t2["oovV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ...
# ws2s2vvVV += 0.250000000 * np.einsum("ijcC,aCij,bcAB->abAB",t2["oovV"],t2["vVoo"],v["vvVV"],optimize="optimal")
# ws2s2vvVV += 0.125000000 * np.einsum("ijAB,cCij,abcC->abAB",t2["ooVV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvVV += 0.062500000 * np.einsum("ijAB,CDij,abCD->abAB",t2["ooVV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vvVV += -1.000000000 * np.einsum("ijAB,aCik,kbjC->abAB",t2["ooVV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vvVV += -1.000000000 * np.einsum("ijAC,aDij,bCBD->abAB",t2["ooVV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s2vvVV += -0.250000000 * np.einsum("ijAC,cCij,abcB->abAB",t2["ooVV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvVV += -0.250000000 * np.einsum("ijAC,CDij,abBD->abAB",t2["ooVV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vvVV += 2.000000000 * np.einsum("ijAC,aCik,kbjB->abAB",t2["ooVV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vvVV += -0.250000000 * np.einsum("ijCD,aCij,bDAB->abAB",t2["ooVV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s2vvoV += -2.000000000 * np.einsum("jkcA,aBij,bckB->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += -1.000000000 * np.einsum("jkcA,cBij,abkB->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += -1.000000000 * np.einsum("jkcA,aBjk,bciB->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += -0.250000000 * np.einsum("jkcA,cBjk,abiB->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += 1.000000000 * np.einsum("jkcB,aBij,bckA->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += 0.500000000 * np.einsum("jkcB,cBij,abkA->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += 0.500000000 * np.einsum("jkcB,aBjk,bciA->abiA",t2["oovV"],t2["vVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += 2.000000000 * np.einsum("jkAB,aCij,bBkC->abiA",t2["ooVV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvoV += -1.000000000 * np.einsum("jkAB,cBij,abkc->abiA",t2["ooVV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvoV += 1.000000000 * np.einsum("jkAB,BCij,abkC->abiA",t2["ooVV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += -1.000000000 * np.einsum("jkAB,aBil,lbjk->abiA",t2["ooVV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vvoV += 1.000000000 * np.einsum("jkAB,aCjk,bBiC->abiA",t2["ooVV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvoV += -0.250000000 * np.einsum("jkAB,cBjk,abic->abiA",t2["ooVV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvoV += 0.250000000 * np.einsum("jkAB,BCjk,abiC->abiA",t2["ooVV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += 2.000000000 * np.einsum("jkAB,aBjl,lbik->abiA",t2["ooVV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vvoV += -1.000000000 * np.einsum("jkBC,aBij,bCkA->abiA",t2["ooVV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvoV += 0.250000000 * np.einsum("jkBC,BCij,abkA->abiA",t2["ooVV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvoV += -0.500000000 * np.einsum("jkBC,aBjk,bCiA->abiA",t2["ooVV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvvV += 0.250000000 * np.einsum("ijaA,dBij,bcdB->bcaA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += 0.125000000 * np.einsum("ijaA,BCij,bcBC->bcaA",t2["oovV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vvvV += -2.000000000 * np.einsum("ijaA,bBik,kcjB->bcaA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vvvV += -1.000000000 * np.einsum("ijaB,bCij,cBAC->bcaA",t2["oovV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s2vvvV += -0.250000000 * np.einsum("ijaB,dBij,bcdA->bcaA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += -0.250000000 * np.einsum("ijaB,BCij,bcAC->bcaA",t2["oovV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vvvV += 2.000000000 * np.einsum("ijaB,bBik,kcjA->bcaA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vvvV += -1.000000000 * np.einsum("ijdA,aBij,cdbB->acbA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += -0.250000000 * np.einsum("ijdA,dBij,bcaB->bcaA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += 0.500000000 * np.einsum("ijdB,aBij,cdbA->acbA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += 1.000000000 * np.einsum("ijAB,aCij,cBbC->acbA",t2["ooVV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vvvV += -0.250000000 * np.einsum("ijAB,dBij,bcad->bcaA",t2["ooVV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s2vvvV += 0.250000000 * np.einsum("ijAB,BCij,bcaC->bcaA",t2["ooVV"],t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvV += -2.000000000 * np.einsum("ijAB,aBik,kcjb->acbA",t2["ooVV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vvvV += -0.500000000 * np.einsum("ijBC,aBij,cCbA->acbA",t2["ooVV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vvoo += -0.500000000 * np.einsum("aAij,bBkl,klAB->abij",t2["vVoo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2s2vvoo += 1.000000000 * np.einsum("aAik,bBjl,klAB->abij",t2["vVoo"],t2["vVoo"],v["ooVV"],optimize="optimal")
# ws2s2vvoo += 0.250000000 * np.einsum("klcA,aAij,bckl->abij",t2["oovV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += 0.125000000 * np.einsum("klcA,cAij,abkl->abij",t2["oovV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += -1.000000000 * np.einsum("klcA,aAik,bcjl->abij",t2["oovV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += -0.500000000 * np.einsum("klcA,cAik,abjl->abij",t2["oovV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += 0.250000000 * np.einsum("klcA,aAkl,bcij->abij",t2["oovV"],t2["vVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += -0.250000000 * np.einsum("klAB,aAij,bBkl->abij",t2["ooVV"],t2["vVoo"],v["vVoo"],optimize="optimal")
# ws2s2vvoo += 0.062500000 * np.einsum("klAB,ABij,abkl->abij",t2["ooVV"],t2["VVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += 1.000000000 * np.einsum("klAB,aAik,bBjl->abij",t2["ooVV"],t2["vVoo"],v["vVoo"],optimize="optimal")
# ws2s2vvoo += -0.250000000 * np.einsum("klAB,ABik,abjl->abij",t2["ooVV"],t2["VVoo"],v["vvoo"],optimize="optimal")
# ws2s2vvoo += -0.250000000 * np.einsum("klAB,aAkl,bBij->abij",t2["ooVV"],t2["vVoo"],v["vVoo"],optimize="optimal")
# ws2s2vvov += 2.000000000 * np.einsum("jkaA,bBij,cAkB->bcia",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvov += -1.000000000 * np.einsum("jkaA,dAij,bckd->bcia",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += 1.000000000 * np.einsum("jkaA,ABij,bckB->bcia",t2["oovV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvov += -1.000000000 * np.einsum("jkaA,bAil,lcjk->bcia",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vvov += 1.000000000 * np.einsum("jkaA,bBjk,cAiB->bcia",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vvov += -0.250000000 * np.einsum("jkaA,dAjk,bcid->bcia",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += 0.250000000 * np.einsum("jkaA,ABjk,bciB->bcia",t2["oovV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vvov += 2.000000000 * np.einsum("jkaA,bAjl,lcik->bcia",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vvov += 1.000000000 * np.einsum("jkdA,aAij,cdkb->acib",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += 0.500000000 * np.einsum("jkdA,dAij,bcka->bcia",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += 0.500000000 * np.einsum("jkdA,aAjk,cdib->acib",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += -1.000000000 * np.einsum("jkAB,aAij,cBkb->acib",t2["ooVV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2vvov += 0.250000000 * np.einsum("jkAB,ABij,bcka->bcia",t2["ooVV"],t2["VVoo"],v["vvov"],optimize="optimal")
# ws2s2vvov += -0.500000000 * np.einsum("jkAB,aAjk,cBib->acib",t2["ooVV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2vvvv += -1.000000000 * np.einsum("ijaA,bBij,dAcB->bdac",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vvvv += 0.250000000 * np.einsum("ijaA,eAij,cdbe->cdab",t2["oovV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s2vvvv += -0.250000000 * np.einsum("ijaA,ABij,cdbB->cdab",t2["oovV"],t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2s2vvvv += 2.000000000 * np.einsum("ijaA,bAik,kdjc->bdac",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vvvv += 0.250000000 * np.einsum("ijeA,aAij,debc->adbc",t2["oovV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s2vvvv += -0.250000000 * np.einsum("ijAB,aAij,dBbc->adbc",t2["ooVV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s2vV += 1.000000000 * np.einsum("ijbA,cBij,abcB->aA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vV += 0.500000000 * np.einsum("ijbA,BCij,abBC->aA",t2["oovV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vV += -2.000000000 * np.einsum("ijbA,aBik,kbjB->aA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vV += 2.000000000 * np.einsum("ijbA,bBik,kajB->aA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vV += -1.000000000 * np.einsum("ijbB,aCij,bBAC->aA",t2["oovV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s2vV += 1.000000000 * np.einsum("ijbB,bCij,aBAC->aA",t2["oovV"],t2["vVoo"],v["vVVV"],optimize="optimal")
# ws2s2vV += -1.000000000 * np.einsum("ijbB,cBij,abcA->aA",t2["oovV"],t2["vVoo"],v["vvvV"],optimize="optimal")
# ws2s2vV += -1.000000000 * np.einsum("ijbB,BCij,abAC->aA",t2["oovV"],t2["VVoo"],v["vvVV"],optimize="optimal")
# ws2s2vV += 2.000000000 * np.einsum("ijbB,aBik,kbjA->aA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vV += -2.000000000 * np.einsum("ijbB,bBik,kajA->aA",t2["oovV"],t2["vVoo"],v["ovoV"],optimize="optimal")
# ws2s2vV += -1.000000000 * np.einsum("ijAB,bCij,aBbC->aA",t2["ooVV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vV += -0.500000000 * np.einsum("ijAB,CDij,aBCD->aA",t2["ooVV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2vV += 2.000000000 * np.einsum("ijAB,aCik,kBjC->aA",t2["ooVV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2vV += 2.000000000 * np.einsum("ijAB,bBik,kajb->aA",t2["ooVV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vV += -2.000000000 * np.einsum("ijAB,BCik,kajC->aA",t2["ooVV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2vV += -0.500000000 * np.einsum("ijAB,aBkl,klij->aA",t2["ooVV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws2s2vV += -0.500000000 * np.einsum("ijBC,aDij,BCAD->aA",t2["ooVV"],t2["vVoo"],v["VVVV"],optimize="optimal")
# ws2s2vV += 1.000000000 * np.einsum("ijBC,bBij,aCbA->aA",t2["ooVV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vV += 1.000000000 * np.einsum("ijBC,BDij,aCAD->aA",t2["ooVV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2vV += -2.000000000 * np.einsum("ijBC,aBik,kCjA->aA",t2["ooVV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2vV += -1.000000000 * np.einsum("ijBC,BCik,kajA->aA",t2["ooVV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2vo += -2.000000000 * np.einsum("jkbA,aBij,bAkB->ai",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += 2.000000000 * np.einsum("jkbA,bBij,aAkB->ai",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += 2.000000000 * np.einsum("jkbA,cAij,abkc->ai",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vo += -2.000000000 * np.einsum("jkbA,ABij,abkB->ai",t2["oovV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vo += 1.000000000 * np.einsum("jkbA,aAil,lbjk->ai",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkbA,bAil,lajk->ai",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkbA,aBjk,bAiB->ai",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += 1.000000000 * np.einsum("jkbA,bBjk,aAiB->ai",t2["oovV"],t2["vVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += 1.000000000 * np.einsum("jkbA,cAjk,abic->ai",t2["oovV"],t2["vVoo"],v["vvov"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkbA,ABjk,abiB->ai",t2["oovV"],t2["VVoo"],v["vvoV"],optimize="optimal")
# ws2s2vo += -2.000000000 * np.einsum("jkbA,aAjl,lbik->ai",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vo += 2.000000000 * np.einsum("jkbA,bAjl,laik->ai",t2["oovV"],t2["vVoo"],v["ovoo"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkAB,aCij,ABkC->ai",t2["ooVV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2vo += -2.000000000 * np.einsum("jkAB,bAij,aBkb->ai",t2["ooVV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2vo += 2.000000000 * np.einsum("jkAB,ACij,aBkC->ai",t2["ooVV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkAB,aAil,lBjk->ai",t2["ooVV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2vo += -0.500000000 * np.einsum("jkAB,ABil,lajk->ai",t2["ooVV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2vo += -0.500000000 * np.einsum("jkAB,aCjk,ABiC->ai",t2["ooVV"],t2["vVoo"],v["VVoV"],optimize="optimal")
# ws2s2vo += -1.000000000 * np.einsum("jkAB,bAjk,aBib->ai",t2["ooVV"],t2["vVoo"],v["vVov"],optimize="optimal")
# ws2s2vo += 1.000000000 * np.einsum("jkAB,ACjk,aBiC->ai",t2["ooVV"],t2["VVoo"],v["vVoV"],optimize="optimal")
# ws2s2vo += 2.000000000 * np.einsum("jkAB,aAjl,lBik->ai",t2["ooVV"],t2["vVoo"],v["oVoo"],optimize="optimal")
# ws2s2vo += 1.000000000 * np.einsum("jkAB,ABjl,laik->ai",t2["ooVV"],t2["VVoo"],v["ovoo"],optimize="optimal")
# ws2s2vv += -1.000000000 * np.einsum("ijaA,cBij,bAcB->ba",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vv += -0.500000000 * np.einsum("ijaA,BCij,bABC->ba",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2vv += 2.000000000 * np.einsum("ijaA,bBik,kAjB->ba",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2vv += 2.000000000 * np.einsum("ijaA,cAik,kbjc->ba",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vv += -2.000000000 * np.einsum("ijaA,ABik,kbjB->ba",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2vv += -0.500000000 * np.einsum("ijaA,bAkl,klij->ba",t2["oovV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws2s2vv += -1.000000000 * np.einsum("ijcA,aBij,cAbB->ab",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vv += 1.000000000 * np.einsum("ijcA,cBij,bAaB->ba",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2vv += 1.000000000 * np.einsum("ijcA,dAij,bcad->ba",t2["oovV"],t2["vVoo"],v["vvvv"],optimize="optimal")
# ws2s2vv += -1.000000000 * np.einsum("ijcA,ABij,bcaB->ba",t2["oovV"],t2["VVoo"],v["vvvV"],optimize="optimal")
# ws2s2vv += 2.000000000 * np.einsum("ijcA,aAik,kcjb->ab",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vv += -2.000000000 * np.einsum("ijcA,cAik,kbja->ba",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2vv += -0.500000000 * np.einsum("ijAB,aCij,ABbC->ab",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2vv += -1.000000000 * np.einsum("ijAB,cAij,bBac->ba",t2["ooVV"],t2["vVoo"],v["vVvv"],optimize="optimal")
# ws2s2vv += 1.000000000 * np.einsum("ijAB,ACij,bBaC->ba",t2["ooVV"],t2["VVoo"],v["vVvV"],optimize="optimal")
# ws2s2vv += -2.000000000 * np.einsum("ijAB,aAik,kBjb->ab",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2vv += -1.000000000 * np.einsum("ijAB,ABik,kbja->ba",t2["ooVV"],t2["VVoo"],v["ovov"],optimize="optimal")
# ws2s2 += 1.000000000 * np.einsum("ijaA,bBij,aAbB->",t2["oovV"],t2["vVoo"],v["vVvV"],optimize="optimal")
# ws2s2 += 0.500000000 * np.einsum("ijaA,BCij,aABC->",t2["oovV"],t2["VVoo"],v["vVVV"],optimize="optimal")
# ws2s2 += -2.000000000 * np.einsum("ijaA,aBik,kAjB->",t2["oovV"],t2["vVoo"],v["oVoV"],optimize="optimal")
# ws2s2 += -2.000000000 * np.einsum("ijaA,bAik,kajb->",t2["oovV"],t2["vVoo"],v["ovov"],optimize="optimal")
# ws2s2 += 2.000000000 * np.einsum("ijaA,ABik,kajB->",t2["oovV"],t2["VVoo"],v["ovoV"],optimize="optimal")
# ws2s2 += 0.500000000 * np.einsum("ijaA,aAkl,klij->",t2["oovV"],t2["vVoo"],v["oooo"],optimize="optimal")
# ws2s2 += 0.500000000 * np.einsum("ijAB,aCij,ABaC->",t2["ooVV"],t2["vVoo"],v["VVvV"],optimize="optimal")
# ws2s2 += 0.250000000 * np.einsum("ijAB,CDij,ABCD->",t2["ooVV"],t2["VVoo"],v["VVVV"],optimize="optimal")
# ws2s2 += 2.000000000 * np.einsum("ijAB,aAik,kBja->",t2["ooVV"],t2["vVoo"],v["oVov"],optimize="optimal")
# ws2s2 += -2.000000000 * np.einsum("ijAB,ACik,kBjC->",t2["ooVV"],t2["VVoo"],v["oVoV"],optimize="optimal")
# ws2s2 += 0.250000000 * np.einsum("ijAB,ABkl,klij->",t2["ooVV"],t2["VVoo"],v["oooo"],optimize="optimal")

# %%
# [[[F,s1_ext],s1_ext],s1_ext]
print("[[[F,s1_ext],s1_ext],s1_ext]")
Fs1s1s1 = w.commutator(F,s1_ext,s1_ext,s1_ext)
expr = wt.contract(Fs1s1s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s1s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s1_ext],s1_ext],s1_ext]
# fs1s1s1VV += 1.000000000 * np.einsum("Ai,jB,iC,Cj->AB",f["Vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1VV += 3.000000000 * np.einsum("Ci,iA,jC,Bj->BA",f["Vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1VV += 1.000000000 * np.einsum("iA,jC,Bj,Ci->BA",f["oV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1VV += 3.000000000 * np.einsum("iC,jA,Cj,Bi->BA",f["oV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1Vo += 1.000000000 * np.einsum("ji,kB,Ak,Bj->Ai",f["oo"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1Vo += 3.000000000 * np.einsum("kj,jB,Bi,Ak->Ai",f["oo"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1Vo += -1.000000000 * np.einsum("AB,jC,Ci,Bj->Ai",f["VV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1Vo += -3.000000000 * np.einsum("CB,jC,Bi,Aj->Ai",f["VV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1Vv += 1.000000000 * np.einsum("ia,jB,Aj,Bi->Aa",f["ov"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1oV += 1.000000000 * np.einsum("ij,kA,jB,Bk->iA",f["oo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oV += 3.000000000 * np.einsum("kj,jA,iB,Bk->iA",f["oo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oV += -1.000000000 * np.einsum("BA,iC,jB,Cj->iA",f["VV"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oV += -3.000000000 * np.einsum("CB,jA,iC,Bj->iA",f["VV"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oo += -1.000000000 * np.einsum("Ai,jB,kA,Bk->ji",f["Vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oo += -3.000000000 * np.einsum("Ak,kB,iA,Bj->ij",f["Vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1oo += -1.000000000 * np.einsum("iA,kB,Bj,Ak->ij",f["oV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1oo += -3.000000000 * np.einsum("kA,iB,Aj,Bk->ij",f["oV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1ov += -1.000000000 * np.einsum("Aa,iB,jA,Bj->ia",f["Vv"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1vV += 1.000000000 * np.einsum("ai,jA,iB,Bj->aA",f["vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1vo += -1.000000000 * np.einsum("aA,jB,Bi,Aj->ai",f["vV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")
# fs1s1s1 += -4.000000000 * np.einsum("Ai,iB,jA,Bj->",f["Vo"],t1["oV"],t1["oV"],t1["Vo"],optimize="optimal")
# fs1s1s1 += -4.000000000 * np.einsum("iA,jB,Aj,Bi->",f["oV"],t1["oV"],t1["Vo"],t1["Vo"],optimize="optimal")

# %%
# [[[F,s1_ext],s1_ext],s2_ext]
print("[[[F,s1_ext],s1_ext],s2_ext]")
Fs1s1s2 = w.commutator(F,s1_ext,s1_ext,s2_ext)
expr = wt.contract(Fs1s1s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s1s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s1_ext],s1_ext],s2_ext]
# fs1s1s2VVoV += 1.000000000 * np.einsum("Dj,jA,kD,BCik->BCiA",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoV += 0.500000000 * np.einsum("jA,kD,Dj,BCik->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoV += 0.500000000 * np.einsum("jD,kA,Dk,BCij->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += -0.500000000 * np.einsum("ki,lC,Ck,ABjl->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += -0.500000000 * np.einsum("lk,kC,Ci,ABjl->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += -1.000000000 * np.einsum("lk,kC,Al,BCij->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += -0.500000000 * np.einsum("Ca,kC,Ak,aBij->ABij",f["Vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2VVoo += 0.500000000 * np.einsum("AC,kD,Ck,BDij->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += 1.000000000 * np.einsum("DC,kD,Ci,ABjk->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVoo += 0.500000000 * np.einsum("DC,kD,Ak,BCij->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2VVov += 0.500000000 * np.einsum("ja,kC,Cj,ABik->ABia",f["ov"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2Vo += -2.000000000 * np.einsum("Bj,jC,kB,ACik->Ai",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s1s2Vo += 1.000000000 * np.einsum("ja,kB,Bj,aAik->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2Vo += -1.000000000 * np.einsum("jB,kC,Cj,ABik->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2Vo += -1.000000000 * np.einsum("jB,kC,Bk,ACij->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2oVVV += 0.500000000 * np.einsum("Aj,jD,Dk,ikBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oVVV += 0.500000000 * np.einsum("Dj,kD,Ak,ijBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oVVV += 1.000000000 * np.einsum("jD,Dk,Aj,ikBC->iABC",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oVvV += 1.000000000 * np.einsum("Aj,jC,Ck,ikaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oVvV += 1.000000000 * np.einsum("Cj,kC,Ak,ijaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oVvV += 2.000000000 * np.einsum("jC,Ck,Aj,ikaB->iAaB",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oVoo += 1.000000000 * np.einsum("Bl,lC,iB,ACjk->iAjk",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s1s2oVoo += -0.500000000 * np.einsum("la,iB,Bl,aAjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2oVoo += 0.500000000 * np.einsum("iB,lC,Bl,ACjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2oVoo += 0.500000000 * np.einsum("lB,iC,Cl,ABjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2ooVV += -0.500000000 * np.einsum("ik,kC,Cl,jlAB->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ooVV += -1.000000000 * np.einsum("lk,kA,Cl,ijBC->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ooVV += -0.500000000 * np.einsum("lk,iC,Cl,jkAB->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ooVV += 0.500000000 * np.einsum("CA,kC,Dk,ijBD->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ooVV += -0.500000000 * np.einsum("aC,kA,Ck,ijaB->ijAB",f["vV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ooVV += 0.500000000 * np.einsum("DC,kA,Ck,ijBD->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ooVV += 1.000000000 * np.einsum("DC,iD,Ck,jkAB->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oooV += 0.500000000 * np.einsum("Bi,lB,Cl,jkAC->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oooV += -0.500000000 * np.einsum("al,lB,Bi,jkaA->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oooV += 0.500000000 * np.einsum("Bl,lC,Ci,jkAB->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oooV += 1.000000000 * np.einsum("lB,Bi,Cl,jkAC->jkiA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oovV += -1.000000000 * np.einsum("ik,kB,Bl,jlaA->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovV += 1.000000000 * np.einsum("lk,kA,Bl,ijaB->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovV += -1.000000000 * np.einsum("lk,iB,Bl,jkaA->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovV += 0.500000000 * np.einsum("Ba,kB,Ck,ijAC->ijaA",f["Vv"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oovV += -0.500000000 * np.einsum("BA,kB,Ck,ijaC->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovV += -0.500000000 * np.einsum("CB,kA,Bk,ijaC->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovV += 2.000000000 * np.einsum("CB,iC,Bk,jkaA->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ooov += 0.500000000 * np.einsum("Ai,lA,Bl,jkaB->jkia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ooov += 0.500000000 * np.einsum("Al,lB,Bi,jkaA->jkia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ooov += 1.000000000 * np.einsum("lA,Ai,Bl,jkaB->jkia",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oovv += 0.500000000 * np.einsum("Aa,kA,Bk,ijbB->ijab",f["Vv"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ovVV += 0.500000000 * np.einsum("aj,jC,Ck,ikAB->iaAB",f["vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ovvV += 1.000000000 * np.einsum("aj,jB,Bk,ikbA->iabA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ovoo += 1.000000000 * np.einsum("Al,lB,iA,aBjk->iajk",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s1s2ovoo += 0.500000000 * np.einsum("iA,lB,Al,aBjk->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2ovoo += 0.500000000 * np.einsum("lA,iB,Bl,aAjk->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2oV += 1.000000000 * np.einsum("aj,jB,Bk,ikaA->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2oV += -1.000000000 * np.einsum("Bj,kB,Ck,ijAC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oV += -1.000000000 * np.einsum("Bj,jC,Ck,ikAB->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2oV += -2.000000000 * np.einsum("jB,Bk,Cj,ikAC->iA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s1s2ov += -1.000000000 * np.einsum("Aj,kA,Bk,ijaB->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ov += -1.000000000 * np.einsum("Aj,jB,Bk,ikaA->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2ov += -2.000000000 * np.einsum("jA,Ak,Bj,ikaB->ia",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s1s2vVoV += 2.000000000 * np.einsum("Cj,jA,kC,aBik->aBiA",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoV += 1.000000000 * np.einsum("jA,kC,Cj,aBik->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoV += 1.000000000 * np.einsum("jC,kA,Ck,aBij->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += -1.000000000 * np.einsum("ki,lB,Bk,aAjl->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += -1.000000000 * np.einsum("lk,kB,Bi,aAjl->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += 1.000000000 * np.einsum("lk,kB,Al,aBij->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += 0.500000000 * np.einsum("aB,kC,Bk,ACij->aAij",f["vV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s1s2vVoo += -0.500000000 * np.einsum("AB,kC,Bk,aCij->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += 2.000000000 * np.einsum("CB,kC,Bi,aAjk->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVoo += -0.500000000 * np.einsum("CB,kC,Ak,aBij->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vVov += 1.000000000 * np.einsum("ja,kB,Bj,bAik->bAia",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vvoo += 0.500000000 * np.einsum("aA,kB,Ak,bBij->abij",f["vV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vo += -2.000000000 * np.einsum("Aj,jB,kA,aBik->ai",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s1s2vo += -1.000000000 * np.einsum("jA,kB,Bj,aAik->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s1s2vo += -1.000000000 * np.einsum("jA,kB,Ak,aBij->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")

# %%
# [[[F,s1_ext],s2_ext],s1_ext]
print("[[[F,s1_ext],s2_ext],s1_ext]")
Fs1s2s1 = w.commutator(F,s1_ext,s2_ext,s1_ext)
expr = wt.contract(Fs1s2s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s2s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s1_ext],s2_ext],s1_ext]
# fs1s2s1VVVV += 0.500000000 * np.einsum("ji,Ak,Bj,ikCD->ABCD",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VVVV += 0.500000000 * np.einsum("ji,kA,iB,CDjk->CDAB",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVVV += -0.500000000 * np.einsum("EA,iB,jE,CDij->CDAB",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVVV += -0.500000000 * np.einsum("AE,Bi,Ej,ijCD->ABCD",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VVoV += -0.500000000 * np.einsum("Di,jA,kD,BCjk->BCiA",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoV += -1.000000000 * np.einsum("Aj,kB,jD,CDik->ACiB",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoV += 0.500000000 * np.einsum("Dj,jA,kD,BCik->BCiA",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoV += 1.000000000 * np.einsum("ja,kA,Bj,aCik->BCiA",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1VVoV += 0.500000000 * np.einsum("jD,kA,Di,BCjk->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoV += -1.000000000 * np.einsum("jD,kA,Bj,CDik->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoV += 0.500000000 * np.einsum("jD,kA,Dk,BCij->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVvV += 1.000000000 * np.einsum("ji,Ak,Bj,ikaC->ABaC",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1VVvV += -0.500000000 * np.einsum("Da,iA,jD,BCij->BCaA",f["Vv"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVvV += -1.000000000 * np.einsum("AD,Bi,Dj,ijaC->ABaC",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1VVoo += -0.500000000 * np.einsum("lk,kC,Ci,ABjl->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoo += -0.500000000 * np.einsum("lk,kC,Al,BCij->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoo += -0.500000000 * np.einsum("Ca,kC,Ak,aBij->ABij",f["Vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1VVoo += 0.500000000 * np.einsum("DC,kD,Ci,ABjk->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VVoo += 0.500000000 * np.einsum("DC,kD,Ak,BCij->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1VV += -1.000000000 * np.einsum("ji,Ak,Cj,ikBC->AB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("ji,Ck,Aj,ikBC->AB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("ji,iA,kC,BCjk->BA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VV += -1.000000000 * np.einsum("ji,kA,iC,BCjk->BA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("Ca,iA,jC,aBij->BA",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("CA,iD,jC,BDij->BA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("aC,Ai,Cj,ijaB->AB",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1VV += 1.000000000 * np.einsum("AC,Di,Cj,ijBD->AB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VV += -1.000000000 * np.einsum("DC,Ai,Cj,ijBD->AB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1VV += -1.000000000 * np.einsum("DC,iA,jD,BCij->BA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += 1.000000000 * np.einsum("Bi,jC,kB,ACjk->Ai",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += 1.000000000 * np.einsum("Aj,kB,jC,BCik->Ai",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += -2.000000000 * np.einsum("Bj,jC,kB,ACik->Ai",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += -1.000000000 * np.einsum("ja,kB,Aj,aBik->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1Vo += 1.000000000 * np.einsum("ja,kB,Bj,aAik->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1Vo += -1.000000000 * np.einsum("jB,kC,Bi,ACjk->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += -1.000000000 * np.einsum("jB,kC,Aj,BCik->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += -1.000000000 * np.einsum("jB,kC,Cj,ABik->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vo += -1.000000000 * np.einsum("jB,kC,Bk,ACij->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vv += -1.000000000 * np.einsum("ji,Ak,Bj,ikaB->Aa",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1Vv += 1.000000000 * np.einsum("ji,Bk,Aj,ikaB->Aa",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1Vv += 1.000000000 * np.einsum("Ba,iC,jB,ACij->Aa",f["Vv"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1Vv += 1.000000000 * np.einsum("AB,Ci,Bj,ijaC->Aa",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1Vv += -1.000000000 * np.einsum("CB,Ai,Bj,ijaC->Aa",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVVV += 1.000000000 * np.einsum("aj,jA,Bk,ikaC->iBAC",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVVV += -1.000000000 * np.einsum("Dj,jA,Bk,ikCD->iBAC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVVV += 0.500000000 * np.einsum("Dj,iD,Ak,jkBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVVV += 0.500000000 * np.einsum("Dj,kD,Ak,ijBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVVV += -1.000000000 * np.einsum("jA,Bk,Dj,ikCD->iBAC",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVVV += -0.500000000 * np.einsum("iD,Aj,Dk,jkBC->iABC",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVVV += 0.500000000 * np.einsum("jD,Dk,Aj,ikBC->iABC",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("ki,Al,Ck,jlBC->jAiB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("ik,lA,kC,BCjl->iBjA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("lk,Ci,Al,jkBC->jAiB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("lk,kA,iC,BCjl->iBjA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("Ca,kA,iC,aBjk->iBjA",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1oVoV += 1.000000000 * np.einsum("CA,iD,kC,BDjk->iBjA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoV += -1.000000000 * np.einsum("aC,Ci,Ak,jkaB->jAiB",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVoV += 1.000000000 * np.einsum("AC,Di,Ck,jkBD->jAiB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVoV += 1.000000000 * np.einsum("DC,Ci,Ak,jkBD->jAiB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVoV += 1.000000000 * np.einsum("DC,kA,iD,BCjk->iBjA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVvV += 1.000000000 * np.einsum("Cj,jA,Bk,ikaC->iBaA",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvV += 1.000000000 * np.einsum("Cj,iC,Ak,jkaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvV += 1.000000000 * np.einsum("Cj,kC,Ak,ijaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvV += -1.000000000 * np.einsum("ja,Ak,Cj,ikBC->iAaB",f["ov"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oVvV += 1.000000000 * np.einsum("jA,Bk,Cj,ikaC->iBaA",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvV += -1.000000000 * np.einsum("iC,Aj,Ck,jkaB->iAaB",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvV += 1.000000000 * np.einsum("jC,Ck,Aj,ikaB->iAaB",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVoo += -1.000000000 * np.einsum("Bi,jC,lB,ACkl->jAik",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoo += -0.500000000 * np.einsum("Al,iB,lC,BCjk->iAjk",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoo += 0.500000000 * np.einsum("Bl,lC,iB,ACjk->iAjk",f["Vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoo += 0.500000000 * np.einsum("la,iB,Al,aBjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1oVoo += -0.500000000 * np.einsum("la,iB,Bl,aAjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1oVoo += -1.000000000 * np.einsum("lB,iC,Bj,ACkl->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoo += 0.500000000 * np.einsum("lB,iC,Al,BCjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVoo += 0.500000000 * np.einsum("lB,iC,Cl,ABjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVov += -1.000000000 * np.einsum("ki,Al,Bk,jlaB->jAia",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVov += -1.000000000 * np.einsum("lk,Bi,Al,jkaB->jAia",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVov += 1.000000000 * np.einsum("Ba,iC,kB,ACjk->iAja",f["Vv"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oVov += 1.000000000 * np.einsum("AB,Ci,Bk,jkaC->jAia",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVov += 1.000000000 * np.einsum("CB,Bi,Ak,jkaC->jAia",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oVvv += -1.000000000 * np.einsum("ja,Ak,Bj,ikbB->iAab",f["ov"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ooVV += -0.500000000 * np.einsum("lk,kA,Cl,ijBC->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ooVV += -0.500000000 * np.einsum("lk,iC,Cl,jkAB->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ooVV += -0.500000000 * np.einsum("aC,kA,Ck,ijaB->ijAB",f["vV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ooVV += 0.500000000 * np.einsum("DC,kA,Ck,ijBD->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ooVV += 0.500000000 * np.einsum("DC,iD,Ck,jkAB->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += 0.500000000 * np.einsum("al,lA,Bi,jkaB->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oooV += -0.500000000 * np.einsum("al,lB,Bi,jkaA->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oooV += 0.500000000 * np.einsum("Bl,lA,Ci,jkBC->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += -1.000000000 * np.einsum("Bl,iB,Cj,klAC->ikjA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += 0.500000000 * np.einsum("Bl,lC,Ci,jkAB->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += -0.500000000 * np.einsum("lA,Bi,Cl,jkBC->jkiA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += -1.000000000 * np.einsum("iB,Cj,Bl,klAC->ikjA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooV += 0.500000000 * np.einsum("lB,Bi,Cl,jkAC->jkiA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oovV += 0.500000000 * np.einsum("lk,kA,Bl,ijaB->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oovV += -1.000000000 * np.einsum("lk,iB,Bl,jkaA->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oovV += -0.500000000 * np.einsum("CB,kA,Bk,ijaC->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oovV += 1.000000000 * np.einsum("CB,iC,Bk,jkaA->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oooo += 0.500000000 * np.einsum("mi,Aj,Bm,klAB->klij",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooo += 0.500000000 * np.einsum("im,jA,mB,ABkl->ijkl",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oooo += -0.500000000 * np.einsum("Aa,iB,jA,aBkl->ijkl",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1oooo += -0.500000000 * np.einsum("aA,Bi,Aj,klaB->klij",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oooo += -0.500000000 * np.einsum("BA,Ci,Aj,klBC->klij",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oooo += -0.500000000 * np.einsum("BA,iC,jB,ACkl->ijkl",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1ooov += -1.000000000 * np.einsum("Al,iA,Bj,klaB->ikja",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ooov += 0.500000000 * np.einsum("Al,lB,Bi,jkaA->jkia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ooov += -0.500000000 * np.einsum("la,Ai,Bl,jkAB->jkia",f["ov"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ooov += -1.000000000 * np.einsum("iA,Bj,Al,klaB->ikja",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ooov += 0.500000000 * np.einsum("lA,Ai,Bl,jkaB->jkia",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ovoV += -1.000000000 * np.einsum("ik,lA,kB,aBjl->iajA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoV += -1.000000000 * np.einsum("lk,kA,iB,aBjl->iajA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoV += 1.000000000 * np.einsum("BA,iC,kB,aCjk->iajA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoV += 1.000000000 * np.einsum("aB,Ci,Bk,jkAC->jaiA",f["vV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ovoV += 1.000000000 * np.einsum("CB,kA,iC,aBjk->iajA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoo += -1.000000000 * np.einsum("Ai,jB,lA,aBkl->jaik",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoo += -0.500000000 * np.einsum("al,iA,lB,ABjk->iajk",f["vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1ovoo += 0.500000000 * np.einsum("Al,lB,iA,aBjk->iajk",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoo += -1.000000000 * np.einsum("lA,iB,Aj,aBkl->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovoo += 0.500000000 * np.einsum("lA,iB,Bl,aAjk->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovov += 1.000000000 * np.einsum("Aa,iB,kA,bBjk->ibja",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1ovov += 1.000000000 * np.einsum("aA,Bi,Ak,jkbB->jaib",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oV += -1.000000000 * np.einsum("aj,jA,Bk,ikaB->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oV += 1.000000000 * np.einsum("aj,jB,Bk,ikaA->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oV += -1.000000000 * np.einsum("Bj,jA,Ck,ikBC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += -1.000000000 * np.einsum("Bj,iB,Ck,jkAC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += -1.000000000 * np.einsum("Bj,kB,Ck,ijAC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += -1.000000000 * np.einsum("Bj,jC,Ck,ikAB->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += 1.000000000 * np.einsum("jA,Bk,Cj,ikBC->iA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += 1.000000000 * np.einsum("iB,Cj,Bk,jkAC->iA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oV += -2.000000000 * np.einsum("jB,Bk,Cj,ikAC->iA",f["oV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("ki,Al,Bk,jlAB->ji",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("ik,lA,kB,ABjl->ij",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("lk,Ai,Bl,jkAB->ji",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("lk,iA,kB,ABjl->ij",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("Aa,iB,kA,aBjk->ij",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("Aa,kB,iA,aBjk->ij",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("aA,Ai,Bk,jkaB->ji",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("aA,Bi,Ak,jkaB->ji",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("BA,Ai,Ck,jkBC->ji",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("BA,Ci,Ak,jkBC->ji",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1oo += -1.000000000 * np.einsum("BA,iC,kB,ACjk->ij",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1oo += 1.000000000 * np.einsum("BA,kC,iB,ACjk->ij",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1ov += -1.000000000 * np.einsum("Aj,iA,Bk,jkaB->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ov += -1.000000000 * np.einsum("Aj,kA,Bk,ijaB->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ov += -1.000000000 * np.einsum("Aj,jB,Bk,ikaA->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ov += 1.000000000 * np.einsum("ja,Ak,Bj,ikAB->ia",f["ov"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1ov += 1.000000000 * np.einsum("iA,Bj,Ak,jkaB->ia",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1ov += -2.000000000 * np.einsum("jA,Ak,Bj,ikaB->ia",f["oV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1vVVV += 1.000000000 * np.einsum("ji,kA,iB,aCjk->aCAB",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVVV += -1.000000000 * np.einsum("DA,iB,jD,aCij->aCAB",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVVV += -0.500000000 * np.einsum("aD,Ai,Dj,ijBC->aABC",f["vV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1vVoV += -1.000000000 * np.einsum("Ci,jA,kC,aBjk->aBiA",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoV += -1.000000000 * np.einsum("aj,kA,jC,BCik->aBiA",f["vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1vVoV += 1.000000000 * np.einsum("Aj,kB,jC,aCik->aAiB",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoV += 1.000000000 * np.einsum("Cj,jA,kC,aBik->aBiA",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoV += 1.000000000 * np.einsum("jC,kA,Ci,aBjk->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoV += 1.000000000 * np.einsum("jC,kA,Bj,aCik->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoV += 1.000000000 * np.einsum("jC,kA,Ck,aBij->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVvV += -1.000000000 * np.einsum("Ca,iA,jC,bBij->bBaA",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVvV += -1.000000000 * np.einsum("aC,Ai,Cj,ijbB->aAbB",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1vVoo += -1.000000000 * np.einsum("lk,kB,Bi,aAjl->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoo += 0.500000000 * np.einsum("lk,kB,Al,aBij->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoo += 1.000000000 * np.einsum("CB,kC,Bi,aAjk->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vVoo += -0.500000000 * np.einsum("CB,kC,Ak,aBij->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vvoV += -1.000000000 * np.einsum("aj,kA,jB,bBik->abiA",f["vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vV += 1.000000000 * np.einsum("ji,iA,kB,aBjk->aA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vV += -1.000000000 * np.einsum("ji,kA,iB,aBjk->aA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vV += 1.000000000 * np.einsum("BA,iC,jB,aCij->aA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vV += 1.000000000 * np.einsum("aB,Ci,Bj,ijAC->aA",f["vV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1vV += -1.000000000 * np.einsum("CB,iA,jC,aBij->aA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vo += 1.000000000 * np.einsum("Ai,jB,kA,aBjk->ai",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vo += 1.000000000 * np.einsum("aj,kA,jB,ABik->ai",f["vo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1vo += -2.000000000 * np.einsum("Aj,jB,kA,aBik->ai",f["Vo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vo += -1.000000000 * np.einsum("jA,kB,Ai,aBjk->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vo += -1.000000000 * np.einsum("jA,kB,Bj,aAik->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vo += -1.000000000 * np.einsum("jA,kB,Ak,aBij->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs1s2s1vv += 1.000000000 * np.einsum("Aa,iB,jA,bBij->ba",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1vv += 1.000000000 * np.einsum("aA,Bi,Aj,ijbB->ab",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1 += 1.000000000 * np.einsum("ji,Ak,Bj,ikAB->",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1 += 1.000000000 * np.einsum("ji,kA,iB,ABjk->",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs1s2s1 += -1.000000000 * np.einsum("Aa,iB,jA,aBij->",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs1s2s1 += -1.000000000 * np.einsum("aA,Bi,Aj,ijaB->",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs1s2s1 += -1.000000000 * np.einsum("BA,Ci,Aj,ijBC->",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs1s2s1 += -1.000000000 * np.einsum("BA,iC,jB,ACij->",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")

# %%
# [[[F,s2_ext],s1_ext],s1_ext]
print("[[[F,s2_ext],s1_ext],s1_ext]")
Fs2s1s1 = w.commutator(F,s2_ext,s1_ext,s1_ext)
expr = wt.contract(Fs2s1s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2s1s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s2_ext],s1_ext],s1_ext]
# fs2s1s1VVVV += 1.000000000 * np.einsum("ji,Ak,Bj,ikCD->ABCD",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VVVV += 1.000000000 * np.einsum("ji,kA,iB,CDjk->CDAB",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVVV += 1.000000000 * np.einsum("Aa,iB,jC,aDij->ADBC",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1VVVV += 1.000000000 * np.einsum("aA,Bi,Cj,ijaD->BCAD",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVVV += -1.000000000 * np.einsum("EA,Bi,Cj,ijDE->BCAD",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VVVV += -1.000000000 * np.einsum("AE,iB,jC,DEij->ADBC",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoV += 1.000000000 * np.einsum("ai,Aj,Bk,jkaC->ABiC",f["vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVoV += -1.000000000 * np.einsum("Di,Aj,Bk,jkCD->ABiC",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VVoV += -2.000000000 * np.einsum("Aj,Di,Bk,jkCD->ABiC",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VVoV += 2.000000000 * np.einsum("ja,kA,Bj,aCik->BCiA",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1VVoV += -0.500000000 * np.einsum("jA,kD,Di,BCjk->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoV += -1.000000000 * np.einsum("jA,kD,Bk,CDij->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoV += 1.000000000 * np.einsum("jD,kA,Di,BCjk->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoV += -2.000000000 * np.einsum("jD,kA,Bj,CDik->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoV += 0.500000000 * np.einsum("jD,kA,Dk,BCij->BCiA",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVvV += 2.000000000 * np.einsum("ji,Ak,Bj,ikaC->ABaC",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVvV += 1.000000000 * np.einsum("ba,Ai,Bj,ijbC->ABaC",f["vv"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVvV += -1.000000000 * np.einsum("Da,Ai,Bj,ijCD->ABaC",f["Vv"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VVvV += 1.000000000 * np.einsum("DA,Bi,Cj,ijaD->BCaA",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVoo += 0.500000000 * np.einsum("ki,lC,Cj,ABkl->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoo += 1.000000000 * np.einsum("ki,lC,Al,BCjk->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoo += -0.500000000 * np.einsum("lk,kC,Ci,ABjl->ABij",f["oo"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoo += 1.000000000 * np.einsum("Aa,kC,Ci,aBjk->ABij",f["Vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1VVoo += -0.500000000 * np.einsum("Aa,kC,Bk,aCij->ABij",f["Vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1VVoo += -0.500000000 * np.einsum("Ca,kC,Ak,aBij->ABij",f["Vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1VVoo += -1.000000000 * np.einsum("AC,kD,Di,BCjk->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoo += -0.500000000 * np.einsum("AC,kD,Bk,CDij->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVoo += 0.500000000 * np.einsum("DC,kD,Ak,BCij->ABij",f["VV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVov += -1.000000000 * np.einsum("Ci,Aj,Bk,jkaC->ABia",f["Vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVov += -2.000000000 * np.einsum("Aj,Ci,Bk,jkaC->ABia",f["Vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VVov += -0.500000000 * np.einsum("ja,kC,Ci,ABjk->ABia",f["ov"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVov += -1.000000000 * np.einsum("ja,kC,Ak,BCij->ABia",f["ov"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1VVvv += -1.000000000 * np.einsum("Ca,Ai,Bj,ijbC->ABab",f["Vv"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("ji,Ak,Cj,ikBC->AB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VV += 2.000000000 * np.einsum("ji,Ck,Aj,ikBC->AB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VV += 2.000000000 * np.einsum("ji,iA,kC,BCjk->BA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("ji,kA,iC,BCjk->BA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("Aa,iB,jC,aCij->AB",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1VV += 2.000000000 * np.einsum("Ca,iA,jC,aBij->BA",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("aA,Bi,Cj,ijaC->BA",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("CA,Bi,Dj,ijCD->BA",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VV += 2.000000000 * np.einsum("aC,Ai,Cj,ijaB->AB",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("AC,iB,jD,CDij->AB",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("DC,Ai,Cj,ijBD->AB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1VV += -2.000000000 * np.einsum("DC,iA,jD,BCij->BA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("ai,Aj,Bk,jkaB->Ai",f["vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("Bi,Aj,Ck,jkBC->Ai",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("aj,Bi,Ak,jkaB->Ai",f["vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("Aj,Bi,Ck,jkBC->Ai",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("Bj,Ci,Ak,jkBC->Ai",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1Vo += -1.000000000 * np.einsum("ja,kB,Bi,aAjk->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("ja,kB,Aj,aBik->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1Vo += 2.000000000 * np.einsum("ja,kB,Bj,aAik->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1Vo += 1.000000000 * np.einsum("ja,kB,Ak,aBij->Ai",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("jB,kC,Bi,ACjk->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += 1.000000000 * np.einsum("jB,kC,Ci,ABjk->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("jB,kC,Aj,BCik->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("jB,kC,Cj,ABik->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += 1.000000000 * np.einsum("jB,kC,Ak,BCij->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vo += -2.000000000 * np.einsum("jB,kC,Bk,ACij->Ai",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1Vv += -2.000000000 * np.einsum("ji,Ak,Bj,ikaB->Aa",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1Vv += 2.000000000 * np.einsum("ji,Bk,Aj,ikaB->Aa",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1Vv += -2.000000000 * np.einsum("ba,Ai,Bj,ijbB->Aa",f["vv"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1Vv += -2.000000000 * np.einsum("Ba,Ai,Cj,ijBC->Aa",f["Vv"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1Vv += -2.000000000 * np.einsum("CB,Ai,Bj,ijaC->Aa",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVVV += 2.000000000 * np.einsum("aj,jA,Bk,ikaC->iBAC",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVVV += -1.000000000 * np.einsum("Aj,kB,Dk,ijCD->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVVV += -0.500000000 * np.einsum("Aj,iD,Dk,jkBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVVV += -2.000000000 * np.einsum("Dj,jA,Bk,ikCD->iBAC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVVV += 1.000000000 * np.einsum("Dj,iD,Ak,jkBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVVV += 0.500000000 * np.einsum("Dj,kD,Ak,ijBC->iABC",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVVV += 1.000000000 * np.einsum("ia,jA,kB,aCjk->iCAB",f["ov"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVVV += -2.000000000 * np.einsum("jA,kB,iD,CDjk->iCAB",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVVV += -1.000000000 * np.einsum("iD,jA,kB,CDjk->iCAB",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("ki,lA,jC,BCkl->jBiA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("ik,Cj,Al,klBC->iAjB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("lk,Ci,Al,jkBC->jAiB",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("lk,kA,iC,BCjl->iBjA",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("Aa,kB,iC,aCjk->iAjB",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("Ca,kA,iC,aBjk->iBjA",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("aA,Ci,Bk,jkaC->jBiA",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("CA,Di,Bk,jkCD->jBiA",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoV += -2.000000000 * np.einsum("aC,Ci,Ak,jkaB->jAiB",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("AC,kB,iD,CDjk->iAjB",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("DC,Ci,Ak,jkBD->jAiB",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoV += 2.000000000 * np.einsum("DC,kA,iD,BCjk->iBjA",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVvV += 1.000000000 * np.einsum("Aj,kB,Ck,ijaC->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVvV += -1.000000000 * np.einsum("Aj,iC,Ck,jkaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVvV += 2.000000000 * np.einsum("Cj,jA,Bk,ikaC->iBaA",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVvV += 2.000000000 * np.einsum("Cj,iC,Ak,jkaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVvV += 1.000000000 * np.einsum("Cj,kC,Ak,ijaB->iAaB",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVvV += -2.000000000 * np.einsum("ja,kA,iC,BCjk->iBaA",f["ov"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoo += -2.000000000 * np.einsum("ai,Bj,Al,klaB->kAij",f["vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVoo += -2.000000000 * np.einsum("Bi,Cj,Al,klBC->kAij",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoo += -1.000000000 * np.einsum("Al,Bi,Cj,klBC->kAij",f["Vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVoo += 1.000000000 * np.einsum("ia,lB,Bj,aAkl->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoo += -0.500000000 * np.einsum("ia,lB,Al,aBjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoo += 1.000000000 * np.einsum("la,iB,Al,aBjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoo += -0.500000000 * np.einsum("la,iB,Bl,aAjk->iAjk",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1oVoo += -1.000000000 * np.einsum("iB,lC,Cj,ABkl->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoo += -0.500000000 * np.einsum("iB,lC,Al,BCjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoo += -2.000000000 * np.einsum("lB,iC,Bj,ACkl->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoo += 1.000000000 * np.einsum("lB,iC,Al,BCjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVoo += 0.500000000 * np.einsum("lB,iC,Cl,ABjk->iAjk",f["oV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1oVov += -2.000000000 * np.einsum("ik,Bj,Al,klaB->iAja",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVov += -2.000000000 * np.einsum("lk,Bi,Al,jkaB->jAia",f["oo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVov += 2.000000000 * np.einsum("ba,Bi,Ak,jkbB->jAia",f["vv"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oVov += 2.000000000 * np.einsum("Ba,Ci,Ak,jkBC->jAia",f["Vv"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oVov += 2.000000000 * np.einsum("CB,Bi,Ak,jkaC->jAia",f["VV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooVV += 1.000000000 * np.einsum("ik,lA,Cl,jkBC->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ooVV += 0.500000000 * np.einsum("ik,jC,Cl,klAB->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ooVV += -0.500000000 * np.einsum("lk,iC,Cl,jkAB->ijAB",f["oo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ooVV += -0.500000000 * np.einsum("aA,kB,Ck,ijaC->ijAB",f["vV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooVV += 1.000000000 * np.einsum("aA,iC,Ck,jkaB->ijAB",f["vV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooVV += -0.500000000 * np.einsum("CA,kB,Dk,ijCD->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ooVV += -1.000000000 * np.einsum("CA,iD,Dk,jkBC->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ooVV += -0.500000000 * np.einsum("aC,kA,Ck,ijaB->ijAB",f["vV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooVV += 0.500000000 * np.einsum("DC,kA,Ck,ijBD->ijAB",f["VV"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += -0.500000000 * np.einsum("ai,lA,Bl,jkaB->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooV += 1.000000000 * np.einsum("ai,jB,Bl,klaA->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooV += -0.500000000 * np.einsum("Bi,lA,Cl,jkBC->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += -1.000000000 * np.einsum("Bi,jC,Cl,klAB->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += 1.000000000 * np.einsum("al,lA,Bi,jkaB->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooV += -0.500000000 * np.einsum("al,lB,Bi,jkaA->jkiA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooV += 1.000000000 * np.einsum("Bl,lA,Ci,jkBC->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += -2.000000000 * np.einsum("Bl,iB,Cj,klAC->ikjA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += 0.500000000 * np.einsum("Bl,lC,Ci,jkAB->jkiA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooV += -2.000000000 * np.einsum("ia,lA,jB,aBkl->ijkA",f["ov"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oooV += -1.000000000 * np.einsum("lA,iB,jC,BCkl->ijkA",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oooV += -2.000000000 * np.einsum("iB,lA,jC,BCkl->ijkA",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oovV += -1.000000000 * np.einsum("ik,lA,Bl,jkaB->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += 1.000000000 * np.einsum("ik,jB,Bl,klaA->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += -1.000000000 * np.einsum("lk,iB,Bl,jkaA->ijaA",f["oo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += -0.500000000 * np.einsum("ba,kA,Bk,ijbB->ijaA",f["vv"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += 1.000000000 * np.einsum("ba,iB,Bk,jkbA->ijaA",f["vv"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += -0.500000000 * np.einsum("Ba,kA,Ck,ijBC->ijaA",f["Vv"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oovV += -1.000000000 * np.einsum("Ba,iC,Ck,jkAB->ijaA",f["Vv"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oovV += 1.000000000 * np.einsum("BA,iC,Ck,jkaB->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oovV += -0.500000000 * np.einsum("CB,kA,Bk,ijaC->ijaA",f["VV"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooo += 1.000000000 * np.einsum("mi,jA,kB,ABlm->jkil",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oooo += 1.000000000 * np.einsum("im,Aj,Bk,lmAB->iljk",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooo += -1.000000000 * np.einsum("Aa,iB,jA,aBkl->ijkl",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oooo += -1.000000000 * np.einsum("aA,Bi,Aj,klaB->klij",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oooo += -1.000000000 * np.einsum("BA,Ci,Aj,klBC->klij",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oooo += -1.000000000 * np.einsum("BA,iC,jB,ACkl->ijkl",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1ooov += -1.000000000 * np.einsum("Ai,jB,Bl,klaA->jkia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooov += -2.000000000 * np.einsum("Al,iA,Bj,klaB->ikja",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooov += 0.500000000 * np.einsum("Al,lB,Bi,jkaA->jkia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ooov += -1.000000000 * np.einsum("la,iA,jB,ABkl->ijka",f["ov"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oovv += -1.000000000 * np.einsum("Aa,iB,Bk,jkbA->ijab",f["Vv"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ovVV += -1.000000000 * np.einsum("aj,kA,Ck,ijBC->iaAB",f["vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ovVV += -0.500000000 * np.einsum("aj,iC,Ck,jkAB->iaAB",f["vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ovVV += -2.000000000 * np.einsum("jA,kB,iC,aCjk->iaAB",f["oV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovVV += -1.000000000 * np.einsum("iC,jA,kB,aCjk->iaAB",f["oV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoV += -2.000000000 * np.einsum("ki,lA,jB,aBkl->jaiA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoV += -2.000000000 * np.einsum("lk,kA,iB,aBjl->iajA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoV += 2.000000000 * np.einsum("ab,kA,iB,bBjk->iajA",f["vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoV += 2.000000000 * np.einsum("aB,kA,iC,BCjk->iajA",f["vV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1ovoV += 2.000000000 * np.einsum("CB,kA,iC,aBjk->iajA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovvV += 1.000000000 * np.einsum("aj,kA,Bk,ijbB->iabA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ovvV += -1.000000000 * np.einsum("aj,iB,Bk,jkbA->iabA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ovvV += -2.000000000 * np.einsum("ja,kA,iB,bBjk->ibaA",f["ov"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoo += -1.000000000 * np.einsum("al,Ai,Bj,klAB->kaij",f["vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1ovoo += -1.000000000 * np.einsum("iA,lB,Bj,aAkl->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoo += -2.000000000 * np.einsum("lA,iB,Aj,aBkl->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1ovoo += 0.500000000 * np.einsum("lA,iB,Bl,aAjk->iajk",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("aj,jA,Bk,ikaB->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oV += 1.000000000 * np.einsum("aj,kA,Bk,ijaB->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oV += -1.000000000 * np.einsum("aj,iB,Bk,jkaA->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oV += 2.000000000 * np.einsum("aj,jB,Bk,ikaA->iA",f["vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("Bj,jA,Ck,ikBC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += 1.000000000 * np.einsum("Bj,kA,Ck,ijBC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("Bj,iB,Ck,jkAC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("Bj,kB,Ck,ijAC->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += 1.000000000 * np.einsum("Bj,iC,Ck,jkAB->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("Bj,jC,Ck,ikAB->iA",f["Vo"],t1["oV"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("ia,jA,kB,aBjk->iA",f["ov"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("ja,kA,iB,aBjk->iA",f["ov"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("jA,iB,kC,BCjk->iA",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("iB,jA,kC,BCjk->iA",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oV += -2.000000000 * np.einsum("jB,kA,iC,BCjk->iA",f["oV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("ki,jA,lB,ABkl->ji",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("ik,Aj,Bl,klAB->ij",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("lk,Ai,Bl,jkAB->ji",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("lk,iA,kB,ABjl->ij",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("Aa,iB,kA,aBjk->ij",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oo += 2.000000000 * np.einsum("Aa,kB,iA,aBjk->ij",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1oo += 2.000000000 * np.einsum("aA,Ai,Bk,jkaB->ji",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("aA,Bi,Ak,jkaB->ji",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1oo += 2.000000000 * np.einsum("BA,Ai,Ck,jkBC->ji",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("BA,Ci,Ak,jkBC->ji",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1oo += -2.000000000 * np.einsum("BA,iC,kB,ACjk->ij",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1oo += 2.000000000 * np.einsum("BA,kC,iB,ACjk->ij",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1ov += -2.000000000 * np.einsum("Aj,iA,Bk,jkaB->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ov += -2.000000000 * np.einsum("Aj,kA,Bk,ijaB->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ov += 1.000000000 * np.einsum("Aj,iB,Bk,jkaA->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ov += -2.000000000 * np.einsum("Aj,jB,Bk,ikaA->ia",f["Vo"],t1["oV"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1ov += -2.000000000 * np.einsum("ja,iA,kB,ABjk->ia",f["ov"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1vVVV += 2.000000000 * np.einsum("ji,kA,iB,aCjk->aCAB",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVVV += 1.000000000 * np.einsum("ab,iA,jB,bCij->aCAB",f["vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVVV += -1.000000000 * np.einsum("aD,iA,jB,CDij->aCAB",f["vV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1vVVV += 1.000000000 * np.einsum("AD,iB,jC,aDij->aABC",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoV += -2.000000000 * np.einsum("aj,Ci,Ak,jkBC->aAiB",f["vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1vVoV += -1.000000000 * np.einsum("jA,kC,Ci,aBjk->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoV += 1.000000000 * np.einsum("jA,kC,Bk,aCij->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoV += 2.000000000 * np.einsum("jC,kA,Ci,aBjk->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoV += 2.000000000 * np.einsum("jC,kA,Bj,aCik->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoV += 1.000000000 * np.einsum("jC,kA,Ck,aBij->aBiA",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += 1.000000000 * np.einsum("ki,lB,Bj,aAkl->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += -1.000000000 * np.einsum("ki,lB,Al,aBjk->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += -1.000000000 * np.einsum("lk,kB,Bi,aAjl->aAij",f["oo"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += 1.000000000 * np.einsum("ab,kB,Bi,bAjk->aAij",f["vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += -0.500000000 * np.einsum("ab,kB,Ak,bBij->aAij",f["vv"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += -1.000000000 * np.einsum("aB,kC,Ci,ABjk->aAij",f["vV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1vVoo += -0.500000000 * np.einsum("aB,kC,Ak,BCij->aAij",f["vV"],t1["oV"],t1["Vo"],t2["VVoo"],optimize="optimal")
# fs2s1s1vVoo += 1.000000000 * np.einsum("AB,kC,Ci,aBjk->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVoo += -0.500000000 * np.einsum("CB,kC,Ak,aBij->aAij",f["VV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVov += -2.000000000 * np.einsum("aj,Bi,Ak,jkbB->aAib",f["vo"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1vVov += -1.000000000 * np.einsum("ja,kB,Bi,bAjk->bAia",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vVov += 1.000000000 * np.einsum("ja,kB,Ak,bBij->bAia",f["ov"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vvVV += -1.000000000 * np.einsum("aC,iA,jB,bCij->abAB",f["vV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vvoo += -1.000000000 * np.einsum("aA,kB,Bi,bAjk->abij",f["vV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vV += 2.000000000 * np.einsum("ji,iA,kB,aBjk->aA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vV += -2.000000000 * np.einsum("ji,kA,iB,aBjk->aA",f["oo"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vV += -2.000000000 * np.einsum("ab,iA,jB,bBij->aA",f["vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vV += -2.000000000 * np.einsum("aB,iA,jC,BCij->aA",f["vV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1vV += -2.000000000 * np.einsum("CB,iA,jC,aBij->aA",f["VV"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1vo += -2.000000000 * np.einsum("aj,Ai,Bk,jkAB->ai",f["vo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1vo += -2.000000000 * np.einsum("jA,kB,Ai,aBjk->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vo += 1.000000000 * np.einsum("jA,kB,Bi,aAjk->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vo += -2.000000000 * np.einsum("jA,kB,Bj,aAik->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1vo += -2.000000000 * np.einsum("jA,kB,Ak,aBij->ai",f["oV"],t1["oV"],t1["Vo"],t2["vVoo"],optimize="optimal")
# fs2s1s1 += 2.000000000 * np.einsum("ji,Ak,Bj,ikAB->",f["oo"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1 += 2.000000000 * np.einsum("ji,kA,iB,ABjk->",f["oo"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")
# fs2s1s1 += -2.000000000 * np.einsum("Aa,iB,jA,aBij->",f["Vv"],t1["oV"],t1["oV"],t2["vVoo"],optimize="optimal")
# fs2s1s1 += -2.000000000 * np.einsum("aA,Bi,Aj,ijaB->",f["vV"],t1["Vo"],t1["Vo"],t2["oovV"],optimize="optimal")
# fs2s1s1 += -2.000000000 * np.einsum("BA,Ci,Aj,ijBC->",f["VV"],t1["Vo"],t1["Vo"],t2["ooVV"],optimize="optimal")
# fs2s1s1 += -2.000000000 * np.einsum("BA,iC,jB,ACij->",f["VV"],t1["oV"],t1["oV"],t2["VVoo"],optimize="optimal")

# %%
# [[[F,s1_ext],s2_ext],s2_ext]
print("[[[F,s1_ext],s2_ext],s2_ext]")
Fs1s2s2 = w.commutator(F,s1_ext,s2_ext,s2_ext)
expr = wt.contract(Fs1s2s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs1s2s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s1_ext],s2_ext],s2_ext]
# fs1s2s2VVVoVV += 0.250000000 * np.einsum("kj,Ak,jlBC,DEil->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVoVV += -0.250000000 * np.einsum("AG,Gj,jkBC,DEik->ADEiBC",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVovV += 0.500000000 * np.einsum("kj,Ak,jlaB,CDil->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVovV += -0.500000000 * np.einsum("AE,Ej,jkaB,CDik->ACDiaB",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVooo += -0.500000000 * np.einsum("ml,lD,ADij,BCkm->ABCijk",f["oo"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVooo += -0.500000000 * np.einsum("Da,lD,ABil,aCjk->ABCijk",f["Vv"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2VVVooo += 0.500000000 * np.einsum("ED,lE,ADij,BCkl->ABCijk",f["VV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += -0.250000000 * np.einsum("ai,iA,jkaB,CDjk->CDAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += 0.250000000 * np.einsum("Ai,iE,jkBC,DEjk->ADBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += 0.250000000 * np.einsum("Ei,iA,jkBE,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += -0.500000000 * np.einsum("Ei,jE,ikAB,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += -0.250000000 * np.einsum("ia,Ai,jkBC,aDjk->ADBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VVVV += 0.250000000 * np.einsum("iA,Ei,jkBE,CDjk->CDAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += 0.250000000 * np.einsum("iE,Ai,jkBC,DEjk->ADBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVVV += -0.500000000 * np.einsum("iE,Ej,jkAB,CDik->CDAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += 0.250000000 * np.einsum("ji,Dj,klAD,BCkl->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += -1.000000000 * np.einsum("kj,Ak,jlaB,aCil->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VVoV += -1.000000000 * np.einsum("kj,Ak,jlBD,CDil->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += -0.500000000 * np.einsum("kj,Dk,jlAD,BCil->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += 0.250000000 * np.einsum("aD,Di,jkaA,BCjk->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += -0.500000000 * np.einsum("aD,Dj,jkaA,BCik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += 1.000000000 * np.einsum("AD,Dj,jkaB,aCik->ACiB",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VVoV += 1.000000000 * np.einsum("AD,Dj,jkBE,CEik->ACiB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += -0.250000000 * np.einsum("ED,Di,jkAE,BCjk->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVoV += 0.500000000 * np.einsum("ED,Dj,jkAE,BCik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += 0.500000000 * np.einsum("Ai,iD,jkaB,CDjk->ACaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += -0.250000000 * np.einsum("Di,iA,jkaD,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += -1.000000000 * np.einsum("Di,jD,ikaA,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += 0.250000000 * np.einsum("ia,Di,jkAD,BCjk->BCaA",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += -0.500000000 * np.einsum("ib,Ai,jkaB,bCjk->ACaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VVvV += -0.250000000 * np.einsum("iA,Di,jkaD,BCjk->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += 0.500000000 * np.einsum("iD,Ai,jkaB,CDjk->ACaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvV += -1.000000000 * np.einsum("iD,Dj,jkaA,BCik->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += 0.250000000 * np.einsum("ji,Cj,klaC,ABkl->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += -1.000000000 * np.einsum("kj,Ak,jlaC,BCil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += -0.500000000 * np.einsum("kj,Ck,jlaC,ABil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += 1.000000000 * np.einsum("AC,Cj,jkaD,BDik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += -0.250000000 * np.einsum("DC,Ci,jkaD,ABjk->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVov += 0.500000000 * np.einsum("DC,Cj,jkaD,ABik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VVvv += 0.250000000 * np.einsum("ia,Ci,jkbC,ABjk->ABab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("ai,iA,jkaC,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += -1.000000000 * np.einsum("ai,iC,jkaA,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("Ai,iC,jkaB,aCjk->AB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("Ai,iC,jkBD,CDjk->AB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("Ci,iA,jkaC,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("Ci,iA,jkCD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 2.000000000 * np.einsum("Ci,jC,ikaA,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 2.000000000 * np.einsum("Ci,jC,ikAD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 1.000000000 * np.einsum("Ci,iD,jkAC,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("ia,Ai,jkBC,aCjk->AB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += -1.000000000 * np.einsum("ia,Ci,jkAC,aBjk->BA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("iA,Ci,jkaC,aBjk->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("iA,Ci,jkCD,BDjk->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("iC,Ai,jkaB,aCjk->AB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 0.500000000 * np.einsum("iC,Ai,jkBD,CDjk->AB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 1.000000000 * np.einsum("iC,Di,jkAD,BCjk->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2VV += 2.000000000 * np.einsum("iC,Cj,jkaA,aBik->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2VV += 2.000000000 * np.einsum("iC,Cj,jkAD,BDik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += 0.500000000 * np.einsum("ji,Bj,klaB,aAkl->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += 0.500000000 * np.einsum("ji,Bj,klBC,ACkl->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += 1.000000000 * np.einsum("kj,Ak,jlaB,aBil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += 0.500000000 * np.einsum("kj,Ak,jlBC,BCil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += -1.000000000 * np.einsum("kj,Bk,jlaB,aAil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += -1.000000000 * np.einsum("kj,Bk,jlBC,ACil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += -0.500000000 * np.einsum("aB,Bi,jkaC,ACjk->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += 1.000000000 * np.einsum("aB,Bj,jkaC,ACik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += -1.000000000 * np.einsum("AB,Bj,jkaC,aCik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += -0.500000000 * np.einsum("AB,Bj,jkCD,CDik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += -0.500000000 * np.einsum("CB,Bi,jkaC,aAjk->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += -0.500000000 * np.einsum("CB,Bi,jkCD,ADjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vo += 1.000000000 * np.einsum("CB,Bj,jkaC,aAik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vo += 1.000000000 * np.einsum("CB,Bj,jkCD,ADik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 0.500000000 * np.einsum("Ai,iB,jkaC,BCjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 2.000000000 * np.einsum("Bi,jB,ikaC,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 1.000000000 * np.einsum("Bi,iC,jkaB,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 0.500000000 * np.einsum("ia,Bi,jkbB,bAjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vv += 0.500000000 * np.einsum("ia,Bi,jkBC,ACjk->Aa",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 0.500000000 * np.einsum("ib,Ai,jkaB,bBjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vv += -1.000000000 * np.einsum("ib,Bi,jkaB,bAjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2Vv += 0.500000000 * np.einsum("iB,Ai,jkaC,BCjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 1.000000000 * np.einsum("iB,Ci,jkaC,ABjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2Vv += 2.000000000 * np.einsum("iB,Bj,jkaC,ACik->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVVVV += 0.250000000 * np.einsum("kj,jA,ilBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVVVV += -0.250000000 * np.einsum("GA,jG,ikBC,DEjk->iDEABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.250000000 * np.einsum("Ei,kE,jlAB,CDkl->jCDiAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.500000000 * np.einsum("ak,kA,ilaB,CDjl->iCDjAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += 0.500000000 * np.einsum("Ak,kE,ilBC,DEjl->iADjBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += 0.500000000 * np.einsum("Ek,kA,ilBE,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.250000000 * np.einsum("Ek,iE,klAB,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.500000000 * np.einsum("Ek,lE,ikAB,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.500000000 * np.einsum("ka,Ak,ilBC,aDjl->iADjBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVoVV += 0.500000000 * np.einsum("kA,Ek,ilBE,CDjl->iCDjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.250000000 * np.einsum("iE,Ek,klAB,CDjl->iCDjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.250000000 * np.einsum("kE,Ei,jlAB,CDkl->jCDiAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += 0.500000000 * np.einsum("kE,Ak,ilBC,DEjl->iADjBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoVV += -0.500000000 * np.einsum("kE,El,ilAB,CDjk->iCDjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVvVV += -0.500000000 * np.einsum("kj,jA,ilaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVvVV += -0.250000000 * np.einsum("Ea,jE,ikAB,CDjk->iCDaAB",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVvVV += 0.500000000 * np.einsum("EA,jE,ikaB,CDjk->iCDaAB",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVooV += -0.500000000 * np.einsum("li,Dl,jmAD,BCkm->jBCikA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVooV += -0.500000000 * np.einsum("ml,Am,ilaB,aCjk->iACjkB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVooV += -0.500000000 * np.einsum("ml,Am,ilBD,CDjk->iACjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVooV += -0.500000000 * np.einsum("aD,Di,jlaA,BCkl->jBCikA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVooV += 0.500000000 * np.einsum("AD,Dl,ilaB,aCjk->iACjkB",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVooV += 0.500000000 * np.einsum("AD,Dl,ilBE,CEjk->iACjkB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVooV += 0.500000000 * np.einsum("ED,Di,jlAE,BCkl->jBCikA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("Di,kD,jlaA,BCkl->jBCiaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += 1.000000000 * np.einsum("Ak,kD,ilaB,CDjl->iACjaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("Dk,kA,ilaD,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("Dk,iD,klaA,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -1.000000000 * np.einsum("Dk,lD,ikaA,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += 0.500000000 * np.einsum("ka,Dk,ilAD,BCjl->iBCjaA",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -1.000000000 * np.einsum("kb,Ak,ilaB,bCjl->iACjaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("kA,Dk,ilaD,BCjl->iBCjaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("iD,Dk,klaA,BCjl->iBCjaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -0.500000000 * np.einsum("kD,Di,jlaA,BCkl->jBCiaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += 1.000000000 * np.einsum("kD,Ak,ilaB,CDjl->iACjaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovV += -1.000000000 * np.einsum("kD,Dl,ilaA,BCjk->iBCjaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVvvV += -0.500000000 * np.einsum("Da,jD,ikbA,BCjk->iBCabA",f["Vv"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoov += -0.500000000 * np.einsum("li,Cl,jmaC,ABkm->jABika",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoov += -0.500000000 * np.einsum("ml,Am,ilaC,BCjk->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoov += 0.500000000 * np.einsum("AC,Cl,ilaD,BDjk->iABjka",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVoov += 0.500000000 * np.einsum("DC,Ci,jlaD,ABkl->jABika",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVovv += 0.500000000 * np.einsum("ka,Ck,ilbC,ABjl->iABjab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += 0.250000000 * np.einsum("ij,jD,klAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += -1.000000000 * np.einsum("kj,jA,ilaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVV += -1.000000000 * np.einsum("kj,jA,ilBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += -0.500000000 * np.einsum("kj,jD,ilAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += 0.250000000 * np.einsum("Da,iD,jkAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVV += -0.500000000 * np.einsum("Da,jD,ikAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVV += 1.000000000 * np.einsum("DA,jD,ikaB,aCjk->iCAB",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVVV += 1.000000000 * np.einsum("DA,jD,ikBE,CEjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += -0.250000000 * np.einsum("ED,iE,jkAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVVV += 0.500000000 * np.einsum("ED,jE,ikAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ci,kC,jlaA,aBkl->jBiA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ci,kC,jlAD,BDkl->jBiA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("ak,kA,ilaC,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += -2.000000000 * np.einsum("ak,kC,ilaA,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ak,kC,ilaB,aCjl->iAjB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ak,kC,ilBD,CDjl->iAjB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ck,kA,ilaC,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ck,kA,ilCD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ck,iC,klaA,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("Ck,iC,klAD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("Ck,lC,ikaA,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("Ck,lC,ikAD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("Ck,kD,ilAC,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("ka,Ak,ilBC,aCjl->iAjB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += -2.000000000 * np.einsum("ka,Ck,ilAC,aBjl->iBjA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kA,Ck,ilaC,aBjl->iBjA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kA,Ck,ilCD,BDjl->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("iC,Ck,klaA,aBjl->iBjA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("iC,Ck,klAD,BDjl->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kC,Ci,jlaA,aBkl->jBiA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kC,Ci,jlAD,BDkl->jBiA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kC,Ak,ilaB,aCjl->iAjB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 1.000000000 * np.einsum("kC,Ak,ilBD,CDjl->iAjB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("kC,Dk,ilAD,BCjl->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("kC,Cl,ilaA,aBjk->iBjA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoV += 2.000000000 * np.einsum("kC,Cl,ilAD,BDjk->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += 0.500000000 * np.einsum("ij,jC,klaA,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += 1.000000000 * np.einsum("kj,jA,ilaC,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += -1.000000000 * np.einsum("kj,jC,ilaA,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += 1.000000000 * np.einsum("Ca,jC,ikbA,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVvV += 1.000000000 * np.einsum("Ca,jC,ikAD,BDjk->iBaA",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += 0.500000000 * np.einsum("Cb,iC,jkaA,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVvV += -1.000000000 * np.einsum("Cb,jC,ikaA,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVvV += -1.000000000 * np.einsum("CA,jC,ikaD,BDjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += -0.500000000 * np.einsum("DC,iD,jkaA,BCjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvV += 1.000000000 * np.einsum("DC,jD,ikaA,BCjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += -1.000000000 * np.einsum("li,Bl,jmaB,aAkm->jAik",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += -1.000000000 * np.einsum("li,Bl,jmBC,ACkm->jAik",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += 0.500000000 * np.einsum("ml,Am,ilaB,aBjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += 0.250000000 * np.einsum("ml,Am,ilBC,BCjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += -0.500000000 * np.einsum("ml,Bm,ilaB,aAjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += -0.500000000 * np.einsum("ml,Bm,ilBC,ACjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += 1.000000000 * np.einsum("aB,Bi,jlaC,ACkl->jAik",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += 0.500000000 * np.einsum("aB,Bl,ilaC,ACjk->iAjk",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += -0.500000000 * np.einsum("AB,Bl,ilaC,aCjk->iAjk",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += -0.250000000 * np.einsum("AB,Bl,ilCD,CDjk->iAjk",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += 1.000000000 * np.einsum("CB,Bi,jlaC,aAkl->jAik",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += 1.000000000 * np.einsum("CB,Bi,jlCD,ADkl->jAik",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVoo += 0.500000000 * np.einsum("CB,Bl,ilaC,aAjk->iAjk",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVoo += 0.500000000 * np.einsum("CB,Bl,ilCD,ADjk->iAjk",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("Bi,kB,jlaC,ACkl->jAia",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("Ak,kB,ilaC,BCjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("Bk,iB,klaC,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 2.000000000 * np.einsum("Bk,lB,ikaC,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 2.000000000 * np.einsum("Bk,kC,ilaB,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("ka,Bk,ilbB,bAjl->iAja",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("ka,Bk,ilBC,ACjl->iAja",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("kb,Ak,ilaB,bBjl->iAja",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVov += -2.000000000 * np.einsum("kb,Bk,ilaB,bAjl->iAja",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("iB,Bk,klaC,ACjl->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("kB,Bi,jlaC,ACkl->jAia",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 1.000000000 * np.einsum("kB,Ak,ilaC,BCjl->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 2.000000000 * np.einsum("kB,Ck,ilaC,ABjl->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVov += 2.000000000 * np.einsum("kB,Bl,ilaC,ACjk->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oVvv += 1.000000000 * np.einsum("Ba,jB,ikbC,ACjk->iAab",f["Vv"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoVV += -0.500000000 * np.einsum("il,lD,jmAB,CDkm->ijCkAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoVV += -0.500000000 * np.einsum("ml,lA,ijaB,aCkm->ijCkAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoVV += -0.500000000 * np.einsum("ml,lA,ijBD,CDkm->ijCkAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoVV += -0.500000000 * np.einsum("Da,iD,jlAB,aCkl->ijCkAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoVV += 0.500000000 * np.einsum("DA,lD,ijaB,aCkl->ijCkAB",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoVV += 0.500000000 * np.einsum("DA,lD,ijBE,CEkl->ijCkAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoVV += 0.500000000 * np.einsum("ED,iE,jlAB,CDkl->ijCkAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("Ci,mC,jkaA,aBlm->jkBilA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("Ci,mC,jkAD,BDlm->jkBilA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("am,mA,ijaC,BCkl->ijBklA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("am,mC,ijaA,BCkl->ijBklA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("Am,mC,ijaB,aCkl->ijAklB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("Am,mC,ijBD,CDkl->ijAklB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("Cm,mA,ijaC,aBkl->ijBklA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("Cm,mA,ijCD,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("Cm,iC,jmaA,aBkl->ijBklA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("Cm,iC,jmAD,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.500000000 * np.einsum("Cm,mD,ijAC,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("ma,Am,ijBC,aCkl->ijAklB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("ma,Cm,ijAC,aBkl->ijBklA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("mA,Cm,ijaC,aBkl->ijBklA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("mA,Cm,ijCD,BDkl->ijBklA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("iC,Cm,jmaA,aBkl->ijBklA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("iC,Cm,jmAD,BDkl->ijBklA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("mC,Ci,jkaA,aBlm->jkBilA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += -0.500000000 * np.einsum("mC,Ci,jkAD,BDlm->jkBilA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("mC,Am,ijaB,aCkl->ijAklB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.250000000 * np.einsum("mC,Am,ijBD,CDkl->ijAklB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooV += 0.500000000 * np.einsum("mC,Dm,ijAD,BCkl->ijBklA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovV += -1.000000000 * np.einsum("il,lC,jmaA,BCkm->ijBkaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovV += 0.500000000 * np.einsum("ml,lA,ijaC,BCkm->ijBkaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovV += 0.500000000 * np.einsum("Ca,lC,ijbA,bBkl->ijBkaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVovV += 0.500000000 * np.einsum("Ca,lC,ijAD,BDkl->ijBkaA",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovV += -1.000000000 * np.einsum("Cb,iC,jlaA,bBkl->ijBkaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVovV += -0.500000000 * np.einsum("CA,lC,ijaD,BDkl->ijBkaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovV += 1.000000000 * np.einsum("DC,iD,jlaA,BCkl->ijBkaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooo += 0.250000000 * np.einsum("ai,Ba,jkbB,bAlm->jkAilm",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooo += 0.250000000 * np.einsum("ai,Ba,jkBC,AClm->jkAilm",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooo += -0.250000000 * np.einsum("aB,Bi,jkaC,AClm->jkAilm",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVooo += -0.250000000 * np.einsum("CB,Bi,jkaC,aAlm->jkAilm",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVooo += -0.250000000 * np.einsum("CB,Bi,jkCD,ADlm->jkAilm",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += -0.500000000 * np.einsum("Bi,mB,jkaC,AClm->jkAila",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.250000000 * np.einsum("Am,mB,ijaC,BCkl->ijAkla",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += -0.500000000 * np.einsum("Bm,iB,jmaC,ACkl->ijAkla",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.500000000 * np.einsum("Bm,mC,ijaB,ACkl->ijAkla",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.250000000 * np.einsum("ma,Bm,ijbB,bAkl->ijAkla",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.250000000 * np.einsum("ma,Bm,ijBC,ACkl->ijAkla",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.250000000 * np.einsum("mb,Am,ijaB,bBkl->ijAkla",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoov += -0.500000000 * np.einsum("mb,Bm,ijaB,bAkl->ijAkla",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooVoov += -0.500000000 * np.einsum("iB,Bm,jmaC,ACkl->ijAkla",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += -0.500000000 * np.einsum("mB,Bi,jkaC,AClm->jkAila",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.250000000 * np.einsum("mB,Am,ijaC,BCkl->ijAkla",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVoov += 0.500000000 * np.einsum("mB,Cm,ijaC,ABkl->ijAkla",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooVovv += 0.500000000 * np.einsum("Ba,lB,ijbC,ACkl->ijAkab",f["Vv"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooVVV += -0.500000000 * np.einsum("ml,Dm,ilAB,jkCD->ijkABC",f["oo"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs1s2s2oooVVV += -0.500000000 * np.einsum("aD,Dl,ilAB,jkaC->ijkABC",f["vV"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs1s2s2oooVVV += 0.500000000 * np.einsum("ED,Dl,ilAB,jkCE->ijkABC",f["VV"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs1s2s2ooovVV += -0.500000000 * np.einsum("ml,Cm,ilAB,jkaC->ijkaAB",f["oo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooovVV += 1.000000000 * np.einsum("ml,Cm,ijAC,klaB->ijkaAB",f["oo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooovVV += -1.000000000 * np.einsum("bC,Cl,ilaA,jkbB->ijkaAB",f["vV"],t1["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooovVV += 0.500000000 * np.einsum("DC,Cl,ilAB,jkaD->ijkaAB",f["VV"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooovVV += -1.000000000 * np.einsum("DC,Cl,ijAD,klaB->ijkaAB",f["VV"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs1s2s2oooooV += 0.250000000 * np.einsum("ia,aB,jkbA,bBlm->ijklmA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooooV += 0.250000000 * np.einsum("ia,aB,jkAC,BClm->ijklmA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooooV += -0.250000000 * np.einsum("Ba,iB,jkAC,aClm->ijklmA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooooV += -0.250000000 * np.einsum("CB,iC,jkaA,aBlm->ijklmA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooooV += -0.250000000 * np.einsum("CB,iC,jkAD,BDlm->ijklmA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooovvV += 1.000000000 * np.einsum("ml,Bm,ilaA,jkbB->ijkabA",f["oo"],t1["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooovvV += -1.000000000 * np.einsum("CB,Bl,ilaA,jkbC->ijkabA",f["VV"],t1["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs1s2s2ooooov += 0.250000000 * np.einsum("ia,aA,jkbB,ABlm->ijklmb",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooooov += -0.250000000 * np.einsum("Ab,iA,jkaB,bBlm->ijklma",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooooov += -0.250000000 * np.einsum("BA,iB,jkaC,AClm->ijklma",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oovoVV += -0.500000000 * np.einsum("il,lC,jmAB,aCkm->ijakAB",f["oo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoVV += -0.500000000 * np.einsum("ml,lA,ijBC,aCkm->ijakAB",f["oo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoVV += 0.500000000 * np.einsum("CA,lC,ijBD,aDkl->ijakAB",f["VV"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoVV += 0.500000000 * np.einsum("DC,iD,jlAB,aCkl->ijakAB",f["VV"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += -0.500000000 * np.einsum("Bi,mB,jkAC,aClm->jkailA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.250000000 * np.einsum("am,mB,ijbA,bBkl->ijaklA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.250000000 * np.einsum("am,mB,ijAC,BCkl->ijaklA",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.250000000 * np.einsum("bm,mA,ijbB,aBkl->ijaklA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += -0.500000000 * np.einsum("bm,mB,ijbA,aBkl->ijaklA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.250000000 * np.einsum("Bm,mA,ijBC,aCkl->ijaklA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += -0.500000000 * np.einsum("Bm,iB,jmAC,aCkl->ijaklA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.500000000 * np.einsum("Bm,mC,ijAB,aCkl->ijaklA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.250000000 * np.einsum("mA,Bm,ijBC,aCkl->ijaklA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += -0.500000000 * np.einsum("iB,Bm,jmAC,aCkl->ijaklA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += -0.500000000 * np.einsum("mB,Bi,jkAC,aClm->jkailA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooV += 0.500000000 * np.einsum("mB,Cm,ijAC,aBkl->ijaklA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovV += -1.000000000 * np.einsum("il,lB,jmaA,bBkm->ijbkaA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovV += 0.500000000 * np.einsum("ml,lA,ijaB,bBkm->ijbkaA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovV += 0.500000000 * np.einsum("Ba,lB,ijAC,bCkl->ijbkaA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovV += -0.500000000 * np.einsum("BA,lB,ijaC,bCkl->ijbkaA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovV += 1.000000000 * np.einsum("CB,iC,jlaA,bBkl->ijbkaA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooo += 0.250000000 * np.einsum("ai,Aa,jkAB,bBlm->jkbilm",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooo += -0.250000000 * np.einsum("bA,Ai,jkbB,aBlm->jkailm",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovooo += -0.250000000 * np.einsum("BA,Ai,jkBC,aClm->jkailm",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += -0.500000000 * np.einsum("Ai,mA,jkaB,bBlm->jkbila",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += 0.250000000 * np.einsum("am,mA,ijbB,ABkl->ijaklb",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oovoov += -0.500000000 * np.einsum("Am,iA,jmaB,bBkl->ijbkla",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += 0.500000000 * np.einsum("Am,mB,ijaA,bBkl->ijbkla",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += 0.250000000 * np.einsum("ma,Am,ijAB,bBkl->ijbkla",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += -0.500000000 * np.einsum("iA,Am,jmaB,bBkl->ijbkla",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += -0.500000000 * np.einsum("mA,Ai,jkaB,bBlm->jkbila",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovoov += 0.500000000 * np.einsum("mA,Bm,ijaB,bAkl->ijbkla",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oovovv += 0.500000000 * np.einsum("Aa,lA,ijbB,cBkl->ijckab",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += -1.000000000 * np.einsum("il,lB,jmaA,aBkm->ijkA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += -1.000000000 * np.einsum("il,lB,jmAC,BCkm->ijkA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooV += 0.500000000 * np.einsum("ml,lA,ijaB,aBkm->ijkA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += 0.250000000 * np.einsum("ml,lA,ijBC,BCkm->ijkA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooV += -0.500000000 * np.einsum("ml,lB,ijaA,aBkm->ijkA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += -0.500000000 * np.einsum("ml,lB,ijAC,BCkm->ijkA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooV += 1.000000000 * np.einsum("Ba,iB,jlAC,aCkl->ijkA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += 0.500000000 * np.einsum("Ba,lB,ijAC,aCkl->ijkA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += -0.500000000 * np.einsum("BA,lB,ijaC,aCkl->ijkA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += -0.250000000 * np.einsum("BA,lB,ijCD,CDkl->ijkA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooV += 1.000000000 * np.einsum("CB,iC,jlaA,aBkl->ijkA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += 1.000000000 * np.einsum("CB,iC,jlAD,BDkl->ijkA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooV += 0.500000000 * np.einsum("CB,lC,ijaA,aBkl->ijkA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooV += 0.500000000 * np.einsum("CB,lC,ijAD,BDkl->ijkA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += 0.500000000 * np.einsum("Ai,mA,jkaB,aBlm->jkil",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += 0.250000000 * np.einsum("Ai,mA,jkBC,BClm->jkil",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("am,mA,ijaB,ABkl->ijkl",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += 0.500000000 * np.einsum("Am,iA,jmaB,aBkl->ijkl",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += 0.250000000 * np.einsum("Am,iA,jmBC,BCkl->ijkl",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("Am,mB,ijaA,aBkl->ijkl",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("Am,mB,ijAC,BCkl->ijkl",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("ma,Am,ijAB,aBkl->ijkl",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += 0.500000000 * np.einsum("iA,Am,jmaB,aBkl->ijkl",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += 0.250000000 * np.einsum("iA,Am,jmBC,BCkl->ijkl",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += 0.500000000 * np.einsum("mA,Ai,jkaB,aBlm->jkil",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += 0.250000000 * np.einsum("mA,Ai,jkBC,BClm->jkil",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("mA,Bm,ijaB,aAkl->ijkl",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oooo += -0.500000000 * np.einsum("mA,Bm,ijBC,ACkl->ijkl",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooov += -1.000000000 * np.einsum("il,lA,jmaB,ABkm->ijka",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooov += -0.500000000 * np.einsum("ml,lA,ijaB,ABkm->ijka",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooov += -0.500000000 * np.einsum("Aa,lA,ijbB,bBkl->ijka",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooov += -0.250000000 * np.einsum("Aa,lA,ijBC,BCkl->ijka",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooov += 1.000000000 * np.einsum("Ab,iA,jlaB,bBkl->ijka",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooov += 0.500000000 * np.einsum("Ab,lA,ijaB,bBkl->ijka",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ooov += 1.000000000 * np.einsum("BA,iB,jlaC,ACkl->ijka",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ooov += 0.500000000 * np.einsum("BA,lB,ijaC,ACkl->ijka",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ovVVVV += 0.500000000 * np.einsum("kj,jA,ilBC,aDkl->iaDABC",f["oo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVVVV += -0.500000000 * np.einsum("EA,jE,ikBC,aDjk->iaDABC",f["VV"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("Di,kD,jlAB,aCkl->jaCiAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += 0.500000000 * np.einsum("ak,kD,ilAB,CDjl->iaCjAB",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -1.000000000 * np.einsum("bk,kA,ilbB,aCjl->iaCjAB",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("Ak,kD,ilBC,aDjl->iaAjBC",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += 1.000000000 * np.einsum("Dk,kA,ilBD,aCjl->iaCjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("Dk,iD,klAB,aCjl->iaCjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -1.000000000 * np.einsum("Dk,lD,ikAB,aCjl->iaCjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += 1.000000000 * np.einsum("kA,Dk,ilBD,aCjl->iaCjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("iD,Dk,klAB,aCjl->iaCjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("kD,Di,jlAB,aCkl->jaCiAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -0.500000000 * np.einsum("kD,Ak,ilBC,aDjl->iaAjBC",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoVV += -1.000000000 * np.einsum("kD,Dl,ilAB,aCjk->iaCjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVvVV += -1.000000000 * np.einsum("kj,jA,ilaB,bCkl->ibCaAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVvVV += -0.500000000 * np.einsum("Da,jD,ikAB,bCjk->ibCaAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVvVV += 1.000000000 * np.einsum("DA,jD,ikaB,bCjk->ibCaAB",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += -1.000000000 * np.einsum("li,Cl,jmAC,aBkm->jaBikA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += 0.500000000 * np.einsum("ml,Am,ilBC,aCjk->iaAjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += 0.500000000 * np.einsum("aC,Cl,ilbA,bBjk->iaBjkA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += 0.500000000 * np.einsum("aC,Cl,ilAD,BDjk->iaBjkA",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ovVooV += -1.000000000 * np.einsum("bC,Ci,jlbA,aBkl->jaBikA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += -0.500000000 * np.einsum("AC,Cl,ilBD,aDjk->iaAjkB",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVooV += 1.000000000 * np.einsum("DC,Ci,jlAD,aBkl->jaBikA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("Ci,kC,jlaA,bBkl->jbBiaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += 1.000000000 * np.einsum("ak,kC,ilbA,BCjl->iaBjbA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("Ak,kC,ilaB,bCjl->ibAjaB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("Ck,kA,ilaC,bBjl->ibBjaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("Ck,iC,klaA,bBjl->ibBjaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -2.000000000 * np.einsum("Ck,lC,ikaA,bBjl->ibBjaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += 1.000000000 * np.einsum("ka,Ck,ilAC,bBjl->ibBjaA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("kA,Ck,ilaC,bBjl->ibBjaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("iC,Ck,klaA,bBjl->ibBjaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("kC,Ci,jlaA,bBkl->jbBiaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -1.000000000 * np.einsum("kC,Ak,ilaB,bCjl->ibAjaB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovV += -2.000000000 * np.einsum("kC,Cl,ilaA,bBjk->ibBjaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVvvV += -1.000000000 * np.einsum("Ca,jC,ikbA,cBjk->icBabA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoov += -1.000000000 * np.einsum("li,Bl,jmaB,bAkm->jbAika",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoov += 0.500000000 * np.einsum("ml,Am,ilaB,bBjk->ibAjka",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoov += 0.500000000 * np.einsum("aB,Bl,ilbC,ACjk->iaAjkb",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ovVoov += -0.500000000 * np.einsum("AB,Bl,ilaC,bCjk->ibAjka",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVoov += 1.000000000 * np.einsum("CB,Bi,jlaC,bAkl->jbAika",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovVovv += 1.000000000 * np.einsum("ka,Bk,ilbB,cAjl->icAjab",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovvoVV += 0.500000000 * np.einsum("ak,kC,ilAB,bCjl->iabjAB",f["vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovvooV += 0.500000000 * np.einsum("aB,Bl,ilAC,bCjk->iabjkA",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovvovV += 1.000000000 * np.einsum("ak,kB,ilbA,cBjl->iacjbA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# ...
# fs1s2s2ovov += 1.000000000 * np.einsum("iA,Ak,klaB,bBjl->ibja",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovov += 1.000000000 * np.einsum("kA,Ai,jlaB,bBkl->jbia",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovov += 2.000000000 * np.einsum("kA,Bk,ilaB,bAjl->ibja",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovov += 2.000000000 * np.einsum("kA,Al,ilaB,bBjk->ibja",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ovvv += 1.000000000 * np.einsum("Aa,jA,ikbB,cBjk->icab",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += 0.500000000 * np.einsum("ij,jB,klaA,aBkl->iA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += 0.500000000 * np.einsum("ij,jB,klAC,BCkl->iA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oV += 1.000000000 * np.einsum("kj,jA,ilaB,aBkl->iA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += 0.500000000 * np.einsum("kj,jA,ilBC,BCkl->iA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oV += -1.000000000 * np.einsum("kj,jB,ilaA,aBkl->iA",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += -1.000000000 * np.einsum("kj,jB,ilAC,BCkl->iA",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oV += -0.500000000 * np.einsum("Ba,iB,jkAC,aCjk->iA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += 1.000000000 * np.einsum("Ba,jB,ikAC,aCjk->iA",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += -1.000000000 * np.einsum("BA,jB,ikaC,aCjk->iA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += -0.500000000 * np.einsum("BA,jB,ikCD,CDjk->iA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oV += -0.500000000 * np.einsum("CB,iC,jkaA,aBjk->iA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += -0.500000000 * np.einsum("CB,iC,jkAD,BDjk->iA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oV += 1.000000000 * np.einsum("CB,jC,ikaA,aBjk->iA",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oV += 1.000000000 * np.einsum("CB,jC,ikAD,BDjk->iA",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("Ai,kA,jlaB,aBkl->ji",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -0.500000000 * np.einsum("Ai,kA,jlBC,BCkl->ji",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("ak,kA,ilaB,ABjl->ij",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("Ak,iA,klaB,aBjl->ij",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -0.500000000 * np.einsum("Ak,iA,klBC,BCjl->ij",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("Ak,lA,ikaB,aBjl->ij",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("Ak,lA,ikBC,BCjl->ij",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("Ak,kB,ilaA,aBjl->ij",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("Ak,kB,ilAC,BCjl->ij",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("ka,Ak,ilAB,aBjl->ij",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("iA,Ak,klaB,aBjl->ij",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -0.500000000 * np.einsum("iA,Ak,klBC,BCjl->ij",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("kA,Ai,jlaB,aBkl->ji",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -0.500000000 * np.einsum("kA,Ai,jlBC,BCkl->ji",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("kA,Bk,ilaB,aAjl->ij",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("kA,Bk,ilBC,ACjl->ij",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2oo += -2.000000000 * np.einsum("kA,Al,ilaB,aBjk->ij",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2oo += -1.000000000 * np.einsum("kA,Al,ilBC,BCjk->ij",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ov += 0.500000000 * np.einsum("ij,jA,klaB,ABkl->ia",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ov += -1.000000000 * np.einsum("kj,jA,ilaB,ABkl->ia",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ov += -1.000000000 * np.einsum("Aa,jA,ikbB,bBjk->ia",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ov += -0.500000000 * np.einsum("Aa,jA,ikBC,BCjk->ia",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ov += -0.500000000 * np.einsum("Ab,iA,jkaB,bBjk->ia",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ov += 1.000000000 * np.einsum("Ab,jA,ikaB,bBjk->ia",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2ov += -0.500000000 * np.einsum("BA,iB,jkaC,ACjk->ia",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2ov += 1.000000000 * np.einsum("BA,jB,ikaC,ACjk->ia",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVVoVV += -0.500000000 * np.einsum("kj,Ak,jlBC,aDil->aADiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVoVV += -0.250000000 * np.einsum("aE,Ej,jkAB,CDik->aCDiAB",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVVoVV += 0.500000000 * np.einsum("AE,Ej,jkBC,aDik->aADiBC",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVovV += -1.000000000 * np.einsum("kj,Ak,jlaB,bCil->bACiaB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVovV += -0.500000000 * np.einsum("aD,Dj,jkbA,BCik->aBCibA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVVovV += 1.000000000 * np.einsum("AD,Dj,jkaB,bCik->bACiaB",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVooo += 1.000000000 * np.einsum("ml,lC,ACij,aBkm->aABijk",f["oo"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVooo += -0.500000000 * np.einsum("ml,lC,ABim,aCjk->aABijk",f["oo"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVooo += 1.000000000 * np.einsum("Cb,lC,bAij,aBkl->aABijk",f["Vv"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVooo += -1.000000000 * np.einsum("DC,lD,ACij,aBkl->aABijk",f["VV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVooo += 0.500000000 * np.einsum("DC,lD,ABil,aCjk->aABijk",f["VV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += 0.250000000 * np.einsum("ai,iD,jkAB,CDjk->aCAB",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVVV += -0.500000000 * np.einsum("bi,iA,jkbB,aCjk->aCAB",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += -0.250000000 * np.einsum("Ai,iD,jkBC,aDjk->aABC",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += 0.500000000 * np.einsum("Di,iA,jkBD,aCjk->aCAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += -1.000000000 * np.einsum("Di,jD,ikAB,aCjk->aCAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += 0.500000000 * np.einsum("iA,Di,jkBD,aCjk->aCAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += -0.250000000 * np.einsum("iD,Ai,jkBC,aDjk->aABC",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVVV += -1.000000000 * np.einsum("iD,Dj,jkAB,aCik->aCAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += 0.500000000 * np.einsum("ji,Cj,klAC,aBkl->aBiA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += 1.000000000 * np.einsum("kj,Ak,jlBC,aCil->aAiB",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += -1.000000000 * np.einsum("kj,Ck,jlAC,aBil->aBiA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += 1.000000000 * np.einsum("aC,Cj,jkbA,bBik->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += 1.000000000 * np.einsum("aC,Cj,jkAD,BDik->aBiA",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVoV += 0.500000000 * np.einsum("bC,Ci,jkbA,aBjk->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += -1.000000000 * np.einsum("bC,Cj,jkbA,aBik->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += -1.000000000 * np.einsum("AC,Cj,jkBD,aDik->aAiB",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += -0.500000000 * np.einsum("DC,Ci,jkAD,aBjk->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVoV += 1.000000000 * np.einsum("DC,Cj,jkAD,aBik->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += 0.500000000 * np.einsum("ai,iC,jkbA,BCjk->aBbA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVvV += -0.500000000 * np.einsum("Ai,iC,jkaB,bCjk->bAaB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += -0.500000000 * np.einsum("Ci,iA,jkaC,bBjk->bBaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += -2.000000000 * np.einsum("Ci,jC,ikaA,bBjk->bBaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += 0.500000000 * np.einsum("ia,Ci,jkAC,bBjk->bBaA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += -0.500000000 * np.einsum("iA,Ci,jkaC,bBjk->bBaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += -0.500000000 * np.einsum("iC,Ai,jkaB,bCjk->bAaB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvV += -2.000000000 * np.einsum("iC,Cj,jkaA,bBik->bBaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += 0.500000000 * np.einsum("ji,Bj,klaB,bAkl->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += 1.000000000 * np.einsum("kj,Ak,jlaB,bBil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += -1.000000000 * np.einsum("kj,Bk,jlaB,bAil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += 1.000000000 * np.einsum("aB,Bj,jkbC,ACik->aAib",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vVov += -1.000000000 * np.einsum("AB,Bj,jkaC,bCik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += -0.500000000 * np.einsum("CB,Bi,jkaC,bAjk->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVov += 1.000000000 * np.einsum("CB,Bj,jkaC,bAik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vVvv += 0.500000000 * np.einsum("ia,Bi,jkbB,cAjk->cAab",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvVoVV += -0.500000000 * np.einsum("aD,Dj,jkAB,bCik->abCiAB",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvVovV += -1.000000000 * np.einsum("aC,Cj,jkbA,cBik->acBibA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvVooo += -1.000000000 * np.einsum("ml,lB,aBij,bAkm->abAijk",f["oo"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvVooo += 1.000000000 * np.einsum("CB,lC,aBij,bAkl->abAijk",f["VV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvVV += 0.250000000 * np.einsum("ai,iC,jkAB,bCjk->abAB",f["vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvoV += 1.000000000 * np.einsum("aB,Bj,jkAC,bCik->abiA",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvvV += 0.500000000 * np.einsum("ai,iB,jkbA,cBjk->acbA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vvov += 1.000000000 * np.einsum("aA,Aj,jkbB,cBik->acib",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 0.500000000 * np.einsum("ai,iB,jkbA,bBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 0.500000000 * np.einsum("ai,iB,jkAC,BCjk->aA",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vV += 0.500000000 * np.einsum("bi,iA,jkbB,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += -1.000000000 * np.einsum("bi,iB,jkbA,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 0.500000000 * np.einsum("Bi,iA,jkBC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 2.000000000 * np.einsum("Bi,jB,ikAC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 1.000000000 * np.einsum("Bi,iC,jkAB,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 0.500000000 * np.einsum("iA,Bi,jkBC,aCjk->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 1.000000000 * np.einsum("iB,Ci,jkAC,aBjk->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vV += 2.000000000 * np.einsum("iB,Bj,jkAC,aCik->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += 0.500000000 * np.einsum("ji,Aj,klAB,aBkl->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += -1.000000000 * np.einsum("kj,Ak,jlAB,aBil->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += -1.000000000 * np.einsum("aA,Aj,jkbB,bBik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += -0.500000000 * np.einsum("aA,Aj,jkBC,BCik->ai",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vo += -0.500000000 * np.einsum("bA,Ai,jkbB,aBjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += 1.000000000 * np.einsum("bA,Aj,jkbB,aBik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += -0.500000000 * np.einsum("BA,Ai,jkBC,aCjk->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vo += 1.000000000 * np.einsum("BA,Aj,jkBC,aCik->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vv += 0.500000000 * np.einsum("ai,iA,jkbB,ABjk->ab",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2vv += 2.000000000 * np.einsum("Ai,jA,ikaB,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vv += 1.000000000 * np.einsum("Ai,iB,jkaA,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vv += 0.500000000 * np.einsum("ia,Ai,jkAB,bBjk->ba",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vv += 1.000000000 * np.einsum("iA,Bi,jkaB,bAjk->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2vv += 2.000000000 * np.einsum("iA,Aj,jkaB,bBik->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("ai,iA,jkaB,ABjk->",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs1s2s2 += -2.000000000 * np.einsum("Ai,jA,ikaB,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("Ai,jA,ikBC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("Ai,iB,jkaA,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("Ai,iB,jkAC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("ia,Ai,jkAB,aBjk->",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("iA,Bi,jkaB,aAjk->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("iA,Bi,jkBC,ACjk->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs1s2s2 += -2.000000000 * np.einsum("iA,Aj,jkaB,aBik->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs1s2s2 += -1.000000000 * np.einsum("iA,Aj,jkBC,BCik->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")

# %%
# [[[F,s2_ext],s1_ext],s2_ext]
print("[[[F,s2_ext],s1_ext],s2_ext]")
Fs2s1s2 = w.commutator(F,s2_ext,s1_ext,s2_ext)
expr = wt.contract(Fs2s1s2,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2s1s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s2_ext],s1_ext],s2_ext]
# fs2s1s2VVVoVV += 0.250000000 * np.einsum("kj,Ak,jlBC,DEil->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoVV += -0.250000000 * np.einsum("kj,Al,jlBC,DEik->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoVV += -0.500000000 * np.einsum("aA,Bj,jkaC,DEik->BDEiAC",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoVV += 0.500000000 * np.einsum("GA,Bj,jkCG,DEik->BDEiAC",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += 0.500000000 * np.einsum("ai,Ak,klaB,CDjl->ACDijB",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.500000000 * np.einsum("Ei,Ak,klBE,CDjl->ACDijB",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.500000000 * np.einsum("Ak,Ei,klBE,CDjl->ACDijB",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.500000000 * np.einsum("Ak,Bl,klaC,aDij->ABDijC",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.500000000 * np.einsum("Ak,Bl,klCE,DEij->ABDijC",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += 0.500000000 * np.einsum("ka,lA,BCik,aDjl->BCDijA",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.250000000 * np.einsum("ka,lA,BCkl,aDij->BCDijA",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.250000000 * np.einsum("kA,lE,BEij,CDkl->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += -0.500000000 * np.einsum("kA,lE,BCil,DEjk->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += 0.250000000 * np.einsum("kE,lA,BEij,CDkl->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooV += 0.500000000 * np.einsum("kE,lA,BEil,CDjk->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovV += 0.500000000 * np.einsum("kj,Ak,jlaB,CDil->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovV += -0.500000000 * np.einsum("kj,Al,jlaB,CDik->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovV += -0.500000000 * np.einsum("ba,Aj,jkbB,CDik->ACDiaB",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovV += 0.500000000 * np.einsum("Ea,Aj,jkBE,CDik->ACDiaB",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovV += -0.500000000 * np.einsum("EA,Bj,jkaE,CDik->BCDiaA",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += -0.250000000 * np.einsum("li,mD,ADjk,BClm->ABCijk",f["oo"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += -0.500000000 * np.einsum("li,mD,ABjm,CDkl->ABCijk",f["oo"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += -0.250000000 * np.einsum("ml,lD,ADij,BCkm->ABCijk",f["oo"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += -0.500000000 * np.einsum("Aa,lD,BDij,aCkl->ABCijk",f["Vv"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooo += 0.250000000 * np.einsum("Aa,lD,BCil,aDjk->ABCijk",f["Vv"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooo += -0.250000000 * np.einsum("Da,lD,ABil,aCjk->ABCijk",f["Vv"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVooo += 0.500000000 * np.einsum("AD,lE,BEij,CDkl->ABCijk",f["VV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += 0.250000000 * np.einsum("AD,lE,DEij,BCkl->ABCijk",f["VV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVooo += 0.250000000 * np.einsum("ED,lE,ADij,BCkl->ABCijk",f["VV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoov += -0.500000000 * np.einsum("Di,Ak,klaD,BCjl->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoov += -0.500000000 * np.einsum("Ak,Di,klaD,BCjl->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoov += -0.500000000 * np.einsum("Ak,Bl,klaD,CDij->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoov += -0.250000000 * np.einsum("ka,lD,ADij,BCkl->ABCija",f["ov"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVoov += -0.500000000 * np.einsum("ka,lD,ABil,CDjk->ABCija",f["ov"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVovv += 0.500000000 * np.einsum("Da,Aj,jkbD,BCik->ABCiab",f["Vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVV += -0.250000000 * np.einsum("ai,iA,jkaB,CDjk->CDAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVV += 0.250000000 * np.einsum("Ei,iA,jkBE,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVV += -0.250000000 * np.einsum("Ei,jE,ikAB,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVV += -0.250000000 * np.einsum("ia,Ai,jkBC,aDjk->ADBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVVV += 0.250000000 * np.einsum("iE,Ai,jkBC,DEjk->ADBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVVV += -0.250000000 * np.einsum("iE,Ej,jkAB,CDik->CDAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.500000000 * np.einsum("kj,Di,jlAD,BCkl->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -1.000000000 * np.einsum("kj,Ak,jlaB,aCil->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoV += -1.000000000 * np.einsum("kj,Ak,jlBD,CDil->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -0.500000000 * np.einsum("kj,Dk,jlAD,BCil->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("kj,Al,jlaB,aCik->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("kj,Al,jlBD,CDik->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.500000000 * np.einsum("kj,Dl,jlAD,BCik->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("ba,Aj,jkbB,aCik->ACiB",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoV += -1.000000000 * np.einsum("Da,Aj,jkBD,aCik->ACiB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoV += -0.250000000 * np.einsum("aA,Di,jkaD,BCjk->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("aA,Bj,jkaD,CDik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.500000000 * np.einsum("aA,Dj,jkaD,BCik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -0.250000000 * np.einsum("DA,Ei,jkDE,BCjk->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("DA,Bj,jkaD,aCik->BCiA",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("DA,Bj,jkDE,CEik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.500000000 * np.einsum("DA,Ej,jkDE,BCik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.250000000 * np.einsum("aD,Di,jkaA,BCjk->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -1.000000000 * np.einsum("aD,Aj,jkaB,CDik->ACiB",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -0.500000000 * np.einsum("aD,Dj,jkaA,BCik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += -0.250000000 * np.einsum("ED,Di,jkAE,BCjk->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 1.000000000 * np.einsum("ED,Aj,jkBE,CDik->ACiB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoV += 0.500000000 * np.einsum("ED,Dj,jkAE,BCik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVvV += -0.250000000 * np.einsum("Di,iA,jkaD,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVvV += -0.500000000 * np.einsum("Di,jD,ikaA,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVvV += -0.500000000 * np.einsum("ib,Ai,jkaB,bCjk->ACaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVvV += 0.500000000 * np.einsum("iD,Ai,jkaB,CDjk->ACaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVvV += -0.500000000 * np.einsum("iD,Dj,jkaA,BCik->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.250000000 * np.einsum("ai,Cj,klaC,ABkl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -1.000000000 * np.einsum("ai,Ak,klaC,BCjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("ai,Ck,klaC,ABjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.250000000 * np.einsum("Ci,Dj,klCD,ABkl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -1.000000000 * np.einsum("Ci,Ak,klaC,aBjl->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -1.000000000 * np.einsum("Ci,Ak,klCD,BDjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("Ci,Dk,klCD,ABjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("ak,Ci,klaC,ABjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("ak,Al,klaC,BCij->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -1.000000000 * np.einsum("Ak,Ci,klaC,aBjl->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -1.000000000 * np.einsum("Ak,Ci,klCD,BDjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("Ak,Bl,klaC,aCij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.250000000 * np.einsum("Ak,Bl,klCD,CDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("Ak,Cl,klaC,aBij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("Ak,Cl,klCD,BDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("Ck,Di,klCD,ABjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("Ck,Al,klaC,aBij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("Ck,Al,klCD,BDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("ka,lC,ACij,aBkl->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("ka,lC,ABik,aCjl->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += 2.000000000 * np.einsum("ka,lC,ACik,aBjl->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("ka,lC,ABil,aCjk->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("ka,lC,ABkl,aCij->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("ka,lC,ACkl,aBij->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVoo += -0.500000000 * np.einsum("kC,lD,ACij,BDkl->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("kC,lD,ADij,BCkl->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("kC,lD,CDij,ABkl->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("kC,lD,ABil,CDjk->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += -2.000000000 * np.einsum("kC,lD,ACil,BDjk->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVoo += 0.500000000 * np.einsum("kC,lD,CDil,ABjk->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 0.500000000 * np.einsum("kj,Ci,jlaC,ABkl->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += -1.000000000 * np.einsum("kj,Ak,jlaC,BCil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += -0.500000000 * np.einsum("kj,Ck,jlaC,ABil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 1.000000000 * np.einsum("kj,Al,jlaC,BCik->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 0.500000000 * np.einsum("kj,Cl,jlaC,ABik->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += -0.250000000 * np.einsum("ba,Ci,jkbC,ABjk->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 1.000000000 * np.einsum("ba,Aj,jkbC,BCik->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 0.500000000 * np.einsum("ba,Cj,jkbC,ABik->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += -0.250000000 * np.einsum("Ca,Di,jkCD,ABjk->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 1.000000000 * np.einsum("Ca,Aj,jkbC,bBik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVov += 1.000000000 * np.einsum("Ca,Aj,jkCD,BDik->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 0.500000000 * np.einsum("Ca,Dj,jkCD,ABik->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += -1.000000000 * np.einsum("Cb,Aj,jkaC,bBik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VVov += -0.250000000 * np.einsum("DC,Ci,jkaD,ABjk->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 1.000000000 * np.einsum("DC,Aj,jkaD,BCik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VVov += 0.500000000 * np.einsum("DC,Cj,jkaD,ABik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("ai,iA,jkaC,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += -0.500000000 * np.einsum("ai,iC,jkaA,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("Ci,iA,jkaC,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("Ci,iA,jkCD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 1.000000000 * np.einsum("Ci,jC,ikaA,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += 1.000000000 * np.einsum("Ci,jC,ikAD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("Ci,iD,jkAC,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("ia,Ai,jkBC,aCjk->AB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += -0.500000000 * np.einsum("ia,Ci,jkAC,aBjk->BA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("iC,Ai,jkaB,aCjk->AB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("iC,Ai,jkBD,CDjk->AB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 0.500000000 * np.einsum("iC,Di,jkAD,BCjk->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2VV += 1.000000000 * np.einsum("iC,Cj,jkaA,aBik->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2VV += 1.000000000 * np.einsum("iC,Cj,jkAD,BDik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("kj,Bi,jlaB,aAkl->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("kj,Bi,jlBC,ACkl->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("kj,Ak,jlaB,aBil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 0.500000000 * np.einsum("kj,Ak,jlBC,BCil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("kj,Bk,jlaB,aAil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("kj,Bk,jlBC,ACil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("kj,Al,jlaB,aBik->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("kj,Al,jlBC,BCik->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("kj,Bl,jlaB,aAik->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("kj,Bl,jlBC,ACik->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("ba,Bi,jkbB,aAjk->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("ba,Aj,jkbB,aBik->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("ba,Bj,jkbB,aAik->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("Ba,Ci,jkBC,aAjk->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("Ba,Aj,jkBC,aCik->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("Ba,Cj,jkBC,aAik->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("aB,Bi,jkaC,ACjk->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 0.500000000 * np.einsum("aB,Ci,jkaC,ABjk->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("aB,Aj,jkaC,BCik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("aB,Bj,jkaC,ACik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("aB,Cj,jkaC,ABik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("CB,Bi,jkaC,aAjk->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -0.500000000 * np.einsum("CB,Bi,jkCD,ADjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 0.500000000 * np.einsum("CB,Di,jkCD,ABjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("CB,Aj,jkaC,aBik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("CB,Aj,jkCD,BDik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("CB,Bj,jkaC,aAik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vo += 1.000000000 * np.einsum("CB,Bj,jkCD,ADik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vo += -1.000000000 * np.einsum("CB,Dj,jkCD,ABik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vv += 1.000000000 * np.einsum("Bi,jB,ikaC,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vv += 0.500000000 * np.einsum("Bi,iC,jkaB,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vv += 0.500000000 * np.einsum("ib,Ai,jkaB,bBjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vv += -0.500000000 * np.einsum("ib,Bi,jkaB,bAjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2Vv += 0.500000000 * np.einsum("iB,Ai,jkaC,BCjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vv += 0.500000000 * np.einsum("iB,Ci,jkaC,ABjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2Vv += 1.000000000 * np.einsum("iB,Bj,jkaC,ACik->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVVVV += 0.250000000 * np.einsum("kj,jA,ilBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVVVV += -0.250000000 * np.einsum("kj,lA,ijBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVVVV += -0.500000000 * np.einsum("Aa,jB,ikCD,aEjk->iAEBCD",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVVVV += 0.500000000 * np.einsum("AG,jB,ikCD,EGjk->iAEBCD",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.500000000 * np.einsum("ak,kA,ilaB,CDjl->iCDjAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += 0.500000000 * np.einsum("Ek,kA,ilBE,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.250000000 * np.einsum("Ek,iE,klAB,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.250000000 * np.einsum("Ek,lE,ikAB,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.500000000 * np.einsum("ka,Ak,ilBC,aDjl->iADjBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.250000000 * np.einsum("kE,Ei,jlAB,CDkl->jCDiAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += 0.500000000 * np.einsum("kE,Ak,ilBC,DEjl->iADjBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoVV += -0.250000000 * np.einsum("kE,El,ilAB,CDjk->iCDjAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVvVV += -0.500000000 * np.einsum("kj,jA,ilaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVvVV += 0.500000000 * np.einsum("kj,lA,ijaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVvVV += 1.000000000 * np.einsum("Ab,jB,ikaC,bDjk->iADaBC",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVvVV += -1.000000000 * np.einsum("AE,jB,ikaC,DEjk->iADaBC",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("il,Dj,lmAD,BCkm->iBCjkA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("il,Am,lmaB,aCjk->iACjkB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("il,Am,lmBD,CDjk->iACjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("ml,Di,jlAD,BCkm->jBCikA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("ml,Am,ilaB,aCjk->iACjkB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("ml,Am,ilBD,CDjk->iACjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("ba,Al,ilbB,aCjk->iACjkB",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("Da,Al,ilBD,aCjk->iACjkB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("aA,Di,jlaD,BCkl->jBCikA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("aA,Bl,ilaD,CDjk->iBCjkA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("DA,Ei,jlDE,BCkl->jBCikA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("DA,Bl,ilaD,aCjk->iBCjkA",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("DA,Bl,ilDE,CEjk->iBCjkA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("aD,Di,jlaA,BCkl->jBCikA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += -0.500000000 * np.einsum("aD,Al,ilaB,CDjk->iACjkB",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("ED,Di,jlAE,BCkl->jBCikA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooV += 0.500000000 * np.einsum("ED,Al,ilBE,CDjk->iACjkB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += -0.500000000 * np.einsum("Dk,kA,ilaD,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += -0.500000000 * np.einsum("Dk,iD,klaA,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += -0.500000000 * np.einsum("Dk,lD,ikaA,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += -1.000000000 * np.einsum("kb,Ak,ilaB,bCjl->iACjaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVovV += -0.500000000 * np.einsum("kD,Di,jlaA,BCkl->jBCiaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += 1.000000000 * np.einsum("kD,Ak,ilaB,CDjl->iACjaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVovV += -0.500000000 * np.einsum("kD,Dl,ilaA,BCjk->iBCjaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("ai,Cj,kmaC,ABlm->kABijl",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("ai,Am,jmaC,BCkl->jABikl",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("Ci,Dj,kmCD,ABlm->kABijl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("Ci,Am,jmaC,aBkl->jABikl",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("Ci,Am,jmCD,BDkl->jABikl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("Am,Ci,jmaC,aBkl->jABikl",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("Am,Ci,jmCD,BDkl->jABikl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += -0.500000000 * np.einsum("ia,mC,ACjk,aBlm->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.250000000 * np.einsum("ia,mC,ABjm,aCkl->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += -0.250000000 * np.einsum("ma,iC,ABjm,aCkl->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("ma,iC,ACjm,aBkl->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("iC,mD,ADjk,BClm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.250000000 * np.einsum("iC,mD,CDjk,ABlm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += 0.500000000 * np.einsum("mC,iD,ACjk,BDlm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVooo += -0.250000000 * np.einsum("mC,iD,CDjk,ABlm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += -0.500000000 * np.einsum("il,Cj,lmaC,ABkm->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += -0.500000000 * np.einsum("il,Am,lmaC,BCjk->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += -0.500000000 * np.einsum("ml,Ci,jlaC,ABkm->jABika",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += -0.500000000 * np.einsum("ml,Am,ilaC,BCjk->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("ba,Ci,jlbC,ABkl->jABika",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("ba,Al,ilbC,BCjk->iABjka",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("Ca,Di,jlCD,ABkl->jABika",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("Ca,Al,ilbC,bBjk->iABjka",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("Ca,Al,ilCD,BDjk->iABjka",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += -0.500000000 * np.einsum("Cb,Al,ilaC,bBjk->iABjka",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("DC,Ci,jlaD,ABkl->jABika",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVoov += 0.500000000 * np.einsum("DC,Al,ilaD,BCjk->iABjka",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += -1.000000000 * np.einsum("kj,jA,ilaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += -1.000000000 * np.einsum("kj,jA,ilBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("kj,lA,ijaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("kj,lA,ijBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.500000000 * np.einsum("kj,iD,jlAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += -0.500000000 * np.einsum("kj,jD,ilAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.500000000 * np.einsum("kj,lD,ijAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("ba,jA,ikbB,aCjk->iCAB",f["vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("Aa,jB,ikCD,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += -0.250000000 * np.einsum("Aa,iD,jkBC,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.500000000 * np.einsum("Aa,jD,ikBC,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += -1.000000000 * np.einsum("Da,jA,ikBD,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.250000000 * np.einsum("Da,iD,jkAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += -0.500000000 * np.einsum("Da,jD,ikAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += -1.000000000 * np.einsum("aD,jA,ikaB,CDjk->iCAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("AD,jB,ikaC,aDjk->iABC",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("AD,jB,ikCE,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += -0.250000000 * np.einsum("AD,iE,jkBC,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.500000000 * np.einsum("AD,jE,ikBC,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 1.000000000 * np.einsum("ED,jA,ikBE,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += -0.250000000 * np.einsum("ED,iE,jkAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVVV += 0.500000000 * np.einsum("ED,jE,ikAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("ak,kA,ilaC,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += -1.000000000 * np.einsum("ak,kC,ilaA,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,kA,ilaC,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,kA,ilCD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,iC,klaA,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,iC,klAD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,lC,ikaA,aBjl->iBjA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,lC,ikAD,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("Ck,kD,ilAC,BDjl->iBjA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("ka,Ak,ilBC,aCjl->iAjB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += -1.000000000 * np.einsum("ka,Ck,ilAC,aBjl->iBjA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Ci,jlaA,aBkl->jBiA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Ci,jlAD,BDkl->jBiA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Ak,ilaB,aCjl->iAjB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Ak,ilBD,CDjl->iAjB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Dk,ilAD,BCjl->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Cl,ilaA,aBjk->iBjA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoV += 1.000000000 * np.einsum("kC,Cl,ilAD,BDjk->iBjA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("kj,jA,ilaC,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("kj,lA,ijaC,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("kj,iC,jlaA,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("kj,jC,ilaA,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("kj,lC,ijaA,BCkl->iBaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("Ab,jB,ikaC,bCjk->iAaB",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += -0.500000000 * np.einsum("Ab,iC,jkaB,bCjk->iAaB",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("Ab,jC,ikaB,bCjk->iAaB",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("Cb,jA,ikaC,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += 0.500000000 * np.einsum("Cb,iC,jkaA,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("Cb,jC,ikaA,bBjk->iBaA",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("AC,jB,ikaD,CDjk->iAaB",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -0.500000000 * np.einsum("AC,iD,jkaB,CDjk->iAaB",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("AC,jD,ikaB,CDjk->iAaB",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -1.000000000 * np.einsum("DC,jA,ikaD,BCjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += -0.500000000 * np.einsum("DC,iD,jkaA,BCjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVvV += 1.000000000 * np.einsum("DC,jD,ikaA,BCjk->iBaA",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("il,Bj,lmaB,aAkm->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("il,Bj,lmBC,ACkm->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("il,Am,lmaB,aBjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.250000000 * np.einsum("il,Am,lmBC,BCjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("il,Bm,lmaB,aAjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("il,Bm,lmBC,ACjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("ml,Bi,jlaB,aAkm->jAik",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("ml,Bi,jlBC,ACkm->jAik",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("ml,Am,ilaB,aBjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.250000000 * np.einsum("ml,Am,ilBC,BCjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("ml,Bm,ilaB,aAjk->iAjk",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("ml,Bm,ilBC,ACjk->iAjk",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 1.000000000 * np.einsum("ba,Bi,jlbB,aAkl->jAik",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("ba,Al,ilbB,aBjk->iAjk",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("ba,Bl,ilbB,aAjk->iAjk",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 1.000000000 * np.einsum("Ba,Ci,jlBC,aAkl->jAik",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("Ba,Al,ilBC,aCjk->iAjk",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("Ba,Cl,ilBC,aAjk->iAjk",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 1.000000000 * np.einsum("aB,Bi,jlaC,ACkl->jAik",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("aB,Ci,jlaC,ABkl->jAik",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("aB,Al,ilaC,BCjk->iAjk",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("aB,Bl,ilaC,ACjk->iAjk",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("aB,Cl,ilaC,ABjk->iAjk",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 1.000000000 * np.einsum("CB,Bi,jlaC,aAkl->jAik",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 1.000000000 * np.einsum("CB,Bi,jlCD,ADkl->jAik",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -1.000000000 * np.einsum("CB,Di,jlCD,ABkl->jAik",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("CB,Al,ilaC,aBjk->iAjk",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("CB,Al,ilCD,BDjk->iAjk",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("CB,Bl,ilaC,aAjk->iAjk",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVoo += 0.500000000 * np.einsum("CB,Bl,ilCD,ADjk->iAjk",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVoo += -0.500000000 * np.einsum("CB,Dl,ilCD,ABjk->iAjk",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("Bk,iB,klaC,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("Bk,lB,ikaC,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("Bk,kC,ilaB,ACjl->iAja",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("kb,Ak,ilaB,bBjl->iAja",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVov += -1.000000000 * np.einsum("kb,Bk,ilaB,bAjl->iAja",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("kB,Bi,jlaC,ACkl->jAia",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("kB,Ak,ilaC,BCjl->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("kB,Ck,ilaC,ABjl->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2oVov += 1.000000000 * np.einsum("kB,Bl,ilaC,ACjk->iAja",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVVVV += 0.500000000 * np.einsum("ak,Al,ikBC,jlaD->ijABCD",f["vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVVVV += -0.250000000 * np.einsum("ak,Al,klBC,ijaD->ijABCD",f["vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("Ak,El,ilBC,jkDE->ijABCD",f["Vo"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs2s1s2ooVVVV += -0.250000000 * np.einsum("Ak,El,klBC,ijDE->ijABCD",f["Vo"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("Ek,Al,ikBC,jlDE->ijABCD",f["Vo"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs2s1s2ooVVVV += 0.250000000 * np.einsum("Ek,Al,klBC,ijDE->ijABCD",f["Vo"],t1["Vo"],t2["ooVV"],t2["ooVV"],optimize="optimal")
# fs2s1s2ooVVVV += 0.500000000 * np.einsum("ia,kA,jlBC,aDkl->ijDABC",f["ov"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("kA,lB,ijaC,aDkl->ijDABC",f["oV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("kA,lB,ijCE,DEkl->ijDABC",f["oV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("kA,iE,jlBC,DEkl->ijDABC",f["oV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVVVV += -0.500000000 * np.einsum("iE,kA,jlBC,DEkl->ijDABC",f["oV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("li,mA,jkaB,aClm->jkCiAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("li,mA,jkBD,CDlm->jkCiAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("li,jD,kmAB,CDlm->jkCiAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("ml,lA,ijaB,aCkm->ijCkAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("ml,lA,ijBD,CDkm->ijCkAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("ml,iD,jlAB,CDkm->ijCkAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("ba,lA,ijbB,aCkl->ijCkAB",f["vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("Aa,lB,ijCD,aDkl->ijAkBC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("Aa,iD,jlBC,aDkl->ijAkBC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("Da,lA,ijBD,aCkl->ijCkAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("Da,iD,jlAB,aCkl->ijCkAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += -0.500000000 * np.einsum("aD,lA,ijaB,CDkl->ijCkAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("AD,lB,ijaC,aDkl->ijAkBC",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("AD,lB,ijCE,DEkl->ijAkBC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("AD,iE,jlBC,DEkl->ijAkBC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("ED,lA,ijBE,CDkl->ijCkAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVoVV += 0.500000000 * np.einsum("ED,iE,jlAB,CDkl->ijCkAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVvVV += 1.000000000 * np.einsum("bk,Al,ikaB,jlbC->ijAaBC",f["vo"],t1["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("bk,Al,klaB,ijbC->ijAaBC",f["vo"],t1["Vo"],t2["oovV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("Ak,Dl,ilBC,jkaD->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.250000000 * np.einsum("Ak,Dl,klBC,ijaD->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += 0.500000000 * np.einsum("Ak,Dl,ijBD,klaC->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -1.000000000 * np.einsum("Ak,Dl,ikBD,jlaC->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("Dk,Al,ikBC,jlaD->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += 0.250000000 * np.einsum("Dk,Al,klBC,ijaD->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("Dk,Al,ijBD,klaC->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -1.000000000 * np.einsum("Dk,Al,ilBD,jkaC->ijAaBC",f["Vo"],t1["Vo"],t2["ooVV"],t2["oovV"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("ka,lA,ijbB,bCkl->ijCaAB",f["ov"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("ka,lA,ijBD,CDkl->ijCaAB",f["ov"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("ka,iD,jlAB,CDkl->ijCaAB",f["ov"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVvVV += -1.000000000 * np.einsum("ib,kA,jlaB,bCkl->ijCaAB",f["ov"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVvVV += -0.500000000 * np.einsum("kA,lB,ijaD,CDkl->ijCaAB",f["oV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVvVV += 1.000000000 * np.einsum("kA,iD,jlaB,CDkl->ijCaAB",f["oV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVvVV += 1.000000000 * np.einsum("iD,kA,jlaB,CDkl->ijCaAB",f["oV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("am,mA,ijaC,BCkl->ijBklA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.250000000 * np.einsum("am,mC,ijaA,BCkl->ijBklA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("Cm,mA,ijaC,aBkl->ijBklA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("Cm,mA,ijCD,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.500000000 * np.einsum("Cm,iC,jmaA,aBkl->ijBklA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.500000000 * np.einsum("Cm,iC,jmAD,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("Cm,mD,ijAC,BDkl->ijBklA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("ma,Am,ijBC,aCkl->ijAklB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.250000000 * np.einsum("ma,Cm,ijAC,aBkl->ijBklA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.500000000 * np.einsum("mC,Ci,jkaA,aBlm->jkBilA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += -0.500000000 * np.einsum("mC,Ci,jkAD,BDlm->jkBilA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("mC,Am,ijaB,aCkl->ijAklB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("mC,Am,ijBD,CDkl->ijAklB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVooV += 0.250000000 * np.einsum("mC,Dm,ijAD,BCkl->ijBklA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2ooVovV += 0.500000000 * np.einsum("li,mA,jkaC,BClm->jkBiaA",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# ...
# fs2s1s2vVVV += -0.500000000 * np.einsum("bi,iA,jkbB,aCjk->aCAB",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVVV += 0.500000000 * np.einsum("Di,iA,jkBD,aCjk->aCAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVVV += -0.500000000 * np.einsum("Di,jD,ikAB,aCjk->aCAB",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVVV += -0.250000000 * np.einsum("iD,Ai,jkBC,aDjk->aABC",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVVV += -0.500000000 * np.einsum("iD,Dj,jkAB,aCik->aCAB",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("kj,Ci,jlAC,aBkl->aBiA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("kj,Ak,jlBC,aCil->aAiB",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("kj,Ck,jlAC,aBil->aBiA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("kj,Al,jlBC,aCik->aAiB",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("kj,Cl,jlAC,aBik->aBiA",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -0.500000000 * np.einsum("bA,Ci,jkbC,aBjk->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("bA,Bj,jkbC,aCik->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("bA,Cj,jkbC,aBik->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -0.500000000 * np.einsum("CA,Di,jkCD,aBjk->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("CA,Bj,jkCD,aDik->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("CA,Dj,jkCD,aBik->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 0.500000000 * np.einsum("bC,Ci,jkbA,aBjk->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("bC,Aj,jkbB,aCik->aAiB",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("bC,Cj,jkbA,aBik->aBiA",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -0.500000000 * np.einsum("DC,Ci,jkAD,aBjk->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += -1.000000000 * np.einsum("DC,Aj,jkBD,aCik->aAiB",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoV += 1.000000000 * np.einsum("DC,Cj,jkAD,aBik->aBiA",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVvV += -0.500000000 * np.einsum("Ci,iA,jkaC,bBjk->bBaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVvV += -1.000000000 * np.einsum("Ci,jC,ikaA,bBjk->bBaA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVvV += -0.500000000 * np.einsum("iC,Ai,jkaB,bCjk->bAaB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVvV += -1.000000000 * np.einsum("iC,Cj,jkaA,bBik->bBaA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("bi,Bj,klbB,aAkl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("bi,Ak,klbB,aBjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -1.000000000 * np.einsum("bi,Bk,klbB,aAjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("Bi,Cj,klBC,aAkl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("Bi,Ak,klBC,aCjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -1.000000000 * np.einsum("Bi,Ck,klBC,aAjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -1.000000000 * np.einsum("ak,Bi,klbB,bAjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -1.000000000 * np.einsum("ak,Bi,klBC,ACjl->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("ak,Al,klbB,bBij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.250000000 * np.einsum("ak,Al,klBC,BCij->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("ak,Bl,klbB,bAij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("ak,Bl,klBC,ACij->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("bk,Bi,klbB,aAjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("bk,Al,klbB,aBij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("Ak,Bi,klBC,aCjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("Ak,Bl,klBC,aCij->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("Bk,Ci,klBC,aAjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("Bk,Al,klBC,aCij->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("kb,lB,aBij,bAkl->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("kb,lB,bAij,aBkl->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("kb,lB,bBij,aAkl->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("kb,lB,aAil,bBjk->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -2.000000000 * np.einsum("kb,lB,bAil,aBjk->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("kb,lB,bBil,aAjk->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("kB,lC,ABij,aCkl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("kB,lC,ACij,aBkl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("kB,lC,BCij,aAkl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 2.000000000 * np.einsum("kB,lC,ACik,aBjl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -1.000000000 * np.einsum("kB,lC,BCik,aAjl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 2.000000000 * np.einsum("kB,lC,ABil,aCjk->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 1.000000000 * np.einsum("kB,lC,BCil,aAjk->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += 0.500000000 * np.einsum("kB,lC,ABkl,aCij->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVoo += -0.500000000 * np.einsum("kB,lC,ACkl,aBij->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("kj,Bi,jlaB,bAkl->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("kj,Ak,jlaB,bBil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -1.000000000 * np.einsum("kj,Bk,jlaB,bAil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -1.000000000 * np.einsum("kj,Al,jlaB,bBik->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("kj,Bl,jlaB,bAik->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -0.500000000 * np.einsum("ca,Bi,jkcB,bAjk->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -1.000000000 * np.einsum("ca,Aj,jkcB,bBik->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("ca,Bj,jkcB,bAik->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -0.500000000 * np.einsum("Ba,Ci,jkBC,bAjk->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -1.000000000 * np.einsum("Ba,Aj,jkBC,bCik->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("Ba,Cj,jkBC,bAik->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -0.500000000 * np.einsum("CB,Bi,jkaC,bAjk->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += -1.000000000 * np.einsum("CB,Aj,jkaC,bBik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vVov += 1.000000000 * np.einsum("CB,Bj,jkaC,bAik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += -1.000000000 * np.einsum("ak,Ci,klAC,bBjl->abBijA",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += 0.500000000 * np.einsum("ak,Al,klBC,bCij->abAijB",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += -0.500000000 * np.einsum("kA,lC,aCij,bBkl->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += 1.000000000 * np.einsum("kA,lC,aBil,bCjk->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += 0.500000000 * np.einsum("kC,lA,aCij,bBkl->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooV += 1.000000000 * np.einsum("kC,lA,aCil,bBjk->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += -0.500000000 * np.einsum("li,mB,aBjk,bAlm->abAijk",f["oo"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 1.000000000 * np.einsum("li,mB,aAjm,bBkl->abAijk",f["oo"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += -0.500000000 * np.einsum("ml,lB,aBij,bAkm->abAijk",f["oo"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += -0.500000000 * np.einsum("ac,lB,bBij,cAkl->abAijk",f["vv"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 0.500000000 * np.einsum("ac,lB,cBij,bAkl->abAijk",f["vv"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += -0.500000000 * np.einsum("aB,lC,ACij,bBkl->abAijk",f["vV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 0.500000000 * np.einsum("aB,lC,BCij,bAkl->abAijk",f["vV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 0.500000000 * np.einsum("aB,lC,ABil,bCjk->abAijk",f["vV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 0.500000000 * np.einsum("AB,lC,aCij,bBkl->abAijk",f["VV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVooo += 0.500000000 * np.einsum("CB,lC,aBij,bAkl->abAijk",f["VV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVoov += -1.000000000 * np.einsum("ak,Bi,klbB,cAjl->acAijb",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVoov += 0.500000000 * np.einsum("ak,Al,klbB,cBij->acAijb",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVoov += -0.500000000 * np.einsum("ka,lB,bBij,cAkl->bcAija",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvVoov += 1.000000000 * np.einsum("ka,lB,bAil,cBjk->bcAija",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvvooo += 0.500000000 * np.einsum("aA,lB,bBij,cAkl->abcijk",f["vV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvoo += -1.000000000 * np.einsum("ak,Ai,klAB,bBjl->abij",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvoo += -0.500000000 * np.einsum("ak,Al,klAB,bBij->abij",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvoo += -0.500000000 * np.einsum("kA,lB,aAij,bBkl->abij",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvoo += 0.500000000 * np.einsum("kA,lB,aBij,bAkl->abij",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vvoo += -2.000000000 * np.einsum("kA,lB,aAil,bBjk->abij",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 0.500000000 * np.einsum("bi,iA,jkbB,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += -0.500000000 * np.einsum("bi,iB,jkbA,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 0.500000000 * np.einsum("Bi,iA,jkBC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 1.000000000 * np.einsum("Bi,jB,ikAC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 0.500000000 * np.einsum("Bi,iC,jkAB,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 0.500000000 * np.einsum("iB,Ci,jkAC,aBjk->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vV += 1.000000000 * np.einsum("iB,Bj,jkAC,aCik->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 1.000000000 * np.einsum("kj,Ai,jlAB,aBkl->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += -1.000000000 * np.einsum("kj,Ak,jlAB,aBil->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 1.000000000 * np.einsum("kj,Al,jlAB,aBik->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += -0.500000000 * np.einsum("bA,Ai,jkbB,aBjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 0.500000000 * np.einsum("bA,Bi,jkbB,aAjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 1.000000000 * np.einsum("bA,Aj,jkbB,aBik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += -1.000000000 * np.einsum("bA,Bj,jkbB,aAik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += -0.500000000 * np.einsum("BA,Ai,jkBC,aCjk->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 0.500000000 * np.einsum("BA,Ci,jkBC,aAjk->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += 1.000000000 * np.einsum("BA,Aj,jkBC,aCik->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vo += -1.000000000 * np.einsum("BA,Cj,jkBC,aAik->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vv += 1.000000000 * np.einsum("Ai,jA,ikaB,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vv += 0.500000000 * np.einsum("Ai,iB,jkaA,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vv += 0.500000000 * np.einsum("iA,Bi,jkaB,bAjk->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2vv += 1.000000000 * np.einsum("iA,Aj,jkaB,bBik->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("ai,iA,jkaB,ABjk->",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s1s2 += -1.000000000 * np.einsum("Ai,jA,ikaB,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("Ai,jA,ikBC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("Ai,iB,jkaA,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("Ai,iB,jkAC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("ia,Ai,jkAB,aBjk->",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("iA,Bi,jkaB,aAjk->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("iA,Bi,jkBC,ACjk->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s1s2 += -1.000000000 * np.einsum("iA,Aj,jkaB,aBik->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s1s2 += -0.500000000 * np.einsum("iA,Aj,jkBC,BCik->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")

# %%
# [[[F,s2_ext],s2_ext],s1_ext]
print("[[[F,s2_ext],s2_ext],s1_ext]")
Fs2s2s1 = w.commutator(F,s2_ext,s2_ext,s1_ext)
expr = wt.contract(Fs2s2s1,minrank=0,maxrank=6)
mbeq = expr.to_manybody_equations('fs2s2s1')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s2_ext],s2_ext],s1_ext]
# fs2s2s1VVVVVV += 0.250000000 * np.einsum("Ai,jB,ikCD,EGjk->AEGBCD",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVVVV += 0.250000000 * np.einsum("iA,Bj,jkCD,EGik->BEGACD",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += 0.250000000 * np.einsum("ji,Ak,klBC,DEjl->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += 0.250000000 * np.einsum("kj,Ak,jlBC,DEil->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += -0.500000000 * np.einsum("kj,Al,jlBC,DEik->ADEiBC",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += 0.500000000 * np.einsum("Aa,Bj,jkCD,aEik->ABEiCD",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVoVV += -0.500000000 * np.einsum("aA,Bj,jkaC,DEik->BDEiAC",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += 0.500000000 * np.einsum("GA,Bj,jkCG,DEik->BDEiAC",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoVV += -0.500000000 * np.einsum("AG,Bj,jkCD,EGik->ABEiCD",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVvVV += -0.500000000 * np.einsum("Ai,jB,ikaC,DEjk->ADEaBC",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVvVV += 0.250000000 * np.einsum("ia,Aj,jkBC,DEik->ADEaBC",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVvVV += -0.500000000 * np.einsum("iA,Bj,jkaC,DEik->BDEaAC",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += 0.500000000 * np.einsum("ai,Ak,klaB,CDjl->ACDijB",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += -0.500000000 * np.einsum("Ei,Ak,klBE,CDjl->ACDijB",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += -0.500000000 * np.einsum("Ak,Ei,klBE,CDjl->ACDijB",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += -0.500000000 * np.einsum("Ak,Bl,klaC,aDij->ABDijC",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVooV += -0.500000000 * np.einsum("Ak,Bl,klCE,DEij->ABDijC",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += 1.000000000 * np.einsum("ka,lA,BCik,aDjl->BCDijA",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVooV += -0.500000000 * np.einsum("ka,lA,BCkl,aDij->BCDijA",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVooV += 0.500000000 * np.einsum("kE,lA,BEij,CDkl->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVooV += 1.000000000 * np.einsum("kE,lA,BEil,CDjk->BCDijA",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += 0.500000000 * np.einsum("ji,Ak,klaB,CDjl->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += 0.500000000 * np.einsum("kj,Ak,jlaB,CDil->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += -1.000000000 * np.einsum("kj,Al,jlaB,CDik->ACDiaB",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += -0.500000000 * np.einsum("ba,Aj,jkbB,CDik->ACDiaB",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += 0.500000000 * np.einsum("Ea,Aj,jkBE,CDik->ACDiaB",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += 1.000000000 * np.einsum("Ab,Bj,jkaC,bDik->ABDiaC",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVovV += -0.500000000 * np.einsum("EA,Bj,jkaE,CDik->BCDiaA",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovV += -1.000000000 * np.einsum("AE,Bj,jkaC,DEik->ABDiaC",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVvvV += 0.500000000 * np.einsum("ia,Aj,jkbB,CDik->ACDabB",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoov += -0.500000000 * np.einsum("Di,Ak,klaD,BCjl->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoov += -0.500000000 * np.einsum("Ak,Di,klaD,BCjl->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVoov += -0.500000000 * np.einsum("Ak,Bl,klaD,CDij->ABCija",f["Vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVovv += 0.500000000 * np.einsum("Da,Aj,jkbD,BCik->ABCiab",f["Vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.250000000 * np.einsum("ai,iA,jkaB,CDjk->CDAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += 0.500000000 * np.einsum("ai,jA,ikaB,CDjk->CDAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -1.000000000 * np.einsum("Ai,jB,ikaC,aDjk->ADBC",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVV += -1.000000000 * np.einsum("Ai,jB,ikCE,DEjk->ADBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.500000000 * np.einsum("Ai,jE,ikBC,DEjk->ADBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += 0.250000000 * np.einsum("Ei,iA,jkBE,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.500000000 * np.einsum("Ei,jA,ikBE,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.250000000 * np.einsum("Ei,jE,ikAB,CDjk->CDAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.250000000 * np.einsum("ia,Ai,jkBC,aDjk->ADBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVV += 0.500000000 * np.einsum("ia,Aj,jkBC,aDik->ADBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVV += -1.000000000 * np.einsum("iA,Bj,jkaC,aDik->BDAC",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVVV += -1.000000000 * np.einsum("iA,Bj,jkCE,DEik->BDAC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.500000000 * np.einsum("iA,Ej,jkBE,CDik->CDAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += 0.250000000 * np.einsum("iE,Ai,jkBC,DEjk->ADBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.500000000 * np.einsum("iE,Aj,jkBC,DEik->ADBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVVV += -0.250000000 * np.einsum("iE,Ej,jkAB,CDik->CDAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("ji,Ak,klaB,aCjl->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("ji,Ak,klBD,CDjl->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.500000000 * np.einsum("ji,Dk,klAD,BCjl->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("kj,Di,jlAD,BCkl->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("kj,Ak,jlaB,aCil->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("kj,Ak,jlBD,CDil->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.500000000 * np.einsum("kj,Dk,jlAD,BCil->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 2.000000000 * np.einsum("kj,Al,jlaB,aCik->ACiB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += 2.000000000 * np.einsum("kj,Al,jlBD,CDik->ACiB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("kj,Dl,jlAD,BCik->BCiA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 2.000000000 * np.einsum("ba,Aj,jkbB,aCik->ACiB",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.500000000 * np.einsum("Aa,Di,jkBD,aCjk->ACiB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("Aa,Bj,jkCD,aDik->ABiC",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("Aa,Dj,jkBD,aCik->ACiB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -2.000000000 * np.einsum("Da,Aj,jkBD,aCik->ACiB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.250000000 * np.einsum("aA,Di,jkaD,BCjk->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("aA,Bj,jkaD,CDik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 0.500000000 * np.einsum("aA,Dj,jkaD,BCik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.250000000 * np.einsum("DA,Ei,jkDE,BCjk->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("DA,Bj,jkaD,aCik->BCiA",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += 1.000000000 * np.einsum("DA,Bj,jkDE,CEik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 0.500000000 * np.einsum("DA,Ej,jkDE,BCik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 0.250000000 * np.einsum("aD,Di,jkaA,BCjk->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -2.000000000 * np.einsum("aD,Aj,jkaB,CDik->ACiB",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.500000000 * np.einsum("aD,Dj,jkaA,BCik->BCiA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 0.500000000 * np.einsum("AD,Ei,jkBE,CDjk->ACiB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("AD,Bj,jkaC,aDik->ABiC",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("AD,Bj,jkCE,DEik->ABiC",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -1.000000000 * np.einsum("AD,Ej,jkBE,CDik->ACiB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += -0.250000000 * np.einsum("ED,Di,jkAE,BCjk->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 2.000000000 * np.einsum("ED,Aj,jkBE,CDik->ACiB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoV += 0.500000000 * np.einsum("ED,Dj,jkAE,BCik->BCiA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += 1.000000000 * np.einsum("Ai,jB,ikaD,CDjk->ACaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -1.000000000 * np.einsum("Ai,jD,ikaB,CDjk->ACaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -0.250000000 * np.einsum("Di,iA,jkaD,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += 0.500000000 * np.einsum("Di,jA,ikaD,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -0.500000000 * np.einsum("Di,jD,ikaA,BCjk->BCaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -1.000000000 * np.einsum("ia,Aj,jkbB,bCik->ACaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVvV += -1.000000000 * np.einsum("ia,Aj,jkBD,CDik->ACaB",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -0.500000000 * np.einsum("ia,Dj,jkAD,BCik->BCaA",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -0.500000000 * np.einsum("ib,Ai,jkaB,bCjk->ACaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVvV += 1.000000000 * np.einsum("ib,Aj,jkaB,bCik->ACaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVvV += 1.000000000 * np.einsum("iA,Bj,jkaD,CDik->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += 0.500000000 * np.einsum("iA,Dj,jkaD,BCik->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += 0.500000000 * np.einsum("iD,Ai,jkaB,CDjk->ACaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -1.000000000 * np.einsum("iD,Aj,jkaB,CDik->ACaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvV += -0.500000000 * np.einsum("iD,Dj,jkaA,BCik->BCaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.250000000 * np.einsum("ai,Cj,klaC,ABkl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("ai,Ak,klaC,BCjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -0.500000000 * np.einsum("ai,Ck,klaC,ABjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.250000000 * np.einsum("Ci,Dj,klCD,ABkl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("Ci,Ak,klaC,aBjl->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("Ci,Ak,klCD,BDjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -0.500000000 * np.einsum("Ci,Dk,klCD,ABjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("ak,Ci,klaC,ABjl->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("ak,Al,klaC,BCij->ABij",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("Ak,Ci,klaC,aBjl->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("Ak,Ci,klCD,BDjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("Ak,Bl,klaC,aCij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.250000000 * np.einsum("Ak,Bl,klCD,CDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -0.500000000 * np.einsum("Ak,Cl,klaC,aBij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += -0.500000000 * np.einsum("Ak,Cl,klCD,BDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("Ck,Di,klCD,ABjl->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("Ck,Al,klaC,aBij->ABij",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("Ck,Al,klCD,BDij->ABij",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("ka,lC,ABik,aCjl->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += 2.000000000 * np.einsum("ka,lC,ACik,aBjl->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("ka,lC,ABkl,aCij->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("ka,lC,ACkl,aBij->ABij",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVoo += -1.000000000 * np.einsum("kC,lD,ACij,BDkl->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 0.500000000 * np.einsum("kC,lD,CDij,ABkl->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += -2.000000000 * np.einsum("kC,lD,ACil,BDjk->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVoo += 1.000000000 * np.einsum("kC,lD,CDil,ABjk->ABij",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -1.000000000 * np.einsum("ji,Ak,klaC,BCjl->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.500000000 * np.einsum("ji,Ck,klaC,ABjl->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("kj,Ci,jlaC,ABkl->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -1.000000000 * np.einsum("kj,Ak,jlaC,BCil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.500000000 * np.einsum("kj,Ck,jlaC,ABil->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 2.000000000 * np.einsum("kj,Al,jlaC,BCik->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("kj,Cl,jlaC,ABik->ABia",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.250000000 * np.einsum("ba,Ci,jkbC,ABjk->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("ba,Aj,jkbC,BCik->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 0.500000000 * np.einsum("ba,Cj,jkbC,ABik->ABia",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.250000000 * np.einsum("Ca,Di,jkCD,ABjk->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("Ca,Aj,jkbC,bBik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("Ca,Aj,jkCD,BDik->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 0.500000000 * np.einsum("Ca,Dj,jkCD,ABik->ABia",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.500000000 * np.einsum("Ab,Ci,jkaC,bBjk->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVov += -1.000000000 * np.einsum("Ab,Bj,jkaC,bCik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVov += 1.000000000 * np.einsum("Ab,Cj,jkaC,bBik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVov += -2.000000000 * np.einsum("Cb,Aj,jkaC,bBik->ABia",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VVov += 0.500000000 * np.einsum("AC,Di,jkaD,BCjk->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -1.000000000 * np.einsum("AC,Bj,jkaD,CDik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -1.000000000 * np.einsum("AC,Dj,jkaD,BCik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += -0.250000000 * np.einsum("DC,Ci,jkaD,ABjk->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 2.000000000 * np.einsum("DC,Aj,jkaD,BCik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVov += 0.500000000 * np.einsum("DC,Cj,jkaD,ABik->ABia",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvv += -1.000000000 * np.einsum("ia,Aj,jkbC,BCik->ABab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VVvv += -0.500000000 * np.einsum("ia,Cj,jkbC,ABik->ABab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("ai,iA,jkaC,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("ai,jA,ikaC,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -0.500000000 * np.einsum("ai,iC,jkaA,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("ai,jC,ikaA,BCjk->BA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("Ai,jB,ikaC,aCjk->AB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("Ai,jB,ikCD,CDjk->AB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("Ai,jC,ikaB,aCjk->AB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("Ai,jC,ikBD,CDjk->AB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("Ci,iA,jkaC,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("Ci,iA,jkCD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("Ci,jA,ikaC,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("Ci,jA,ikCD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("Ci,jC,ikaA,aBjk->BA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("Ci,jC,ikAD,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("Ci,iD,jkAC,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("Ci,jD,ikAC,BDjk->BA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("ia,Ai,jkBC,aCjk->AB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -0.500000000 * np.einsum("ia,Ci,jkAC,aBjk->BA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("ia,Aj,jkBC,aCik->AB",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("ia,Cj,jkAC,aBik->BA",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("iA,Bj,jkaC,aCik->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("iA,Bj,jkCD,CDik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("iA,Cj,jkaC,aBik->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("iA,Cj,jkCD,BDik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("iC,Ai,jkaB,aCjk->AB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("iC,Ai,jkBD,CDjk->AB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 0.500000000 * np.einsum("iC,Di,jkAD,BCjk->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("iC,Aj,jkaB,aCik->AB",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("iC,Aj,jkBD,CDik->AB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("iC,Cj,jkaA,aBik->BA",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1VV += 1.000000000 * np.einsum("iC,Cj,jkAD,BDik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1VV += -1.000000000 * np.einsum("iC,Dj,jkAD,BCik->BA",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("ji,Ak,klaB,aBjl->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 0.500000000 * np.einsum("ji,Ak,klBC,BCjl->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("ji,Bk,klaB,aAjl->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("ji,Bk,klBC,ACjl->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("kj,Bi,jlaB,aAkl->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("kj,Bi,jlBC,ACkl->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("kj,Ak,jlaB,aBil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 0.500000000 * np.einsum("kj,Ak,jlBC,BCil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("kj,Bk,jlaB,aAil->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("kj,Bk,jlBC,ACil->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("kj,Al,jlaB,aBik->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("kj,Al,jlBC,BCik->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("kj,Bl,jlaB,aAik->Ai",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("kj,Bl,jlBC,ACik->Ai",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("ba,Bi,jkbB,aAjk->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("ba,Aj,jkbB,aBik->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("ba,Bj,jkbB,aAik->Ai",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("Aa,Bi,jkBC,aCjk->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("Aa,Bj,jkBC,aCik->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -1.000000000 * np.einsum("Ba,Ci,jkBC,aAjk->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("Ba,Aj,jkBC,aCik->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 2.000000000 * np.einsum("Ba,Cj,jkBC,aAik->Ai",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("aB,Bi,jkaC,ACjk->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("aB,Ci,jkaC,ABjk->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("aB,Aj,jkaC,BCik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("aB,Bj,jkaC,ACik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("aB,Cj,jkaC,ABik->Ai",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("AB,Ci,jkaC,aBjk->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("AB,Ci,jkCD,BDjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("AB,Cj,jkaC,aBik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("AB,Cj,jkCD,BDik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("CB,Bi,jkaC,aAjk->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -0.500000000 * np.einsum("CB,Bi,jkCD,ADjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("CB,Di,jkCD,ABjk->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("CB,Aj,jkaC,aBik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("CB,Aj,jkCD,BDik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("CB,Bj,jkaC,aAik->Ai",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vo += 1.000000000 * np.einsum("CB,Bj,jkCD,ADik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vo += -2.000000000 * np.einsum("CB,Dj,jkCD,ABik->Ai",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("Ai,jB,ikaC,BCjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 1.000000000 * np.einsum("Bi,jB,ikaC,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 0.500000000 * np.einsum("Bi,iC,jkaB,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("Bi,jC,ikaB,ACjk->Aa",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 1.000000000 * np.einsum("ia,Aj,jkbB,bBik->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += 0.500000000 * np.einsum("ia,Aj,jkBC,BCik->Aa",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("ia,Bj,jkbB,bAik->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("ia,Bj,jkBC,ACik->Aa",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 0.500000000 * np.einsum("ib,Ai,jkaB,bBjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += -0.500000000 * np.einsum("ib,Bi,jkaB,bAjk->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("ib,Aj,jkaB,bBik->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += 1.000000000 * np.einsum("ib,Bj,jkaB,bAik->Aa",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1Vv += 0.500000000 * np.einsum("iB,Ai,jkaC,BCjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 0.500000000 * np.einsum("iB,Ci,jkaC,ABjk->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("iB,Aj,jkaC,BCik->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += 1.000000000 * np.einsum("iB,Bj,jkaC,ACik->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1Vv += -1.000000000 * np.einsum("iB,Cj,jkaC,ABik->Aa",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += 0.250000000 * np.einsum("ij,kA,jlBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += 0.250000000 * np.einsum("kj,jA,ilBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += -0.500000000 * np.einsum("kj,lA,ijBC,DEkl->iDEABC",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += -0.500000000 * np.einsum("Aa,jB,ikCD,aEjk->iAEBCD",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVVVV += 0.500000000 * np.einsum("aA,jB,ikaC,DEjk->iDEABC",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += -0.500000000 * np.einsum("GA,jB,ikCG,DEjk->iDEABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVVVV += 0.500000000 * np.einsum("AG,jB,ikCD,EGjk->iAEBCD",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += 0.500000000 * np.einsum("ai,kA,jlaB,CDkl->jCDiAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("Ei,kA,jlBE,CDkl->jCDiAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("ak,kA,ilaB,CDjl->iCDjAB",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -1.000000000 * np.einsum("Ak,lB,ikaC,aDjl->iADjBC",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -1.000000000 * np.einsum("Ak,lB,ikCE,DEjl->iADjBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("Ak,iE,klBC,DEjl->iADjBC",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += 0.500000000 * np.einsum("Ek,kA,ilBE,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.250000000 * np.einsum("Ek,iE,klAB,CDjl->iCDjAB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += 0.500000000 * np.einsum("ia,Ak,klBC,aDjl->iADjBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("ka,Ak,ilBC,aDjl->iADjBC",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("kA,Ei,jlBE,CDkl->jCDiAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -1.000000000 * np.einsum("kA,Bl,ilaC,aDjk->iBDjAC",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -1.000000000 * np.einsum("kA,Bl,ilCE,DEjk->iBDjAC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.500000000 * np.einsum("iE,Ak,klBC,DEjl->iADjBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += -0.250000000 * np.einsum("kE,Ei,jlAB,CDkl->jCDiAB",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoVV += 0.500000000 * np.einsum("kE,Ak,ilBC,DEjl->iADjBC",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += -0.500000000 * np.einsum("ij,kA,jlaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += -0.500000000 * np.einsum("kj,jA,ilaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += 1.000000000 * np.einsum("kj,lA,ijaB,CDkl->iCDaAB",f["oo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += 0.500000000 * np.einsum("ba,jA,ikbB,CDjk->iCDaAB",f["vv"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += -0.500000000 * np.einsum("Ea,jA,ikBE,CDjk->iCDaAB",f["Vv"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += 1.000000000 * np.einsum("Ab,jB,ikaC,bDjk->iADaBC",f["Vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVvVV += -0.500000000 * np.einsum("EA,jB,ikaE,CDjk->iCDaAB",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvVV += -1.000000000 * np.einsum("AE,jB,ikaC,DEjk->iADaBC",f["VV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("li,Dj,kmAD,BClm->kBCijA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 1.000000000 * np.einsum("li,Am,jmaB,aCkl->jACikB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += 1.000000000 * np.einsum("li,Am,jmBD,CDkl->jACikB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("il,Dj,lmAD,BCkm->iBCjkA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("il,Am,lmaB,aCjk->iACjkB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("il,Am,lmBD,CDjk->iACjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -1.000000000 * np.einsum("ml,Di,jlAD,BCkm->jBCikA",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("ml,Am,ilaB,aCjk->iACjkB",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("ml,Am,ilBD,CDjk->iACjkB",f["oo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 1.000000000 * np.einsum("ba,Al,ilbB,aCjk->iACjkB",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += 1.000000000 * np.einsum("Aa,Di,jlBD,aCkl->jACikB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("Aa,Bl,ilCD,aDjk->iABjkC",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += -1.000000000 * np.einsum("Da,Al,ilBD,aCjk->iACjkB",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("aA,Di,jlaD,BCkl->jBCikA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("aA,Bl,ilaD,CDjk->iBCjkA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("DA,Ei,jlDE,BCkl->jBCikA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("DA,Bl,ilaD,aCjk->iBCjkA",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("DA,Bl,ilDE,CEjk->iBCjkA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("aD,Di,jlaA,BCkl->jBCikA",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -1.000000000 * np.einsum("aD,Al,ilaB,CDjk->iACjkB",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -1.000000000 * np.einsum("AD,Ei,jlBE,CDkl->jACikB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("AD,Bl,ilaC,aDjk->iABjkC",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooV += -0.500000000 * np.einsum("AD,Bl,ilCE,DEjk->iABjkC",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 0.500000000 * np.einsum("ED,Di,jlAE,BCkl->jBCikA",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooV += 1.000000000 * np.einsum("ED,Al,ilBE,CDjk->iACjkB",f["VV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += 0.500000000 * np.einsum("Di,kA,jlaD,BCkl->jBCiaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += 1.000000000 * np.einsum("Ak,lB,ikaD,CDjl->iACjaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -1.000000000 * np.einsum("Ak,iD,klaB,CDjl->iACjaB",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -0.500000000 * np.einsum("Dk,kA,ilaD,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -0.500000000 * np.einsum("Dk,iD,klaA,BCjl->iBCjaA",f["Vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -0.500000000 * np.einsum("ka,Di,jlAD,BCkl->jBCiaA",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -1.000000000 * np.einsum("ka,Al,ilbB,bCjk->iACjaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVovV += -1.000000000 * np.einsum("ka,Al,ilBD,CDjk->iACjaB",f["ov"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += 1.000000000 * np.einsum("ib,Ak,klaB,bCjl->iACjaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVovV += -1.000000000 * np.einsum("kb,Ak,ilaB,bCjl->iACjaB",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVovV += 0.500000000 * np.einsum("kA,Di,jlaD,BCkl->jBCiaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += 1.000000000 * np.einsum("kA,Bl,ilaD,CDjk->iBCjaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -1.000000000 * np.einsum("iD,Ak,klaB,CDjl->iACjaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += -0.500000000 * np.einsum("kD,Di,jlaA,BCkl->jBCiaA",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovV += 1.000000000 * np.einsum("kD,Ak,ilaB,CDjl->iACjaB",f["oV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVvvV += 0.500000000 * np.einsum("Da,jA,ikbD,BCjk->iBCabA",f["Vv"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("ai,Cj,kmaC,ABlm->kABijl",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("ai,Am,jmaC,BCkl->jABikl",f["vo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("Ci,Dj,kmCD,ABlm->kABijl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("Ci,Am,jmaC,aBkl->jABikl",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("Ci,Am,jmCD,BDkl->jABikl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("Am,Ci,jmaC,aBkl->jABikl",f["Vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooo += 0.500000000 * np.einsum("Am,Ci,jmCD,BDkl->jABikl",f["Vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += -0.500000000 * np.einsum("ma,iC,ABjm,aCkl->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooo += 1.000000000 * np.einsum("ma,iC,ACjm,aBkl->iABjkl",f["ov"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVooo += 1.000000000 * np.einsum("mC,iD,ACjk,BDlm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVooo += -0.500000000 * np.einsum("mC,iD,CDjk,ABlm->iABjkl",f["oV"],t1["oV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("li,Cj,kmaC,ABlm->kABija",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 1.000000000 * np.einsum("li,Am,jmaC,BCkl->jABika",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += -0.500000000 * np.einsum("il,Cj,lmaC,ABkm->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += -0.500000000 * np.einsum("il,Am,lmaC,BCjk->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += -1.000000000 * np.einsum("ml,Ci,jlaC,ABkm->jABika",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += -0.500000000 * np.einsum("ml,Am,ilaC,BCjk->iABjka",f["oo"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("ba,Ci,jlbC,ABkl->jABika",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("ba,Al,ilbC,BCjk->iABjka",f["vv"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("Ca,Di,jlCD,ABkl->jABika",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("Ca,Al,ilbC,bBjk->iABjka",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("Ca,Al,ilCD,BDjk->iABjka",f["Vv"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 1.000000000 * np.einsum("Ab,Ci,jlaC,bBkl->jABika",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoov += -0.500000000 * np.einsum("Ab,Bl,ilaC,bCjk->iABjka",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoov += -1.000000000 * np.einsum("Cb,Al,ilaC,bBjk->iABjka",f["Vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVoov += -1.000000000 * np.einsum("AC,Di,jlaD,BCkl->jABika",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += -0.500000000 * np.einsum("AC,Bl,ilaD,CDjk->iABjka",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 0.500000000 * np.einsum("DC,Ci,jlaD,ABkl->jABika",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVoov += 1.000000000 * np.einsum("DC,Al,ilaD,BCjk->iABjka",f["VV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovv += -0.500000000 * np.einsum("ka,Ci,jlbC,ABkl->jABiab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVovv += -1.000000000 * np.einsum("ka,Al,ilbC,BCjk->iABjab",f["ov"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("ij,kA,jlaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("ij,kA,jlBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.500000000 * np.einsum("ij,kD,jlAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("kj,jA,ilaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("kj,jA,ilBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 2.000000000 * np.einsum("kj,lA,ijaB,aCkl->iCAB",f["oo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += 2.000000000 * np.einsum("kj,lA,ijBD,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("kj,iD,jlAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.500000000 * np.einsum("kj,jD,ilAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("kj,lD,ijAB,CDkl->iCAB",f["oo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 2.000000000 * np.einsum("ba,jA,ikbB,aCjk->iCAB",f["vv"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("Aa,jB,ikCD,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.250000000 * np.einsum("Aa,iD,jkBC,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += 0.500000000 * np.einsum("Aa,jD,ikBC,aDjk->iABC",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -2.000000000 * np.einsum("Da,jA,ikBD,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += 0.250000000 * np.einsum("Da,iD,jkAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.500000000 * np.einsum("Da,jD,ikAB,aCjk->iCAB",f["Vv"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("aA,jB,ikaD,CDjk->iCAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.500000000 * np.einsum("aA,iD,jkaB,CDjk->iCAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("aA,jD,ikaB,CDjk->iCAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("DA,jB,ikaD,aCjk->iCAB",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("DA,jB,ikDE,CEjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 0.500000000 * np.einsum("DA,iE,jkBD,CEjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -1.000000000 * np.einsum("DA,jE,ikBD,CEjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -2.000000000 * np.einsum("aD,jA,ikaB,CDjk->iCAB",f["vV"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("AD,jB,ikaC,aDjk->iABC",f["VV"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVVV += 1.000000000 * np.einsum("AD,jB,ikCE,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.250000000 * np.einsum("AD,iE,jkBC,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 0.500000000 * np.einsum("AD,jE,ikBC,DEjk->iABC",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 2.000000000 * np.einsum("ED,jA,ikBE,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += -0.250000000 * np.einsum("ED,iE,jkAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVVV += 0.500000000 * np.einsum("ED,jE,ikAB,CDjk->iCAB",f["VV"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("ai,kA,jlaC,BCkl->jBiA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -0.500000000 * np.einsum("ai,jC,klaA,BCkl->jBiA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += 1.000000000 * np.einsum("ai,kC,jlaA,BCkl->jBiA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ci,kA,jlaC,aBkl->jBiA",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ci,kA,jlCD,BDkl->jBiA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += 0.500000000 * np.einsum("Ci,jD,klAC,BDkl->jBiA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ci,kD,jlAC,BDkl->jBiA",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += 1.000000000 * np.einsum("ak,kA,ilaC,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("ak,lA,ikaC,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += 1.000000000 * np.einsum("ak,iC,klaA,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("ak,kC,ilaA,BCjl->iBjA",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += 1.000000000 * np.einsum("Ak,lB,ikaC,aCjl->iAjB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVoV += 0.500000000 * np.einsum("Ak,lB,ikCD,CDjl->iAjB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ak,iC,klaB,aCjl->iAjB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ak,iC,klBD,CDjl->iAjB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ak,lC,ikaB,aCjl->iAjB",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1oVoV += -1.000000000 * np.einsum("Ak,lC,ikBD,CDjl->iAjB",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# ...
# fs2s2s1vVoo += 0.500000000 * np.einsum("Bi,Cj,klBC,aAkl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("Bi,Ak,klBC,aCjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -1.000000000 * np.einsum("Bi,Ck,klBC,aAjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -1.000000000 * np.einsum("ak,Bi,klbB,bAjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -1.000000000 * np.einsum("ak,Bi,klBC,ACjl->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVoo += 0.500000000 * np.einsum("ak,Al,klbB,bBij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 0.250000000 * np.einsum("ak,Al,klBC,BCij->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVoo += -0.500000000 * np.einsum("ak,Bl,klbB,bAij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -0.500000000 * np.einsum("ak,Bl,klBC,ACij->aAij",f["vo"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("bk,Bi,klbB,aAjl->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -0.500000000 * np.einsum("bk,Al,klbB,aBij->aAij",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("Ak,Bi,klBC,aCjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 0.500000000 * np.einsum("Ak,Bl,klBC,aCij->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("Bk,Ci,klBC,aAjl->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -0.500000000 * np.einsum("Bk,Al,klBC,aCij->aAij",f["Vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -1.000000000 * np.einsum("kb,lB,bAij,aBkl->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("kb,lB,bBij,aAkl->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -2.000000000 * np.einsum("kb,lB,bAil,aBjk->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 2.000000000 * np.einsum("kb,lB,bBil,aAjk->aAij",f["ov"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("kB,lC,ABij,aCkl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 1.000000000 * np.einsum("kB,lC,BCij,aAkl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 2.000000000 * np.einsum("kB,lC,ACik,aBjl->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 2.000000000 * np.einsum("kB,lC,ABil,aCjk->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += 2.000000000 * np.einsum("kB,lC,BCil,aAjk->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVoo += -1.000000000 * np.einsum("kB,lC,ACkl,aBij->aAij",f["oV"],t1["oV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("ji,Ak,klaB,bBjl->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("ji,Bk,klaB,bAjl->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 2.000000000 * np.einsum("kj,Bi,jlaB,bAkl->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("kj,Ak,jlaB,bBil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("kj,Bk,jlaB,bAil->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -2.000000000 * np.einsum("kj,Al,jlaB,bBik->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 2.000000000 * np.einsum("kj,Bl,jlaB,bAik->bAia",f["oo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -0.500000000 * np.einsum("ca,Bi,jkcB,bAjk->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("ca,Aj,jkcB,bBik->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("ca,Bj,jkcB,bAik->bAia",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -0.500000000 * np.einsum("Ba,Ci,jkBC,bAjk->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("Ba,Aj,jkBC,bCik->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("Ba,Cj,jkBC,bAik->bAia",f["Vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -0.500000000 * np.einsum("ac,Bi,jkbB,cAjk->aAib",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("ac,Aj,jkbB,cBik->aAib",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("ac,Bj,jkbB,cAik->aAib",f["vv"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 0.500000000 * np.einsum("aB,Ci,jkbC,ABjk->aAib",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("aB,Aj,jkbC,BCik->aAib",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVov += -1.000000000 * np.einsum("aB,Cj,jkbC,ABik->aAib",f["vV"],t1["Vo"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vVov += -0.500000000 * np.einsum("AB,Ci,jkaC,bBjk->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("AB,Cj,jkaC,bBik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -0.500000000 * np.einsum("CB,Bi,jkaC,bAjk->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += -2.000000000 * np.einsum("CB,Aj,jkaC,bBik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVov += 1.000000000 * np.einsum("CB,Bj,jkaC,bAik->bAia",f["VV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVvv += 1.000000000 * np.einsum("ia,Aj,jkbB,cBik->cAab",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vVvv += -1.000000000 * np.einsum("ia,Bj,jkbB,cAik->cAab",f["ov"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVVVV += 0.500000000 * np.einsum("ai,jA,ikBC,bDjk->abDABC",f["vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVoVV += 0.500000000 * np.einsum("aD,Aj,jkBC,bDik->abAiBC",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVvVV += -1.000000000 * np.einsum("ai,jA,ikbB,cCjk->acCbAB",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVooV += -1.000000000 * np.einsum("ak,Ci,klAC,bBjl->abBijA",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVooV += 0.500000000 * np.einsum("ak,Al,klBC,bCij->abAijB",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVooV += 1.000000000 * np.einsum("kC,lA,aCij,bBkl->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVooV += 2.000000000 * np.einsum("kC,lA,aCil,bBjk->abBijA",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVovV += 1.000000000 * np.einsum("aC,Aj,jkbB,cCik->acAibB",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVoov += -1.000000000 * np.einsum("ak,Bi,klbB,cAjl->acAijb",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVoov += 0.500000000 * np.einsum("ak,Al,klbB,cBij->acAijb",f["vo"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVV += -1.000000000 * np.einsum("ai,jA,ikBC,bCjk->abAB",f["vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvVV += -0.500000000 * np.einsum("ai,jC,ikAB,bCjk->abAB",f["vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoV += 0.500000000 * np.einsum("aB,Ci,jkAC,bBjk->abiA",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoV += -1.000000000 * np.einsum("aB,Cj,jkAC,bBik->abiA",f["vV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvvV += 1.000000000 * np.einsum("ai,jA,ikbB,cBjk->acbA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvvV += -1.000000000 * np.einsum("ai,jB,ikbA,cBjk->acbA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoo += -1.000000000 * np.einsum("ak,Ai,klAB,bBjl->abij",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoo += -0.500000000 * np.einsum("ak,Al,klAB,bBij->abij",f["vo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoo += -1.000000000 * np.einsum("kA,lB,aAij,bBkl->abij",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvoo += -2.000000000 * np.einsum("kA,lB,aAil,bBjk->abij",f["oV"],t1["oV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvov += 0.500000000 * np.einsum("aA,Bi,jkbB,cAjk->acib",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vvov += -1.000000000 * np.einsum("aA,Bj,jkbB,cAik->acib",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 1.000000000 * np.einsum("ai,jA,ikbB,bBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 0.500000000 * np.einsum("ai,jA,ikBC,BCjk->aA",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("ai,jB,ikbA,bBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("ai,jB,ikAC,BCjk->aA",f["vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vV += 0.500000000 * np.einsum("bi,iA,jkbB,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("bi,jA,ikbB,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -0.500000000 * np.einsum("bi,iB,jkbA,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 1.000000000 * np.einsum("bi,jB,ikbA,aBjk->aA",f["vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 0.500000000 * np.einsum("Bi,iA,jkBC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("Bi,jA,ikBC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 1.000000000 * np.einsum("Bi,jB,ikAC,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 0.500000000 * np.einsum("Bi,iC,jkAB,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("Bi,jC,ikAB,aCjk->aA",f["Vo"],t1["oV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("iA,Bj,jkBC,aCik->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 0.500000000 * np.einsum("iB,Ci,jkAC,aBjk->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += 1.000000000 * np.einsum("iB,Bj,jkAC,aCik->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vV += -1.000000000 * np.einsum("iB,Cj,jkAC,aBik->aA",f["oV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -1.000000000 * np.einsum("ji,Ak,klAB,aBjl->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 2.000000000 * np.einsum("kj,Ai,jlAB,aBkl->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -1.000000000 * np.einsum("kj,Ak,jlAB,aBil->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 2.000000000 * np.einsum("kj,Al,jlAB,aBik->ai",f["oo"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -0.500000000 * np.einsum("ab,Ai,jkAB,bBjk->ai",f["vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("ab,Aj,jkAB,bBik->ai",f["vv"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -0.500000000 * np.einsum("aA,Bi,jkbB,bAjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -0.500000000 * np.einsum("aA,Bi,jkBC,ACjk->ai",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("aA,Bj,jkbB,bAik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("aA,Bj,jkBC,ACik->ai",f["vV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vo += -0.500000000 * np.einsum("bA,Ai,jkbB,aBjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("bA,Bi,jkbB,aAjk->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("bA,Aj,jkbB,aBik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -2.000000000 * np.einsum("bA,Bj,jkbB,aAik->ai",f["vV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -0.500000000 * np.einsum("BA,Ai,jkBC,aCjk->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("BA,Ci,jkBC,aAjk->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += 1.000000000 * np.einsum("BA,Aj,jkBC,aCik->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vo += -2.000000000 * np.einsum("BA,Cj,jkBC,aAik->ai",f["VV"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += -1.000000000 * np.einsum("ai,jA,ikbB,ABjk->ab",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1vv += 1.000000000 * np.einsum("Ai,jA,ikaB,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += 0.500000000 * np.einsum("Ai,iB,jkaA,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += -1.000000000 * np.einsum("Ai,jB,ikaA,bBjk->ba",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += -1.000000000 * np.einsum("ia,Aj,jkAB,bBik->ba",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += 0.500000000 * np.einsum("iA,Bi,jkaB,bAjk->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += 1.000000000 * np.einsum("iA,Aj,jkaB,bBik->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1vv += -1.000000000 * np.einsum("iA,Bj,jkaB,bAik->ba",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("ai,iA,jkaB,ABjk->",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("ai,jA,ikaB,ABjk->",f["vo"],t1["oV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += -1.000000000 * np.einsum("Ai,jA,ikaB,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("Ai,jA,ikBC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("Ai,iB,jkaA,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("Ai,iB,jkAC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("Ai,jB,ikaA,aBjk->",f["Vo"],t1["oV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("Ai,jB,ikAC,BCjk->",f["Vo"],t1["oV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("ia,Ai,jkAB,aBjk->",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("ia,Aj,jkAB,aBik->",f["ov"],t1["Vo"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("iA,Bi,jkaB,aAjk->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("iA,Bi,jkBC,ACjk->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += -1.000000000 * np.einsum("iA,Aj,jkaB,aBik->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += -0.500000000 * np.einsum("iA,Aj,jkBC,BCik->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("iA,Bj,jkaB,aAik->",f["oV"],t1["Vo"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s1 += 1.000000000 * np.einsum("iA,Bj,jkBC,ACik->",f["oV"],t1["Vo"],t2["ooVV"],t2["VVoo"],optimize="optimal")

# %%
# [[[F,s2_ext],s2_ext],s2_ext]
print("[[[F,s2_ext],s2_ext],s2_ext]")
Fs2s2s2 = w.commutator(F,s2_ext,s2_ext,s2_ext)
expr = wt.contract(Fs2s2s2,minrank=8,maxrank=10)
mbeq = expr.to_manybody_equations('fs2s2s2')
for key in mbeq.keys():
	for eq in mbeq[key]:
		print(eq.compile('einsum'))
# Out:
# [[[F,s2_ext],s2_ext],s2_ext]
# fs2s2s2VVVVoVVV += -0.125000000 * np.einsum("jA,klBC,DEil,Gajk->DEGaiABC",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += 0.125000000 * np.einsum("ki,lmAB,CDjm,EGkl->CDEGijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += -0.375000000 * np.einsum("lk,kmAB,CDim,EGjl->CDEGijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += -0.250000000 * np.einsum("Aa,klBC,DEik,aGjl->ADEGijBC",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += -0.250000000 * np.einsum("aA,klaB,CDik,EGjl->CDEGijAB",f["vV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += 0.250000000 * np.einsum("aA,klBa,CDik,EGjl->CDEGijAB",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooVV += -0.250000000 * np.einsum("Aa,klBC,DEil,Gajk->ADEGijBC",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVovVV += -0.125000000 * np.einsum("ja,klAB,CDil,EGjk->CDEGiaAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVovVV += 0.250000000 * np.einsum("jA,klaB,CDil,EGjk->CDEGiaAB",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoooV += -0.250000000 * np.einsum("ai,lmaA,BCjl,DEkm->BCDEijkA",f["vo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoooV += 0.250000000 * np.einsum("Gi,lmAG,BCjl,DEkm->BCDEijkA",f["Vo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoooV += 0.500000000 * np.einsum("Al,lmaB,CDim,aEjk->ACDEijkB",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2VVVVoooV += 0.500000000 * np.einsum("Al,lmBG,CGij,DEkm->ACDEijkB",f["Vo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += 0.250000000 * np.einsum("ki,lmaA,BCjm,DEkl->BCDEijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += -0.750000000 * np.einsum("lk,kmaA,BCim,DEjl->BCDEijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += -0.250000000 * np.einsum("ba,klbA,BCik,DEjl->BCDEijaA",f["vv"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += 0.250000000 * np.einsum("Ga,klAG,BCik,DEjl->BCDEijaA",f["Vv"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += -0.500000000 * np.einsum("Ab,klaB,CDik,bEjl->ACDEijaB",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += -0.250000000 * np.einsum("GA,klaG,BCik,DEjl->BCDEijaA",f["VV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovV += -0.500000000 * np.einsum("AG,klaB,CDil,EGjk->ACDEijaB",f["VV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVovvV += -0.250000000 * np.einsum("ja,klbA,BCil,DEjk->BCDEiabA",f["ov"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooov += 0.250000000 * np.einsum("Ei,lmaE,ABjl,CDkm->ABCDijka",f["Vo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVooov += 0.500000000 * np.einsum("Al,lmaE,BEij,CDkm->ABCDijka",f["Vo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2VVVVoovv += 0.250000000 * np.einsum("Ea,klbE,ABik,CDjl->ABCDijab",f["Vv"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVVVVV += 0.125000000 * np.einsum("Aj,ikBC,jlDE,Gakl->iAGaBCDE",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVvVVV += 0.250000000 * np.einsum("Aj,ikBC,jlaD,EGkl->iAEGaBCD",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVvVVV += -0.250000000 * np.einsum("Aj,jkBC,ilaD,EGkl->iAEGaBCD",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += -0.250000000 * np.einsum("ia,lmAB,CDjl,aEkm->iCDEjkAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.750000000 * np.einsum("la,imAB,CDjl,aEkm->iCDEjkAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += -0.375000000 * np.einsum("la,imAB,CDlm,aEjk->iCDEjkAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.500000000 * np.einsum("lA,imaB,CDjm,aEkl->iCDEjkAB",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.250000000 * np.einsum("lA,imaB,CDlm,aEjk->iCDEjkAB",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.250000000 * np.einsum("lA,imBG,CGjk,DElm->iCDEjkAB",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.500000000 * np.einsum("lA,imBG,CDjm,EGkl->iCDEjkAB",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += -0.250000000 * np.einsum("iG,lmAB,CDjm,EGkl->iCDEjkAB",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.375000000 * np.einsum("lG,imAB,CGjk,DElm->iCDEjkAB",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooVV += 0.750000000 * np.einsum("lG,imAB,CGjm,DEkl->iCDEjkAB",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVvvVV += -0.500000000 * np.einsum("Aj,ikaB,jlbC,DEkl->iADEabBC",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("mi,jabA,BCka,bDlm->jBCDiklA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.250000000 * np.einsum("mi,jabA,BCma,bDkl->jBCDiklA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.250000000 * np.einsum("mi,jaAE,BEkl,CDma->jBCDiklA",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("mi,jaAE,BCka,DElm->jBCDiklA",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("im,mabA,BCja,bDkl->iBCDjklA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("im,maAE,BEjk,CDla->iBCDjklA",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.750000000 * np.einsum("am,imbA,BCja,bDkl->iBCDjklA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.750000000 * np.einsum("am,imAE,BEjk,CDla->iBCDjklA",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.750000000 * np.einsum("ba,imbA,BCjm,aDkl->iBCDjklA",f["vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("Aa,imbB,bCjk,aDlm->iACDjklB",f["Vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("Aa,imBE,CEjk,aDlm->iACDjklB",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.250000000 * np.einsum("Aa,imBE,CDjm,aEkl->iACDjklB",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.750000000 * np.einsum("Ea,imAE,BCjm,aDkl->iBCDjklA",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.500000000 * np.einsum("aA,imaE,BEjk,CDlm->iBCDjklA",f["vV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.500000000 * np.einsum("EA,imaE,BCjm,aDkl->iBCDjklA",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.500000000 * np.einsum("EA,imEG,BGjk,CDlm->iBCDjklA",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.750000000 * np.einsum("aE,imaA,BEjk,CDlm->iBCDjklA",f["vV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.250000000 * np.einsum("AE,imaB,CDjm,aEkl->iACDjklB",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += 0.500000000 * np.einsum("AE,imaB,CEjm,aDkl->iACDjklB",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.500000000 * np.einsum("AE,imBG,CGjk,DElm->iACDjklB",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.250000000 * np.einsum("AE,imBG,EGjk,CDlm->iACDjklB",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooV += -0.750000000 * np.einsum("GE,imAG,BEjk,CDlm->iBCDjklA",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 0.500000000 * np.einsum("la,imbA,BCjm,bDkl->iBCDjkaA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 0.250000000 * np.einsum("la,imbA,BClm,bDjk->iBCDjkaA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 0.250000000 * np.einsum("la,imAE,BEjk,CDlm->iBCDjkaA",f["ov"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 0.500000000 * np.einsum("la,imAE,BCjm,DEkl->iBCDjkaA",f["ov"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += -0.500000000 * np.einsum("ib,lmaA,BCjl,bDkm->iBCDjkaA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 1.500000000 * np.einsum("lb,imaA,BCjl,bDkm->iBCDjkaA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += -0.750000000 * np.einsum("lb,imaA,BClm,bDjk->iBCDjkaA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += -0.250000000 * np.einsum("lA,imaE,BEjk,CDlm->iBCDjkaA",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += -0.500000000 * np.einsum("lA,imaE,BCjm,DEkl->iBCDjkaA",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += -0.500000000 * np.einsum("iE,lmaA,BCjm,DEkl->iBCDjkaA",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 0.750000000 * np.einsum("lE,imaA,BEjk,CDlm->iBCDjkaA",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovV += 1.500000000 * np.einsum("lE,imaA,BEjm,CDkl->iBCDjkaA",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooo += 0.500000000 * np.einsum("ai,jbaD,ADkl,BCmb->jABCiklm",f["vo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooo += 0.500000000 * np.einsum("Di,jabD,ABka,bClm->jABCiklm",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooo += 0.500000000 * np.einsum("Di,jaDE,AEkl,BCma->jABCiklm",f["Vo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoooo += 0.500000000 * np.einsum("Aa,iabD,BDjk,bClm->iABCjklm",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVoooo += 0.250000000 * np.einsum("Aa,iaDE,BDjk,CElm->iABCjklm",f["Vo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.250000000 * np.einsum("mi,jabD,ADkl,BCma->jABCiklb",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.500000000 * np.einsum("mi,jabD,ABka,CDlm->jABCiklb",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.500000000 * np.einsum("im,mabD,ADjk,BCla->iABCjklb",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.750000000 * np.einsum("am,imbD,ADjk,BCla->iABCjklb",f["oo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.500000000 * np.einsum("ba,imbD,ADjk,BClm->iABCjkla",f["vv"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.500000000 * np.einsum("Da,imbD,ABjm,bCkl->iABCjkla",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.500000000 * np.einsum("Da,imDE,AEjk,BClm->iABCjkla",f["Vv"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.500000000 * np.einsum("Ab,imaD,BDjk,bClm->iABCjkla",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.250000000 * np.einsum("Ab,imaD,BCjm,bDkl->iABCjkla",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooov += 0.750000000 * np.einsum("Db,imaD,ABjm,bCkl->iABCjkla",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.500000000 * np.einsum("AD,imaE,BEjk,CDlm->iABCjkla",f["VV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.250000000 * np.einsum("AD,imaE,DEjk,BClm->iABCjkla",f["VV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVooov += -0.750000000 * np.einsum("ED,imaE,ADjk,BClm->iABCjkla",f["VV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovv += 0.250000000 * np.einsum("la,imbD,ADjk,BClm->iABCjkab",f["ov"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oVVVoovv += 0.500000000 * np.einsum("la,imbD,ABjm,CDkl->iABCjkab",f["ov"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += -0.125000000 * np.einsum("ik,jlAB,kmCD,EGlm->ijEGABCD",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += -0.375000000 * np.einsum("lk,imAB,jkCD,EGlm->ijEGABCD",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += -0.250000000 * np.einsum("Aa,ikBC,jlDE,aGkl->ijAGBCDE",f["Vv"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += -0.250000000 * np.einsum("aA,ikBC,jlaD,EGkl->ijEGABCD",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += 0.250000000 * np.einsum("aA,ikBC,jlDa,EGkl->ijEGABCD",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVVVVV += 0.250000000 * np.einsum("Aa,ikBC,jlDE,Gakl->ijAGBCDE",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += -0.250000000 * np.einsum("ai,jlAB,kmaC,DElm->jkDEiABC",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.250000000 * np.einsum("Gi,jlAB,kmCG,DElm->jkDEiABC",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.750000000 * np.einsum("al,ilAB,jmaC,DEkm->ijDEkABC",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += -0.375000000 * np.einsum("al,lmAB,ijaC,DEkm->ijDEkABC",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.500000000 * np.einsum("Al,imBC,jlaD,aEkm->ijAEkBCD",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.500000000 * np.einsum("Al,imBC,jlDG,EGkm->ijAEkBCD",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.250000000 * np.einsum("Al,lmBC,ijaD,aEkm->ijAEkBCD",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.250000000 * np.einsum("Al,lmBC,ijDG,EGkm->ijAEkBCD",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += -0.750000000 * np.einsum("Gl,ilAB,jmCG,DEkm->ijDEkABC",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoVVV += 0.375000000 * np.einsum("Gl,lmAB,ijCG,DEkm->ijDEkABC",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += -0.250000000 * np.einsum("ik,jlAB,kmaC,DElm->ijDEaABC",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 0.250000000 * np.einsum("ik,klAB,jmaC,DElm->ijDEaABC",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 0.750000000 * np.einsum("lk,ikAB,jmaC,DElm->ijDEaABC",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += -0.750000000 * np.einsum("lk,imAB,jkaC,DElm->ijDEaABC",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += -0.250000000 * np.einsum("ba,ikAB,jlbC,DEkl->ijDEaABC",f["vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 0.250000000 * np.einsum("Ga,ikAB,jlCG,DEkl->ijDEaABC",f["Vv"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += -1.000000000 * np.einsum("Ab,ikBC,jlaD,bEkl->ijAEaBCD",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 0.500000000 * np.einsum("bA,ikaB,jlbC,DEkl->ijDEaABC",f["vV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += -0.250000000 * np.einsum("GA,ikBC,jlaG,DEkl->ijDEaABC",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 0.500000000 * np.einsum("GA,ikBG,jlaC,DEkl->ijDEaABC",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvVVV += 1.000000000 * np.einsum("AG,ikBC,jlaD,EGkl->ijAEaBCD",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.500000000 * np.einsum("bi,jlaA,kmbB,CDlm->jkCDiaAB",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 0.250000000 * np.einsum("Ei,jlAB,kmaE,CDlm->jkCDiaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.500000000 * np.einsum("Ei,jlAE,kmaB,CDlm->jkCDiaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 1.500000000 * np.einsum("bl,ilaA,jmbB,CDkm->ijCDkaAB",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.750000000 * np.einsum("bl,lmaA,ijbB,CDkm->ijCDkaAB",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 1.000000000 * np.einsum("Al,imaB,jlbC,bDkm->ijADkaBC",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 0.500000000 * np.einsum("Al,lmaB,ijbC,bDkm->ijADkaBC",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 0.500000000 * np.einsum("Al,imBC,jlaE,DEkm->ijADkaBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 0.250000000 * np.einsum("Al,lmBC,ijaE,DEkm->ijADkaBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.500000000 * np.einsum("Al,ijBE,lmaC,DEkm->ijADkaBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 1.000000000 * np.einsum("Al,ilBE,jmaC,DEkm->ijADkaBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.750000000 * np.einsum("El,ilAB,jmaE,CDkm->ijCDkaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += 0.375000000 * np.einsum("El,lmAB,ijaE,CDkm->ijCDkaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -0.750000000 * np.einsum("El,ijAE,lmaB,CDkm->ijCDkaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovVV += -1.500000000 * np.einsum("El,imAE,jlaB,CDkm->ijCDkaAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += 0.500000000 * np.einsum("ik,jlaA,kmbB,CDlm->ijCDabAB",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += 1.500000000 * np.einsum("lk,imaA,jkbB,CDlm->ijCDabAB",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += -0.500000000 * np.einsum("ca,ikbA,jlcB,CDkl->ijCDabAB",f["vv"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += 0.250000000 * np.einsum("Ea,ikAB,jlbE,CDkl->ijCDabAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += -0.500000000 * np.einsum("Ea,ikAE,jlbB,CDkl->ijCDabAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += 1.000000000 * np.einsum("Ac,ikaB,jlbC,cDkl->ijADabBC",f["Vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += -0.500000000 * np.einsum("EA,ikaB,jlbE,CDkl->ijCDabAB",f["VV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvVV += -1.000000000 * np.einsum("AE,ikaB,jlbC,DEkl->ijADabBC",f["VV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.500000000 * np.einsum("ia,jbcA,cBkl,aCmb->ijBCklmA",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.500000000 * np.einsum("ia,jbAD,BDkl,aCmb->ijBCklmA",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.250000000 * np.einsum("ia,jbAD,BCkb,aDlm->ijBCklmA",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.750000000 * np.einsum("ab,ijcA,bBkl,cCma->ijBCklmA",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.375000000 * np.einsum("ab,ijAD,BCka,bDlm->ijBCklmA",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.750000000 * np.einsum("ab,ijAD,BDka,bClm->ijBCklmA",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.250000000 * np.einsum("aA,ijbD,BDkl,bCma->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.250000000 * np.einsum("aA,ijbD,BDka,bClm->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.250000000 * np.einsum("aA,ijDE,BEkl,CDma->ijBCklmA",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.250000000 * np.einsum("iD,jabA,BCka,bDlm->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.500000000 * np.einsum("iD,jabA,BDka,bClm->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.500000000 * np.einsum("iD,jaAE,BEkl,CDma->ijBCklmA",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.250000000 * np.einsum("iD,jaAE,DEkl,BCma->ijBCklmA",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.750000000 * np.einsum("aD,ijbA,BDkl,bCma->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.375000000 * np.einsum("aD,ijbA,BCka,bDlm->ijBCklmA",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += -0.750000000 * np.einsum("aD,ijAE,BDkl,CEma->ijBCklmA",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooV += 0.375000000 * np.einsum("aD,ijAE,DEkl,BCma->ijBCklmA",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovvV += -0.500000000 * np.einsum("Di,jlaA,kmbD,BClm->jkBCiabA",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovvV += -1.000000000 * np.einsum("Al,imaB,jlbD,CDkm->ijACkabB",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovvV += -0.500000000 * np.einsum("Al,lmaB,ijbD,CDkm->ijACkabB",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovvV += 1.500000000 * np.einsum("Dl,ilaA,jmbD,BCkm->ijBCkabA",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVovvV += -0.750000000 * np.einsum("Dl,lmaA,ijbD,BCkm->ijBCkabA",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVvvvV += -0.500000000 * np.einsum("Da,ikbA,jlcD,BCkl->ijBCabcA",f["Vv"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.250000000 * np.einsum("ai,jkbC,AClm,bBca->jkABilmc",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.250000000 * np.einsum("ai,jkbC,ACla,bBmc->jkABilmc",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += 0.250000000 * np.einsum("ai,jkCD,ADlm,BCba->jkABilmb",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.500000000 * np.einsum("ia,jabC,ACkl,bBmc->ijABklmc",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.250000000 * np.einsum("ia,jaCD,ACkl,BDmb->ijABklmb",f["oo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.375000000 * np.einsum("ba,ijbC,ACkl,aBmc->ijABklmc",f["vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.125000000 * np.einsum("Aa,ijbC,bBkl,aCmc->ijABklmc",f["Vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += 0.125000000 * np.einsum("Aa,ijCD,BCkl,aDmb->ijABklmb",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.375000000 * np.einsum("Ca,ijbC,bAkl,aBmc->ijABklmc",f["Vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.375000000 * np.einsum("Ca,ijCD,ADkl,aBmb->ijABklmb",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += 0.375000000 * np.einsum("aC,ijaD,ADkl,BCmb->ijABklmb",f["vV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += 0.125000000 * np.einsum("AC,ijaD,BDkl,aCmb->ijABklmb",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.125000000 * np.einsum("AC,ijaD,CDkl,aBmb->ijABklmb",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.125000000 * np.einsum("AC,ijDE,BEkl,CDma->ijABklma",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += -0.375000000 * np.einsum("DC,ijaD,ACkl,aBmb->ijABklmb",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVoooo += 0.375000000 * np.einsum("DC,ijDE,AEkl,BCma->ijABklma",f["VV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.250000000 * np.einsum("ab,ijcC,ACkl,cBma->ijABklmb",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.250000000 * np.einsum("ab,ijcC,ACka,cBlm->ijABklmb",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += -0.250000000 * np.einsum("ab,ijCD,ADkl,BCma->ijABklmb",f["ov"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVooov += -0.500000000 * np.einsum("ib,jacC,ACkl,bBma->ijABklmc",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.250000000 * np.einsum("ib,jacC,ABka,bClm->ijABklmc",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.375000000 * np.einsum("ab,ijcC,ABka,bClm->ijABklmc",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += -0.750000000 * np.einsum("ab,ijcC,ACka,bBlm->ijABklmc",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.500000000 * np.einsum("iC,jabD,ADkl,BCma->ijABklmb",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.250000000 * np.einsum("iC,jabD,CDkl,ABma->ijABklmb",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVooov += -0.750000000 * np.einsum("aC,ijbD,ACkl,BDma->ijABklmb",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooVVooov += 0.375000000 * np.einsum("aC,ijbD,CDkl,ABma->ijABklmb",f["oV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVVVVV += -0.250000000 * np.einsum("ia,jlAB,kmCD,aElm->ijkEABCD",f["ov"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVVVVV += 0.500000000 * np.einsum("lA,imBC,jkaD,aElm->ijkEABCD",f["oV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVVVVV += 0.500000000 * np.einsum("lA,imBC,jkDG,EGlm->ijkEABCD",f["oV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVVVVV += 0.250000000 * np.einsum("iG,jlAB,kmCD,EGlm->ijkEABCD",f["oV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("mi,jaAB,klbC,bDma->jklDiABC",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("mi,jaAB,klCE,DEma->jklDiABC",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("im,jaAB,kmbC,bDla->ijkDlABC",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("im,jaAB,kmCE,DEla->ijkDlABC",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.250000000 * np.einsum("im,maAB,jkbC,bDla->ijkDlABC",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.250000000 * np.einsum("im,maAB,jkCE,DEla->ijkDlABC",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.750000000 * np.einsum("am,imAB,jkbC,bDla->ijkDlABC",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.750000000 * np.einsum("am,imAB,jkCE,DEla->ijkDlABC",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.750000000 * np.einsum("ba,imAB,jkbC,aDlm->ijkDlABC",f["vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.500000000 * np.einsum("Aa,imBC,jkDE,aElm->ijkAlBCD",f["Vv"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.750000000 * np.einsum("Ea,imAB,jkCE,aDlm->ijkDlABC",f["Vv"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("aA,ijbB,kmaC,bDlm->ijkDlABC",f["vV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.250000000 * np.einsum("aA,imBC,jkaE,DElm->ijkDlABC",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("aA,ijBE,kmaC,DElm->ijkDlABC",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.250000000 * np.einsum("EA,imBC,jkaE,aDlm->ijkDlABC",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.250000000 * np.einsum("EA,imBC,jkEG,DGlm->ijkDlABC",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.500000000 * np.einsum("EA,imBE,jkaC,aDlm->ijkDlABC",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.500000000 * np.einsum("EA,ijBG,kmCE,DGlm->ijkDlABC",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += 0.750000000 * np.einsum("aE,imAB,jkaC,DElm->ijkDlABC",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.500000000 * np.einsum("AE,imBC,jkaD,aElm->ijkAlBCD",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.500000000 * np.einsum("AE,imBC,jkDG,EGlm->ijkAlBCD",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoVVV += -0.750000000 * np.einsum("GE,imAB,jkCG,DElm->ijkDlABC",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += 0.500000000 * np.einsum("la,imAB,jkbC,bDlm->ijkDaABC",f["ov"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += 0.500000000 * np.einsum("la,imAB,jkCE,DElm->ijkDaABC",f["ov"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += -1.000000000 * np.einsum("ib,jlAB,kmaC,bDlm->ijkDaABC",f["ov"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += -1.000000000 * np.einsum("lA,imaB,jkbC,bDlm->ijkDaABC",f["oV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += -0.500000000 * np.einsum("lA,imBC,jkaE,DElm->ijkDaABC",f["oV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += 1.000000000 * np.einsum("lA,ijBE,kmaC,DElm->ijkDaABC",f["oV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvVVV += 1.000000000 * np.einsum("iE,jlAB,kmaC,DElm->ijkDaABC",f["oV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.500000000 * np.einsum("ai,jkbA,lcaB,bCmc->jklCimAB",f["vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("ai,jbAB,klaD,CDmb->jklCimAB",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.500000000 * np.einsum("ai,jkAD,lbaB,CDmb->jklCimAB",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("Di,jaAB,klbD,bCma->jklCimAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("Di,jaAB,klDE,CEma->jklCimAB",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.500000000 * np.einsum("Di,jaAD,klbB,bCma->jklCimAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.500000000 * np.einsum("Di,jkAE,laBD,CEma->jklCimAB",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.750000000 * np.einsum("ab,ibcA,jkaB,cClm->ijkClmAB",f["vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.375000000 * np.einsum("ab,ibAB,jkaD,CDlm->ijkClmAB",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.750000000 * np.einsum("ab,ibAD,jkaB,CDlm->ijkClmAB",f["vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("Aa,ijBD,kabC,bDlm->ijkAlmBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("Aa,ijBD,kaCE,DElm->ijkAlmBC",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.250000000 * np.einsum("Aa,iaBD,jkbC,bDlm->ijkAlmBC",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.375000000 * np.einsum("Da,iaAB,jkbD,bClm->ijkClmAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.375000000 * np.einsum("Da,iaAB,jkDE,CElm->ijkClmAB",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVooVV += -0.750000000 * np.einsum("Da,ijAD,kabB,bClm->ijkClmAB",f["Vo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVooVV += 0.750000000 * np.einsum("Da,iaAE,jkBD,CElm->ijkClmAB",f["Vo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.000000000 * np.einsum("mi,jabA,klcB,cCma->jklCibAB",f["oo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("mi,jaAB,klbD,CDma->jklCibAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -1.000000000 * np.einsum("mi,jkAD,labB,CDma->jklCibAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.000000000 * np.einsum("im,jabA,kmcB,cCla->ijkClbAB",f["oo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("im,mabA,jkcB,cCla->ijkClbAB",f["oo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("im,jaAB,kmbD,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.250000000 * np.einsum("im,maAB,jkbD,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("im,jkAD,mabB,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.000000000 * np.einsum("im,jmAD,kabB,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.500000000 * np.einsum("am,imbA,jkcB,cCla->ijkClbAB",f["oo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.750000000 * np.einsum("am,imAB,jkbD,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -1.500000000 * np.einsum("am,ijAD,kmbB,CDla->ijkClbAB",f["oo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("ba,ijcA,kmbB,cClm->ijkClaAB",f["vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.250000000 * np.einsum("ba,imAB,jkbD,CDlm->ijkClaAB",f["vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("ba,ijAD,kmbB,CDlm->ijkClaAB",f["vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.250000000 * np.einsum("Da,imAB,jkbD,bClm->ijkClaAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.250000000 * np.einsum("Da,imAB,jkDE,CElm->ijkClaAB",f["Vv"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("Da,imAD,jkbB,bClm->ijkClaAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("Da,ijAE,kmBD,CElm->ijkClaAB",f["Vv"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -1.500000000 * np.einsum("cb,imaA,jkcB,bClm->ijkClaAB",f["vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("Ab,imBC,jkaD,bDlm->ijkAlaBC",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.000000000 * np.einsum("Ab,ijBD,kmaC,bDlm->ijkAlaBC",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.750000000 * np.einsum("Db,imAB,jkaD,bClm->ijkClaAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -1.500000000 * np.einsum("Db,ijAD,kmaB,bClm->ijkClaAB",f["Vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("bA,imaB,jkbD,CDlm->ijkClaAB",f["vV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("bA,ijaD,kmbB,CDlm->ijkClaAB",f["vV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("DA,imaB,jkbD,bClm->ijkClaAB",f["VV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("DA,ijbB,kmaD,bClm->ijkClaAB",f["VV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("DA,imBD,jkaE,CElm->ijkClaAB",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("DA,ijBE,kmaD,CElm->ijkClaAB",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 0.500000000 * np.einsum("DA,ijDE,kmaB,CElm->ijkClaAB",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.500000000 * np.einsum("bD,imaA,jkbB,CDlm->ijkClaAB",f["vV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -1.000000000 * np.einsum("AD,imaB,jkbC,bDlm->ijkAlaBC",f["VV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.500000000 * np.einsum("AD,imBC,jkaE,DElm->ijkAlaBC",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.000000000 * np.einsum("AD,ijBE,kmaC,DElm->ijkAlaBC",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += -0.750000000 * np.einsum("ED,imAB,jkaE,CDlm->ijkClaAB",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovVV += 1.500000000 * np.einsum("ED,ijAE,kmaB,CDlm->ijkClaAB",f["VV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += 1.000000000 * np.einsum("la,imbA,jkcB,cClm->ijkCabAB",f["ov"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += 0.500000000 * np.einsum("la,imAB,jkbD,CDlm->ijkCabAB",f["ov"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += -1.000000000 * np.einsum("la,ijAD,kmbB,CDlm->ijkCabAB",f["ov"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += 1.000000000 * np.einsum("ic,jlaA,kmbB,cClm->ijkCabAB",f["ov"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += -1.000000000 * np.einsum("lA,imaB,jkbD,CDlm->ijkCabAB",f["oV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvvVV += -1.000000000 * np.einsum("iD,jlaA,kmbB,CDlm->ijkCabAB",f["oV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.500000000 * np.einsum("bi,jacA,klbC,BCma->jklBimcA",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.500000000 * np.einsum("bi,jkaC,lcbA,BCmc->jklBimaA",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.500000000 * np.einsum("Ci,jabA,klcC,cBma->jklBimbA",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.500000000 * np.einsum("Ci,jkbA,lacC,bBma->jklBimcA",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.500000000 * np.einsum("Ci,jaAC,klbD,BDma->jklBimbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.500000000 * np.einsum("Ci,jkAD,labC,BDma->jklBimbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.500000000 * np.einsum("Ci,jkCD,labA,BDma->jklBimbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.750000000 * np.einsum("ba,iacA,jkbC,BClm->ijkBlmcA",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.750000000 * np.einsum("ba,iacC,jkbA,BClm->ijkBlmcA",f["vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.250000000 * np.einsum("Aa,ijbC,kacB,cClm->ijkAlmbB",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.250000000 * np.einsum("Aa,iabC,jkcB,cClm->ijkAlmbB",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.250000000 * np.einsum("Aa,ijBC,kabD,CDlm->ijkAlmbB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.250000000 * np.einsum("Aa,iaBC,jkbD,CDlm->ijkAlmbB",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.750000000 * np.einsum("Ca,iabA,jkcC,cBlm->ijkBlmbA",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.750000000 * np.einsum("Ca,iabA,jkcC,bBlm->ijkBlmcA",f["Vo"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.750000000 * np.einsum("Ca,ijAC,kabD,BDlm->ijkBlmbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += -0.750000000 * np.einsum("Ca,iaAD,jkbC,BDlm->ijkBlmbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovV += 0.750000000 * np.einsum("Ca,ijCD,kabA,BDlm->ijkBlmbA",f["Vo"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -1.000000000 * np.einsum("mi,jabA,klcC,BCma->jklBibcA",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -1.000000000 * np.einsum("im,jabA,kmcC,BCla->ijkBlbcA",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("im,mabA,jkcC,BCla->ijkBlbcA",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -1.500000000 * np.einsum("am,imbA,jkcC,BCla->ijkBlbcA",f["oo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("ca,imbA,jkcC,BClm->ijkBlabA",f["vv"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 0.500000000 * np.einsum("ca,ijbC,kmcA,BClm->ijkBlabA",f["vv"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("Ca,imbA,jkcC,cBlm->ijkBlabA",f["Vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 0.500000000 * np.einsum("Ca,ijcA,kmbC,cBlm->ijkBlabA",f["Vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("Ca,imAC,jkbD,BDlm->ijkBlabA",f["Vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 0.500000000 * np.einsum("Ca,ijAD,kmbC,BDlm->ijkBlabA",f["Vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("Ca,ijCD,kmbA,BDlm->ijkBlabA",f["Vv"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 1.000000000 * np.einsum("Ac,imaB,jkbC,cClm->ijkAlabB",f["Vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -1.500000000 * np.einsum("Cc,imaA,jkbC,cBlm->ijkBlabA",f["Vv"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVovvV += -0.500000000 * np.einsum("CA,ijaD,kmbC,BDlm->ijkBlabA",f["VV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 1.000000000 * np.einsum("AC,imaB,jkbD,CDlm->ijkAlabB",f["VV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvV += 1.500000000 * np.einsum("DC,imaA,jkbD,BClm->ijkBlabA",f["VV"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVvvvV += -1.000000000 * np.einsum("la,imbA,jkcC,BClm->ijkBabcA",f["ov"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoooo += -0.125000000 * np.einsum("ia,jkbB,bAlm,aBcd->ijkAlmcd",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoooo += 0.125000000 * np.einsum("ia,jkBC,ABlm,aCbc->ijkAlmbc",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoooo += 0.125000000 * np.einsum("iB,jkaC,AClm,aBbc->ijkAlmbc",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoooo += -0.125000000 * np.einsum("iB,jkaC,BClm,aAbc->ijkAlmbc",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooVoooo += -0.125000000 * np.einsum("iB,jkCD,ADlm,BCab->ijkAlmab",f["oV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovv += 0.500000000 * np.einsum("Bi,jkaC,lbcB,ACmb->jklAimac",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovv += 0.250000000 * np.einsum("Aa,ijbB,kacC,BClm->ijkAlmbc",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVoovv += 0.750000000 * np.einsum("Ba,iabC,jkcB,AClm->ijkAlmbc",f["Vo"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooVovvv += -0.500000000 * np.einsum("Ba,ijbC,kmcB,AClm->ijkAlabc",f["Vv"],t2["oovV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooooVVV += 0.500000000 * np.einsum("ia,jbAB,klCD,aDmb->ijklmABC",f["ov"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooooVVV += 0.500000000 * np.einsum("aA,ijBD,klbC,bDma->ijklmABC",f["oV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooooVVV += 0.250000000 * np.einsum("aA,ijBD,klCE,DEma->ijklmABC",f["oV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2oooooVVV += 0.500000000 * np.einsum("iD,jaAB,klbC,bDma->ijklmABC",f["oV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2oooooVVV += 0.500000000 * np.einsum("iD,jaAB,klCE,DEma->ijklmABC",f["oV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.500000000 * np.einsum("ai,jkAC,lmbB,bCca->jklmicAB",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.250000000 * np.einsum("ai,jkAC,lmBD,CDba->jklmibAB",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.250000000 * np.einsum("ia,jkAC,labB,bCmc->ijklmcAB",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.250000000 * np.einsum("ia,jkAC,laBD,CDmb->ijklmbAB",f["oo"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.250000000 * np.einsum("ia,jaAC,klbB,bCmc->ijklmcAB",f["oo"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.375000000 * np.einsum("ba,ijAC,klbB,aCmc->ijklmcAB",f["vv"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += 0.375000000 * np.einsum("Ca,ijAD,klBC,aDmb->ijklmbAB",f["Vv"],t2["ooVV"],t2["ooVV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.125000000 * np.einsum("aA,ijbB,klaC,bCmc->ijklmcAB",f["vV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += 0.125000000 * np.einsum("aA,ijBC,klaD,CDmb->ijklmbAB",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += 0.125000000 * np.einsum("CA,ijBD,klaC,aDmb->ijklmbAB",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += 0.125000000 * np.einsum("CA,ijBD,klCE,DEma->ijklmaAB",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.125000000 * np.einsum("CA,ijCD,klaB,aDmb->ijklmbAB",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.375000000 * np.einsum("aC,ijbA,klaB,bCmc->ijklmcAB",f["vV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.375000000 * np.einsum("aC,ijAD,klaB,CDmb->ijklmbAB",f["vV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooooVV += -0.375000000 * np.einsum("DC,ijAD,klaB,aCmb->ijklmbAB",f["VV"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooooVV += 0.375000000 * np.einsum("DC,ijAE,klBD,CEma->ijklmaAB",f["VV"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooovVV += 0.500000000 * np.einsum("ab,ijAC,klcB,cCma->ijklmbAB",f["ov"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooovVV += 0.250000000 * np.einsum("ab,ijAC,klBD,CDma->ijklmbAB",f["ov"],t2["ooVV"],t2["ooVV"],t2["VVoo"],optimize="optimal")
# fs2s2s2ooooovVV += 0.500000000 * np.einsum("ib,jaAB,klcC,bCma->ijklmcAB",f["ov"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooovVV += -1.000000000 * np.einsum("ib,jkAC,lacB,bCma->ijklmcAB",f["ov"],t2["ooVV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooovVV += -0.500000000 * np.einsum("aA,ijbC,klcB,cCma->ijklmbAB",f["oV"],t2["oovV"],t2["oovV"],t2["vVoo"],optimize="optimal")
# fs2s2s2ooooovVV += 0.500000000 * np.einsum("aA,ijBC,klbD,CDma->ijklmbAB",f["oV"],t2["ooVV"],t2["oovV"],t2["VVoo"],optimize="optimal")
# ...
# fs2s2s2ovvVoooV += -1.000000000 * np.einsum("CA,imCD,aDjk,bBlm->iabBjklA",f["VV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += 0.500000000 * np.einsum("aC,imcA,cBjk,bClm->iabBjklA",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += -0.500000000 * np.einsum("aC,imcA,cCjk,bBlm->iabBjklA",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += 0.500000000 * np.einsum("aC,imAD,BDjk,bClm->iabBjklA",f["vV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += -0.500000000 * np.einsum("aC,imAD,CDjk,bBlm->iabBjklA",f["vV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += -0.500000000 * np.einsum("aC,imAD,BCjm,bDkl->iabBjklA",f["vV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += 1.500000000 * np.einsum("cC,imcA,aCjk,bBlm->iabBjklA",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += -0.500000000 * np.einsum("AC,imBD,aDjk,bClm->iabAjklB",f["VV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooV += -1.500000000 * np.einsum("DC,imAD,aCjk,bBlm->iabBjklA",f["VV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += 0.500000000 * np.einsum("la,imAC,bCjk,cBlm->ibcBjkaA",f["ov"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += -1.000000000 * np.einsum("la,imAC,bBjm,cCkl->ibcBjkaA",f["ov"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += -0.500000000 * np.einsum("lA,imaC,bCjk,cBlm->ibcBjkaA",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += 1.000000000 * np.einsum("lA,imaC,bBjm,cCkl->ibcBjkaA",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += 1.000000000 * np.einsum("iC,lmaA,bBjm,cCkl->ibcBjkaA",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += 1.500000000 * np.einsum("lC,imaA,bCjk,cBlm->ibcBjkaA",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovV += 3.000000000 * np.einsum("lC,imaA,bCjm,cBkl->ibcBjkaA",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooo += 1.000000000 * np.einsum("ci,jacB,bBkl,dAma->jbdAiklm",f["vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooo += 1.000000000 * np.einsum("Bi,jaBC,bCkl,cAma->jbcAiklm",f["Vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooo += 0.500000000 * np.einsum("ab,ibcB,dBjk,cAlm->iadAjklm",f["vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooo += -0.500000000 * np.einsum("ab,ibBC,ABjk,cClm->iacAjklm",f["vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoooo += 0.250000000 * np.einsum("Aa,iaBC,bBjk,cClm->ibcAjklm",f["Vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += 0.500000000 * np.einsum("mi,jabB,cBkl,dAma->jcdAiklb",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -1.000000000 * np.einsum("mi,jabB,cAka,dBlm->jcdAiklb",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += 1.000000000 * np.einsum("im,mabB,cBjk,dAla->icdAjklb",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += 1.500000000 * np.einsum("am,imbB,cBjk,dAla->icdAjklb",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -1.000000000 * np.einsum("da,imdB,bBjk,cAlm->ibcAjkla",f["vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -1.000000000 * np.einsum("Ba,imBC,bCjk,cAlm->ibcAjkla",f["Vv"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += 0.500000000 * np.einsum("ad,imbB,cBjk,dAlm->iacAjklb",f["vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -0.500000000 * np.einsum("ad,imbB,dBjk,cAlm->iacAjklb",f["vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += 0.500000000 * np.einsum("aB,imbC,ACjk,cBlm->iacAjklb",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -0.500000000 * np.einsum("aB,imbC,BCjk,cAlm->iacAjklb",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -0.500000000 * np.einsum("aB,imbC,ABjm,cCkl->iacAjklb",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -0.500000000 * np.einsum("AB,imaC,bCjk,cBlm->ibcAjkla",f["VV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVooov += -1.500000000 * np.einsum("CB,imaC,bBjk,cAlm->ibcAjkla",f["VV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovv += 0.500000000 * np.einsum("la,imbB,cBjk,dAlm->icdAjkab",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvVoovv += -1.000000000 * np.einsum("la,imbB,cAjm,dBkl->icdAjkab",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvvoooV += -0.500000000 * np.einsum("aB,imAC,bCjk,cBlm->iabcjklA",f["vV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvvoooo += 0.250000000 * np.einsum("ab,ibAB,cAjk,dBlm->iacdjklm",f["vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2ovvvooov += -0.500000000 * np.einsum("aA,imbB,cBjk,dAlm->iacdjklb",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoVVV += 0.250000000 * np.einsum("jA,klBC,DEik,aGjl->aDEGiABC",f["oV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoVVV += -0.250000000 * np.einsum("jA,klBC,DEjk,aGil->aDEGiABC",f["oV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.250000000 * np.einsum("ki,lmAB,CDjl,aEkm->aCDEijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += 0.250000000 * np.einsum("ki,lmAB,CDkl,aEjm->aCDEijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += 0.750000000 * np.einsum("lk,kmAB,CDil,aEjm->aCDEijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.750000000 * np.einsum("lk,kmAB,CDim,aEjl->aCDEijAB",f["oo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.250000000 * np.einsum("ab,klAB,CDik,bEjl->aCDEijAB",f["vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.500000000 * np.einsum("Ab,klBC,aDil,bEjk->aADEijBC",f["Vv"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -1.000000000 * np.einsum("bA,klbB,CDik,aEjl->aCDEijAB",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += 1.000000000 * np.einsum("GA,klBG,CDik,aEjl->aCDEijAB",f["VV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.250000000 * np.einsum("aG,klAB,CDil,EGjk->aCDEijAB",f["vV"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += -0.250000000 * np.einsum("AG,klBC,DEik,aGjl->aADEijBC",f["VV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooVV += 0.500000000 * np.einsum("AG,klBC,DGik,aEjl->aADEijBC",f["VV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovVV += 0.250000000 * np.einsum("ja,klAB,CDik,bEjl->bCDEiaAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovVV += -0.250000000 * np.einsum("ja,klAB,CDjk,bEil->bCDEiaAB",f["ov"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovVV += -0.500000000 * np.einsum("jA,klaB,CDik,bEjl->bCDEiaAB",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovVV += 0.500000000 * np.einsum("jA,klaB,CDjk,bEil->bCDEiaAB",f["oV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += -1.000000000 * np.einsum("bi,lmbA,BCjl,aDkm->aBCDijkA",f["vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += 1.000000000 * np.einsum("Ei,lmAE,BCjl,aDkm->aBCDijkA",f["Vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += 0.500000000 * np.einsum("al,lmbA,BCim,bDjk->aBCDijkA",f["vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += 0.500000000 * np.einsum("al,lmAE,BEij,CDkm->aBCDijkA",f["vo"],t2["ooVV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += 1.000000000 * np.einsum("Al,lmbB,bCij,aDkm->aACDijkB",f["Vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += 1.000000000 * np.einsum("Al,lmBE,CEij,aDkm->aACDijkB",f["Vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoooV += -0.500000000 * np.einsum("Al,lmBE,CDim,aEjk->aACDijkB",f["Vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -0.500000000 * np.einsum("ki,lmaA,BCjl,bDkm->bBCDijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += 0.500000000 * np.einsum("ki,lmaA,BCkl,bDjm->bBCDijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += 1.500000000 * np.einsum("lk,kmaA,BCil,bDjm->bBCDijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -1.500000000 * np.einsum("lk,kmaA,BCim,bDjl->bBCDijaA",f["oo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -1.000000000 * np.einsum("ca,klcA,BCik,bDjl->bBCDijaA",f["vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += 1.000000000 * np.einsum("Ea,klAE,BCik,bDjl->bBCDijaA",f["Vv"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -0.500000000 * np.einsum("ac,klbA,BCik,cDjl->aBCDijbA",f["vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -1.000000000 * np.einsum("Ac,klaB,bCil,cDjk->bACDijaB",f["Vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -1.000000000 * np.einsum("EA,klaE,BCik,bDjl->bBCDijaA",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -0.500000000 * np.einsum("aE,klbA,BCil,DEjk->aBCDijbA",f["vV"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += -0.500000000 * np.einsum("AE,klaB,CDik,bEjl->bACDijaB",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovV += 1.000000000 * np.einsum("AE,klaB,CEik,bDjl->bACDijaB",f["VV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovvV += 0.500000000 * np.einsum("ja,klbA,BCik,cDjl->cBCDiabA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVovvV += -0.500000000 * np.einsum("ja,klbA,BCjk,cDil->cBCDiabA",f["ov"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooov += 1.000000000 * np.einsum("Di,lmaD,ABjl,bCkm->bABCijka",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooov += 0.500000000 * np.einsum("al,lmbD,ADij,BCkm->aABCijkb",f["vo"],t2["oovV"],t2["VVoo"],t2["VVoo"],optimize="optimal")
# fs2s2s2vVVVooov += 1.000000000 * np.einsum("Al,lmaD,BDij,bCkm->bABCijka",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVooov += -0.500000000 * np.einsum("Al,lmaD,BCim,bDjk->bABCijka",f["Vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vVVVoovv += 1.000000000 * np.einsum("Da,klbD,ABik,cCjl->cABCijab",f["Vv"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoVVV += 0.500000000 * np.einsum("jA,klBC,aDil,bEjk->abDEiABC",f["oV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += -0.500000000 * np.einsum("ki,lmAB,aCjm,bDkl->abCDijAB",f["oo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += 1.500000000 * np.einsum("lk,kmAB,aCim,bDjl->abCDijAB",f["oo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += 0.500000000 * np.einsum("ac,klAB,bCil,cDjk->abCDijAB",f["vv"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += 1.000000000 * np.einsum("cA,klcB,aCik,bDjl->abCDijAB",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += -1.000000000 * np.einsum("EA,klBE,aCik,bDjl->abCDijAB",f["VV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += 0.250000000 * np.einsum("aE,klAB,CDik,bEjl->abCDijAB",f["vV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += -0.500000000 * np.einsum("aE,klAB,CEik,bDjl->abCDijAB",f["vV"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooVV += 0.500000000 * np.einsum("AE,klBC,aDil,bEjk->abADijBC",f["VV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVovVV += 0.500000000 * np.einsum("ja,klAB,bCil,cDjk->bcCDiaAB",f["ov"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVovVV += -1.000000000 * np.einsum("jA,klaB,bCil,cDjk->bcCDiaAB",f["oV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += 1.000000000 * np.einsum("ci,lmcA,aBjl,bCkm->abBCijkA",f["vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += -1.000000000 * np.einsum("Di,lmAD,aBjl,bCkm->abBCijkA",f["Vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += -1.000000000 * np.einsum("al,lmcA,cBij,bCkm->abBCijkA",f["vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += -1.000000000 * np.einsum("al,lmAD,BDij,bCkm->abBCijkA",f["vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += 0.500000000 * np.einsum("al,lmAD,BCim,bDjk->abBCijkA",f["vo"],t2["ooVV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoooV += 1.000000000 * np.einsum("Al,lmBD,aDij,bCkm->abACijkB",f["Vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += -1.000000000 * np.einsum("ki,lmaA,bBjm,cCkl->bcBCijaA",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 3.000000000 * np.einsum("lk,kmaA,bBim,cCjl->bcBCijaA",f["oo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 1.000000000 * np.einsum("da,kldA,bBik,cCjl->bcBCijaA",f["vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += -1.000000000 * np.einsum("Da,klAD,bBik,cCjl->bcBCijaA",f["Vv"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 1.000000000 * np.einsum("ad,klbA,cBil,dCjk->acBCijbA",f["vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 1.000000000 * np.einsum("DA,klaD,bBik,cCjl->bcBCijaA",f["VV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 0.500000000 * np.einsum("aD,klbA,BCik,cDjl->acBCijbA",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += -1.000000000 * np.einsum("aD,klbA,BDik,cCjl->acBCijbA",f["vV"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovV += 1.000000000 * np.einsum("AD,klaB,bCil,cDjk->bcACijaB",f["VV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVovvV += 1.000000000 * np.einsum("ja,klbA,cBil,dCjk->cdBCiabA",f["ov"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooov += -1.000000000 * np.einsum("Ci,lmaC,bAjl,cBkm->bcABijka",f["Vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooov += -1.000000000 * np.einsum("al,lmbC,ACij,cBkm->acABijkb",f["vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooov += 0.500000000 * np.einsum("al,lmbC,ABim,cCjk->acABijkb",f["vo"],t2["oovV"],t2["VVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVooov += 1.000000000 * np.einsum("Al,lmaC,bCij,cBkm->bcABijka",f["Vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvVVoovv += -1.000000000 * np.einsum("Ca,klbC,cAik,dBjl->cdABijab",f["Vv"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvvVooVV += 0.500000000 * np.einsum("aD,klAB,bCil,cDjk->abcCijAB",f["vV"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvvVoooV += 1.000000000 * np.einsum("al,lmAC,bCij,cBkm->abcBijkA",f["vo"],t2["ooVV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvvVoovV += 1.000000000 * np.einsum("aC,klbA,cBil,dCjk->acdBijbA",f["vV"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
# fs2s2s2vvvVooov += 1.000000000 * np.einsum("al,lmbB,cBij,dAkm->acdAijkb",f["vo"],t2["oovV"],t2["vVoo"],t2["vVoo"],optimize="optimal")
